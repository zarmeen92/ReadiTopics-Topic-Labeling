# %%
import re
from ast import literal_eval
import numpy as np
import pandas as pd
from pprint import pprint
import collections
import math
# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
#scipy
import scipy 
from sklearn.cluster import KMeans
# spacy for lemmatization
import spacy
from urduhack import stop_words
from urduhack import tokenization as tok
from urduhack import preprocess
from urduhack import utils
from urduhack import normalization as norm
from utilities import words as urduwords
from urduhack import stop_words
from sklearn import metrics
import os
from kneed import KneeLocator
from sklearn.datasets import fetch_20newsgroups
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
import CRFTagger
# NLTK Stop words
# Extract noun chunks from corpus
import spacy
nlp = spacy.load('en_core_web_sm')
stopwords = list(stop_words.STOP_WORDS)

# %%
dataset = pd.read_csv('urduNewsHeadlines-clusteringDS.csv',encoding='utf-8',sep='\t')

# %%
dataset.shape
# Out:
# (260, 6)

# %%
def purity_score(y_true, y_pred):
    # compute contingency matrix (also called confusion matrix)
    contingency_matrix = metrics.cluster.contingency_matrix(y_true, y_pred)
    # return purity
    return np.sum(np.amax(contingency_matrix, axis=0)) / np.sum(contingency_matrix) 

# Tokenize and lemmatize
def preprocess_func(text):
    text = text.replace('\n'," ")
    text = text.replace('\r'," ")
    text = preprocess.normalize_whitespace(text)
    text = preprocess.remove_punctuation(text)
    text = norm.remove_diacritics(text)
    text = urduwords.fix_join_words(text)
    text = re.sub(r"http\S+", "", text)
    text = re.sub('@[^\s]+','',text)
    nonalpha = re.compile(r"[a-zA-Z0-9.@#_:)(-]")
    text = re.sub(nonalpha,'',text).strip()#remove english alphabets
    wordsC = text.split()
    non_stops = [w for w in wordsC if w not in stopwords]
    cleanText = " ".join(non_stops)
    return cleanText 

    return cleanText
            
def candidate_label_lemmatized(label):
    w_labels = label.split()
    lemmatized = lemmatization(w_labels)
    return " ".join(lemmatized)

def news_group_target_names(k):
    return newsgroups_train.target_names[k]
def return_preprocessed_text(words):
    x = literal_eval(words)
    return " ".join(x)
def get_pd_of_cluster(dataset,cluster_idx):
    dataset_sub = dataset[dataset['km_label'] == cluster_idx]
    cnt = CountVectorizer()
    voc = cnt.fit_transform(dataset_sub.preprocessed_text)
    vocab = list(cnt.get_feature_names())
    counts = voc.sum(axis=0).A1
    freq_distribution = Counter(dict(zip(vocab, counts)))
    prob = {}
    for w in vocab:
        prob[w] = freq_distribution[w]/np.sum(counts)
    return prob
def get_words_from_tags(postags):
    words = []
    tags = []
    for u,v in postags:
        words.append(u)
        tags.append(v)
    return words,tags
def pos_regex_matches(doc, pattern,tgs):
    """
    Extract sequences of consecutive tokens from a spacy-parsed doc whose
    part-of-speech tags match the specified regex pattern.

    Args:
        doc (``textacy.Doc`` or ``spacy.Doc`` or ``spacy.Span``)
        pattern (str): Pattern of consecutive POS tags whose corresponding words
            are to be extracted, inspired by the regex patterns used in NLTK's
            `nltk.chunk.regexp`. Tags are uppercase, from the universal tag set;
            delimited by < and >, which are basically converted to parentheses
            with spaces as needed to correctly extract matching word sequences;
            white space in the input doesn't matter.

            Examples (see ``constants.POS_REGEX_PATTERNS``):

            * noun phrase: r'<DET>? (<NOUN>+ <ADP|CONJ>)* <NOUN>+'
            * compound nouns: r'<NOUN>+'
            * verb phrase: r'<VERB>?<ADV>*<VERB>+'
            * prepositional phrase: r'<PREP> <DET>? (<NOUN>+<ADP>)* <NOUN>+'

    Yields:
        ``spacy.Span``: the next span of consecutive tokens from ``doc`` whose
        parts-of-speech match ``pattern``, in order of apperance
    """
    # standardize and transform the regular expression pattern...
    pattern = re.sub(r'\s', '', pattern)
    pattern = re.sub(r'<([A-Z]+)\|([A-Z]+)>', r'( (\1|\2))', pattern)
    pattern = re.sub(r'<([A-Z]+)>', r'( \1)', pattern)

    tags = ' ' + ' '.join(tgs)

    for m in re.finditer(pattern, tags):
        yield doc[tags[0:m.start()].count(' '):tags[0:m.end()].count(' ')]

def filter_noun_adj_from_phrase(sent):
    noun_phrases = []
    tags = CRFTagger.pos_tag(sent)
    words,tgs = get_words_from_tags(tags)
    print(words)
    print(tgs)
    patern = r'<ADJ|A>*<NN|PN>+'
    lists = pos_regex_matches(words, patern,tgs)
    for j in lists:
        noun_phrases.append(" ".join(j))
  
    return noun_phrases

# %%
document_num = 50
doc_sample = dataset.iloc[document_num].Title

print("Original document: ")
words = []
for word in doc_sample.split(' '):
    words.append(word)
print(words)
print("\n\nTokenized and lemmatized document: ")
print(preprocess_func(doc_sample))
# Out:
# Original document:
# ['مظفرگڑھ,کشمیری', 'عوام', 'سے', 'اظہار', 'یکجہتی', 'کیلئی', 'ریلیاں', 'نکالی', 'گئیں']
#
#
# Tokenized and lemmatized document:
# مظفرگڑھ کشمیری عوام اظہار یکجہتی کیلئی ریلیاں نکالی گئیں

# %%
dataset['preprocessed_text'] = dataset['Title'].apply(preprocess_func)

# %%
dataset['NounChunks'] = dataset['Title'].apply(filter_noun_adj_from_phrase)
# Out:
# ['سی', 'پیک', 'منصوبہ', 'ختم،آئی', 'ایم', 'ایف', 'کی', 'شرائط', 'پرعملدرآمد', 'شروع', 'امریکہ', 'کی', 'خوشنودی', 'کے', 'لیے', 'پاکستانی', 'مفاد', 'پسِ', 'پشت', 'ڈال', 'دیا', 'گیا']
# ['A', 'NN', 'NN', 'PN', 'PN', 'PN', 'P', 'NN', 'NN', 'NN', 'PN', 'P', 'NN', 'P', 'ADV', 'ADJ', 'NN', 'NN', 'NN', 'VB', 'AA', 'AA']
# ['حکومت', 'نے', 'سی', 'پیک', 'کے', 'تحت', 'اکانامک', 'زونز', 'پر', 'توجہ', 'مرکوز', 'رکھی', 'ہے‘', 'رشکئی', 'اکنامک', 'زون', 'گراونڈ', 'بریکینگ', 'کے', 'لیے', 'مکمل', 'ہے‘', 'آئندہ', 'ماہ', 'افتتاح', 'کردیا', 'جائے', 'گا،', 'وفاقی', 'وزیر', 'برائے', 'منصوبہ', 'بندی', '...', 'مزید']
# ['NN', 'P', 'A', 'NN', 'P', 'NN', 'PN', 'PN', 'P', 'NN', 'ADJ', 'VB', 'PN', 'PN', 'PN', 'PN', 'PN', 'PN', 'P', 'ADV', 'ADJ', 'NN', 'ADJ', 'NN', 'NN', 'VB', 'AA', 'NN', 'ADJ', 'NN', 'ADV', 'NN', 'NN', 'NN', 'ADJ']
# ['NN', 'A', 'PN', 'PN', 'NN', 'P', 'NN', 'CC', 'NN', 'CA', 'P', 'NN', 'VB', 'AA', 'PN', 'A', 'NN', 'CC', 'PN', 'PN', 'PN', 'NN', 'NN', 'P', 'NN']
# ['احتیاط', 'سے', 'ڈینگی', 'سے', 'بچا', 'جا', 'سکتا', 'ہے']
# ['NN', 'SE', 'NN', 'SE', 'VB', 'AA', 'AA', 'TA']
# ['سرویلنس', 'ٹیمیں', 'ڈینگی', 'مچھر', 'کی', 'افزائش', 'کے', 'مقامات', 'کا', 'بھرپور', 'طریقے', 'سے', 'تدارک', 'کریں،ڈی', 'سی', 'خانیوال']
# ['PN', 'NN', 'NN', 'NN', 'P', 'NN', 'P', 'NN', 'P', 'ADJ', 'NN', 'SE', 'ADJ', 'NN', 'A', 'NN']
# ['انسداد', 'ڈینگی', 'مہم،', 'کمرشل', 'اداروں', '‘دکانوں', 'کی', 'باقاعدگی', 'سے', 'چیکنگ', 'کی', 'جائے۔سیکرٹری', 'سپیشل', 'ایجوکیشن', 'ڈاکٹر', 'راشد', 'منصور']
# ['NN', 'NN', 'NN', 'ADJ', 'NN', 'NN', 'P', 'NN', 'SE', 'NN', 'P', 'PN', 'PN', 'PN', 'PN', 'PN', 'PN']
# ['سوات:ضلعی', 'انتظامیہ', 'اور', 'محکمہ', 'صحت', 'کی', 'ناقص', 'منصوبہ', 'بندی', 'سوات', 'میں', 'ڈینگی', 'کے', 'وارجاری', '،مزید13افراد', 'ڈینگی', 'سے', 'متاثر،ہسپتال', 'داخل،سرکاری', 'تعدا426تک', 'جبکہ', 'غیر', 'سرکاری', 'اعداد', 'وشمارہزاروں', '...', 'مزید']
# ['ADJ', 'NN', 'CC', 'NN', 'NN', 'P', 'ADJ', 'NN', 'NN', 'NN', 'P', 'NN', 'P', 'ADJ', 'NN', 'NN', 'SE', 'PN', 'PN', 'PN', 'SC', 'ADJ', 'ADJ', 'NN', 'NN', 'NN', 'ADJ']
# ['اوکاڑہ،ڈسٹرکٹ', 'انٹا', 'مالوجسٹکا', 'مارکیٹوں،', 'مختلف', 'جگہوں', 'پر', 'ڈینگی', 'سرویلینس', 'معائنہ']
# ['PN', 'PN', 'PN', 'PN', 'ADJ', 'NN', 'P', 'NN', 'PN', 'NN']
# ['انسداد', 'ڈینگی', 'کی', 'کارکردگی', 'کا', 'جائزہ', 'لینے', 'کے', 'حوالہ', 'سے', 'اجلاس', 'کا', 'انعقاد']
# ['NN', 'NN', 'P', 'NN', 'P', 'NN', 'VB', 'P', 'NN', 'SE', 'NN', 'P', 'NN']

# %%
dataset
# Out:
#                 DateTime       Source  \
# 0    2019-09-20 00:54:51    UrduPoint
# 1    2019-09-20 05:45:20    UrduPoint
# 2    2019-09-20 18:53:21    UrduPoint
# 3    2019-09-21 09:28:12    UrduPoint
# 4    2019-09-23 06:40:21    UrduPoint
# 5    2019-09-23 06:40:21    UrduPoint
# 6    2019-09-24 06:20:17    UrduPoint
# 239  رواں سال بلوچستان کے تین اضلاع میں اب تک 1950 ...   ur                1
# 240  خیبر پختونخوا میں ڈینگی کے 55 نئے کیسز رپورٹ‘ ...   ur                1
# 241  انسداد ڈینگی مہم میں ڈپٹی کمشنر سرگودھا کا محک...   ur                1
# 242  ملک بھر میں ڈینگی سے متاثر افراد کی تعداد چوبی...   ur                1
# 243  سیکرٹری صحت کی زیر صدارت ، ڈینگی کی تازہ ترین ...   ur                1
# 244  فوزیہ نامی خاتون بے نظیر بھٹو اسپتال میں ڈینگی...   ur                1
# 245  پاکستان وآزادکشمیر کو ڈینگی وائر سے پاک بنائی...   ur                1
# 246  ڈینگی کا خاتمے کے لیے عملی اقداما ت نہیں اُٹھا...   ur                1
# 247  پمز میں ڈینگی کے 2000 مشتبہ مریضوں میں سے 200 ...   ur                1
# 248      صوبائی وزیر ملک اسد کھوکھر ڈینگی کا شکارہوگئے   ur                1
# 249  آر ڈبلیو ایم سی  کی جانب سے ڈینگی کیخلاف حفاظ...   ur                1
# 250  انسداد ڈینگی سرویلنس میں کوئی کوتاہی برداشت نہ...   ur                1
# 251  ڈی سی لاہور اصغر جوئیہ کی این ڈی بوائز ہائی سک...   ur                1
# 252  افسران ڈینگی سروئلنس، صفائی ستھرائی اور پرائس ...   ur                1
# 253  اے سی رائیونڈ عدنان بدر کا ڈینگی اور صفائی ستھ...   ur                1
# 254                  احتیاط سے ڈینگی سے بچا جا سکتا ہے   ur                1
# 255  سرویلنس ٹیمیں ڈینگی مچھر کی افزائش کے مقامات ک...   ur                1
# 256  انسداد ڈینگی مہم، کمرشل اداروں ‘دکانوں کی باقا...   ur                1
# 257  سوات:ضلعی انتظامیہ اور محکمہ صحت کی ناقص منصوب...   ur                1
# 258  اوکاڑہ،ڈسٹرکٹ انٹا مالوجسٹکا مارکیٹوں، مختلف ج...   ur                1
# 259  انسداد ڈینگی کی کارکردگی کا جائزہ لینے کے حوال...   ur                1
#
#            Label                                  preprocessed_text  km_label  \
# 0           CPEC  پیک منصوبہ ایم ایف شرائط عمل درآمد شروع امریکہ...         3
# 1           CPEC  حکومت پیک اکانامک زونز توجہ مرکوز رشکئی اکنامک...         4
# 2           CPEC  پیک کاموجودہ مرحلہ پاکستانی عوام کیلئے معاشی ف...         3
# 3           CPEC  وزیر اعلی خیبر پختونخوا محمود خان جمعہ روز چتر...         4
# 4           CPEC            غربت شرح کمی پیک مرحلے اہم ترجیحات شامل         3
# 5           CPEC            حکومت عوام ریلیف فراہمی عزم پیک اتھارٹی         3
# 6           CPEC  چین پاکستان اقتصادی راہداری منصوبہ مرحلہ غربت ...         3
# 7           CPEC  وزیر اعظم عمران خان دورہ چین ممالک مابین تعلقا...         4
# 8           CPEC              صدارتی آرڈیننس پیک اتھارٹی قائم فیصلہ         3
# 9           CPEC  خیبر پختونخوا حکومت متعلقہ محکموں ترقیاتی منصو...         4
# 10          CPEC  وزیراعظم عمران خان دورہ چین پیک منصوبوں اہم حس...         4
# 11          CPEC  چین پاکستان اقتصادی راہداری ملک انائی شدید بحر...         3
# 12          CPEC  وزیراعظم عمران خان دورہ چین چینی صدر بھارت شاہ...         4
# 13          CPEC  ض آر وفاقی حکومت سردمہری رویہ قابل افسوس سعید...         4
# 14          CPEC  خطے تنازع کوشش سعودیہ ایران غلط فہماں دور وزیر...         4
# 15          CPEC  پیک مرحلے تکمیل پاکستان بنیادی ڈھانچے بہتری آ...         4
# 16          CPEC  پیک بلوچستان اقتصادی زونز قیام مقامی صنعت ترقی...         3
# 17          CPEC  پیک بلوچستان تحصیل بوستان انڈسٹریل زون کام تیز...         5
# 18          CPEC  پیک متعلقہ منصوبوں ہزار پاکستانیوں روزگار ملا ...         3
# 19          CPEC    وزیراعظم پیک اتھارٹی چیئرپرسن مقرر آرڈیننس جاری         3
# 20          CPEC  احسن اقبال پیک اتھارٹی آرڈیننس قانون قرار دید...         3
# 21          CPEC  صدر مملکت عارف علوی پیک اتھارٹی آرڈیننس دستخط...         3
# 22          CPEC  پاکستان چین پیک معاشی و معاشی ترقی صنعتی انقلا...         4
# 23          CPEC  چین پاکستان قومی مفاد ایشو بھرپور تعاون یقین د...         4
# 24          CPEC  وفاقی حکومت سردمہری رویہ قابل افسوس سعید غنی پ...         4
# 25          CPEC  کراچی سرکولر ریلوے وفاقی حکومت سردمہری قابل اف...         4
# 26          CPEC  وفاقی حکومت پیک اتھارٹی صدارتی آرڈیننس جاری ش...         3
# 27          CPEC  پاکستان چین پیک اربوں ڈالر مالیت ایم ایل ون من...         4
# 28          CPEC  پاکستان چین قریبی دوست شراکت دار آہنی برادرز ...         4
# 29          CPEC  پیک مرحلے تکمیل روزگار مواقع پیدا مدد ملے حکام...         3
# ..           ...                                                ...       ...
# 230  DengueFever  سری لنکن آل راﺅنڈ ر تھیسارا پریرا دورہ پاکستان...         8
# 231  DengueFever  یو ای ٹی لاہورکے زیر اہتمام ڈینگی متعلق آگاہی ...         2
# 232  DengueFever  ٹی ایم لاچی بڑے پیمانے صفائی مہم آغاز علاقے ش...         5
# 233  DengueFever  مظفرآباد لچھراٹ ویلفئیر آرگنائزیشن آزادجموں...         6
# 234  DengueFever  ڈینگی خاتمہ بلدیات چیف افسران نکاسی آب صفائی ...         1
# 235  DengueFever  حکومت ڈینگی خاتمہ کیلئے ٹھوس عملی اقدامات کررہ...         2
# 236  DengueFever  ٹی ایم لاچی بڑے پیمانے صفائی مہم آغاز علاقے ش...         5
# 237  DengueFever            ڈینگی خدشہ پیش نظر دکانداروں مقدمات درج         2
# 238  DengueFever  افسران شہر صفائی ستھرائی ڈینگی سیمینار ڈینگی ا...         2
# 239  DengueFever  رواں سال بلوچستان تین اضلاع اب ڈینگی وائرس کیس...         9
# 240  DengueFever           خیبر پختونخوا ڈینگی نئے کیسز رپورٹ تعداد        10
# 241  DengueFever  انسداد ڈینگی مہم ڈپٹی کمشنر سرگودھا محکموں پاپ...        11
# 242  DengueFever       ملک ڈینگی متاثر افراد تعداد چوبیس ہزار تجاوز        10
# 243  DengueFever  سیکرٹری صحت زیر صدارت ڈینگی تازہ ترین حال بریف...        12
# 244  DengueFever  فوزیہ نامی خاتون نظیر بھٹو اسپتال ڈینگی وائرس ...         9
# 245  DengueFever  پاکستان وآزادکشمیر ڈینگی وائر پاک بنائیں ڈینگ...         2
# 246  DengueFever  ڈینگی خاتمے عملی اقداما ت اٹھائے شیخ عقیل الرح...         2
# 247  DengueFever    پمز ڈینگی مشتبہ مریضوں مریضوں ڈینگی وائرس تصدیق        10
# 248  DengueFever         صوبائی وزیر ملک اسد کھوکھر ڈینگی شکارہوگئے         2
# 249  DengueFever  آر ڈبلیو ایم جانب ڈینگی کیخلاف حفاظتی اقدامات...         2
# 250  DengueFever   انسداد ڈینگی سرویلنس کوتاہی برداشت سیکرٹری آرٹی        12
# 251  DengueFever  ڈی لاہور اصغر جوئیہ این ڈی بوائز ہائی سکول اچھ...         1
# 252  DengueFever  افسران ڈینگی سروئلنس صفائی ستھرائی پرائس چیکنگ...         1
# 253  DengueFever  رائیونڈ عدنان بدر ڈینگی صفائی ستھرائی چیک کیلئ...         2
# 254  DengueFever                                   احتیاط ڈینگی بچا         2
# 255  DengueFever  سرویلنس ٹیمیں ڈینگی مچھر افزائش مقامات بھرپور ...         1
# 256  DengueFever  انسداد ڈینگی مہم کمرشل اداروں دکانوں باقاعدگی ...        12
# 257  DengueFever  سوات ضلعی انتظامیہ محکمہ صحت ناقص منصوبہ بندی ...         9
# 258  DengueFever  اوکاڑہ ڈسٹرکٹ انٹا مالوجسٹکا مارکیٹوں مختلف جگ...         2
# 259  DengueFever  انسداد ڈینگی کار کردگی جائزہ لینے حوالہ اجلاس ...        12
#
#                                             NounChunks
# 0    [سی پیک منصوبہ ختم،آئی ایم ایف, شرائط پرعملدرآ...
# 1    [حکومت, سی پیک, تحت اکانامک زونز, توجہ, ہے‘ رش...
# 2    [سی پیک, کاموجودہ مرحلہ, پاکستانی عوام, معاشی ...
# 3    [وزیر, اعلیٰ خیبر پختونخوا محمود خان, جمعہ, رو...
# 4    [غربت, شرح, کمی, سی پیک, دوسرے مرحلے, اہم ترجی...
# 5    [حکومت عوام, ریلیف, فراہمی, لئے, عزم ہے،, سی پ...
# 6    [چین پاکستان, اقتصادی راہداری منصوبہ, دوسرے مر...
# 7    [وزیر اعظم عمران خان, دورہ چین, ممالک, مابین ت...
# 8       [صدارتی آرڈیننس, ذریعے, سی پیک اتھارٹی, فیصلہ]
# 9    [خیبرپختونخوا حکومت, متعلقہ محکموں, ترقیاتی من...
# 10   [وزیراعظم عمران خان, دورہ چین, سی پیک منصوبوں,...
# 11   [چین پاکستان, اقتصادی راہداری, ملک, توانائی, ش...
# 12   [وزیراعظم عمران خان, دورہ چین, بعد چینی صدر بھ...
# 13   [ض*کے, سی آر, وفاقی حکومت, سردمہری, رویہ, قاب...
# 14   [خطے, مزید تنازع, چاہتے، کوشش, سعودیہ, ایران, ...
# 15   [سی پیک, پہلے مرحلے, تکمیل, پاکستان, بنیادی ڈھ...
# 16   [سی پیک, تحت بلوچستان, اقتصادی زونز, قیام, مقا...
# 17   [سی پیک, تحت بلوچستان, تحصیل بوستان, انڈسٹریل ...
# 18   [سی پیک, متعلقہ منصوبوں میں70, پاکستانیوں, روز...
# 19   [وزیراعظم, سی پیک اتھارٹی, چیئرپرسن مقرر، آرڈی...
# 20   [احسن اقبال, سی پیک اتھارٹی, آرڈیننس, خلاف قا...
# 21   [صدر مملکت عارف علوی, سی پیک اتھارٹی آرڈیننس,...
# 22   [پاکستان, چین, سی پیک, معاشی ترقی،, صنعتی انقل...
# 23   [چین, پاکستان, قومی مفاد, ایشو, بھرپور تعاون, ...
# 24   [وفاقی حکومت, سردمہری, رویہ, قابل افسوس ہے،, س...
# 25   [کراچی سرکولر ریلوے, وفاقی حکومت, سردمہری قابل...
# 26   [وفاقی حکومت, سی پیک اتھارٹی بارے, صدارتی آرڈ...
# 27   [پاکستان, چین, سی پیک, تحت اربوں ڈالر مالیت, ا...
# 28   [پاکستان, چین, قریبی دوست، شراکت دار, آہنی بر...
# 29   [سی پیک, دوسرے مرحلے, تکمیل, روزگار, مواقع پید...
# ..                                                 ...
# 230  [سری لنکن آل راﺅنڈ ر تھیسارا پریرا, دورہ پاکست...
# 231  [یو ای ٹی لاہورکے زیر اہتمام ڈینگی, متعلق آگاہ...
# 232  [ٹی ایم اے لاچی, بڑے پیمانے, صفائی مہم, آغاز،...
# 233  [مظفرآباد،لچھراٹ ویلفئیر آرگنائزیشن آزادجمو...
# 234  [ڈینگی, خاتمہ, لئے بلدیات, چیف افسران نکاسی, ص...
# 235  [حکومت ڈینگی, مکمل خاتمہ, ٹھوس عملی اقدامات, خ...
# 236  [ٹی ایم اے لاچی, بڑے پیمانے, صفائی مہم, آغاز ...
# 237     [ڈینگی, خدشہ, پیش نظر 3دکانداروں, خلاف مقدمات]
# 238  [افسران, شہر, صفائی, ڈینگی سیمینار, ڈینگی انتظ...
# 239  [رواں سال بلوچستان, اضلاع, ڈینگی وائرس, کیسز ر...
# 240     [خیبر پختونخوا, ڈینگی, نئے کیسز, رپورٹ‘ تعداد]
# 241  [انسداد ڈینگی مہم, ڈپٹی کمشنر سرگودھا, محکموں ...
# 242            [ملک, ڈینگی, متاثر افراد, تعداد, تجاوز]
# 243  [سیکرٹری صحت, زیر صدارت, ڈینگی, تازہ ترین صورت...
# 244  [فوزیہ نامی خاتون بے, نظیر بھٹو اسپتال, ڈینگی ...
# 245  [پاکستان وآزادکشمیر, ڈینگی وائر, ،ڈینگی وائر,...
# 246  [ڈینگی, خاتمے, عملی اقداما ت, ہیں‘شیخ عقیل الر...
# 247  [پمز, ڈینگی, مشتبہ مریضوں, مریضوں, ڈینگی وائرس...
# 248      [صوبائی وزیر ملک اسد کھوکھر ڈینگی, شکارہوگئے]
# 249  [آر ڈبلیو ایم, جانب, ڈینگی کیخلاف, حفاظتی اقد...
# 250  [انسداد ڈینگی سرویلنس, کوتاہی برداشت, گی، سیکر...
# 251  [ڈی, سی لاہور اصغر جوئیہ, این ڈی بوائز ہائی سک...
# 252  [افسران ڈینگی, سروئلنس، صفائی, پرائس چیکنگ, عم...
# 253  [اے, سی رائیونڈ عدنان بدر, ڈینگی, صفائی, چیک, ...
# 254                                    [احتیاط, ڈینگی]
# 255  [سرویلنس ٹیمیں ڈینگی مچھر, افزائش, مقامات, بھر...
# 256  [انسداد ڈینگی مہم،, کمرشل اداروں ‘دکانوں, باقا...
# 257  [سوات:ضلعی انتظامیہ, محکمہ صحت, ناقص منصوبہ بن...
# 258  [اوکاڑہ،ڈسٹرکٹ انٹا مالوجسٹکا مارکیٹوں،, مختلف...
# 259  [انسداد ڈینگی, کارکردگی, جائزہ, حوالہ, اجلاس, ...
#
# [260 rows x 9 columns]

# %%
cnt_vectorizer = TfidfVectorizer(min_df=0.02)
vec = cnt_vectorizer.fit_transform(dataset['preprocessed_text'])

# %%
#elbow curve for optimal clusters
#Elbow curve method
X = vec.todense()
Sum_of_squared_distances = []
K = range(1,30)
for k in K:
    print('K is %s'%k)
    km = KMeans(n_clusters=k,random_state=3)
    km = km.fit(X)
    Sum_of_squared_distances.append(km.inertia_)


# In[25]:


kn = KneeLocator(K, Sum_of_squared_distances, curve='convex', direction='decreasing')
print(kn.knee)
# Out:
# K is 1
# K is 2
# K is 3
# K is 4
# K is 5
# K is 6
# K is 7
# K is 8
# K is 9
# K is 10
# K is 11
# K is 12
# K is 13
# K is 14
# K is 15
# K is 16
# K is 17
# K is 18
# K is 19
# K is 20
# K is 21
# K is 22
# K is 23
# K is 24
# K is 25
# K is 26
# K is 27
# K is 28
# K is 29
# 13

# %%
km = KMeans(kn.knee,random_state=3)
km.fit(X)
labels = km.labels_
dataset['km_label'] = labels

# %%
print(purity_score(dataset.Label,dataset['km_label']))
# Out:
# 0.9807692307692307

# %%
order_centroids = km.cluster_centers_.argsort()[:, ::-1]
terms = cnt_vectorizer.get_feature_names()

# %%
for i in range(kn.knee):
    print("Cluster %d:" % i),
    for ind in order_centroids[i, :10]:
        print(' %s' % terms[ind])
# Out:
# Cluster 0:
#  کارروائی
#  فوجی
#  شام
#  ترکی
#  غاز
#  لاروا
#  عمل
#  اجلاس
#  افراد
#  شہریوں
# Cluster 1:
#  ڈی
#  ڈینگی
#  ہسپتال
#  لاہور
#  مریضوں
#  دورہ
#  خانیوال
#  بھرپور
#  کار
#  جائزہ
# Cluster 2:
#  ڈینگی
#  حکومت
#  اقدامات
#  بچاؤ
#  کیلئے
#  سیمینار
#  ملک
#  مہم
#  پنجاب
#  لاروا
# Cluster 3:
#  پیک
#  اتھارٹی
#  حکام
#  تعاون
#  چین
#  جاری
#  عوام
#  حکومت
#  وزیراعظم
#  پاکستان
# Cluster 4:
#  پیک
#  چین
#  وزیر
#  پاکستان
#  وفاقی
#  حکومت
#  منصوبوں
#  وزیراعظم
#  دورہ
#  خان
# Cluster 5:
#  جاری
#  ضلعی
#  انتظامیہ
#  ڈینگی
#  صفائی
#  مہم
#  رپورٹ
#  انسداد
#  غاز
#  ایم
# Cluster 6:
#  باد
#  اسلام
#  ڈاکٹر
#  ڈینگی
#  عمران
#  افراد
#  کشمیر
#  انتظامیہ
#  حوالے
#  خان
# Cluster 7:
#  یکجہتی
#  اظہار
#  کشمیریوں
#  ریلی
#  کیلئے
#  کشمیری
#  کشمیر
#  انعقاد
#  عوام
#  اہتمام
# Cluster 8:
#  سری
#  لنکن
#  ٹیم
#  سیریز
#  ٹی
#  کرکٹ
#  پاکستان
#  میچ
#  ٹونٹی
#  پاک
# Cluster 9:
#  صحت
#  ڈینگی
#  وائرس
#  محکمہ
#  عوام
#  وزیر
#  ڈاکٹر
#  ہسپتال
#  سرکاری
#  کیلئے
# Cluster 10:
#  تعداد
#  مریضوں
#  ڈینگی
#  ہزار
#  خیبر
#  پنجاب
#  راولپنڈی
#  پختونخوا
#  قابو
#  مریض
# Cluster 11:
#  ڈپٹی
#  کمشنر
#  ڈینگی
#  راولپنڈی
#  انسداد
#  ممکن
#  کردار
#  ضلع
#  خاتمہ
#  سیف
# Cluster 12:
#  سیکرٹری
#  حال
#  انسداد
#  ڈینگی
#  صدارت
#  اقدامات
#  اجلاس
#  زیر
#  حوالے
#  کیلئے

# %%
vocab = list(terms)

# %%
len(vocab)
# Out:
# 112

# %%
n_clust = kn.knee

# %%
prob_clusters = []
for i in range(0,n_clust):
    prob_clusters.append(get_pd_of_cluster(dataset,i))

# %%
theta=[]
for i in range(0,n_clust):
    p_w = []
    for w in vocab:
        if w in prob_clusters[i].keys():
            p_w.append(prob_clusters[i][w])
        else:
            p_w.append(0)
    theta.append(p_w)

# %%
x = pd.DataFrame(theta)
x.columns = vocab

# %%
x.shape
# Out:
# (13, 112)

# %%
theta=x.values

# %%
theta.shape
# Out:
# (13, 112)

# %%
freq = vec.sum(axis=0)

# %%
freq = (freq/np.sum(freq))

# %%
freq.shape
# Out:
# (1, 112)

# %%
all_noun_chunks =[]

# %%
for x in dataset.NounChunks:
    for j in x:
        all_noun_chunks.append(j)

# %%
all_noun_chunks
# Out:
# ['سی پیک منصوبہ ختم،آئی ایم ایف',
#  'شرائط پرعملدرآمد شروع امریکہ',
#  'خوشنودی',
#  'پاکستانی مفاد پسِ پشت',
#  'حکومت',
#  'سی پیک',
#  'تحت اکانامک زونز',
#  'توجہ',
#  'ہے‘ رشکئی اکنامک زون گراونڈ بریکینگ',
#  'مکمل ہے‘',
#  'آئندہ ماہ افتتاح',
#  'گا،',
#  'وفاقی وزیر',
#  'منصوبہ بندی ...',
#  'سی پیک',
#  'کاموجودہ مرحلہ',
#  'پاکستانی عوام',
#  'معاشی فوائد',
#  'آئے گا،',
#  'سی پیک',
#  'دوسرے مرحلہ',
#  'داخل',
#  'غربت',
#  'خاتمہ، زراعت',
#  'صنعتی تعاون',
#  'توجہ',
#  '...',
#  'وزیر',
#  'اعلیٰ خیبر پختونخوا محمود خان',
#  'جمعہ',
#  'روز چترال',
#  'سرکاری دورہ وزیر اعلیٰ',
#  'سی پیک',
#  'متبادل روٹ چترل',
#  'گا،',
#  'متاثرہ ریشن بجلی گھر ...',
#  'غربت',
#  'شرح',
#  'کمی',
#  'سی پیک',
#  'دوسرے مرحلے',
#  'اہم ترجیحات',
#  'حکومت عوام',
#  'ریلیف',
#  'فراہمی',
#  'لئے',
#  'عزم ہے،',
#  'سی پیک اتھارٹی',
#  'چین پاکستان',
#  'اقتصادی راہداری منصوبہ',
#  'دوسرے مرحلہ',
#  'غربت',
#  'خاتمے، زراعت',
#  'صنعتی تعاون',
#  'خصوصی توجہ',
#  'گی، حکام',
#  'سی پیک اتھارٹی',
#  'وزیر اعظم عمران خان',
#  'دورہ چین',
#  'ممالک',
#  'مابین تعلقات',
#  'نئے دور',
#  'آغاز',
#  'سی پیک',
#  'کام',
#  'رفتار',
#  'گی، شاہد رشید',
#  'صدارتی آرڈیننس',
#  'ذریعے',
#  'سی پیک اتھارٹی',
#  'فیصلہ',
#  'خیبرپختونخوا حکومت',
#  'متعلقہ محکموں',
#  'ترقیاتی منصوبوںکی',
#  'حتمی منصوبہ بندی',
#  'ہدایت صوبے',
#  'ترقیاتی منصوبوں',
#  'پچھلی وفاقی دور حکومت',
#  'سی پیک',
#  '...',
#  'وزیراعظم عمران خان',
#  'دورہ چین',
#  'سی پیک منصوبوں',
#  'لئے',
#  'اہم ہے، حسن داد',
#  'چینی سرمایہ کاروں',
#  'وفد',
#  'خیبر پختونخوا',
#  'انڈسٹریل زونز',
#  'دورہ',
#  '...',
#  'چین پاکستان',
#  'اقتصادی راہداری',
#  'ملک',
#  'توانائی',
#  'شدید بحران پرقابو',
#  'مدد',
#  'ہے، حکام',
#  'سی پیک اتھارٹی',
#  'وزیراعظم عمران خان',
#  'دورہ چین',
#  'بعد چینی صدر بھارت',
#  'گے: شاہ محمود قریشی چین',
#  'اپوزیشن بلاوجہ',
#  'سی پیک',
#  'ایشو',
#  'ہے، پاکستان',
#  'ایف اے ٹی ایف',
#  'مطمئن ...',
#  'ض*کے',
#  'سی آر',
#  'وفاقی حکومت',
#  'سردمہری',
#  'رویہ',
#  'قابل افسوس',
#  'ہے،سعید غنی',
#  'Gوزیر اعظم',
#  'حالیہ دورے',
#  'دوران',
#  'سی پیک',
#  'نکات',
#  'سی آر',
#  '...',
#  'خطے',
#  'مزید تنازع',
#  'چاہتے، کوشش',
#  'سعودیہ',
#  'ایران',
#  'غلط فہماں دور',
#  'ہوں، وزیر خارجہ',
#  'سی پیک',
#  'چین',
#  'پاکستان',
#  'مطمئن ہیں،',
#  'اگلے فیز',
#  'جانب آگے',
#  '...',
#  'سی پیک',
#  'پہلے مرحلے',
#  'تکمیل',
#  'پاکستان',
#  'بنیادی ڈھانچے',
#  'بہتری آئی ہے، منصوبے',
#  'افغانستان،',
#  'وسطی ایشیاء',
#  'روس',
#  'رسائی',
#  'چینی سفیر یاؤچنگ',
#  'اے',
#  '...',
#  'سی پیک',
#  'تحت بلوچستان',
#  'اقتصادی زونز',
#  'قیام',
#  'مقامی صنعت ترقی',
#  'گی، حکام',
#  'سی پیک اتھارٹی',
#  'سی پیک',
#  'تحت بلوچستان',
#  'تحصیل بوستان',
#  'انڈسٹریل زون',
#  'کام تیزی',
#  'سی پیک',
#  'متعلقہ منصوبوں میں70',
#  'پاکستانیوں',
#  'روزگار',
#  'حکام',
#  'سی پیک اتھارٹی',
#  'وزیراعظم',
#  'سی پیک اتھارٹی',
#  'چیئرپرسن مقرر، آرڈیننس',
#  'احسن اقبال',
#  'سی پیک اتھارٹی',
#  'آرڈیننس',
#  'خلاف قانون قرار',
#  'سی پیک اتھارٹی',
#  'قیام',
#  'پارلیمانی کمیٹی',
#  'سفارشات',
#  'منافی ہے،',
#  'سیکرٹری ...',
#  'صدر مملکت عارف علوی',
#  'سی پیک اتھارٹی آرڈیننس',
#  'دستخط کردیئے',
#  'سی پیک اتھارٹی آرڈیننس',
#  'اطلاق',
#  'پورے پاکستان',
#  'وزیراعظم عمران خان اتھارٹی',
#  'سربراہ',
#  'پاکستان',
#  'چین',
#  'سی پیک',
#  'معاشی ترقی،',
#  'صنعتی انقلاب',
#  'جدید زراعتی نظام',
#  'عمل انگیز',
#  'طور',
#  'ہیں، پاکستان',
#  'اقتصادی سفارتکاری',
#  'خصوصی توجہ ...',
#  'چین',
#  'پاکستان',
#  'قومی مفاد',
#  'ایشو',
#  'بھرپور تعاون',
#  'یقین دہانی وزیراعظم',
#  'چینی',
#  'منصب',
#  'درمیان',
#  'ملاقات،مقبوضہ کشمیر',
#  'صورتحال',
#  'اورسی پیک',
#  'منصوبوں پرتبادلہ',
#  'خیال،چینی ...',
#  'وفاقی حکومت',
#  'سردمہری',
#  'رویہ',
#  'قابل افسوس ہے،',
#  'سعید غنی',
#  'سی پیک',
#  'سی آر',
#  'زیادتی',
#  'مترادف ہے،صوبائی وزیر',
#  'کراچی سرکولر ریلوے',
#  'وفاقی حکومت',
#  'سردمہری قابل افسوس',
#  'ہے،سعید غنی',
#  'حالیہ دورے',
#  'دوران وزیراعظم',
#  'سی پیک',
#  'نکات',
#  'ہیں،',
#  'سی آر',
#  'صوبہ ...',
#  'وفاقی حکومت',
#  'سی پیک اتھارٹی بارے',
#  'صدارتی آرڈیننس',
#  'جاری کرکے',
#  'شاندار اقدامات',
#  'کئے،انوار الحق رامے',
#  'پاکستان',
#  'چین',
#  'سی پیک',
#  'تحت اربوں ڈالر مالیت',
#  'ایم ایل۔ ون منصوبے',
#  'حتمی شکل',
#  'ہے، کراچی',
#  'پشاور',
#  'ریلوے ٹریک',
#  'لمبائی',
#  'نیا سگنلنگ ...',
#  'پاکستان',
#  'چین',
#  'قریبی دوست، شراکت دار',
#  'آہنی برادرز ہیں، پاکستان غربت',
#  'خاتمہ',
#  'چین',
#  'تجربات',
#  'استفادہ',
#  'ہے،',
#  'سی پیک',
#  'تکمیل',
#  'موجودہ حکومت',
#  'اولین ...',
#  'سی پیک',
#  'دوسرے مرحلے',
#  'تکمیل',
#  'روزگار',
#  'مواقع پیدا',
#  'مدد',
#  'گی، حکام',
#  'سی پیک اتھارٹی',
#  'پاک چین',
#  'صنعتی تعاون',
#  'فروغ',
#  'لئے',
#  'جامع فریم ورک',
#  'ہے، حکام',
#  'سی پیک اتھارٹی',
#  'وزیراعظم',
#  'دورہ چین',
#  'سی پیک',
#  'نئے منصوبوں',
#  'مددگار ثابت ہوگا، حسن دائودبٹ',
#  'چین',
#  'چیف پلانرکنگ ژی وانگ',
#  'سی پیک',
#  'تحت',
#  'جاری منصوبوں',
#  'بروقت تکمیل',
#  'اطمینان',
#  'اظہار',
#  'ترکی',
#  'شام',
#  'فوجی کارروائی',
#  'آغاز',
#  'ترکی',
#  'شام',
#  'فوجی کارروائی',
#  'آغاز',
#  'ترکی شام',
#  'کرد جنگجوؤں کیخلاف فوجی کارروائی',
#  'دے‘یورپی یونین',
#  'یورپی یونین شام',
#  'مجوزہ ’’سیف زون‘‘',
#  'قیام',
#  'رقم',
#  'شام',
#  'ترک فوجی کارروائی',
#  'عالمی برادری',
#  'صدر',
#  'سلامتی کونسل',
#  'ترکی',
#  'شہریوں',
#  'جان ومال',
#  'حفاظت',
#  'تحمل',
#  'مظاہرہ',
#  'مطالبہ',
#  'ترکی',
#  'فوجی کارروائی',
#  'بعد شام',
#  'بڑے پیمانے پرلوگوں',
#  'نقل مکانی ْ راس العین',
#  'نقل مکانی',
#  'افراد',
#  'جنوبی علاقے الحسکہ',
#  'طرف جنوب',
#  'طرف',
#  'عالمی برادری کیشام',
#  'ترک فوجی کارروائی',
#  'مذمت',
#  'ترک فوجی کارروائی',
#  'غور',
#  'لئے اقوام متحدہ',
#  'اجلاس آج',
#  'سلامتی کونسل',
#  'رکن',
#  'یورپی ممالک',
#  'ترکی',
#  'شام',
#  'فوجی کارروائی',
#  'مطالبہ',
#  'کشمیریوں',
#  'اظہار یکجہتی',
#  'قرارداد',
#  'پنجاب اسمبلی',
#  'سیالکوٹ، کشمیریوں',
#  'اظہار یکجہتی',
#  'ریلی',
#  'ضلعی انتظامیہ',
#  'ڈسٹرکٹ ایجوکیشن اتھارٹی',
#  'اشتراک',
#  'کشمیری خواتین',
#  'وقار',
#  'بحالی',
#  'اظہار',
#  'ریلی',
#  'انعقاد',
#  'وکلاء',
#  'کشمیری مسلمانوں',
#  'اظہار',
#  'ستمبر',
#  'کنونشن',
#  'ریلی',
#  'انعقاد',
#  'گے، محمد ارشد اعوان ایڈووکیٹ',
#  'ہرنائی',
#  'کشمیریوں',
#  'اظہار یکجہتی',
#  'ریلی،احتجاجی مظاہرہ',
#  'مقبوضہ کشمیر',
#  'مظلوم',
#  'محکوم',
#  'کشمیری خواتین',
#  'ساتھ اظہار یکجہتی',
#  'محکمہ ترقی نسواں',
#  'زیر اہتمام یکجہتی ریلی',
#  'انعقاد',
#  'ڈیرہ مرادجمالی',
#  'کشمیریوں',
#  'اظہار',
#  'ریلی',
#  'شیخوپورہ',
#  '،ضلعی انتظامیہ',
#  'زیر اہتمام',
#  'کشمیری بھائیوں',
#  'اظہار یکجہتی',
#  'بھارتی مظالم',
#  'کیخلاف سیمینار',
#  'خواتین',
#  'ریلی',
#  'انعقاد',
#  'کشمیر پاکستانیوں',
#  'رگوں',
#  'خون',
#  'طرح',
#  '،مسرت جمشید چیمہ چیئر پرسن قائمہ کمیٹی داخلہ',
#  'قیادت',
#  'کاشانہ ہوم',
#  'بچیوں',
#  'کشمیریوں',
#  'اظہار',
#  'ریلی ...',
#  'مظفرگڑھ,کشمیری عوام',
#  'اظہار یکجہتی',
#  'کیلئی ریلیاں',
#  'کشمیریوں',
#  'اظہار یکجہتی',
#  'لازمی ہے، عبدالوسیم پاکستان',
#  'سلامی',
#  'زندگی',
#  'قربان ہے، شرف الدین',
#  'مقبوضہ کشمیر',
#  'خواتین',
#  'اظہار یکجہتی',
#  'لئے گورنمنٹ گرلزکالج وہاڑی',
#  'ریلی',
#  'کشمیریوں',
#  'ساتھ اظہار یکجہتی',
#  'پوری قوم',
#  'کھڑی ہے،رانا شکیل احمد',
#  'کشمیریوں',
#  'اظہار یکجہتی',
#  'شعبہ خواتین',
#  'کشمیر کمیٹی',
#  'زیر اہتمام پاکپتن',
#  'ریلی',
#  'انعقاد',
#  'کوہلو ،کشمیریوں',
#  'اظہار',
#  'ریلی',
#  'نصیرآباد:ڈیرہ مرادجمالی',
#  'کشمیریوں',
#  'اظہار یکجہتی',
#  'پاک فوج',
#  'حق',
#  'قبائلی رہنماء',
#  'وڈیرہ عرض محمد جتک',
#  'قیادت',
#  'جتک ہاوس',
#  'ریلی',
#  'الپوری:ضلع',
#  'مختلف تنظیموں،مذہبی',
#  'وسیاسی جماعتوں',
#  'مختلف سکولوں، کالجوں',
#  'طلباء۔ انجمن تاجران',
#  'کشمیریوں',
#  'اظہار یکجہتی',
#  'حوالے',
#  'ریلیاں',
#  'اوراحتجاجی مظاہرے',
#  'ڈپٹی کمشنر صحبت پور محمد یونس سنجرانی',
#  'قیادت میںکشمیر',
#  'مظلوم بھائیوں',
#  'اظہار',
#  'ریلی',
#  'انعقاد',
#  'کمشنر سبی ڈویژن سید فیصل احمد',
#  'قیادت',
#  'کشمیریوں',
#  'اظہار یکجہتی',
#  'حوالے',
#  'ریلی',
#  'انعقاد',
#  'مرکزی علماء کونسل',
#  'اپیل',
#  'کشمیریوں',
#  'اظہار',
#  'ملک بھرمیں’’یوم ندائے کشمیر‘‘',
#  'جمعہ',
#  'اجتماعات',
#  'مقبوضہ کشمیر',
#  'بھارتی مظالم کیخلاف',
#  'مذمتی ...',
#  'گورنمنٹ ڈگری کالج سکھر',
#  'کشمیری عوام کیساتھ اظہار یکجہتی',
#  'ریلی',
#  'کشمیر کمیٹی کراچی',
#  'تحت کشمیریوں',
#  'اظہار یکجہتی',
#  'عظیم الشان موٹر سائیکل ریلی نکالی گئی، شہریوں',
#  'بڑی تعداد',
#  'شرکت دنیا',
#  'طاقت کشمیری حریت پسندوں',
#  'حمایت ...',
#  'اظہار یکجہتی',
#  'دکھاوا؟',
#  'پشین ۔پشین',
#  'کشمیری عوام',
#  'ساتھ اظہار',
#  'تحریک جوانان پاکستان',
#  'زیر اہتمام ریلی',
#  'انعقاد',
#  'وزیر اعظم عمران خان',
#  'مسئلہ کشمیر',
#  'بین الاقوامی فورم',
#  'حقیقی جذبے',
#  'نورالحق',
#  'قادری وفاقی وزیر',
#  'مذہبی امور کاکشمیریوں',
#  'ساتھ اظہار یکجہتی',
#  'لئے ...',
#  'گلوکارہ رابی پیر زادہ',
#  'کشمیری بھائیوں',
#  'اظہار یکجہتی',
#  'نیا گانا ریکارڈ',
#  'سوشل میڈیا',
#  'اپ لوڈ',
#  'صدر جے آئی یوتھ چناری',
#  'مظاہرین',
#  'اظہار',
#  'چناری',
#  'بھرپور استقبال',
#  'کشمیریوں',
#  'اظہار یکجہتی؛حکومت',
#  'اسلام',
#  'انسانی ہاتھوں',
#  'زنجیر',
#  'اعلان',
#  'مقبوضہ جموں کشمیر',
#  'مظلوموں',
#  'ساتھ اظہار یکجہتی',
#  'لئے (کل )اسلام آباد',
#  'انسانی ہاتھوں',
#  'زنجیر',
#  'گی، ڈاکٹر فردوس',
#  'عاشق اعوان',
#  'پہر',
#  'بجے ایکسپریس چوک',
#  '...',
#  'حیدرآباد',
#  'شہری 13اکتوبر',
#  'کشمیر مارچ',
#  'بھرپور شرکت کرکے کشمیر',
#  'مظلوم عوام',
#  'اظہار یکجہتی',
#  'گے‘ حافظ طاہر مجید',
#  'نواز',
#  'چوہدری شوگر',
#  'کیس',
#  'امکان ن) لیگ',
#  'رہنمائوں',
#  'کارکنوں',
#  'ممکنہ پیشی',
#  'موقع',
#  'اظہار',
#  'عدالت',
#  'باہر',
#  'ہدایت ...',
#  'کشمیریوں',
#  'اظہار یکجہتی',
#  'لئے',
#  'اکتوبر',
#  'یوم',
#  'گا، وزارت داخلہ',
#  'طرف',
#  'نوٹیفکیشن',
#  'پاک سری لنکن ٹی ٹوئنٹی سیریز؛ ٹکٹوں',
#  'فروخت شروع',
#  'پاک سری لنکن ٹی ٹوئنٹی سیریز؛ ٹکٹوں',
#  'فروخت شروع',
#  'سری لنکنز',
#  'استقبال، کراچی',
#  'بانہیں',
#  'انشاء اللہ انگلینڈ',
#  'ٹیم جلد',
#  'پاکستان',
#  'دورہ',
#  'پاکستان',
#  'بین الاقوامی کرکٹ',
#  'چاہیئے، سری لنکن ٹیم',
#  'دورہ',
#  'خوش آئندہ ہے: انگلش لیگ اسپنر عادل رشید',
#  'پاک سری لنکن ٹی ٹونٹی کرکٹ سیریز',
#  'سکیورٹی',
#  'حسب معمول',
#  'سخت اقدمات',
#  'قذافی سٹیڈیم',
#  'جانب',
#  'سڑکوں',
#  'دوپہر',
#  'بجے',
#  'قسم',
#  'ٹریفک',
#  'لئے',
#  'گیادوپہر ...',
#  'ٹیم',
#  'ہارپر جواب',
#  'دہ ہوں‘ سری لنکن ٹیم',
#  'بائولنگ',
#  '‘ بیٹنگ',
#  'اچھی پرفارمنس دی‘',
#  'شعبوں',
#  'مکمل فیل',
#  'ہوئے‘ ہار',
#  'بعد ٹیم',
#  'خامیوں',
#  'پتہ',
#  '‘',
#  'مضبوط ٹیم',
#  '...',
#  'پاکستان',
#  'سری لنکا',
#  'درمیان',
#  'آخری ٹی ٹونٹی انٹرنیشنل کرکٹ میچ (آج)',
#  'گا، سری لنکن ٹیم',
#  'پاکستان',
#  'خلاف سیریز',
#  '2-0',
#  'فیصلہ',
#  'برتری',
#  'حاصل، مہمان ...',
#  'پاکستان',
#  'سری لنکن',
#  'کرکٹ ٹیموں',
#  'درمیان',
#  'آخری ٹی ٹوئنٹی میچ',
#  'میچ شام',
#  'بجکر',
#  'منٹ',
#  'شروع',
#  'ہوگا،برقی قمقموں',
#  'روشنی',
#  'جائیگا، سری ...',
#  'پاک سری لنکن ٹی ٹونٹی کرکٹ سیریز',
#  'آخری میچ',
#  'پاکستان',
#  'سری لنکا',
#  'درمیان',
#  'آخری ٹی ٹونٹی انٹرنیشنل کرکٹ میچ',
#  'سری لنکن ٹیم',
#  'پاکستان',
#  'خلاف سیریز',
#  '2-0',
#  'فیصلہ',
#  'برتری',
#  'حاصل، مہمان ...',
#  'سری لنکن آل راﺅنڈ ر تھیسارا پریرا',
#  'دورہ پاکستان',
#  'انکار',
#  'وجہ',
#  'کیریبئن لیگ',
#  'دوران ڈینگی بخار ہوگیا،ڈاکٹر',
#  'ایڈوائس',
#  'آرام کررہا ہوں:آل راﺅنڈر',
#  'چھاتی',
#  'سرطان',
#  'حوالے',
#  'پنک ربن ڈے پاکستان کرکٹ بورڈ',
#  'قذافی سٹیڈیم',
#  'پاک سری لنکن ٹی ٹونٹی سیریز',
#  'آخری میچ',
#  'پنک ربن',
#  'میچ ...',
#  '’میچ',
#  'ٹکٹ',
#  'لان',
#  'سوٹ',
#  'لیتی‘ سری لنکن ٹیم',
#  'ٹی ٹوئنٹی سیریز',
#  'بعد',
#  'سوشل میڈیا صارفین',
#  'قومی ٹیم',
#  'خراب کارکردگی',
#  'دلچسپ تبصرے',
#  'سری لنکن کرکٹ ٹیم',
#  'کوچ',
#  'پنجاب سیف سٹیز اتھارٹی',
#  'دورہ،',
#  'سیکورٹی بارے بریفنگ',
#  'سری لنکن ”ریلوکٹوں“',
#  'پاکستان کےخلاف ٹی ٹونٹی سیریز',
#  'وائٹ واش',
#  'مکمل کرلیا گرین شرٹس148رنز',
#  'ہدف',
#  'ناکام،بلے بازوں',
#  'ناقص کھیل',
#  'سرفراز احمد',
#  'قومی ٹیم',
#  'کپتانی',
#  'قرارداد',
#  'پنجاب اسمبلی',
#  'جمع سری لنکن ٹیم',
#  'ٹی ٹونٹی سیریز',
#  'وائٹ واش',
#  'تحقیقات',
#  'جائیں:متن',
#  'سری لنکن ٹیم',
#  'سکیورٹی اہلکاروں',
#  'خراج تحسین مہمان کھلاڑیوں',
#  'سٹیڈیم',
#  'سکیورٹی اہلکاروں',
#  'ساتھ',
#  'خصوصی تصاویر',
#  'وزیر',
#  'اعلیٰ پنجاب',
#  'پاکستان',
#  'کرکٹ سیریز',
#  'سری لنکن ٹیم',
#  'کھلاڑیوں',
#  'مینجمنٹ',
#  'اظہار تشکر انٹرنیشنل کرکٹ',
#  'بحالی',
#  'خوش آئند‘امید',
#  'دیگر',
#  'غیر ملکی ٹیمیں ...',
#  'سری لنکن ٹیم',
#  'کوچ',
#  'اُردو',
#  'سری لنکن ٹیم',
#  'کوچ',
#  'اُردو',
#  'محبتوں',
#  'پھول',
#  'سری لنکن ٹیم',
#  'واپسی',
#  'ملک',
#  'ڈینگی',
#  'متاثرہ مریضوں',
#  'تعداد 3674 ہوگئی، محکمہ صحت',
#  'راولپنڈی اسلام آباد',
#  'ڈینگی',
#  'خطرات',
#  'پیشِ نظر ریورگارڈن اوردیگر',
#  'رہائشی آبادیوں',
#  'انسدادِڈینگی سپرے',
#  'ریورگارڈن اوراردگرد',
#  'رہائشی آبادیوں',
#  'انسدادِ ڈینگی سپرے رکنِ',
#  'قومی اسمبلی،',
#  'ڈپٹی کمشنراسلام آباد اورایڈیشنل',
#  'ڈپٹی کمشنر',
#  'خصوصی اقدامات',
#  'ڈینگی',
#  'خاتمہ',
#  'مشن ہے‘ڈپٹی کمشنر بہاولنگر',
#  'فیصل آباد روڈ',
#  'ٹائر شاپس',
#  'ڈینگی لاوا',
#  'گیا‘ مالک دکان',
#  'خلاف مقدمہ',
#  'راولپنڈی',
#  'گھنٹوں',
#  'شہری ڈینگی بخار',
#  'مبتلا،مریضوں',
#  'تعداد',
#  'پمز',
#  'آئسولیشن وارڈ',
#  'ڈینگی',
#  'مریض داخل،',
#  'بچے',
#  'حالت',
#  'تشویشناک ...',
#  'کنگ عبدالله ہسپتال',
#  'ڈینگی',
#  'مریضوں',
#  'بیڈ',
#  'مشتمل وارڈ',
#  'راولپنڈی',
#  'انسداد ڈینگی سرگرمیاں',
#  'ڈینگی',
#  'گھر گھر',
#  'عوامی آگاہی',
#  'ساتھ',
#  'سا تھ',
#  'ہنگامی بنیادوں',
#  'ڈور',
#  'آئوٹ ڈور سرولنس',
#  'یقینی ...',
#  'ڈینگی',
#  'بچائو',
#  'لئے',
#  'موثر طریقہ',
#  'حفاظتی تدابیر',
#  'عمل',
#  'ڈاکٹر اعجاز وہرا',
#  'مسلم لیگ (ن)',
#  'ترجمان مریم اورنگزیب',
#  'ڈینگی',
#  'مریضوں',
#  'تعداد',
#  'اضافہ',
#  'اظہار تشویش',
#  'پاکستان',
#  'ڈینگی',
#  'اموات، کیسز',
#  'تجاوز',
#  'ڈپٹی کمشنر جہلم محمد سیف انور جپہ',
#  'زیر صدارت ڈینگی',
#  'بچاؤ',
#  'حوالے',
#  'اہم اجلاس',
#  'انعقاد',
#  'سیکرٹری پرائمری اینڈ سیکنڈری ہیلتھ کیئر کیپٹن عثمان',
#  'ہیڈ کوارٹر ہسپتال',
#  'دورہ',
#  'انتظامات',
#  'سیکرٹری ہیلتھ',
#  'ڈینگی',
#  'مرض',
#  'مبتلا مریضوں',
#  'عیادت',
#  '،ہسپتال ...',
#  'ڈینگی مچھر ،سیکرٹری پرائمری اینڈ سکینڈری ہیلتھ کئیر',
#  'غلط گھروں',
#  'ہسٹری',
#  'سی او راولپنڈی',
#  'سخت سرزنش وکیل کالونی',
#  'راول ٹائون',
#  'لاروا برآمد',
#  'پورے ...',
#  'پنجاب',
#  'ڈینگی',
#  'مزید 348کیسز، تعداد',
#  'تجاوز',
#  'عوام ڈینگی مہم',
#  'مامور ٹیموں',
#  'ساتھ تعاون کریں‘ڈاکٹر شاہد صد یق اپوز یشن انسا نی صحت',
#  'معا',
#  'ست',
#  'بازآ جائے‘رہنما تحریک انصاف',
#  'سندھ',
#  'رواں برس کانگو',
#  '18،نگلیریا',
#  '13،ڈینگی',
#  'افراد جان',
#  'بازی',
#  'ہیں،ڈاکٹر عمران شاہ',
#  'سندھ',
#  'رواں برس کانگو',
#  '18، نگلیریا',
#  '13، ڈینگی',
#  'افراد جان',
#  'بازی',
#  'ہیں، ڈاکٹر عمران شاہ',
#  'حکومت پنجاب ڈینگی',
#  'روک تھام',
#  'اقدامات',
#  'ہے،سردارعبدالحئی',
#  'ڈینگی لاروا برآمد',
#  'نوٹس',
#  'صورت',
#  'ادارے',
#  'سربراہ',
#  'فیصلہ',
#  'اسلام آباد انتظامیہ صحت فائونڈیشن',
#  'تعاون',
#  'گائوں جنڈیالہ',
#  'مفت ڈینگی آگاہی میڈیکل کیمپ',
#  'ڈینگی',
#  'بچاؤ مہم',
#  'شہری حصہ',
#  'شہباز شاہین',
#  'ڈینگی',
#  'بچاؤ مہم',
#  'شہری حصہ',
#  'شہباز شاہین',
#  'ڈپٹی کمشنر عرفان علی کاٹھیا',
#  'زیر صدارت انسداد ڈینگی',
#  'حوالے',
#  'اہم اجلاس',
#  'انعقاد',
#  'ضلعی انتظامیہ',
#  'کالجوں سکولوں',
#  'یونیورسٹیوں',
#  'ڈینگی',
#  'آگاہی',
#  'پرگرامز',
#  'سیمینار',
#  '‘صالحہ',
#  'سعید طالبات',
#  'گھروںمیں صفائی',
#  'ستھرائی ...',
#  'ضلعی انتظامیہ لاہو ر',
#  'انسداد ڈینگی',
#  'گزشتہ روز',
#  'رپورٹ',
#  'جاری کردی',
#  'پنجاب',
#  'ڈینگی',
#  'مزید 348',
#  'کیسز، تعداد',
#  'تجاوز',
#  'الپوری:شانگلہ',
#  'ڈینگی بے قابو ہوگیا مریضوں',
#  'مسلسل اضافے',
#  'عوام',
#  'تشویش۔محکمہ صحت وباء',
#  'روک تھام',
#  'ناکام بشام',
#  'مزید14افراد',
#  'ڈینگی وائرس',
#  'تصدیق',
#  '...',
#  'ساہیوال: ڈینگی',
#  'وائرس',
#  'سبب',
#  'افرادڈسٹر کٹ ھیڈ کوارٹر ہسپتال ساہیوال ڈینگی وارڈ دا خل',
#  'پنجاب حکومت',
#  'ڈینگی',
#  'ٹیسٹ فری',
#  'ڈینگی',
#  'ٹیسٹ',
#  'علاج',
#  '‘ سیکرٹری صحت کیپٹن (ر) محمد عثمان',
#  'ڈائریکٹرجنرل ہیلتھ سروسز ڈاکٹر کمالان گچکی',
#  'زیرصدارت لسبیلا',
#  'دیگر اضلاع',
#  'ڈینگی وائرس',
#  'پیدا',
#  'صورتحال',
#  'سدباب',
#  'حفاظتی اقدامات',
#  'پیش رفت',
#  'حوالے ...',
#  'ڈینگی2011۔۔۔25',
#  'اموات',
#  '۔۔۔',
#  'ضلعی انتظامیہ',
#  'ڈینگی',
#  'بچائومہم کاآغازکردیا',
#  'وزیر اعظم',
#  'معاون',
#  'خصوصی برائے صحت ڈاکٹر ظفر مرزا',
#  'راولپنڈی',
#  'اسلام آباد',
#  'ڈینگی وائرس',
#  'پیش نظر',
#  'نجی ہسپتالوں',
#  'صحت سہولت پروگرام',
#  'پینل',
#  '...',
#  ',راولپنڈی:ڈینگی مریضوں',
#  'فوری تشخیص',
#  'علاج',
#  'لئے راولپنڈی',
#  'علاقے',
#  'کوٹھہ کلاں مورگاہ',
#  'پہلے فلٹر کلینک',
#  'افتتاح',
#  'ق*ڈینگی',
#  'قابو',
#  'روایتی طریقہ کار اختیار',
#  '،نسیم صادق K',
#  'علاقے',
#  'ڈینگی مریض رپورٹ',
#  'ڈینگی',
#  'معلومات جمع',
#  'جائیں، ...',
#  'پیپلزپارٹی سندھ',
#  'رہنمائوں',
#  'پنجاب',
#  'خیبرپختوانخواہ',
#  'ڈینگی',
#  'بگڑتی صورتحال',
#  'تشویش کااظہار',
#  'بلوچستان',
#  'ڈینگی',
#  'مرض',
#  'تدارک',
#  'اقدامات',
#  'ہیں،',
#  'متاثرہ علاقوں',
#  'ٹیمیں تشکیل',
#  '،وزیر صحت',
#  'میر نصیب اللہ مری',
#  'ڈپٹی کمشنر حیدرآباد',
#  'متعلقہ افسران',
#  'شہر',
#  'صفائی ستھرائی',
#  'موثر انتظامات',
#  'ڈینگی',
#  'بچاؤ',
#  'اسپرے',
#  'ہدایت',
#  'پنجاب',
#  'بعد خیبرپختونخوا',
#  'ڈینگی بے قابو',
#  'سیکنڈری بورڈ سرگودھا میں’’ ڈینگی',
#  'خاتمہ مہم',
#  '‘‘کے حوالے',
#  'تقریب',
#  'انعقاد',
#  'راولپنڈی',
#  'اسلام آباد',
#  'ڈینگی مریضوں',
#  'تعداد',
#  'تجاوز',
#  'شہریوں کیساتھ',
#  'ضلعی انتظامیہ',
#  'خوف',
#  'زدہ ،بیڈز',
#  'کم، عملہ',
#  'ادویات',
#  'قلت',
#  '،سرکاری ہسپتالوں ...',
#  'خانیوال،',
#  'تعلیمی اداروں',
#  'ڈینگی مچھر',
#  ...]

# %%
allnounchunks = pd.DataFrame({'NounChunks':all_noun_chunks})

# %%
allnounchunks.to_csv('allnounchunksUrduDS.csv',index=False)

# %%
allnounchunks = pd.read_csv('allnounchunks20NewsGroup.csv')

# %%
all_noun_chunks = allnounchunks.NounChunks
print(len(all_noun_chunks))
# Out:
# 1814

# %%
from collections import Counter

# %%
freq_all_noun_chunks = Counter(all_noun_chunks)

# %%
freq_all_noun_chunks.most_common(500)
# Out:
# [('ڈینگی', 72),
#  ('سی پیک', 22),
#  ('...', 19),
#  ('اظہار یکجہتی', 16),
#  ('پاکستان', 15),
#  ('انعقاد', 15),
#  ('کشمیریوں', 13),
#  ('ریلی', 12),
#  ('حوالے', 12),
#  ('سی پیک اتھارٹی', 11),
#  ('اظہار', 11),
#  ('مریضوں', 11),
#  ('لئے', 10),
#  ('تعداد', 10),
#  ('ڈینگی وائرس', 10),
#  ('پنجاب', 8),
#  ('چین', 7),
#  ('خاتمہ', 7),
#  ('ضلعی انتظامیہ', 7),
#  ('دورہ', 6),
#  ('سری لنکن ٹیم', 6),
#  ('ڈپٹی کمشنر', 6),
#  ('قابو', 6),
#  ('صفائی', 6),
#  ('ملک', 5),
#  ('ترکی', 5),
#  ('وجہ', 5),
#  ('تجاوز', 5),
#  ('بچاؤ', 5),
#  ('انسداد ڈینگی', 5),
#  ('عوام', 5),
#  ('دورہ چین', 4),
#  ('آغاز', 4),
#  ('فیصلہ', 4),
#  ('سی آر', 4),
#  ('وفاقی حکومت', 4),
#  ('درمیان', 4),
#  ('شام', 4),
#  ('فوجی کارروائی', 4),
#  ('قرارداد', 4),
#  ('پنجاب اسمبلی', 4),
#  ('ساتھ اظہار یکجہتی', 4),
#  ('جانب', 4),
#  ('ساتھ', 4),
#  ('راولپنڈی', 4),
#  ('گھنٹوں', 4),
#  ('عیادت', 4),
#  ('اقدامات', 4),
#  ('آگاہی', 4),
#  ('تصدیق', 4),
#  ('اسلام آباد', 4),
#  ('کنٹرول', 4),
#  ('ڈی', 4),
#  ('کارکردگی', 4),
#  ('انسداد ڈینگی مہم', 4),
#  ('جائزہ', 4),
#  ('بڑے پیمانے', 4),
#  ('داخل', 3),
#  ('غربت', 3),
#  ('صنعتی تعاون', 3),
#  ('وزیر', 3),
#  ('گی، حکام', 3),
#  ('دوران', 3),
#  ('تکمیل', 3),
#  ('قیام', 3),
#  ('سفارشات', 3),
#  ('صورتحال', 3),
#  ('تحت', 3),
#  ('ترک فوجی کارروائی', 3),
#  ('طرف', 3),
#  ('مقبوضہ کشمیر', 3),
#  ('قیادت', 3),
#  ('کوچ', 3),
#  ('بچائو', 3),
#  ('اہم اجلاس', 3),
#  ('مرض', 3),
#  ('تعاون', 3),
#  ('رپورٹ', 3),
#  ('جاری کردی', 3),
#  ('پنجاب حکومت', 3),
#  ('شہر', 3),
#  ('ڈینگی مریضوں', 3),
#  ('ڈینگی مچھر', 3),
#  ('کردار ادا', 3),
#  ('مکمل خاتمہ', 3),
#  ('افزائش', 3),
#  ('احتیاطی تدابیر', 3),
#  ('تشخیص', 3),
#  ('ممکن حکمت', 3),
#  ('توجہ', 2),
#  ('گا،', 2),
#  ('دوسرے مرحلہ', 2),
#  ('جمعہ', 2),
#  ('کمی', 2),
#  ('دوسرے مرحلے', 2),
#  ('چین پاکستان', 2),
#  ('وزیر اعظم عمران خان', 2),
#  ('کام', 2),
#  ('ذریعے', 2),
#  ('وزیراعظم عمران خان', 2),
#  ('وفد', 2),
#  ('خیبر پختونخوا', 2),
#  ('مدد', 2),
#  ('ہے، حکام', 2),
#  ('ایشو', 2),
#  ('سردمہری', 2),
#  ('رویہ', 2),
#  ('ہے،سعید غنی', 2),
#  ('حالیہ دورے', 2),
#  ('نکات', 2),
#  ('اے', 2),
#  ('تحت بلوچستان', 2),
#  ('روزگار', 2),
#  ('وزیراعظم', 2),
#  ('سی پیک اتھارٹی آرڈیننس', 2),
#  ('سربراہ', 2),
#  ('ہیں،', 2),
#  ('سلامتی کونسل', 2),
#  ('شہریوں', 2),
#  ('مطالبہ', 2),
#  ('افراد', 2),
#  ('کشمیری خواتین', 2),
#  ('بحالی', 2),
#  ('کشمیری بھائیوں', 2),
#  ('خواتین', 2),
#  ('انسانی ہاتھوں', 2),
#  ('زنجیر', 2),
#  ('رہنمائوں', 2),
#  ('پاک سری لنکن ٹی ٹوئنٹی سیریز؛ ٹکٹوں', 2),
#  ('فروخت شروع', 2),
#  ('پاک سری لنکن ٹی ٹونٹی کرکٹ سیریز', 2),
#  ('قذافی سٹیڈیم', 2),
#  ('سری لنکا', 2),
#  ('خلاف سیریز', 2),
#  ('2-0', 2),
#  ('برتری', 2),
#  ('حاصل، مہمان ...', 2),
#  ('آخری میچ', 2),
#  ('سری لنکن آل راﺅنڈ ر تھیسارا پریرا', 2),
#  ('دورہ پاکستان', 2),
#  ('انکار', 2),
#  ('کیریبئن لیگ', 2),
#  ('دوران ڈینگی بخار ہوگیا،ڈاکٹر', 2),
#  ('ایڈوائس', 2),
#  ('آرام کررہا ہوں:آل راﺅنڈر', 2),
#  ('قومی ٹیم', 2),
#  ('وائٹ واش', 2),
#  ('سکیورٹی اہلکاروں', 2),
#  ('دیگر', 2),
#  ('اُردو', 2),
#  ('راولپنڈی اسلام آباد', 2),
#  ('رہائشی آبادیوں', 2),
#  ('خلاف مقدمہ', 2),
#  ('پمز', 2),
#  ('حفاظتی تدابیر', 2),
#  ('اضافہ', 2),
#  ('مبتلا مریضوں', 2),
#  ('سندھ', 2),
#  ('رواں برس کانگو', 2),
#  ('افراد جان', 2),
#  ('بازی', 2),
#  ('روک تھام', 2),
#  ('ڈینگی لاروا برآمد', 2),
#  ('بچاؤ مہم', 2),
#  ('شہری حصہ', 2),
#  ('شہباز شاہین', 2),
#  ('زیر صدارت انسداد ڈینگی', 2),
#  ('گزشتہ روز', 2),
#  ('ٹیسٹ', 2),
#  ('علاج', 2),
#  ('حفاظتی اقدامات', 2),
#  ('علاقے', 2),
#  ('بعد خیبرپختونخوا', 2),
#  ('تقریب', 2),
#  ('ادویات', 2),
#  ('خانیوال،', 2),
#  ('فرد', 2),
#  ('وقت', 2),
#  ('زیر صدارت', 2),
#  ('افسران', 2),
#  ('مریض', 2),
#  ('شعور', 2),
#  ('حد', 2),
#  ('خلاف مقدمات', 2),
#  ('وسائل', 2),
#  ('کار', 2),
#  ('ڈینگی لاروا', 2),
#  ('چیک', 2),
#  ('بھرپور طریقے', 2),
#  ('عوام ڈینگی', 2),
#  ('سرکاری ہسپتالوں', 2),
#  ('صوبہ', 2),
#  ('آزادکشمیر', 2),
#  ('خیبر پختون خوا', 2),
#  ('ڈینگی بے قابو،', 2),
#  ('مریض اسپتال', 2),
#  ('سی لاہور', 2),
#  ('ممکنہ مضراثرات او راس', 2),
#  ('ضرورت', 2),
#  ('حکومت ڈینگی', 2),
#  ('زیر علاج', 2),
#  ('ڈپٹی کمشنر سید امان انور قدوائی', 2),
#  ('آل پاکستان پرائیویٹ سکولز مینجمنٹ', 2),
#  ('رکنی وفد', 2),
#  ('ڈپٹی کمشنر راولپنڈی', 2),
#  ('ملاقات سیف اللہ ڈوگر', 2),
#  ('ضلعی انتظامیہ راولپنڈی', 2),
#  ('مشین', 2),
#  ('عطیہ', 2),
#  ('۷ملاقات ...', 2),
#  ('پرویز مشرف', 2),
#  ('درخواست', 2),
#  ('صورتحال قابو', 2),
#  ('فوگنگ', 2),
#  ('موثر اقدامات', 2),
#  ('وبا', 2),
#  ('خلاف', 2),
#  ('لوگ', 2),
#  ('نیشنل ہائی ویز اینڈ موٹروے پولیس', 2),
#  ('متعلق سیمینار', 2),
#  ('انسداد ڈینگی اقدامات', 2),
#  ('محکمہ صحت', 2),
#  ('خیبرپختونخوا', 2),
#  ('اجلاس', 2),
#  ('عملدرآمد', 2),
#  ('ٹی ایم اے لاچی', 2),
#  ('صفائی مہم', 2),
#  ('شجر کاری', 2),
#  ('گھر گھر ڈینگی', 2),
#  ('سپرے', 2),
#  ('سی خانیوال', 2),
#  ('ڈینگی سیمینار', 2),
#  ('چیکنگ', 2),
#  ('سی پیک منصوبہ ختم،آئی ایم ایف', 1),
#  ('شرائط پرعملدرآمد شروع امریکہ', 1),
#  ('خوشنودی', 1),
#  ('پاکستانی مفاد پسِ پشت', 1),
#  ('حکومت', 1),
#  ('تحت اکانامک زونز', 1),
#  ('ہے‘ رشکئی اکنامک زون گراونڈ بریکینگ', 1),
#  ('مکمل ہے‘', 1),
#  ('آئندہ ماہ افتتاح', 1),
#  ('وفاقی وزیر', 1),
#  ('منصوبہ بندی ...', 1),
#  ('کاموجودہ مرحلہ', 1),
#  ('پاکستانی عوام', 1),
#  ('معاشی فوائد', 1),
#  ('آئے گا،', 1),
#  ('خاتمہ، زراعت', 1),
#  ('اعلیٰ خیبر پختونخوا محمود خان', 1),
#  ('روز چترال', 1),
#  ('سرکاری دورہ وزیر اعلیٰ', 1),
#  ('متبادل روٹ چترل', 1),
#  ('متاثرہ ریشن بجلی گھر ...', 1),
#  ('شرح', 1),
#  ('اہم ترجیحات', 1),
#  ('حکومت عوام', 1),
#  ('ریلیف', 1),
#  ('فراہمی', 1),
#  ('عزم ہے،', 1),
#  ('اقتصادی راہداری منصوبہ', 1),
#  ('خاتمے، زراعت', 1),
#  ('خصوصی توجہ', 1),
#  ('ممالک', 1),
#  ('مابین تعلقات', 1),
#  ('نئے دور', 1),
#  ('رفتار', 1),
#  ('گی، شاہد رشید', 1),
#  ('صدارتی آرڈیننس', 1),
#  ('خیبرپختونخوا حکومت', 1),
#  ('متعلقہ محکموں', 1),
#  ('ترقیاتی منصوبوںکی', 1),
#  ('حتمی منصوبہ بندی', 1),
#  ('ہدایت صوبے', 1),
#  ('ترقیاتی منصوبوں', 1),
#  ('پچھلی وفاقی دور حکومت', 1),
#  ('سی پیک منصوبوں', 1),
#  ('اہم ہے، حسن داد', 1),
#  ('چینی سرمایہ کاروں', 1),
#  ('انڈسٹریل زونز', 1),
#  ('اقتصادی راہداری', 1),
#  ('توانائی', 1),
#  ('شدید بحران پرقابو', 1),
#  ('بعد چینی صدر بھارت', 1),
#  ('گے: شاہ محمود قریشی چین', 1),
#  ('اپوزیشن بلاوجہ', 1),
#  ('ہے، پاکستان', 1),
#  ('ایف اے ٹی ایف', 1),
#  ('مطمئن ...', 1),
#  ('ض*کے', 1),
#  ('قابل افسوس', 1),
#  ('Gوزیر اعظم', 1),
#  ('خطے', 1),
#  ('مزید تنازع', 1),
#  ('چاہتے، کوشش', 1),
#  ('سعودیہ', 1),
#  ('ایران', 1),
#  ('غلط فہماں دور', 1),
#  ('ہوں، وزیر خارجہ', 1),
#  ('مطمئن ہیں،', 1),
#  ('اگلے فیز', 1),
#  ('جانب آگے', 1),
#  ('پہلے مرحلے', 1),
#  ('بنیادی ڈھانچے', 1),
#  ('بہتری آئی ہے، منصوبے', 1),
#  ('افغانستان،', 1),
#  ('وسطی ایشیاء', 1),
#  ('روس', 1),
#  ('رسائی', 1),
#  ('چینی سفیر یاؤچنگ', 1),
#  ('اقتصادی زونز', 1),
#  ('مقامی صنعت ترقی', 1),
#  ('تحصیل بوستان', 1),
#  ('انڈسٹریل زون', 1),
#  ('کام تیزی', 1),
#  ('متعلقہ منصوبوں میں70', 1),
#  ('پاکستانیوں', 1),
#  ('حکام', 1),
#  ('چیئرپرسن مقرر، آرڈیننس', 1),
#  ('احسن اقبال', 1),
#  ('آرڈیننس', 1),
#  ('خلاف قانون قرار', 1),
#  ('پارلیمانی کمیٹی', 1),
#  ('منافی ہے،', 1),
#  ('سیکرٹری ...', 1),
#  ('صدر مملکت عارف علوی', 1),
#  ('دستخط کردیئے', 1),
#  ('اطلاق', 1),
#  ('پورے پاکستان', 1),
#  ('وزیراعظم عمران خان اتھارٹی', 1),
#  ('معاشی ترقی،', 1),
#  ('صنعتی انقلاب', 1),
#  ('جدید زراعتی نظام', 1),
#  ('عمل انگیز', 1),
#  ('طور', 1),
#  ('ہیں، پاکستان', 1),
#  ('اقتصادی سفارتکاری', 1),
#  ('خصوصی توجہ ...', 1),
#  ('قومی مفاد', 1),
#  ('بھرپور تعاون', 1),
#  ('یقین دہانی وزیراعظم', 1),
#  ('چینی', 1),
#  ('منصب', 1),
#  ('ملاقات،مقبوضہ کشمیر', 1),
#  ('اورسی پیک', 1),
#  ('منصوبوں پرتبادلہ', 1),
#  ('خیال،چینی ...', 1),
#  ('قابل افسوس ہے،', 1),
#  ('سعید غنی', 1),
#  ('زیادتی', 1),
#  ('مترادف ہے،صوبائی وزیر', 1),
#  ('کراچی سرکولر ریلوے', 1),
#  ('سردمہری قابل افسوس', 1),
#  ('دوران وزیراعظم', 1),
#  ('صوبہ ...', 1),
#  ('سی پیک اتھارٹی بارے', 1),
#  ('صدارتی آرڈیننس', 1),
#  ('جاری کرکے', 1),
#  ('شاندار اقدامات', 1),
#  ('کئے،انوار الحق رامے', 1),
#  ('تحت اربوں ڈالر مالیت', 1),
#  ('ایم ایل۔ ون منصوبے', 1),
#  ('حتمی شکل', 1),
#  ('ہے، کراچی', 1),
#  ('پشاور', 1),
#  ('ریلوے ٹریک', 1),
#  ('لمبائی', 1),
#  ('نیا سگنلنگ ...', 1),
#  ('قریبی دوست، شراکت دار', 1),
#  ('آہنی برادرز ہیں، پاکستان غربت', 1),
#  ('تجربات', 1),
#  ('استفادہ', 1),
#  ('ہے،', 1),
#  ('موجودہ حکومت', 1),
#  ('اولین ...', 1),
#  ('مواقع پیدا', 1),
#  ('پاک چین', 1),
#  ('فروغ', 1),
#  ('جامع فریم ورک', 1),
#  ('نئے منصوبوں', 1),
#  ('مددگار ثابت ہوگا، حسن دائودبٹ', 1),
#  ('چیف پلانرکنگ ژی وانگ', 1),
#  ('جاری منصوبوں', 1),
#  ('بروقت تکمیل', 1),
#  ('اطمینان', 1),
#  ('ترکی شام', 1),
#  ('کرد جنگجوؤں کیخلاف فوجی کارروائی', 1),
#  ('دے‘یورپی یونین', 1),
#  ('یورپی یونین شام', 1),
#  ('مجوزہ ’’سیف زون‘‘', 1),
#  ('رقم', 1),
#  ('عالمی برادری', 1),
#  ('صدر', 1),
#  ('جان ومال', 1),
#  ('حفاظت', 1),
#  ('تحمل', 1),
#  ('مظاہرہ', 1),
#  ('بعد شام', 1),
#  ('بڑے پیمانے پرلوگوں', 1),
#  ('نقل مکانی ْ راس العین', 1),
#  ('نقل مکانی', 1),
#  ('جنوبی علاقے الحسکہ', 1),
#  ('طرف جنوب', 1),
#  ('عالمی برادری کیشام', 1),
#  ('مذمت', 1),
#  ('غور', 1),
#  ('لئے اقوام متحدہ', 1),
#  ('اجلاس آج', 1),
#  ('رکن', 1),
#  ('یورپی ممالک', 1),
#  ('سیالکوٹ، کشمیریوں', 1),
#  ('ڈسٹرکٹ ایجوکیشن اتھارٹی', 1),
#  ('اشتراک', 1),
#  ('وقار', 1),
#  ('وکلاء', 1),
#  ('کشمیری مسلمانوں', 1),
#  ('ستمبر', 1),
#  ('کنونشن', 1),
#  ('گے، محمد ارشد اعوان ایڈووکیٹ', 1),
#  ('ہرنائی', 1),
#  ('ریلی،احتجاجی مظاہرہ', 1),
#  ('مظلوم', 1),
#  ('محکوم', 1),
#  ('محکمہ ترقی نسواں', 1),
#  ('زیر اہتمام یکجہتی ریلی', 1),
#  ('ڈیرہ مرادجمالی', 1),
#  ('شیخوپورہ', 1),
#  ('،ضلعی انتظامیہ', 1),
#  ('زیر اہتمام', 1),
#  ('بھارتی مظالم', 1),
#  ('کیخلاف سیمینار', 1),
#  ('کشمیر پاکستانیوں', 1),
#  ('رگوں', 1),
#  ('خون', 1),
#  ('طرح', 1),
#  ('،مسرت جمشید چیمہ چیئر پرسن قائمہ کمیٹی داخلہ', 1),
#  ('کاشانہ ہوم', 1),
#  ('بچیوں', 1),
#  ('ریلی ...', 1),
#  ('مظفرگڑھ,کشمیری عوام', 1),
#  ('کیلئی ریلیاں', 1),
#  ('لازمی ہے، عبدالوسیم پاکستان', 1),
#  ('سلامی', 1),
#  ('زندگی', 1),
#  ('قربان ہے، شرف الدین', 1),
#  ('لئے گورنمنٹ گرلزکالج وہاڑی', 1),
#  ('پوری قوم', 1),
#  ('کھڑی ہے،رانا شکیل احمد', 1),
#  ('شعبہ خواتین', 1),
#  ('کشمیر کمیٹی', 1),
#  ('زیر اہتمام پاکپتن', 1),
#  ('کوہلو ،کشمیریوں', 1),
#  ('نصیرآباد:ڈیرہ مرادجمالی', 1),
#  ('پاک فوج', 1),
#  ('حق', 1),
#  ('قبائلی رہنماء', 1),
#  ('وڈیرہ عرض محمد جتک', 1),
#  ('جتک ہاوس', 1),
#  ('الپوری:ضلع', 1),
#  ('مختلف تنظیموں،مذہبی', 1),
#  ('وسیاسی جماعتوں', 1),
#  ('مختلف سکولوں، کالجوں', 1),
#  ('طلباء۔ انجمن تاجران', 1),
#  ('ریلیاں', 1),
#  ('اوراحتجاجی مظاہرے', 1),
#  ('ڈپٹی کمشنر صحبت پور محمد یونس سنجرانی', 1),
#  ('قیادت میںکشمیر', 1),
#  ('مظلوم بھائیوں', 1),
#  ('کمشنر سبی ڈویژن سید فیصل احمد', 1),
#  ('مرکزی علماء کونسل', 1),
#  ('اپیل', 1),
#  ('ملک بھرمیں’’یوم ندائے کشمیر‘‘', 1),
#  ('اجتماعات', 1),
#  ('بھارتی مظالم کیخلاف', 1),
#  ('مذمتی ...', 1),
#  ('گورنمنٹ ڈگری کالج سکھر', 1),
#  ('کشمیری عوام کیساتھ اظہار یکجہتی', 1),
#  ('کشمیر کمیٹی کراچی', 1),
#  ('تحت کشمیریوں', 1),
#  ('عظیم الشان موٹر سائیکل ریلی نکالی گئی، شہریوں', 1),
#  ('بڑی تعداد', 1),
#  ('شرکت دنیا', 1),
#  ('طاقت کشمیری حریت پسندوں', 1),
#  ('حمایت ...', 1),
#  ('دکھاوا؟', 1),
#  ('پشین ۔پشین', 1),
#  ('کشمیری عوام', 1),
#  ('ساتھ اظہار', 1),
#  ('تحریک جوانان پاکستان', 1),
#  ('زیر اہتمام ریلی', 1),
#  ('مسئلہ کشمیر', 1),
#  ('بین الاقوامی فورم', 1),
#  ('حقیقی جذبے', 1),
#  ('نورالحق', 1),
#  ('قادری وفاقی وزیر', 1),
#  ('مذہبی امور کاکشمیریوں', 1),
#  ('لئے ...', 1),
#  ('گلوکارہ رابی پیر زادہ', 1),
#  ('نیا گانا ریکارڈ', 1),
#  ('سوشل میڈیا', 1)]

# %%
# Take top 1000 frequent noun phrases as Candidate labels as suggested by Mei et al.
top_1000_candid = freq_all_noun_chunks.most_common(1000)

# %%
candidate_labels = []
for u,v in top_1000_candid:
    candidate_labels.append(u)

# %%
candidate_labels
# Out:
# ['ڈینگی',
#  'سی پیک',
#  '...',
#  'اظہار یکجہتی',
#  'پاکستان',
#  'انعقاد',
#  'کشمیریوں',
#  'ریلی',
#  'حوالے',
#  'سی پیک اتھارٹی',
#  'اظہار',
#  'مریضوں',
#  'لئے',
#  'تعداد',
#  'ڈینگی وائرس',
#  'پنجاب',
#  'چین',
#  'خاتمہ',
#  'ضلعی انتظامیہ',
#  'دورہ',
#  'سری لنکن ٹیم',
#  'ڈپٹی کمشنر',
#  'قابو',
#  'صفائی',
#  'ملک',
#  'ترکی',
#  'وجہ',
#  'تجاوز',
#  'بچاؤ',
#  'انسداد ڈینگی',
#  'عوام',
#  'دورہ چین',
#  'آغاز',
#  'فیصلہ',
#  'سی آر',
#  'وفاقی حکومت',
#  'درمیان',
#  'شام',
#  'فوجی کارروائی',
#  'قرارداد',
#  'پنجاب اسمبلی',
#  'ساتھ اظہار یکجہتی',
#  'جانب',
#  'ساتھ',
#  'راولپنڈی',
#  'گھنٹوں',
#  'عیادت',
#  'اقدامات',
#  'آگاہی',
#  'تصدیق',
#  'اسلام آباد',
#  'کنٹرول',
#  'ڈی',
#  'کارکردگی',
#  'انسداد ڈینگی مہم',
#  'جائزہ',
#  'بڑے پیمانے',
#  'داخل',
#  'غربت',
#  'صنعتی تعاون',
#  'وزیر',
#  'گی، حکام',
#  'دوران',
#  'تکمیل',
#  'قیام',
#  'سفارشات',
#  'صورتحال',
#  'تحت',
#  'ترک فوجی کارروائی',
#  'طرف',
#  'مقبوضہ کشمیر',
#  'قیادت',
#  'کوچ',
#  'بچائو',
#  'اہم اجلاس',
#  'مرض',
#  'تعاون',
#  'رپورٹ',
#  'جاری کردی',
#  'پنجاب حکومت',
#  'شہر',
#  'ڈینگی مریضوں',
#  'ڈینگی مچھر',
#  'کردار ادا',
#  'مکمل خاتمہ',
#  'افزائش',
#  'احتیاطی تدابیر',
#  'تشخیص',
#  'ممکن حکمت',
#  'توجہ',
#  'گا،',
#  'دوسرے مرحلہ',
#  'جمعہ',
#  'کمی',
#  'دوسرے مرحلے',
#  'چین پاکستان',
#  'وزیر اعظم عمران خان',
#  'کام',
#  'ذریعے',
#  'وزیراعظم عمران خان',
#  'وفد',
#  'خیبر پختونخوا',
#  'مدد',
#  'ہے، حکام',
#  'ایشو',
#  'سردمہری',
#  'رویہ',
#  'ہے،سعید غنی',
#  'حالیہ دورے',
#  'نکات',
#  'اے',
#  'تحت بلوچستان',
#  'روزگار',
#  'وزیراعظم',
#  'سی پیک اتھارٹی آرڈیننس',
#  'سربراہ',
#  'ہیں،',
#  'سلامتی کونسل',
#  'شہریوں',
#  'مطالبہ',
#  'افراد',
#  'کشمیری خواتین',
#  'بحالی',
#  'کشمیری بھائیوں',
#  'خواتین',
#  'انسانی ہاتھوں',
#  'زنجیر',
#  'رہنمائوں',
#  'پاک سری لنکن ٹی ٹوئنٹی سیریز؛ ٹکٹوں',
#  'فروخت شروع',
#  'پاک سری لنکن ٹی ٹونٹی کرکٹ سیریز',
#  'قذافی سٹیڈیم',
#  'سری لنکا',
#  'خلاف سیریز',
#  '2-0',
#  'برتری',
#  'حاصل، مہمان ...',
#  'آخری میچ',
#  'سری لنکن آل راﺅنڈ ر تھیسارا پریرا',
#  'دورہ پاکستان',
#  'انکار',
#  'کیریبئن لیگ',
#  'دوران ڈینگی بخار ہوگیا،ڈاکٹر',
#  'ایڈوائس',
#  'آرام کررہا ہوں:آل راﺅنڈر',
#  'قومی ٹیم',
#  'وائٹ واش',
#  'سکیورٹی اہلکاروں',
#  'دیگر',
#  'اُردو',
#  'راولپنڈی اسلام آباد',
#  'رہائشی آبادیوں',
#  'خلاف مقدمہ',
#  'پمز',
#  'حفاظتی تدابیر',
#  'اضافہ',
#  'مبتلا مریضوں',
#  'سندھ',
#  'رواں برس کانگو',
#  'افراد جان',
#  'بازی',
#  'روک تھام',
#  'ڈینگی لاروا برآمد',
#  'بچاؤ مہم',
#  'شہری حصہ',
#  'شہباز شاہین',
#  'زیر صدارت انسداد ڈینگی',
#  'گزشتہ روز',
#  'ٹیسٹ',
#  'علاج',
#  'حفاظتی اقدامات',
#  'علاقے',
#  'بعد خیبرپختونخوا',
#  'تقریب',
#  'ادویات',
#  'خانیوال،',
#  'فرد',
#  'وقت',
#  'زیر صدارت',
#  'افسران',
#  'مریض',
#  'شعور',
#  'حد',
#  'خلاف مقدمات',
#  'وسائل',
#  'کار',
#  'ڈینگی لاروا',
#  'چیک',
#  'بھرپور طریقے',
#  'عوام ڈینگی',
#  'سرکاری ہسپتالوں',
#  'صوبہ',
#  'آزادکشمیر',
#  'خیبر پختون خوا',
#  'ڈینگی بے قابو،',
#  'مریض اسپتال',
#  'سی لاہور',
#  'ممکنہ مضراثرات او راس',
#  'ضرورت',
#  'حکومت ڈینگی',
#  'زیر علاج',
#  'ڈپٹی کمشنر سید امان انور قدوائی',
#  'آل پاکستان پرائیویٹ سکولز مینجمنٹ',
#  'رکنی وفد',
#  'ڈپٹی کمشنر راولپنڈی',
#  'ملاقات سیف اللہ ڈوگر',
#  'ضلعی انتظامیہ راولپنڈی',
#  'مشین',
#  'عطیہ',
#  '۷ملاقات ...',
#  'پرویز مشرف',
#  'درخواست',
#  'صورتحال قابو',
#  'فوگنگ',
#  'موثر اقدامات',
#  'وبا',
#  'خلاف',
#  'لوگ',
#  'نیشنل ہائی ویز اینڈ موٹروے پولیس',
#  'متعلق سیمینار',
#  'انسداد ڈینگی اقدامات',
#  'محکمہ صحت',
#  'خیبرپختونخوا',
#  'اجلاس',
#  'عملدرآمد',
#  'ٹی ایم اے لاچی',
#  'صفائی مہم',
#  'شجر کاری',
#  'گھر گھر ڈینگی',
#  'سپرے',
#  'سی خانیوال',
#  'ڈینگی سیمینار',
#  'چیکنگ',
#  'سی پیک منصوبہ ختم،آئی ایم ایف',
#  'شرائط پرعملدرآمد شروع امریکہ',
#  'خوشنودی',
#  'پاکستانی مفاد پسِ پشت',
#  'حکومت',
#  'تحت اکانامک زونز',
#  'ہے‘ رشکئی اکنامک زون گراونڈ بریکینگ',
#  'مکمل ہے‘',
#  'آئندہ ماہ افتتاح',
#  'وفاقی وزیر',
#  'منصوبہ بندی ...',
#  'کاموجودہ مرحلہ',
#  'پاکستانی عوام',
#  'معاشی فوائد',
#  'آئے گا،',
#  'خاتمہ، زراعت',
#  'اعلیٰ خیبر پختونخوا محمود خان',
#  'روز چترال',
#  'سرکاری دورہ وزیر اعلیٰ',
#  'متبادل روٹ چترل',
#  'متاثرہ ریشن بجلی گھر ...',
#  'شرح',
#  'اہم ترجیحات',
#  'حکومت عوام',
#  'ریلیف',
#  'فراہمی',
#  'عزم ہے،',
#  'اقتصادی راہداری منصوبہ',
#  'خاتمے، زراعت',
#  'خصوصی توجہ',
#  'ممالک',
#  'مابین تعلقات',
#  'نئے دور',
#  'رفتار',
#  'گی، شاہد رشید',
#  'صدارتی آرڈیننس',
#  'خیبرپختونخوا حکومت',
#  'متعلقہ محکموں',
#  'ترقیاتی منصوبوںکی',
#  'حتمی منصوبہ بندی',
#  'ہدایت صوبے',
#  'ترقیاتی منصوبوں',
#  'پچھلی وفاقی دور حکومت',
#  'سی پیک منصوبوں',
#  'اہم ہے، حسن داد',
#  'چینی سرمایہ کاروں',
#  'انڈسٹریل زونز',
#  'اقتصادی راہداری',
#  'توانائی',
#  'شدید بحران پرقابو',
#  'بعد چینی صدر بھارت',
#  'گے: شاہ محمود قریشی چین',
#  'اپوزیشن بلاوجہ',
#  'ہے، پاکستان',
#  'ایف اے ٹی ایف',
#  'مطمئن ...',
#  'ض*کے',
#  'قابل افسوس',
#  'Gوزیر اعظم',
#  'خطے',
#  'مزید تنازع',
#  'چاہتے، کوشش',
#  'سعودیہ',
#  'ایران',
#  'غلط فہماں دور',
#  'ہوں، وزیر خارجہ',
#  'مطمئن ہیں،',
#  'اگلے فیز',
#  'جانب آگے',
#  'پہلے مرحلے',
#  'بنیادی ڈھانچے',
#  'بہتری آئی ہے، منصوبے',
#  'افغانستان،',
#  'وسطی ایشیاء',
#  'روس',
#  'رسائی',
#  'چینی سفیر یاؤچنگ',
#  'اقتصادی زونز',
#  'مقامی صنعت ترقی',
#  'تحصیل بوستان',
#  'انڈسٹریل زون',
#  'کام تیزی',
#  'متعلقہ منصوبوں میں70',
#  'پاکستانیوں',
#  'حکام',
#  'چیئرپرسن مقرر، آرڈیننس',
#  'احسن اقبال',
#  'آرڈیننس',
#  'خلاف قانون قرار',
#  'پارلیمانی کمیٹی',
#  'منافی ہے،',
#  'سیکرٹری ...',
#  'صدر مملکت عارف علوی',
#  'دستخط کردیئے',
#  'اطلاق',
#  'پورے پاکستان',
#  'وزیراعظم عمران خان اتھارٹی',
#  'معاشی ترقی،',
#  'صنعتی انقلاب',
#  'جدید زراعتی نظام',
#  'عمل انگیز',
#  'طور',
#  'ہیں، پاکستان',
#  'اقتصادی سفارتکاری',
#  'خصوصی توجہ ...',
#  'قومی مفاد',
#  'بھرپور تعاون',
#  'یقین دہانی وزیراعظم',
#  'چینی',
#  'منصب',
#  'ملاقات،مقبوضہ کشمیر',
#  'اورسی پیک',
#  'منصوبوں پرتبادلہ',
#  'خیال،چینی ...',
#  'قابل افسوس ہے،',
#  'سعید غنی',
#  'زیادتی',
#  'مترادف ہے،صوبائی وزیر',
#  'کراچی سرکولر ریلوے',
#  'سردمہری قابل افسوس',
#  'دوران وزیراعظم',
#  'صوبہ ...',
#  'سی پیک اتھارٹی بارے',
#  'صدارتی آرڈیننس',
#  'جاری کرکے',
#  'شاندار اقدامات',
#  'کئے،انوار الحق رامے',
#  'تحت اربوں ڈالر مالیت',
#  'ایم ایل۔ ون منصوبے',
#  'حتمی شکل',
#  'ہے، کراچی',
#  'پشاور',
#  'ریلوے ٹریک',
#  'لمبائی',
#  'نیا سگنلنگ ...',
#  'قریبی دوست، شراکت دار',
#  'آہنی برادرز ہیں، پاکستان غربت',
#  'تجربات',
#  'استفادہ',
#  'ہے،',
#  'موجودہ حکومت',
#  'اولین ...',
#  'مواقع پیدا',
#  'پاک چین',
#  'فروغ',
#  'جامع فریم ورک',
#  'نئے منصوبوں',
#  'مددگار ثابت ہوگا، حسن دائودبٹ',
#  'چیف پلانرکنگ ژی وانگ',
#  'جاری منصوبوں',
#  'بروقت تکمیل',
#  'اطمینان',
#  'ترکی شام',
#  'کرد جنگجوؤں کیخلاف فوجی کارروائی',
#  'دے‘یورپی یونین',
#  'یورپی یونین شام',
#  'مجوزہ ’’سیف زون‘‘',
#  'رقم',
#  'عالمی برادری',
#  'صدر',
#  'جان ومال',
#  'حفاظت',
#  'تحمل',
#  'مظاہرہ',
#  'بعد شام',
#  'بڑے پیمانے پرلوگوں',
#  'نقل مکانی ْ راس العین',
#  'نقل مکانی',
#  'جنوبی علاقے الحسکہ',
#  'طرف جنوب',
#  'عالمی برادری کیشام',
#  'مذمت',
#  'غور',
#  'لئے اقوام متحدہ',
#  'اجلاس آج',
#  'رکن',
#  'یورپی ممالک',
#  'سیالکوٹ، کشمیریوں',
#  'ڈسٹرکٹ ایجوکیشن اتھارٹی',
#  'اشتراک',
#  'وقار',
#  'وکلاء',
#  'کشمیری مسلمانوں',
#  'ستمبر',
#  'کنونشن',
#  'گے، محمد ارشد اعوان ایڈووکیٹ',
#  'ہرنائی',
#  'ریلی،احتجاجی مظاہرہ',
#  'مظلوم',
#  'محکوم',
#  'محکمہ ترقی نسواں',
#  'زیر اہتمام یکجہتی ریلی',
#  'ڈیرہ مرادجمالی',
#  'شیخوپورہ',
#  '،ضلعی انتظامیہ',
#  'زیر اہتمام',
#  'بھارتی مظالم',
#  'کیخلاف سیمینار',
#  'کشمیر پاکستانیوں',
#  'رگوں',
#  'خون',
#  'طرح',
#  '،مسرت جمشید چیمہ چیئر پرسن قائمہ کمیٹی داخلہ',
#  'کاشانہ ہوم',
#  'بچیوں',
#  'ریلی ...',
#  'مظفرگڑھ,کشمیری عوام',
#  'کیلئی ریلیاں',
#  'لازمی ہے، عبدالوسیم پاکستان',
#  'سلامی',
#  'زندگی',
#  'قربان ہے، شرف الدین',
#  'لئے گورنمنٹ گرلزکالج وہاڑی',
#  'پوری قوم',
#  'کھڑی ہے،رانا شکیل احمد',
#  'شعبہ خواتین',
#  'کشمیر کمیٹی',
#  'زیر اہتمام پاکپتن',
#  'کوہلو ،کشمیریوں',
#  'نصیرآباد:ڈیرہ مرادجمالی',
#  'پاک فوج',
#  'حق',
#  'قبائلی رہنماء',
#  'وڈیرہ عرض محمد جتک',
#  'جتک ہاوس',
#  'الپوری:ضلع',
#  'مختلف تنظیموں،مذہبی',
#  'وسیاسی جماعتوں',
#  'مختلف سکولوں، کالجوں',
#  'طلباء۔ انجمن تاجران',
#  'ریلیاں',
#  'اوراحتجاجی مظاہرے',
#  'ڈپٹی کمشنر صحبت پور محمد یونس سنجرانی',
#  'قیادت میںکشمیر',
#  'مظلوم بھائیوں',
#  'کمشنر سبی ڈویژن سید فیصل احمد',
#  'مرکزی علماء کونسل',
#  'اپیل',
#  'ملک بھرمیں’’یوم ندائے کشمیر‘‘',
#  'اجتماعات',
#  'بھارتی مظالم کیخلاف',
#  'مذمتی ...',
#  'گورنمنٹ ڈگری کالج سکھر',
#  'کشمیری عوام کیساتھ اظہار یکجہتی',
#  'کشمیر کمیٹی کراچی',
#  'تحت کشمیریوں',
#  'عظیم الشان موٹر سائیکل ریلی نکالی گئی، شہریوں',
#  'بڑی تعداد',
#  'شرکت دنیا',
#  'طاقت کشمیری حریت پسندوں',
#  'حمایت ...',
#  'دکھاوا؟',
#  'پشین ۔پشین',
#  'کشمیری عوام',
#  'ساتھ اظہار',
#  'تحریک جوانان پاکستان',
#  'زیر اہتمام ریلی',
#  'مسئلہ کشمیر',
#  'بین الاقوامی فورم',
#  'حقیقی جذبے',
#  'نورالحق',
#  'قادری وفاقی وزیر',
#  'مذہبی امور کاکشمیریوں',
#  'لئے ...',
#  'گلوکارہ رابی پیر زادہ',
#  'نیا گانا ریکارڈ',
#  'سوشل میڈیا',
#  'اپ لوڈ',
#  'صدر جے آئی یوتھ چناری',
#  'مظاہرین',
#  'چناری',
#  'بھرپور استقبال',
#  'اظہار یکجہتی؛حکومت',
#  'اسلام',
#  'اعلان',
#  'مقبوضہ جموں کشمیر',
#  'مظلوموں',
#  'لئے (کل )اسلام آباد',
#  'گی، ڈاکٹر فردوس',
#  'عاشق اعوان',
#  'پہر',
#  'بجے ایکسپریس چوک',
#  'حیدرآباد',
#  'شہری 13اکتوبر',
#  'کشمیر مارچ',
#  'بھرپور شرکت کرکے کشمیر',
#  'مظلوم عوام',
#  'گے‘ حافظ طاہر مجید',
#  'نواز',
#  'چوہدری شوگر',
#  'کیس',
#  'امکان ن) لیگ',
#  'کارکنوں',
#  'ممکنہ پیشی',
#  'موقع',
#  'عدالت',
#  'باہر',
#  'ہدایت ...',
#  'اکتوبر',
#  'یوم',
#  'گا، وزارت داخلہ',
#  'نوٹیفکیشن',
#  'سری لنکنز',
#  'استقبال، کراچی',
#  'بانہیں',
#  'انشاء اللہ انگلینڈ',
#  'ٹیم جلد',
#  'بین الاقوامی کرکٹ',
#  'چاہیئے، سری لنکن ٹیم',
#  'خوش آئندہ ہے: انگلش لیگ اسپنر عادل رشید',
#  'سکیورٹی',
#  'حسب معمول',
#  'سخت اقدمات',
#  'سڑکوں',
#  'دوپہر',
#  'بجے',
#  'قسم',
#  'ٹریفک',
#  'گیادوپہر ...',
#  'ٹیم',
#  'ہارپر جواب',
#  'دہ ہوں‘ سری لنکن ٹیم',
#  'بائولنگ',
#  '‘ بیٹنگ',
#  'اچھی پرفارمنس دی‘',
#  'شعبوں',
#  'مکمل فیل',
#  'ہوئے‘ ہار',
#  'بعد ٹیم',
#  'خامیوں',
#  'پتہ',
#  '‘',
#  'مضبوط ٹیم',
#  'آخری ٹی ٹونٹی انٹرنیشنل کرکٹ میچ (آج)',
#  'گا، سری لنکن ٹیم',
#  'سری لنکن',
#  'کرکٹ ٹیموں',
#  'آخری ٹی ٹوئنٹی میچ',
#  'میچ شام',
#  'بجکر',
#  'منٹ',
#  'شروع',
#  'ہوگا،برقی قمقموں',
#  'روشنی',
#  'جائیگا، سری ...',
#  'آخری ٹی ٹونٹی انٹرنیشنل کرکٹ میچ',
#  'چھاتی',
#  'سرطان',
#  'پنک ربن ڈے پاکستان کرکٹ بورڈ',
#  'پاک سری لنکن ٹی ٹونٹی سیریز',
#  'پنک ربن',
#  'میچ ...',
#  '’میچ',
#  'ٹکٹ',
#  'لان',
#  'سوٹ',
#  'لیتی‘ سری لنکن ٹیم',
#  'ٹی ٹوئنٹی سیریز',
#  'بعد',
#  'سوشل میڈیا صارفین',
#  'خراب کارکردگی',
#  'دلچسپ تبصرے',
#  'سری لنکن کرکٹ ٹیم',
#  'پنجاب سیف سٹیز اتھارٹی',
#  'دورہ،',
#  'سیکورٹی بارے بریفنگ',
#  'سری لنکن ”ریلوکٹوں“',
#  'پاکستان کےخلاف ٹی ٹونٹی سیریز',
#  'مکمل کرلیا گرین شرٹس148رنز',
#  'ہدف',
#  'ناکام،بلے بازوں',
#  'ناقص کھیل',
#  'سرفراز احمد',
#  'کپتانی',
#  'جمع سری لنکن ٹیم',
#  'ٹی ٹونٹی سیریز',
#  'تحقیقات',
#  'جائیں:متن',
#  'خراج تحسین مہمان کھلاڑیوں',
#  'سٹیڈیم',
#  'خصوصی تصاویر',
#  'اعلیٰ پنجاب',
#  'کرکٹ سیریز',
#  'کھلاڑیوں',
#  'مینجمنٹ',
#  'اظہار تشکر انٹرنیشنل کرکٹ',
#  'خوش آئند‘امید',
#  'غیر ملکی ٹیمیں ...',
#  'محبتوں',
#  'پھول',
#  'واپسی',
#  'متاثرہ مریضوں',
#  'تعداد 3674 ہوگئی، محکمہ صحت',
#  'خطرات',
#  'پیشِ نظر ریورگارڈن اوردیگر',
#  'انسدادِڈینگی سپرے',
#  'ریورگارڈن اوراردگرد',
#  'انسدادِ ڈینگی سپرے رکنِ',
#  'قومی اسمبلی،',
#  'ڈپٹی کمشنراسلام آباد اورایڈیشنل',
#  'خصوصی اقدامات',
#  'مشن ہے‘ڈپٹی کمشنر بہاولنگر',
#  'فیصل آباد روڈ',
#  'ٹائر شاپس',
#  'ڈینگی لاوا',
#  'گیا‘ مالک دکان',
#  'شہری ڈینگی بخار',
#  'مبتلا،مریضوں',
#  'آئسولیشن وارڈ',
#  'مریض داخل،',
#  'بچے',
#  'حالت',
#  'تشویشناک ...',
#  'کنگ عبدالله ہسپتال',
#  'بیڈ',
#  'مشتمل وارڈ',
#  'انسداد ڈینگی سرگرمیاں',
#  'گھر گھر',
#  'عوامی آگاہی',
#  'سا تھ',
#  'ہنگامی بنیادوں',
#  'ڈور',
#  'آئوٹ ڈور سرولنس',
#  'یقینی ...',
#  'موثر طریقہ',
#  'عمل',
#  'ڈاکٹر اعجاز وہرا',
#  'مسلم لیگ (ن)',
#  'ترجمان مریم اورنگزیب',
#  'اظہار تشویش',
#  'اموات، کیسز',
#  'ڈپٹی کمشنر جہلم محمد سیف انور جپہ',
#  'زیر صدارت ڈینگی',
#  'سیکرٹری پرائمری اینڈ سیکنڈری ہیلتھ کیئر کیپٹن عثمان',
#  'ہیڈ کوارٹر ہسپتال',
#  'انتظامات',
#  'سیکرٹری ہیلتھ',
#  '،ہسپتال ...',
#  'ڈینگی مچھر ،سیکرٹری پرائمری اینڈ سکینڈری ہیلتھ کئیر',
#  'غلط گھروں',
#  'ہسٹری',
#  'سی او راولپنڈی',
#  'سخت سرزنش وکیل کالونی',
#  'راول ٹائون',
#  'لاروا برآمد',
#  'پورے ...',
#  'مزید 348کیسز، تعداد',
#  'عوام ڈینگی مہم',
#  'مامور ٹیموں',
#  'ساتھ تعاون کریں‘ڈاکٹر شاہد صد یق اپوز یشن انسا نی صحت',
#  'معا',
#  'ست',
#  'بازآ جائے‘رہنما تحریک انصاف',
#  '18،نگلیریا',
#  '13،ڈینگی',
#  'ہیں،ڈاکٹر عمران شاہ',
#  '18، نگلیریا',
#  '13، ڈینگی',
#  'ہیں، ڈاکٹر عمران شاہ',
#  'حکومت پنجاب ڈینگی',
#  'ہے،سردارعبدالحئی',
#  'نوٹس',
#  'صورت',
#  'ادارے',
#  'اسلام آباد انتظامیہ صحت فائونڈیشن',
#  'گائوں جنڈیالہ',
#  'مفت ڈینگی آگاہی میڈیکل کیمپ',
#  'ڈپٹی کمشنر عرفان علی کاٹھیا',
#  'کالجوں سکولوں',
#  'یونیورسٹیوں',
#  'پرگرامز',
#  'سیمینار',
#  '‘صالحہ',
#  'سعید طالبات',
#  'گھروںمیں صفائی',
#  'ستھرائی ...',
#  'ضلعی انتظامیہ لاہو ر',
#  'مزید 348',
#  'کیسز، تعداد',
#  'الپوری:شانگلہ',
#  'ڈینگی بے قابو ہوگیا مریضوں',
#  'مسلسل اضافے',
#  'تشویش۔محکمہ صحت وباء',
#  'ناکام بشام',
#  'مزید14افراد',
#  'ساہیوال: ڈینگی',
#  'وائرس',
#  'سبب',
#  'افرادڈسٹر کٹ ھیڈ کوارٹر ہسپتال ساہیوال ڈینگی وارڈ دا خل',
#  'ٹیسٹ فری',
#  '‘ سیکرٹری صحت کیپٹن (ر) محمد عثمان',
#  'ڈائریکٹرجنرل ہیلتھ سروسز ڈاکٹر کمالان گچکی',
#  'زیرصدارت لسبیلا',
#  'دیگر اضلاع',
#  'پیدا',
#  'سدباب',
#  'پیش رفت',
#  'حوالے ...',
#  'ڈینگی2011۔۔۔25',
#  'اموات',
#  '۔۔۔',
#  'بچائومہم کاآغازکردیا',
#  'وزیر اعظم',
#  'معاون',
#  'خصوصی برائے صحت ڈاکٹر ظفر مرزا',
#  'پیش نظر',
#  'نجی ہسپتالوں',
#  'صحت سہولت پروگرام',
#  'پینل',
#  ',راولپنڈی:ڈینگی مریضوں',
#  'فوری تشخیص',
#  'لئے راولپنڈی',
#  'کوٹھہ کلاں مورگاہ',
#  'پہلے فلٹر کلینک',
#  'افتتاح',
#  'ق*ڈینگی',
#  'روایتی طریقہ کار اختیار',
#  '،نسیم صادق K',
#  'ڈینگی مریض رپورٹ',
#  'معلومات جمع',
#  'جائیں، ...',
#  'پیپلزپارٹی سندھ',
#  'خیبرپختوانخواہ',
#  'بگڑتی صورتحال',
#  'تشویش کااظہار',
#  'بلوچستان',
#  'تدارک',
#  'متاثرہ علاقوں',
#  'ٹیمیں تشکیل',
#  '،وزیر صحت',
#  'میر نصیب اللہ مری',
#  'ڈپٹی کمشنر حیدرآباد',
#  'متعلقہ افسران',
#  'صفائی ستھرائی',
#  'موثر انتظامات',
#  'اسپرے',
#  'ہدایت',
#  'ڈینگی بے قابو',
#  'سیکنڈری بورڈ سرگودھا میں’’ ڈینگی',
#  'خاتمہ مہم',
#  '‘‘کے حوالے',
#  'شہریوں کیساتھ',
#  'خوف',
#  'زدہ ،بیڈز',
#  'کم، عملہ',
#  'قلت',
#  '،سرکاری ہسپتالوں ...',
#  'تعلیمی اداروں',
#  'اوراحتیاطی تدابیر بارے',
#  'آگاہی کیلئے زیرو پیریڈز',
#  'ممکن نہیں،',
#  'خلاف مہم',
#  'لئے ایمرجنسی',
#  'شہباز',
#  'ڈینگی برادران',
#  '‘بابا محمد اسحاق',
#  'فیصل آباد ڈویژن',
#  'بچائو کیلئے فول',
#  'پروف انتظامات',
#  'ہیں،احتیاطی',
#  'تدارکی اقدامات',
#  'انسدادی صورتحال تسلی',
#  'بخش ہے، ڈویژنل کمشنر محمود ...',
#  'جہلم: انسداد ڈینگی',
#  'سلسلہ',
#  'پرائیویٹ اسکول ایسوسی ایشن',
#  'ساتھ اعلیٰ',
#  'سطحی اجلاس',
#  'ڈپٹی کمشنر محمد سیف انور جپہ',
#  'محکمہ تعلیم',
#  'ضلع کوٹلی',
#  '‘ڈسٹرکٹ ہیلتھ آفیسر کوٹلی محکمہ صحت عامہ ڈینگی',
#  'غرض ...',
#  'وہاڑی:ڈپٹی کمشنر عرفان علی کاٹھیا',
#  'ڈی ایچ کیو ہسپتال وہاڑی کادورہ ہسپتال',
#  'بارے',
#  'دریافت',
#  'دوران ڈینگی',
#  'فیصد مریضوں',
#  'تعلق خطہ پوٹھوہار',
#  'ہے، وزارت نیشنل ہیلتھ سروسز',
#  'خانیوال ۔جب',
#  'ممکن نہیں،ڈپٹی کمشنرخانیوال',
#  'خانیوال ۔ضلع خانیوال',
#  'مریض سامنے',
#  'آیا،',
#  'سی ای او ہیلتھ خانیوال',
#  'وہاڑی:',
#  'احتیاطی تدابیر اختیار',
#  'مچھر',
#  'لاروے',
#  'ہے:ڈپٹی کمشنر عرفان علی کاٹھیا انسداد',
#  'ڈپٹی کمشنر آفس',
#  'خصوصی ...',
#  'ڈینگی بے قابو ہوگیا،ہسپتالوں',
#  'ساہیوال',
#  'ڈینگی فری',
#  'سخت اقدامات شروع',
#  'ہیں،ڈپٹی کمشنرساہیوال محمدزمان وٹو',
#  'ن)لیگ',
#  'میو ہسپتال',
#  'سہولیات',
#  'ذمہ',
#  'داروزیر اعلیٰ',
#  'وزیر صحت',
#  'ہیں،وزیر صحت ...',
#  'ضلع',
#  'مکمل طور',
#  'ہے،ڈاکٹر',
#  'عبدالستار محکمہ صحت',
#  'علاقوں',
#  'ڈینگی مہم',
#  'ڈسٹرکٹ ہیلتھ ...',
#  'انسداد گندگی مہم',
#  'خلاف ورزی',
#  'سروس سٹیشن',
#  'سیل',
#  'گیا،',
#  'محکمہ صحت ڈینگی وائرس',
#  '،راجہ محمد فاروق حیدر آزادکشمیر',
#  'ادارے محکمہ صحت',
#  'سرویلنس',
#  'آ ڈ ٹ',
#  'چاررکنی تھرڈ پارٹی تشکیل',
#  'جھنگ',
#  'محکمہ',
#  'سوشل ویلفیئر',
#  'بیت الما ل',
#  'زیر اہتمام انسداد ڈینگی سیمینار',
#  'نرسیں ڈینگی بخار',
#  'رہنمائی',
#  'حوصلہ',
#  '‘ڈی جی نرسنگ',
#  'نرس',
#  'لواحقین',
#  'اچھا رویہ اختیار',
#  'قانون',
#  'مطابق ...',
#  'سی لاہور اصغر جوئیہ کاکوئینز روڈ',
#  'دورہ ،انسدادِ ڈینگی',
#  'ٹیموں',
#  '‘اصغر جوئیہ افسران ڈینگی ٹیموں',
#  'ہیںجہاں',
#  'ڈینگی لارا',
#  'مقدمات ...',
#  'لالہ',
#  'موسیٰ، شہریوں',
#  'ڈینگی بارے شعور',
#  'بھرپورتو جہ دی جائے،',
#  'اعلیٰ وزیر صحت',
#  'پنجاب عوام',
#  'جان',
#  'مال',
#  'تحفظ',
#  'ناکامی',
#  '‘پرویز ملک پنجاب',
#  'پولیو',
#  'شدید تکلیف اوراذیت',
#  'ہیں، میڈیسن',
#  'خاتمے کیلئے',
#  'بھرپور کاوشوں',
#  'مصروف عمل',
#  'ہیں،ایم ڈی راولپنڈی ویسٹ مینجمنٹ کمپنی اویس',
#  'منظور تارڑ',
#  'وزیراعلیٰ کاڈینگی',
#  'اضافے',
#  'اظہار تشویش،',
#  'سی بی',
#  'سی سمیت ڈینگی',
#  'اعلان راولپنڈی',
#  'فوری طور',
#  'موبائل ہیلتھ ...',
#  'قصور، محکمہ صحت ڈینگی',
#  'ملک بدر',
#  'مرکزی کردار ادا کرے،',
#  '۔کراچی',
#  'کچرے',
#  'بات',
#  'پی ٹی آئی حکومت عمران خان',
#  'حلقے',
#  'خاموش، اہلیان علاقہ',
#  'پریشان عمران خان',
#  'سابق حلقہ گندگی',
#  'اٹ گیا، ڈینگی ...',
#  'سہولتیں فلفور',
#  'لاروا',
#  'اینٹی ڈینگی ٹیمیں',
#  'بھرپور کردار ادا',
#  'حافظ آباد ضلع',
#  'رواں سال',
#  'دوران ڈینگی لاروا',
#  'شخص',
#  'ہوا،ڈپٹی کمشنر',
#  'نوید شہزاد مرزا',
#  'شہری ڈینگی',
#  'اختیار کریں‘ساجد علی قریشی',
#  'ڈینگی کیسز',
#  'واضح فرق',
#  'ہے‘صوبائی وزیر صحت ڈینگی',
#  'مریضوںکی',
#  'بھال کیلئے ہولی فیملی ہسپتال',
#  'خصوصی آئوٹ ...',
#  'فیصل آباد',
#  'کیس سامنے',
#  'آیا، ڈاکٹر معصومہ سردار',
#  'آگہی',
#  'بغیر ڈینگی',
#  'کاشف نثار',
#  'نجی ہائوسنگ سوسائٹی',
#  'مالکان',
#  'ڈینگی ایکٹ',
#  'دفعہ144کے نفاذ',
#  'تحریک',
#  '‘ڈی جی صحت آزاد کشمیر',
#  'سی لاہورکا سروسز ہسپتال',
#  'دورہ، ڈینگی انتظامات',
#  'چھٹکارا',
#  'محکموں',
#  'ضروری ہے، ڈی',
#  'ایڈیشنل',
#  'اسسٹنٹ کمشنرز',
#  'صفائی مہم بارے دورے',
#  '1085لوگ ڈینگی',
#  'متاثر ہوئے، کوآرڈنیٹر نیشنل پروگرام وڈائریکٹر',
#  'سی ڈی',
#  'عوام الناس',
#  'بچاؤ بارے',
#  'آگہی سیمینار',
#  'چیچہ وطنی، ڈینگی',
#  'ذمہ داری',
#  'ہے،صوبائی سیکرٹری',
#  'سوشل ویلفیئر عنبرین رضا',
#  'صوبائی وزیر صحت ڈاکٹر یاسمین راشد',
#  'ہولی فیملی ہسپتال',
#  'ڈینگی آئوٹ ڈور',
#  'دورہ، ڈینگی',
#  'شکار مریضوں',
#  'طبی سہولیات',
#  'جان لیواء مرض',
#  'احیتاط',
#  'بھاری فنڈز خرچ',
#  'مقصد شہریوں',
#  'لاہور:',
#  'ڈینگی بے قا بو',
#  'حکومتی اقدامات افسران',
#  'تبادلوں',
#  'محدود،حکومت',
#  'طرح صحت',
#  'بجٹ',
#  'خمیازہ آج عوام',
#  'ہیں،ایم ساجد عباسی ڈیل',
#  'ضلع چنیوٹ ڈینگی',
#  'خطرہ',
#  'محفوظ ہے،',
#  'ڈینگی مریضوںکیلئے صحت',
#  'بہترین سہولیات',
#  'ہیں،یاسمین راشد ہسپتالوںمیں',
#  'اضافی بیڈز',
#  'ساتھ ساتھ',
#  'ڈاکٹروںاور پیرا میڈیکل سٹاف',
#  'تعیناتی',
#  'راولپنڈی ویسٹ مینجمنٹ کمپنی',
#  'البائراک',
#  'آگاہی مہم',
#  'خیبر پختو نخوا',
#  'متاثرہ افراد',
#  'تعداد 4,522']

# %%
def zero_order(freq,theta,lCandidat,NumTopic):
    """
    Calculate the Zero-Order Relevance

    Parameters:
    ----------
    freq : Array containing the frequency of occurrences of each word in the whole corpus
    theta : Array containing the frequency of occurrences of each word in each topic
    lcandidat: Array containing each label candidate
    NumTopic : The number of the topic
    
    Returns:
    -------
    topCandidate : Array containing the name of the top 10 score candidate for a given topic
    """
    
    #W matrice qui contient le score de chaque mot pour chaque topic
    W=np.log(theta/freq)
    
    # score des tous les candidats pour le topic NumTopic
    score=[]
    
    for indice in range (len(lCandidat)):
        candidat=lCandidat[indice].split(" ")
        sum_w=[]
        #print(candidat)
        for w in candidat:
            if w in vocab:
                i=vocab.index(w)
                sum_w.append(W[k,i])
            else:
                sum_w.append(0)
        #i=id2word.doc2idx(candidat)
        # supprime les -1 (qui signifie pas trouvé)
        #i[:] = [v for v in i if v != -1]
        
        score.append(np.sum(sum_w))
        
    #topValue, topCandidate = top10Score(score,lCandidat)
    dicti=pd.DataFrame({'Labels':lCandidat,'Score':score})
  
    return dicti

# %%
for k in range(0,kn.knee):
    print("Topic %d"%k)
    candid_for_topic_k = zero_order(freq,theta,candidate_labels,k)
    candid_for_topic_k = candid_for_topic_k.sort_values('Score',ascending=False)
    print(candid_for_topic_k.head(3))
    print("=======================")
# Out:
# Topic 0
# C:\Users\Zarmeen\Anaconda2\envs\py36\lib\site-packages\ipykernel_launcher.py:18: RuntimeWarning: divide by zero encountered in log
#                                Labels     Score
# 385                          ترکی شام  5.027776
# 38                      فوجی کارروائی  4.933145
# 386  کرد جنگجوؤں کیخلاف فوجی کارروائی  4.933145
# =======================
# Topic 1
#                                     Labels     Score
# 807  ڈی ایچ کیو ہسپتال وہاڑی کادورہ ہسپتال  4.439810
# 951                           ضروری ہے، ڈی  1.756092
# 957                                  سی ڈی  1.756092
# =======================
# Topic 2
#                     Labels     Score
# 82              ڈینگی مچھر  0.982508
# 197  ممکنہ مضراثرات او راس  0.936505
# 231          ڈینگی سیمینار  0.870673
# =======================
# Topic 3
#                       Labels     Score
# 355      سی پیک اتھارٹی بارے  3.473964
# 9             سی پیک اتھارٹی  3.473964
# 114  سی پیک اتھارٹی آرڈیننس  3.473964
# =======================
# Topic 4
#                   Labels     Score
# 99    وزیراعظم عمران خان  2.955903
# 96   وزیر اعظم عمران خان  2.630050
# 276       سی پیک منصوبوں  1.915823
# =======================
# Topic 5
#                      Labels     Score
# 709    ضلعی انتظامیہ لاہو ر  2.988207
# 18            ضلعی انتظامیہ  2.988207
# 206  ضلعی انتظامیہ راولپنڈی  2.434596
# =======================
# Topic 6
#                    Labels     Score
# 914      پریشان عمران خان  2.487230
# 691  ہیں، ڈاکٹر عمران شاہ  2.154811
# 506                 اسلام  1.639035
# =======================
# Topic 7
#                               Labels     Score
# 476  کشمیری عوام کیساتھ اظہار یکجہتی  3.539747
# 424           زیر اہتمام یکجہتی ریلی  3.233888
# 3                       اظہار یکجہتی  2.527236
# =======================
# Topic 8
#                                Labels     Score
# 130  پاک سری لنکن ٹی ٹونٹی کرکٹ سیریز  9.762020
# 582       پاک سری لنکن ٹی ٹونٹی سیریز  8.241967
# 595                 سری لنکن کرکٹ ٹیم  6.194154
# =======================
# Topic 9
#                                               Labels     Score
# 851                            محکمہ صحت ڈینگی وائرس  3.444152
# 804  ‘ڈسٹرکٹ ہیلتھ آفیسر کوٹلی محکمہ صحت عامہ ڈینگی  2.803092
# 905                            قصور، محکمہ صحت ڈینگی  2.517847
# =======================
# Topic 10
#                          Labels     Score
# 101               خیبر پختونخوا  3.050361
# 713  ڈینگی بے قابو ہوگیا مریضوں  2.607418
# 81                 ڈینگی مریضوں  1.994332
# =======================
# Topic 11
#                                 Labels     Score
# 801       ڈپٹی کمشنر محمد سیف انور جپہ  4.372490
# 664  ڈپٹی کمشنر جہلم محمد سیف انور جپہ  4.372490
# 204                ڈپٹی کمشنر راولپنڈی  3.543787
# =======================
# Topic 12
# 5           CPEC            حکومت عوام ریلیف فراہمی عزم پیک اتھارٹی         3
# 6           CPEC  چین پاکستان اقتصادی راہداری منصوبہ مرحلہ غربت ...         3
# 7           CPEC  وزیر اعظم عمران خان دورہ چین ممالک مابین تعلقا...         4
# 8           CPEC              صدارتی آرڈیننس پیک اتھارٹی قائم فیصلہ         3
# 9           CPEC  خیبر پختونخوا حکومت متعلقہ محکموں ترقیاتی منصو...         4
# 10          CPEC  وزیراعظم عمران خان دورہ چین پیک منصوبوں اہم حس...         4
# 11          CPEC  چین پاکستان اقتصادی راہداری ملک انائی شدید بحر...         3
# 12          CPEC  وزیراعظم عمران خان دورہ چین چینی صدر بھارت شاہ...         4
# 13          CPEC  ض آر وفاقی حکومت سردمہری رویہ قابل افسوس سعید...         4
# 14          CPEC  خطے تنازع کوشش سعودیہ ایران غلط فہماں دور وزیر...         4
# 15          CPEC  پیک مرحلے تکمیل پاکستان بنیادی ڈھانچے بہتری آ...         4
# 16          CPEC  پیک بلوچستان اقتصادی زونز قیام مقامی صنعت ترقی...         3
# 17          CPEC  پیک بلوچستان تحصیل بوستان انڈسٹریل زون کام تیز...         5
# 18          CPEC  پیک متعلقہ منصوبوں ہزار پاکستانیوں روزگار ملا ...         3
# 19          CPEC    وزیراعظم پیک اتھارٹی چیئرپرسن مقرر آرڈیننس جاری         3
# 20          CPEC  احسن اقبال پیک اتھارٹی آرڈیننس قانون قرار دید...         3
# 21          CPEC  صدر مملکت عارف علوی پیک اتھارٹی آرڈیننس دستخط...         3
# 22          CPEC  پاکستان چین پیک معاشی و معاشی ترقی صنعتی انقلا...         4
# 23          CPEC  چین پاکستان قومی مفاد ایشو بھرپور تعاون یقین د...         4
# 24          CPEC  وفاقی حکومت سردمہری رویہ قابل افسوس سعید غنی پ...         4
# 25          CPEC  کراچی سرکولر ریلوے وفاقی حکومت سردمہری قابل اف...         4
# 26          CPEC  وفاقی حکومت پیک اتھارٹی صدارتی آرڈیننس جاری ش...         3
# 27          CPEC  پاکستان چین پیک اربوں ڈالر مالیت ایم ایل ون من...         4
# 28          CPEC  پاکستان چین قریبی دوست شراکت دار آہنی برادرز ...         4
# 29          CPEC  پیک مرحلے تکمیل روزگار مواقع پیدا مدد ملے حکام...         3
# ..           ...                                                ...       ...
# 230  DengueFever  سری لنکن آل راﺅنڈ ر تھیسارا پریرا دورہ پاکستان...         8
# 231  DengueFever  یو ای ٹی لاہورکے زیر اہتمام ڈینگی متعلق آگاہی ...         2
# 232  DengueFever  ٹی ایم لاچی بڑے پیمانے صفائی مہم آغاز علاقے ش...         5
# 233  DengueFever  مظفرآباد لچھراٹ ویلفئیر آرگنائزیشن آزادجموں...         6
# 234  DengueFever  ڈینگی خاتمہ بلدیات چیف افسران نکاسی آب صفائی ...         1
# 235  DengueFever  حکومت ڈینگی خاتمہ کیلئے ٹھوس عملی اقدامات کررہ...         2
# 236  DengueFever  ٹی ایم لاچی بڑے پیمانے صفائی مہم آغاز علاقے ش...         5
# 237  DengueFever            ڈینگی خدشہ پیش نظر دکانداروں مقدمات درج         2
# 238  DengueFever  افسران شہر صفائی ستھرائی ڈینگی سیمینار ڈینگی ا...         2
# 239  DengueFever  رواں سال بلوچستان تین اضلاع اب ڈینگی وائرس کیس...         9
# 240  DengueFever           خیبر پختونخوا ڈینگی نئے کیسز رپورٹ تعداد        10
# 241  DengueFever  انسداد ڈینگی مہم ڈپٹی کمشنر سرگودھا محکموں پاپ...        11
# 242  DengueFever       ملک ڈینگی متاثر افراد تعداد چوبیس ہزار تجاوز        10
# 243  DengueFever  سیکرٹری صحت زیر صدارت ڈینگی تازہ ترین حال بریف...        12
# 244  DengueFever  فوزیہ نامی خاتون نظیر بھٹو اسپتال ڈینگی وائرس ...         9
# 245  DengueFever  پاکستان وآزادکشمیر ڈینگی وائر پاک بنائیں ڈینگ...         2
# 246  DengueFever  ڈینگی خاتمے عملی اقداما ت اٹھائے شیخ عقیل الرح...         2
# 247  DengueFever    پمز ڈینگی مشتبہ مریضوں مریضوں ڈینگی وائرس تصدیق        10
# 248  DengueFever         صوبائی وزیر ملک اسد کھوکھر ڈینگی شکارہوگئے         2
# 249  DengueFever  آر ڈبلیو ایم جانب ڈینگی کیخلاف حفاظتی اقدامات...         2
# 250  DengueFever   انسداد ڈینگی سرویلنس کوتاہی برداشت سیکرٹری آرٹی        12
# 251  DengueFever  ڈی لاہور اصغر جوئیہ این ڈی بوائز ہائی سکول اچھ...         1
# 252  DengueFever  افسران ڈینگی سروئلنس صفائی ستھرائی پرائس چیکنگ...         1
# 253  DengueFever  رائیونڈ عدنان بدر ڈینگی صفائی ستھرائی چیک کیلئ...         2
# 254  DengueFever                                   احتیاط ڈینگی بچا         2
# 255  DengueFever  سرویلنس ٹیمیں ڈینگی مچھر افزائش مقامات بھرپور ...         1
# 256  DengueFever  انسداد ڈینگی مہم کمرشل اداروں دکانوں باقاعدگی ...        12
# 257  DengueFever  سوات ضلعی انتظامیہ محکمہ صحت ناقص منصوبہ بندی ...         9
# 258  DengueFever  اوکاڑہ ڈسٹرکٹ انٹا مالوجسٹکا مارکیٹوں مختلف جگ...         2
# 259  DengueFever  انسداد ڈینگی کار کردگی جائزہ لینے حوالہ اجلاس ...        12
#
#                                             NounChunks
# 0    [سی پیک منصوبہ ختم،آئی ایم ایف, شرائط پرعملدرآ...
# 1    [حکومت, سی پیک, تحت اکانامک زونز, توجہ, ہے‘ رش...
# 2    [سی پیک, کاموجودہ مرحلہ, پاکستانی عوام, معاشی ...
# 3    [وزیر, اعلیٰ خیبر پختونخوا محمود خان, جمعہ, رو...
# 4    [غربت, شرح, کمی, سی پیک, دوسرے مرحلے, اہم ترجی...
# 5    [حکومت عوام, ریلیف, فراہمی, لئے, عزم ہے،, سی پ...
# 6    [چین پاکستان, اقتصادی راہداری منصوبہ, دوسرے مر...
# 7    [وزیر اعظم عمران خان, دورہ چین, ممالک, مابین ت...
# 8       [صدارتی آرڈیننس, ذریعے, سی پیک اتھارٹی, فیصلہ]
# 9    [خیبرپختونخوا حکومت, متعلقہ محکموں, ترقیاتی من...
# 246  [ڈینگی, خاتمے, عملی اقداما ت, ہیں‘شیخ عقیل الر...
# 247  [پمز, ڈینگی, مشتبہ مریضوں, مریضوں, ڈینگی وائرس...
# 248      [صوبائی وزیر ملک اسد کھوکھر ڈینگی, شکارہوگئے]
# 249  [آر ڈبلیو ایم, جانب, ڈینگی کیخلاف, حفاظتی اقد...
# 250  [انسداد ڈینگی سرویلنس, کوتاہی برداشت, گی، سیکر...
# 251  [ڈی, سی لاہور اصغر جوئیہ, این ڈی بوائز ہائی سک...
# 252  [افسران ڈینگی, سروئلنس، صفائی, پرائس چیکنگ, عم...
# 253  [اے, سی رائیونڈ عدنان بدر, ڈینگی, صفائی, چیک, ...
# 254                                    [احتیاط, ڈینگی]
# 255  [سرویلنس ٹیمیں ڈینگی مچھر, افزائش, مقامات, بھر...
# 256  [انسداد ڈینگی مہم،, کمرشل اداروں ‘دکانوں, باقا...
# 257  [سوات:ضلعی انتظامیہ, محکمہ صحت, ناقص منصوبہ بن...
# 258  [اوکاڑہ،ڈسٹرکٹ انٹا مالوجسٹکا مارکیٹوں،, مختلف...
# 259  [انسداد ڈینگی, کارکردگی, جائزہ, حوالہ, اجلاس, ...
#
# [260 rows x 9 columns]

# %% [markdown]
# ## Proposed Topic labeling

# %%
def list_phrases_cluster(cluster_idx,df,key):
    df_sub = df[df[key] == cluster_idx]
    hashs = []
    for index,row in df_sub.iterrows():
        row.Noun_Phrases = row.NounChunks
        for x in row.Noun_Phrases:
            hashs.append(x)
    
    return collections.Counter(hashs)
def return_clusters_title(cluster_idx,dataset,col):
    hash_cluster1 = list_phrases_cluster(cluster_idx,dataset,col) 
    top10  = hash_cluster1.most_common(3)
    dataset_sub = dataset[dataset[col] == cluster_idx]
    cnt_vectorizer = TfidfVectorizer(ngram_range=(3,8))
    vec = cnt_vectorizer.fit_transform(dataset_sub['Title'])
    scores = (vec.toarray()) 
    # Getting top ranking features 
    sums = vec.sum(axis = 0) 
    data1 = [] 
    features = cnt_vectorizer.get_feature_names()
    for col, term in enumerate(features): 
        data1.append((term, sums[0, col] )) 
    ranking = pd.DataFrame(data1, columns = ['term', 'rank'])
    ranking['wCount'] = ranking['term'].apply(lambda x: len(x.split()))
    ranking = ranking.sort_values(['rank','wCount'],ascending=[False,True])
    print(ranking.head(5))
    my_top_4=[]
    for u,v in top10:
        my_top_4.append(u)
    my_top_4 = " ".join(my_top_4)
    my_top_4 = my_top_4.replace("_"," ")

    #print(my_top_4)
    test_list = (my_top_4.split())
    df = pd.DataFrame(columns=ranking.columns) #empty dataframe to add filtered rows
    for index,row in ranking.iterrows():
        # using list comprehension 
        # checking if string contains list element 
        res = all(ele in row['term'] for ele in test_list) 

        # print result 
        if res == True:
            df.loc[len(df)]=[row['term'],row['rank'],row['wCount']] 
    df = df.sort_values(['rank','wCount'],ascending=[False,True])
    #df = df.sort_values(['wCount'])
    if len(df)>0:
        return df.iloc[0]['term']
    else:
        return "No title constructed"

# %%
dataset
# Out:
#                 DateTime       Source  \
# 0    2019-09-20 00:54:51    UrduPoint
# 236  ٹی ایم اے لاچی نے بڑے پیمانے پر صفائی مہم کا ا...   ur                1
# 237  ڈینگی کے خدشہ کے پیش نظر 3دکانداروں کے خلاف مق...   ur                1
# 238  افسران کے شہر میں صفائی ستھرائی اور ڈینگی سیمی...   ur                1
# 239  رواں سال بلوچستان کے تین اضلاع میں اب تک 1950 ...   ur                1
# 240  خیبر پختونخوا میں ڈینگی کے 55 نئے کیسز رپورٹ‘ ...   ur                1
# 241  انسداد ڈینگی مہم میں ڈپٹی کمشنر سرگودھا کا محک...   ur                1
# 242  ملک بھر میں ڈینگی سے متاثر افراد کی تعداد چوبی...   ur                1
# 243  سیکرٹری صحت کی زیر صدارت ، ڈینگی کی تازہ ترین ...   ur                1
# 244  فوزیہ نامی خاتون بے نظیر بھٹو اسپتال میں ڈینگی...   ur                1
# 245  پاکستان وآزادکشمیر کو ڈینگی وائر سے پاک بنائی...   ur                1
# 246  ڈینگی کا خاتمے کے لیے عملی اقداما ت نہیں اُٹھا...   ur                1
# 247  پمز میں ڈینگی کے 2000 مشتبہ مریضوں میں سے 200 ...   ur                1
# 248      صوبائی وزیر ملک اسد کھوکھر ڈینگی کا شکارہوگئے   ur                1
# 249  آر ڈبلیو ایم سی  کی جانب سے ڈینگی کیخلاف حفاظ...   ur                1
# 250  انسداد ڈینگی سرویلنس میں کوئی کوتاہی برداشت نہ...   ur                1
# 251  ڈی سی لاہور اصغر جوئیہ کی این ڈی بوائز ہائی سک...   ur                1
# 252  افسران ڈینگی سروئلنس، صفائی ستھرائی اور پرائس ...   ur                1
# 253  اے سی رائیونڈ عدنان بدر کا ڈینگی اور صفائی ستھ...   ur                1
# 254                  احتیاط سے ڈینگی سے بچا جا سکتا ہے   ur                1
# 255  سرویلنس ٹیمیں ڈینگی مچھر کی افزائش کے مقامات ک...   ur                1
# 256  انسداد ڈینگی مہم، کمرشل اداروں ‘دکانوں کی باقا...   ur                1
# 257  سوات:ضلعی انتظامیہ اور محکمہ صحت کی ناقص منصوب...   ur                1
# 258  اوکاڑہ،ڈسٹرکٹ انٹا مالوجسٹکا مارکیٹوں، مختلف ج...   ur                1
# 259  انسداد ڈینگی کی کارکردگی کا جائزہ لینے کے حوال...   ur                1
#
#            Label                                  preprocessed_text  km_label  \
# 0           CPEC  پیک منصوبہ ایم ایف شرائط عمل درآمد شروع امریکہ...         3
# 1           CPEC  حکومت پیک اکانامک زونز توجہ مرکوز رشکئی اکنامک...         4
# 2           CPEC  پیک کاموجودہ مرحلہ پاکستانی عوام کیلئے معاشی ف...         3
# 3           CPEC  وزیر اعلی خیبر پختونخوا محمود خان جمعہ روز چتر...         4
# 4           CPEC            غربت شرح کمی پیک مرحلے اہم ترجیحات شامل         3
# 5           CPEC            حکومت عوام ریلیف فراہمی عزم پیک اتھارٹی         3
# 6           CPEC  چین پاکستان اقتصادی راہداری منصوبہ مرحلہ غربت ...         3
# 7           CPEC  وزیر اعظم عمران خان دورہ چین ممالک مابین تعلقا...         4
# 8           CPEC              صدارتی آرڈیننس پیک اتھارٹی قائم فیصلہ         3
# 9           CPEC  خیبر پختونخوا حکومت متعلقہ محکموں ترقیاتی منصو...         4
# 10          CPEC  وزیراعظم عمران خان دورہ چین پیک منصوبوں اہم حس...         4
# 11          CPEC  چین پاکستان اقتصادی راہداری ملک انائی شدید بحر...         3
# 12          CPEC  وزیراعظم عمران خان دورہ چین چینی صدر بھارت شاہ...         4
# 13          CPEC  ض آر وفاقی حکومت سردمہری رویہ قابل افسوس سعید...         4
# 14          CPEC  خطے تنازع کوشش سعودیہ ایران غلط فہماں دور وزیر...         4
# 15          CPEC  پیک مرحلے تکمیل پاکستان بنیادی ڈھانچے بہتری آ...         4
# 16          CPEC  پیک بلوچستان اقتصادی زونز قیام مقامی صنعت ترقی...         3
# 17          CPEC  پیک بلوچستان تحصیل بوستان انڈسٹریل زون کام تیز...         5
# 18          CPEC  پیک متعلقہ منصوبوں ہزار پاکستانیوں روزگار ملا ...         3
# 19          CPEC    وزیراعظم پیک اتھارٹی چیئرپرسن مقرر آرڈیننس جاری         3
# 20          CPEC  احسن اقبال پیک اتھارٹی آرڈیننس قانون قرار دید...         3
# 21          CPEC  صدر مملکت عارف علوی پیک اتھارٹی آرڈیننس دستخط...         3
# 22          CPEC  پاکستان چین پیک معاشی و معاشی ترقی صنعتی انقلا...         4
# 23          CPEC  چین پاکستان قومی مفاد ایشو بھرپور تعاون یقین د...         4
# 24          CPEC  وفاقی حکومت سردمہری رویہ قابل افسوس سعید غنی پ...         4
# 25          CPEC  کراچی سرکولر ریلوے وفاقی حکومت سردمہری قابل اف...         4
# 26          CPEC  وفاقی حکومت پیک اتھارٹی صدارتی آرڈیننس جاری ش...         3
# 27          CPEC  پاکستان چین پیک اربوں ڈالر مالیت ایم ایل ون من...         4
# 28          CPEC  پاکستان چین قریبی دوست شراکت دار آہنی برادرز ...         4
# 29          CPEC  پیک مرحلے تکمیل روزگار مواقع پیدا مدد ملے حکام...         3
# ..           ...                                                ...       ...
# 230  DengueFever  سری لنکن آل راﺅنڈ ر تھیسارا پریرا دورہ پاکستان...         8
# 231  DengueFever  یو ای ٹی لاہورکے زیر اہتمام ڈینگی متعلق آگاہی ...         2
# 232  DengueFever  ٹی ایم لاچی بڑے پیمانے صفائی مہم آغاز علاقے ش...         5
# 233  DengueFever  مظفرآباد لچھراٹ ویلفئیر آرگنائزیشن آزادجموں...         6
# 234  DengueFever  ڈینگی خاتمہ بلدیات چیف افسران نکاسی آب صفائی ...         1
# 235  DengueFever  حکومت ڈینگی خاتمہ کیلئے ٹھوس عملی اقدامات کررہ...         2
# 236  DengueFever  ٹی ایم لاچی بڑے پیمانے صفائی مہم آغاز علاقے ش...         5
# 237  DengueFever            ڈینگی خدشہ پیش نظر دکانداروں مقدمات درج         2
# 238  DengueFever  افسران شہر صفائی ستھرائی ڈینگی سیمینار ڈینگی ا...         2
# 239  DengueFever  رواں سال بلوچستان تین اضلاع اب ڈینگی وائرس کیس...         9
# 240  DengueFever           خیبر پختونخوا ڈینگی نئے کیسز رپورٹ تعداد        10
# 241  DengueFever  انسداد ڈینگی مہم ڈپٹی کمشنر سرگودھا محکموں پاپ...        11
# 242  DengueFever       ملک ڈینگی متاثر افراد تعداد چوبیس ہزار تجاوز        10
# 243  DengueFever  سیکرٹری صحت زیر صدارت ڈینگی تازہ ترین حال بریف...        12
# 244  DengueFever  فوزیہ نامی خاتون نظیر بھٹو اسپتال ڈینگی وائرس ...         9
# 245  DengueFever  پاکستان وآزادکشمیر ڈینگی وائر پاک بنائیں ڈینگ...         2
# 246  DengueFever  ڈینگی خاتمے عملی اقداما ت اٹھائے شیخ عقیل الرح...         2
# 247  DengueFever    پمز ڈینگی مشتبہ مریضوں مریضوں ڈینگی وائرس تصدیق        10
# 248  DengueFever         صوبائی وزیر ملک اسد کھوکھر ڈینگی شکارہوگئے         2
# 249  DengueFever  آر ڈبلیو ایم جانب ڈینگی کیخلاف حفاظتی اقدامات...         2
# 250  DengueFever   انسداد ڈینگی سرویلنس کوتاہی برداشت سیکرٹری آرٹی        12
# 251  DengueFever  ڈی لاہور اصغر جوئیہ این ڈی بوائز ہائی سکول اچھ...         1
# 252  DengueFever  افسران ڈینگی سروئلنس صفائی ستھرائی پرائس چیکنگ...         1
# 253  DengueFever  رائیونڈ عدنان بدر ڈینگی صفائی ستھرائی چیک کیلئ...         2
# 254  DengueFever                                   احتیاط ڈینگی بچا         2
# 255  DengueFever  سرویلنس ٹیمیں ڈینگی مچھر افزائش مقامات بھرپور ...         1
# 256  DengueFever  انسداد ڈینگی مہم کمرشل اداروں دکانوں باقاعدگی ...        12
# 257  DengueFever  سوات ضلعی انتظامیہ محکمہ صحت ناقص منصوبہ بندی ...         9
# 258  DengueFever  اوکاڑہ ڈسٹرکٹ انٹا مالوجسٹکا مارکیٹوں مختلف جگ...         2
# 259  DengueFever  انسداد ڈینگی کار کردگی جائزہ لینے حوالہ اجلاس ...        12
#
#                                             NounChunks
# 0    [سی پیک منصوبہ ختم،آئی ایم ایف, شرائط پرعملدرآ...
# 1    [حکومت, سی پیک, تحت اکانامک زونز, توجہ, ہے‘ رش...
# 2    [سی پیک, کاموجودہ مرحلہ, پاکستانی عوام, معاشی ...
# 3    [وزیر, اعلیٰ خیبر پختونخوا محمود خان, جمعہ, رو...
# 4    [غربت, شرح, کمی, سی پیک, دوسرے مرحلے, اہم ترجی...
# 5    [حکومت عوام, ریلیف, فراہمی, لئے, عزم ہے،, سی پ...
# 6    [چین پاکستان, اقتصادی راہداری منصوبہ, دوسرے مر...
# 7    [وزیر اعظم عمران خان, دورہ چین, ممالک, مابین ت...
# 8       [صدارتی آرڈیننس, ذریعے, سی پیک اتھارٹی, فیصلہ]
# 9    [خیبرپختونخوا حکومت, متعلقہ محکموں, ترقیاتی من...
# 10   [وزیراعظم عمران خان, دورہ چین, سی پیک منصوبوں,...
# 11   [چین پاکستان, اقتصادی راہداری, ملک, توانائی, ش...
# 12   [وزیراعظم عمران خان, دورہ چین, بعد چینی صدر بھ...
# 13   [ض*کے, سی آر, وفاقی حکومت, سردمہری, رویہ, قاب...
# 14   [خطے, مزید تنازع, چاہتے، کوشش, سعودیہ, ایران, ...
# 15   [سی پیک, پہلے مرحلے, تکمیل, پاکستان, بنیادی ڈھ...
# 16   [سی پیک, تحت بلوچستان, اقتصادی زونز, قیام, مقا...
# 17   [سی پیک, تحت بلوچستان, تحصیل بوستان, انڈسٹریل ...
# 18   [سی پیک, متعلقہ منصوبوں میں70, پاکستانیوں, روز...
# 19   [وزیراعظم, سی پیک اتھارٹی, چیئرپرسن مقرر، آرڈی...
# 20   [احسن اقبال, سی پیک اتھارٹی, آرڈیننس, خلاف قا...
# 21   [صدر مملکت عارف علوی, سی پیک اتھارٹی آرڈیننس,...
# 22   [پاکستان, چین, سی پیک, معاشی ترقی،, صنعتی انقل...
# 23   [چین, پاکستان, قومی مفاد, ایشو, بھرپور تعاون, ...
# 24   [وفاقی حکومت, سردمہری, رویہ, قابل افسوس ہے،, س...
# 25   [کراچی سرکولر ریلوے, وفاقی حکومت, سردمہری قابل...
# 26   [وفاقی حکومت, سی پیک اتھارٹی بارے, صدارتی آرڈ...
# 27   [پاکستان, چین, سی پیک, تحت اربوں ڈالر مالیت, ا...
# 28   [پاکستان, چین, قریبی دوست، شراکت دار, آہنی بر...
# 29   [سی پیک, دوسرے مرحلے, تکمیل, روزگار, مواقع پید...
# ..                                                 ...
# 230  [سری لنکن آل راﺅنڈ ر تھیسارا پریرا, دورہ پاکست...
# 231  [یو ای ٹی لاہورکے زیر اہتمام ڈینگی, متعلق آگاہ...
# 232  [ٹی ایم اے لاچی, بڑے پیمانے, صفائی مہم, آغاز،...
# 233  [مظفرآباد،لچھراٹ ویلفئیر آرگنائزیشن آزادجمو...
# 234  [ڈینگی, خاتمہ, لئے بلدیات, چیف افسران نکاسی, ص...
# 235  [حکومت ڈینگی, مکمل خاتمہ, ٹھوس عملی اقدامات, خ...
# 236  [ٹی ایم اے لاچی, بڑے پیمانے, صفائی مہم, آغاز ...
# 237     [ڈینگی, خدشہ, پیش نظر 3دکانداروں, خلاف مقدمات]
# 238  [افسران, شہر, صفائی, ڈینگی سیمینار, ڈینگی انتظ...
# 239  [رواں سال بلوچستان, اضلاع, ڈینگی وائرس, کیسز ر...
# 240     [خیبر پختونخوا, ڈینگی, نئے کیسز, رپورٹ‘ تعداد]
# 241  [انسداد ڈینگی مہم, ڈپٹی کمشنر سرگودھا, محکموں ...
# 242            [ملک, ڈینگی, متاثر افراد, تعداد, تجاوز]
# 243  [سیکرٹری صحت, زیر صدارت, ڈینگی, تازہ ترین صورت...
# 244  [فوزیہ نامی خاتون بے, نظیر بھٹو اسپتال, ڈینگی ...
# 245  [پاکستان وآزادکشمیر, ڈینگی وائر, ،ڈینگی وائر,...
# 246  [ڈینگی, خاتمے, عملی اقداما ت, ہیں‘شیخ عقیل الر...
# 247  [پمز, ڈینگی, مشتبہ مریضوں, مریضوں, ڈینگی وائرس...
# 248      [صوبائی وزیر ملک اسد کھوکھر ڈینگی, شکارہوگئے]
# 249  [آر ڈبلیو ایم, جانب, ڈینگی کیخلاف, حفاظتی اقد...
# 250  [انسداد ڈینگی سرویلنس, کوتاہی برداشت, گی، سیکر...
# 251  [ڈی, سی لاہور اصغر جوئیہ, این ڈی بوائز ہائی سک...
# 252  [افسران ڈینگی, سروئلنس، صفائی, پرائس چیکنگ, عم...
# 253  [اے, سی رائیونڈ عدنان بدر, ڈینگی, صفائی, چیک, ...
# 254                                    [احتیاط, ڈینگی]
# 255  [سرویلنس ٹیمیں ڈینگی مچھر, افزائش, مقامات, بھر...
# 256  [انسداد ڈینگی مہم،, کمرشل اداروں ‘دکانوں, باقا...
# 257  [سوات:ضلعی انتظامیہ, محکمہ صحت, ناقص منصوبہ بن...
# 258  [اوکاڑہ،ڈسٹرکٹ انٹا مالوجسٹکا مارکیٹوں،, مختلف...
# 259  [انسداد ڈینگی, کارکردگی, جائزہ, حوالہ, اجلاس, ...
#
# [260 rows x 9 columns]

# %%
top_elements_topics = []
for i in range(0,kn.knee):
    hash_cluster1 = list_phrases_cluster(i,dataset,'km_label')
    top_elements_topics.append(hash_cluster1.most_common(10))

# %%
top_elements_topics
# Out:
# [[('ترکی', 5),
#   ('شام', 4),
#   ('فوجی کارروائی', 4),
#   ('ترک فوجی کارروائی', 3),
#   ('آغاز', 2),
#   ('سلامتی کونسل', 2),
#   ('مطالبہ', 2),
#   ('ترکی شام', 1),
#   ('کرد جنگجوؤں کیخلاف فوجی کارروائی', 1),
#   ('دے‘یورپی یونین', 1)],
#  [('ڈینگی', 7),
#   ('ڈی', 4),
#   ('مریضوں', 2),
#   ('مبتلا مریضوں', 2),
#   ('عیادت', 2),
#   ('آزادکشمیر', 2),
#   ('سی لاہور', 2),
#   ('سی خانیوال', 2),
#   ('کنگ عبدالله ہسپتال', 1),
#   ('بیڈ', 1)],
#  [('ڈینگی', 22),
#   ('قابو', 4),
#   ('انعقاد', 4),
#   ('ڈینگی مچھر', 3),
#   ('بچاؤ', 3),
#   ('بچائو', 2),
#   ('لئے', 2),
#   ('بچاؤ مہم', 2),
#   ('شہری حصہ', 2),
#   ('شہباز شاہین', 2)],
#  [('سی پیک اتھارٹی', 11),
#   ('سی پیک', 6),
#   ('غربت', 3),
#   ('صنعتی تعاون', 3),
#   ('گی، حکام', 3),
#   ('دوسرے مرحلہ', 2),
#   ('دوسرے مرحلے', 2),
#   ('لئے', 2),
#   ('چین پاکستان', 2),
#   ('مدد', 2)],
#  [('سی پیک', 15),
#   ('چین', 7),
#   ('پاکستان', 6),
#   ('...', 5),
#   ('دورہ چین', 4),
#   ('سی آر', 4),
#   ('وفاقی حکومت', 3),
#   ('گا،', 2),
#   ('وزیر اعظم عمران خان', 2),
#   ('وزیراعظم عمران خان', 2)],
#  [('ڈینگی', 5),
#   ('ضلعی انتظامیہ', 4),
#   ('رپورٹ', 3),
#   ('جاری کردی', 3),
#   ('انسداد ڈینگی', 2),
#   ('گزشتہ روز', 2),
#   ('صفائی', 2),
#   ('ٹی ایم اے لاچی', 2),
#   ('بڑے پیمانے', 2),
#   ('صفائی مہم', 2)],
#  [('ڈینگی', 3),
#   ('سندھ', 2),
#   ('رواں برس کانگو', 2),
#   ('افراد جان', 2),
#   ('بازی', 2),
#   ('اسلام آباد', 2),
#   ('مقبوضہ جموں کشمیر', 1),
#   ('مظلوموں', 1),
#   ('ساتھ اظہار یکجہتی', 1),
#   ('لئے (کل )اسلام آباد', 1)],
#  [('اظہار یکجہتی', 16),
#   ('کشمیریوں', 13),
#   ('ریلی', 12),
#   ('اظہار', 9),
#   ('انعقاد', 8),
#   ('مقبوضہ کشمیر', 3),
#   ('قیادت', 3),
#   ('کشمیری خواتین', 2),
#   ('ساتھ اظہار یکجہتی', 2),
#   ('کشمیری بھائیوں', 2)],
#  [('پاکستان', 8),
#   ('سری لنکن ٹیم', 6),
#   ('درمیان', 3),
#   ('کوچ', 3),
#   ('پاک سری لنکن ٹی ٹوئنٹی سیریز؛ ٹکٹوں', 2),
#   ('فروخت شروع', 2),
#   ('دورہ', 2),
#   ('پاک سری لنکن ٹی ٹونٹی کرکٹ سیریز', 2),
#   ('قذافی سٹیڈیم', 2),
#   ('سری لنکا', 2)],
#  [('ڈینگی', 9),
#   ('ڈینگی وائرس', 8),
#   ('...', 6),
#   ('عوام', 3),
#   ('کنٹرول', 3),
#   ('تصدیق', 2),
#   ('لئے', 2),
#   ('حوالے', 2),
#   ('مریضوں', 2),
#   ('عیادت', 2)],
#  [('ڈینگی', 11),
#   ('تعداد', 10),
#   ('مریضوں', 7),
#   ('پنجاب', 6),
#   ('گھنٹوں', 4),
#   ('تجاوز', 4),
#   ('ڈینگی مریضوں', 3),
#   ('راولپنڈی', 2),
#   ('پمز', 2),
#   ('اضافہ', 2)],
#  [('ڈینگی', 9),
#   ('ڈپٹی کمشنر', 6),
#   ('بچاؤ', 2),
#   ('حوالے', 2),
#   ('فرد', 2),
#   ('کردار ادا', 2),
#   ('وقت', 2),
#   ('مکمل خاتمہ', 2),
#   ('...', 2),
#   ('حد', 2)],
#  [('ڈینگی', 6),
#   ('زیر صدارت انسداد ڈینگی', 2),
#   ('حوالے', 2),
#   ('اہم اجلاس', 2),
#   ('انعقاد', 2),
#   ('صورتحال', 2),
#   ('اقدامات', 2),
#   ('جائزہ', 2),
#   ('وجہ', 2),
#   ('صورتحال قابو', 2)]]

# %%
# initializing list of lists 
test_list = top_elements_topics
single_list = []
for x in test_list:
    for u,v in x:
        single_list.append(u)
freq = collections.Counter(single_list)

# %%
freq
# Out:
# Counter({'ترکی': 1,
#          'شام': 1,
#          'فوجی کارروائی': 1,
#          'ترک فوجی کارروائی': 1,
#          'آغاز': 1,
#          'سلامتی کونسل': 1,
#          'مطالبہ': 1,
#          'ترکی شام': 1,
#          'کرد جنگجوؤں کیخلاف فوجی کارروائی': 1,
#          'دے‘یورپی یونین': 1,
#          'ڈینگی': 8,
#          'ڈی': 1,
#          'مریضوں': 3,
#          'مبتلا مریضوں': 1,
#          'عیادت': 2,
#          'آزادکشمیر': 1,
#          'سی لاہور': 1,
#          'سی خانیوال': 1,
#          'کنگ عبدالله ہسپتال': 1,
#          'بیڈ': 1,
#          'قابو': 1,
#          'انعقاد': 3,
#          'ڈینگی مچھر': 1,
#          'بچاؤ': 2,
#          'بچائو': 1,
#          'لئے': 3,
#          'بچاؤ مہم': 1,
#          'شہری حصہ': 1,
#          'شہباز شاہین': 1,
#          'سی پیک اتھارٹی': 1,
#          'سی پیک': 2,
#          'غربت': 1,
#          'صنعتی تعاون': 1,
#          'گی، حکام': 1,
#          'دوسرے مرحلہ': 1,
#          'دوسرے مرحلے': 1,
#          'چین پاکستان': 1,
#          'مدد': 1,
#          'چین': 1,
#          'پاکستان': 2,
#          '...': 3,
#          'دورہ چین': 1,
#          'سی آر': 1,
#          'وفاقی حکومت': 1,
#          'گا،': 1,
#          'وزیر اعظم عمران خان': 1,
#          'وزیراعظم عمران خان': 1,
#          'ضلعی انتظامیہ': 1,
#          'رپورٹ': 1,
#          'جاری کردی': 1,
#          'انسداد ڈینگی': 1,
#          'گزشتہ روز': 1,
#          'صفائی': 1,
#          'ٹی ایم اے لاچی': 1,
#          'بڑے پیمانے': 1,
#          'صفائی مہم': 1,
#          'سندھ': 1,
#          'رواں برس کانگو': 1,
#          'افراد جان': 1,
#          'بازی': 1,
#          'اسلام آباد': 1,
#          'مقبوضہ جموں کشمیر': 1,
#          'مظلوموں': 1,
#          'ساتھ اظہار یکجہتی': 2,
#          'لئے (کل )اسلام آباد': 1,
#          'اظہار یکجہتی': 1,
#          'کشمیریوں': 1,
#          'ریلی': 1,
#          'اظہار': 1,
#          'مقبوضہ کشمیر': 1,
#          'قیادت': 1,
#          'کشمیری خواتین': 1,
#          'کشمیری بھائیوں': 1,
#          'سری لنکن ٹیم': 1,
#          'درمیان': 1,
#          'کوچ': 1,
#          'پاک سری لنکن ٹی ٹوئنٹی سیریز؛ ٹکٹوں': 1,
#          'فروخت شروع': 1,
#          'دورہ': 1,
#          'پاک سری لنکن ٹی ٹونٹی کرکٹ سیریز': 1,
#          'قذافی سٹیڈیم': 1,
#          'سری لنکا': 1,
#          'ڈینگی وائرس': 1,
#          'عوام': 1,
#          'کنٹرول': 1,
#          'تصدیق': 1,
#          'حوالے': 3,
#          'تعداد': 1,
#          'پنجاب': 1,
#          'گھنٹوں': 1,
#          'تجاوز': 1,
#          'ڈینگی مریضوں': 1,
#          'راولپنڈی': 1,
#          'پمز': 1,
#          'اضافہ': 1,
#          'ڈپٹی کمشنر': 1,
#          'فرد': 1,
#          'کردار ادا': 1,
#          'وقت': 1,
#          'مکمل خاتمہ': 1,
#          'حد': 1,
#          'زیر صدارت انسداد ڈینگی': 1,
#          'اہم اجلاس': 1,
#          'صورتحال': 1,
#          'اقدامات': 1,
#          'جائزہ': 1,
#          'وجہ': 1,
#          'صورتحال قابو': 1})

# %%
common_element=[]
for u,v in freq.items():
    if v>1:
        common_element.append(u)
common_element
# Out:
# ['ڈینگی',
#  'مریضوں',
#  'عیادت',
#  'انعقاد',
#  'بچاؤ',
#  'لئے',
#  'سی پیک',
#  'پاکستان',
#  '...',
#  'ساتھ اظہار یکجہتی',
#  'حوالے']

# %%
new_top_elements_topics = []
for top10_in_topic in top_elements_topics:
    new_list_topic = []
    for u,v in top10_in_topic:
        if u not in common_element:
            new_list_topic.append((u,v))
    new_top_elements_topics.append(new_list_topic)

# %%
new_top_elements_topics[12]
# Out:
# [('زیر صدارت انسداد ڈینگی', 2),
#  ('اہم اجلاس', 2),
#  ('صورتحال', 2),
#  ('اقدامات', 2),
#  ('جائزہ', 2),
#  ('وجہ', 2),
#  ('صورتحال قابو', 2)]

# %%
top_elements_topics[12]
# Out:
# [('ڈینگی', 6),
#  ('زیر صدارت انسداد ڈینگی', 2),
#  ('حوالے', 2),
#  ('اہم اجلاس', 2),
#  ('انعقاد', 2),
#  ('صورتحال', 2),
#  ('اقدامات', 2),
#  ('جائزہ', 2),
#  ('وجہ', 2),
#  ('صورتحال قابو', 2)]

# %%
labels=[]
for i in range(0,kn.knee):
    labels.append(return_clusters_title(i,dataset,'km_label'))
# Out:
#                       term      rank  wCount
# 238           شام میں فوجی  0.399441       3
# 423      میں فوجی کارروائی  0.399441       3
# 239  شام میں فوجی کارروائی  0.399441       4
# 334       فوجی کارروائی کا  0.356475       3
# 569        کارروائی کا غاز  0.356475       3
#                     term      rank  wCount
# 953          ڈی سی لاہور  0.333053       3
# 751         میں ڈینگی کے  0.274766       3
# 401        سی لاہور اصغر  0.198980       3
# 572     لاہور اصغر جوئیہ  0.198980       3
# 402  سی لاہور اصغر جوئیہ  0.198980       4
#                term      rank  wCount
# 2755  ڈینگی سے بچاؤ  0.437364       3
# 516    بچاؤ مہم میں  0.321283       3
# 819    حصہ لے شہباز  0.321283       3
# 1374    سے بچاؤ مہم  0.321283       3
# 1527    شہری حصہ لے  0.321283       3
#                      term      rank  wCount
# 433        سی پیک اتھارٹی  0.609845       3
# 238           حکام سی پیک  0.372439       3
# 239   حکام سی پیک اتھارٹی  0.372439       4
# 1074       پیک اتھارٹی کے  0.239567       3
# 457     سی پیک اتھارٹی کے  0.239567       4
#                term      rank  wCount
# 1068      سی پیک کے  0.323730       3
# 2090     چین سی پیک  0.218732       3
# 1029      سی پیک پر  0.217546       3
# 2020     پیک کے تحت  0.192714       3
# 1069  سی پیک کے تحت  0.192714       4
#                    term      rank  wCount
# 402    ضلعی انتظامیہ نے  0.410946       3
# 257     رپورٹ جاری کردی  0.403145       3
# 874       کی رپورٹ جاری  0.403145       3
# 875  کی رپورٹ جاری کردی  0.403145       4
# 37    انتظامیہ نے ڈینگی  0.394274       3
#               term     rank  wCount
# 161  باد میں ڈینگی  0.20799       3
# 0      13 ڈینگی سے  0.19518       3
# 6    18 نگلیریا سے  0.19518       3
# 58    افراد جان کی  0.19518       3
# 175   بازی ہار چکے  0.19518       3
#                           term      rank  wCount
# 736            سے اظہار یکجہتی  0.986678       3
# 1770         کشمیریوں سے اظہار  0.904005       3
# 1771  کشمیریوں سے اظہار یکجہتی  0.904005       4
# 97          اظہار یکجہتی کیلئے  0.755323       3
# 768      سے اظہار یکجہتی کیلئے  0.627716       4
#                  term      rank  wCount
# 650      سری لنکن ٹیم  0.548829       3
# 633       سری لنکن ٹی  0.459467       3
# 1559     پاک سری لنکن  0.459467       3
# 1560  پاک سری لنکن ٹی  0.459467       4
# 1422  ٹی ٹوئنٹی سیریز  0.380523       3
#                  term      rank  wCount
# 1836  میں ڈینگی وائرس  0.367520       3
# 2443   ڈینگی وائرس کے  0.243535       3
# 339     بھر میں ڈینگی  0.191952       3
# 2013   وائرس کی تصدیق  0.187029       3
# 2439   ڈینگی وائرس کی  0.187029       3
#                  term      rank  wCount
# 695   مریضوں کی تعداد  0.458951       3
# 910      میں ڈینگی کے  0.445279       3
# 1084    ڈینگی بے قابو  0.438706       3
# 1492    ہزار سے تجاوز  0.385276       3
# 1157  ڈینگی کے مریضوں  0.341174       3
#                 term      rank  wCount
# 1849   ہے ڈپٹی کمشنر  0.306955       3
# 44     ادا نہیں کرتا  0.199268       3
# 52         اس وقت تک  0.199268       3
# 219   اپنا کردار ادا  0.199268       3
# 363      تک ڈینگی کا  0.199268       3
#                         term      rank  wCount
# 1109            کی زیر صدارت  0.325577       3
# 383         زیر صدارت انسداد  0.303766       3
# 585       صدارت انسداد ڈینگی  0.303766       3
# 384   زیر صدارت انسداد ڈینگی  0.303766       4
# 1110     کی زیر صدارت انسداد  0.303766       4

# %%
labels
# Out:
# ['ترکی کی شام میں فوجی کارروائی',
#  'ڈینگی کے مریضوں',
#  'انعقاد احتیاطی تدابیر اپنا کر ڈینگی پر قابو',
#  'No title constructed',
#  'پاکستان اور چین سی پیک',
#  'ضلعی انتظامیہ نے ڈینگی کی رپورٹ',
#  'سندھ میں رواں برس کانگو سے 18 نگلیریا سے 13 ڈینگی',
#  'کشمیریوں سے اظہار یکجہتی کیلئے ریلی',
#  'پاکستان اور سری لنکن کی کرکٹ ٹیموں کے درمیان',
#  'No title constructed',
#  'ڈینگی کے مریضوں کی تعداد',
#  'ڈپٹی کمشنر جہلم محمد سیف انور جپہ کی زیر صدارت ڈینگی سے بچاؤ',
#  'زیر صدارت انسداد ڈینگی کے حوالے']

# %%
labels
# Out:
# ['ترکی کی شام میں فوجی کارروائی',
#  'ڈینگی کے مریضوں',
#  'No title constructed',
#  'No title constructed',
#  'پاکستان اور چین سی پیک',
#  'ضلعی انتظامیہ نے ڈینگی کی رپورٹ',
#  'No title constructed',
#  'کشمیریوں سے اظہار یکجہتی کیلئے ریلی',
#  'No title constructed',
#  'No title constructed',
#  'ڈینگی کے مریضوں کی تعداد',
#  'No title constructed',
#  'زیر صدارت انسداد ڈینگی کے حوالے']

# %%
labels
# Out:
# ['ترکی کی شام میں فوجی کارروائی',
#  'ڈینگی کے مریضوں',
#  'انعقاد احتیاطی تدابیر اپنا کر ڈینگی پر قابو',
#  'No title constructed',
#  'پاکستان اور چین سی پیک',
#  'ضلعی انتظامیہ نے ڈینگی کی رپورٹ',
#  'No title constructed',
#  'کشمیریوں سے اظہار یکجہتی کیلئے ریلی',
#  'No title constructed',
#  'No title constructed',
#  'ڈینگی کے مریضوں کی تعداد',
#  'No title constructed',
#  'زیر صدارت انسداد ڈینگی کے حوالے']
