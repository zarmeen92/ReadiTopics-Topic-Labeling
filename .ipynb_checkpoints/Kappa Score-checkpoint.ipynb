# %%
from sklearn.metrics import cohen_kappa_score
import pandas as pd
import sklearn

# %%
a = ['cat','dog']
b=['cat is','dog is']

# %%
data = pd.read_csv('all_labels_comparison.csv',sep='\t',encoding='utf-8')

# %%
cohen_kappa_score(data['M-Order'],data.ProposedMethod)
# Out:
# 0.0714285714285714

# %%
labels_zainab = ['ترکی کی شام میں فوجی کاروائی','ڈینگی کے حوالے سے ڈی سی لاہور کے دورے','ڈینگی سے احتیاط','سی پیک سے روزگار کے مواقع','سی پیک','ضلعی انتظامیہ نے ڈینگی رپورٹ جاری کردی','ڈینگی کیسز سامنے آنے کے بعد مقدمات درج','کشمیریوں سے اظہار یکجہتی','پاکستان اور سری لنکا کے درمیان کرکٹ سیریز','ڈینگی کیسز میں اضافہ','ڈینگی مریضوں کی تعداد میں اضافہ','ڈینگی کے خاتمے کیلۓ احتیاطی تدابیر','ڈینگی کی تازہ صورتحال کا جائزہ']

# %%
labels_farah = ['ترکی شام کاروائی','لاہور میں ڈینگی','ڈینگی کی احیتاط','سی پیک کا قیام','سی پیک','ضلعی انتظامیہ','فیصل آباد میں ڈینگی','اظہار یکجہتی کیلئے ریلی','سری لنکن ٹیم','ڈینگی وائرس کی روک تھام','ڈینگی بے قابو','ڈینگی کا خاتمہ','ڈینگی کی تازہ ترین صورتحال']

# %%
for x in labels_zainab:
    print(x)
# Out:
# ترکی کی شام میں فوجی کاروائی
# ڈینگی کے حوالے سے ڈی سی لاہور کے دورے
# ڈینگی سے احتیاط
# سی پیک سے روزگار کے مواقع
# سی پیک
# ضلعی انتظامیہ نے ڈینگی رپورٹ جاری کردی
# ڈینگی کیسز سامنے آنے کے بعد مقدمات درج
# کشمیریوں سے اظہار یکجہتی
# پاکستان اور سری لنکا کے درمیان کرکٹ سیریز
# ڈینگی کیسز میں اضافہ
# ڈینگی مریضوں کی تعداد میں اضافہ
# ڈینگی کے خاتمے کیلۓ احتیاطی تدابیر
# ڈینگی کی تازہ صورتحال کا جائزہ

# %%
data['Farah'] = labels_farah

# %%
data['Zainab'] = labels_zainab

# %%
data
# Out:
#     Cluster                                Zero-Order  \
# 0         0                                  ترکی شام
# 1         1     ڈی ایچ کیو ہسپتال وہاڑی کادورہ ہسپتال
# 2         2                                ڈینگی مچھر
# 3         3                       سی پیک اتھارٹی بارے
# 4         4                        وزیراعظم عمران خان
# 5         5                       ضلعی انتظامیہ لاہور
# 6         6                          پریشان عمران خان
# 7         7           کشمیری عوام کیساتھ اظہار یکجہتی
# 8         8  پاک سری لنکن ٹی ٹونٹی کرکٹ سیریز سکیورٹی
# 9         9                     محکمہ صحت ڈینگی وائرس
# 10       10                             خیبر پختونخوا
# 11       11              ڈپٹی کمشنر محمد سیف انور جپہ
# 12       12                    زیر صدارت انسداد ڈینگی
#
#                                   M-Order  \
# 0                       ترک فوجی کارروائی
# 1   ڈی ایچ کیو ہسپتال وہاڑی کادورہ ہسپتال
# 2                  سی ای او ہیلتھ خانیوال
# ...

# %%
data.to_csv('labels_with_human.csv',sep='\t',encoding='utf-8')
