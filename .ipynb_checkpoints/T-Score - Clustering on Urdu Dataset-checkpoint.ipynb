# %%
import re
from ast import literal_eval
import numpy as np
import pandas as pd
from pprint import pprint
import collections
import math
# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
#scipy
import scipy 
from sklearn.cluster import KMeans
# spacy for lemmatization
import spacy
from urduhack.preprocess import remove_punctuation

from urduhack import stop_words
from urduhack import tokenization as tok
from urduhack import preprocess
from urduhack import utils
from urduhack import normalization as norm
from utilities import words as urduwords
from urduhack import stop_words
from sklearn import metrics
import os
from kneed import KneeLocator
from sklearn.datasets import fetch_20newsgroups
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
import CRFTagger
# NLTK Stop words
# Extract noun chunks from corpus
import spacy
import math
nlp = spacy.load('en_core_web_sm')
stopwords = list(stop_words.STOP_WORDS)

# %%
dataset = pd.read_csv('urduNewsHeadlines-clusteringDS.csv',encoding='utf-8',sep='\t')

# %%
dataset.shape

# %%
def purity_score(y_true, y_pred):
    # compute contingency matrix (also called confusion matrix)
    contingency_matrix = metrics.cluster.contingency_matrix(y_true, y_pred)
    # return purity
    return np.sum(np.amax(contingency_matrix, axis=0)) / np.sum(contingency_matrix) 

# Tokenize and lemmatize
def preprocess_func(text):
    text = text.replace('\n'," ")
    text = text.replace('\r'," ")
    text = preprocess.normalize_whitespace(text)
    text = preprocess.remove_punctuation(text)
    text = norm.remove_diacritics(text)
    text = urduwords.fix_join_words(text)
    text = re.sub(r"http\S+", "", text)
    text = re.sub('@[^\s]+','',text)
    nonalpha = re.compile(r"[a-zA-Z0-9.@#_:)(-]")
    text = re.sub(nonalpha,'',text).strip()#remove english alphabets
    wordsC = text.split()
    non_stops = [w for w in wordsC if w not in stopwords]
    cleanText = " ".join(non_stops)
    return cleanText 

    return cleanText
            
def candidate_label_lemmatized(label):
    w_labels = label.split()
    lemmatized = lemmatization(w_labels)
    return " ".join(lemmatized)

def news_group_target_names(k):
    return newsgroups_train.target_names[k]
def return_preprocessed_text(words):
    x = literal_eval(words)
    return " ".join(x)
def get_pd_of_cluster(dataset,cluster_idx):
    dataset_sub = dataset[dataset['km_label'] == cluster_idx]
    cnt = CountVectorizer()
    voc = cnt.fit_transform(dataset_sub.preprocessed_text)
    vocab = list(cnt.get_feature_names())
    counts = voc.sum(axis=0).A1
    freq_distribution = Counter(dict(zip(vocab, counts)))
    prob = {}
    for w in vocab:
        prob[w] = freq_distribution[w]/np.sum(counts)
    return prob
def get_words_from_tags(postags):
    words = []
    tags = []
    for u,v in postags:
        words.append(u)
        tags.append(v)
    return words,tags
def pos_regex_matches(doc, pattern,tgs):
    """
    Extract sequences of consecutive tokens from a spacy-parsed doc whose
    part-of-speech tags match the specified regex pattern.

    Args:
        doc (``textacy.Doc`` or ``spacy.Doc`` or ``spacy.Span``)
        pattern (str): Pattern of consecutive POS tags whose corresponding words
            are to be extracted, inspired by the regex patterns used in NLTK's
            `nltk.chunk.regexp`. Tags are uppercase, from the universal tag set;
            delimited by < and >, which are basically converted to parentheses
            with spaces as needed to correctly extract matching word sequences;
            white space in the input doesn't matter.

            Examples (see ``constants.POS_REGEX_PATTERNS``):

            * noun phrase: r'<DET>? (<NOUN>+ <ADP|CONJ>)* <NOUN>+'
            * compound nouns: r'<NOUN>+'
            * verb phrase: r'<VERB>?<ADV>*<VERB>+'
            * prepositional phrase: r'<PREP> <DET>? (<NOUN>+<ADP>)* <NOUN>+'

    Yields:
        ``spacy.Span``: the next span of consecutive tokens from ``doc`` whose
        parts-of-speech match ``pattern``, in order of apperance
    """
    # standardize and transform the regular expression pattern...
    pattern = re.sub(r'\s', '', pattern)
    pattern = re.sub(r'<([A-Z]+)\|([A-Z]+)>', r'( (\1|\2))', pattern)
    pattern = re.sub(r'<([A-Z]+)>', r'( \1)', pattern)

    tags = ' ' + ' '.join(tgs)

    for m in re.finditer(pattern, tags):
        yield doc[tags[0:m.start()].count(' '):tags[0:m.end()].count(' ')]

def filter_noun_adj_from_phrase(sent):
    noun_phrases = []
    nonalpha = re.compile(r"[a-zA-Z0-9.@#_:)(-،‘]")
    sent = re.sub(nonalpha,'',sent).strip()#remove english alphabets
    tags = CRFTagger.pos_tag(sent)
    words,tgs = get_words_from_tags(tags)
    print(words)
    print(tgs)
    patern = r'<ADJ|A>*<NN|PN>+'
    lists = pos_regex_matches(words, patern,tgs)
    for j in lists:
        noun_phrases.append(" ".join(j))
  
    return noun_phrases

# %%
document_num = 50
doc_sample = dataset.iloc[document_num].Title

print("Original document: ")
words = []
for word in doc_sample.split(' '):
    words.append(word)
print(words)
print("\n\nTokenized and lemmatized document: ")
print(preprocess_func(doc_sample))

# %%
dataset['preprocessed_text'] = dataset['Title'].apply(preprocess_func)

# %%
dataset['NounChunks'] = dataset['Title'].apply(filter_noun_adj_from_phrase)

# %%
dataset
# Out:
#                 DateTime       Source  \
# 0    2019-09-20 00:54:51    UrduPoint
# 1    2019-09-20 05:45:20    UrduPoint
# 2    2019-09-20 18:53:21    UrduPoint
# 3    2019-09-21 09:28:12    UrduPoint
# 4    2019-09-23 06:40:21    UrduPoint
# 5    2019-09-23 06:40:21    UrduPoint
# 6    2019-09-24 06:20:17    UrduPoint
# 7    2019-10-07 11:01:26    UrduPoint
# 8    2019-10-07 11:08:21  ExpressNews
# 9    2019-10-07 15:09:59    UrduPoint
# 10   2019-10-07 15:52:35    UrduPoint
# 11   2019-10-07 15:52:35    UrduPoint
# 12   2019-10-07 16:39:41    UrduPoint
# 13   2019-10-07 17:05:18    UrduPoint
# 14   2019-10-07 18:09:03    UrduPoint
# 15   2019-10-08 06:40:10    UrduPoint
# 16   2019-10-08 06:40:10    UrduPoint
# 17   2019-10-08 07:08:35    UrduPoint
# 18   2019-10-08 07:08:36    UrduPoint
# 19   2019-10-08 07:20:52  ExpressNews
# 20   2019-10-08 09:39:20    UrduPoint
# 21   2019-10-08 09:39:21    UrduPoint
# 22   2019-10-08 13:42:49    UrduPoint
# 23   2019-10-08 14:49:21    UrduPoint
# 24   2019-10-08 15:40:54    UrduPoint
# 25   2019-10-08 15:59:06    UrduPoint
# 26   2019-10-08 16:43:10    UrduPoint
# 27   2019-10-09 14:28:52    UrduPoint
# 28   2019-10-09 14:30:33    UrduPoint
# 29   2019-10-10 09:31:52    UrduPoint
# ..                   ...          ...
# 230  2019-10-09 12:33:16    UrduPoint
# 231  2019-10-09 12:45:56    UrduPoint
# 232  2019-10-09 13:52:07    UrduPoint
# 233  2019-10-09 13:54:53    UrduPoint
# 234  2019-10-09 14:25:44    UrduPoint
# 235  2019-10-09 14:30:34    UrduPoint
# 236  2019-10-09 14:45:48    UrduPoint
# 237  2019-10-09 14:57:16    UrduPoint
# 238  2019-10-09 15:14:25    UrduPoint
# 239  2019-10-09 17:00:35    UrduPoint
# 240  2019-10-10 07:11:26    UrduPoint
# 241  2019-10-10 08:24:36    UrduPoint
# 242  2019-10-10 08:52:11    UrduPoint
# 243  2019-10-10 08:52:11    UrduPoint
# 244  2019-10-10 08:52:11    UrduPoint
# 245  2019-10-10 09:52:09    UrduPoint
# 246  2019-10-10 09:52:12    UrduPoint
# 247  2019-10-10 12:29:12    UrduPoint
# 248  2019-10-10 12:45:23    UrduPoint
# 249  2019-10-10 12:49:26    UrduPoint
# 250  2019-10-10 13:31:15    UrduPoint
# 251  2019-10-10 13:35:04    UrduPoint
# 252  2019-10-10 13:35:04    UrduPoint
# 253  2019-10-10 13:37:07    UrduPoint
# 254  2019-10-10 13:49:13    UrduPoint
# 255  2019-10-10 14:12:00    UrduPoint
# 256  2019-10-10 14:52:48    UrduPoint
# 257  2019-10-10 16:59:47    UrduPoint
# 258  2019-10-10 18:09:47    UrduPoint
# 259  2019-10-10 18:10:50    UrduPoint
#
#                                                  Title lang  search_keywords  \
# 0    سی پیک منصوبہ ختم،آئی ایم ایف کی شرائط پرعملدر...   ur                1
# 1    حکومت نے سی پیک کے تحت اکانامک زونز پر توجہ مر...   ur                1
# 2    سی پیک کاموجودہ مرحلہ پاکستانی عوام کیلئے معاش...   ur                1
# 3    وزیر اعلیٰ خیبر پختونخوا محمود خان کا جمعہ کے ...   ur                1
# 4    غربت کی شرح میں کمی  سی پیک دوسرے مرحلے کی اہم...   ur                1
# 5    حکومت عوام کو ریلیف کی فراہمی کے لئے پر عزم ہے...   ur                1
# 6    چین پاکستان اقتصادی راہداری منصوبہ کے دوسرے مر...   ur                1
# 7    وزیر اعظم عمران خان کے دورہ چین سے دونوں ممالک...   ur                1
# 8    صدارتی آرڈیننس کے ذریعے سی پیک اتھارٹی قائم کر...   ur                1
# 9    خیبرپختونخوا حکومت کی تمام متعلقہ محکموں کو تر...   ur                1
# 10   وزیراعظم عمران خان کا دورہ چین سی پیک منصوبوں ...   ur                1
# 11   چین پاکستان اقتصادی راہداری سے ملک میں توانائی...   ur                1
# 12   وزیراعظم عمران خان کے دورہ چین کے بعد چینی صدر...   ur                1
# 13   ض*کے سی آر پر وفاقی حکومت کی سردمہری اور ان ک...   ur                1
# 14   خطے میں مزید تنازع نہیں چاہتے، کوشش ہے سعودیہ ...   ur                1
# 15   سی پیک کے پہلے مرحلے کی تکمیل سے پاکستان میں ب...   ur                1
# 16   سی پیک سے کے تحت بلوچستان میں اقتصادی زونز کے ...   ur                1
# 17   سی پیک کے تحت بلوچستان کی تحصیل بوستان میں انڈ...   ur                1
# 18   سی پیک سے متعلقہ منصوبوں میں70 ہزار پاکستانیوں...   ur                1
# 19   وزیراعظم سی پیک اتھارٹی کے چیئرپرسن مقرر، آرڈی...   ur                1
# 20   احسن اقبال نے سی پیک اتھارٹی کے آرڈیننس کو خل...   ur                1
# 21   صدر مملکت عارف علوی نے سی پیک اتھارٹی آرڈیننس...   ur                1
# 22   پاکستان اور چین سی پیک کو معاشی و معاشی ترقی، ...   ur                1
# 23   چین کی پاکستان کو قومی مفاد کے ایشو میں بھرپور...   ur                1
# 24   وفاقی حکومت کی سردمہری اور ان کا رویہ قابل افس...   ur                1
# 25   کراچی سرکولر ریلوے پر وفاقی حکومت کی سردمہری ق...   ur                1
# 26   وفاقی حکومت نے سی پیک اتھارٹی  بارے صدارتی آر...   ur                1
# 27   پاکستان اور چین نے سی پیک کے تحت اربوں ڈالر ما...   ur                1
# 28   پاکستان اور چین قریبی دوست، شراکت دار اور آہن...   ur                1
# 29   سی پیک کے دوسرے مرحلے کی تکمیل سے روزگار کے مو...   ur                1
# ..                                                 ...  ...              ...
# 230  سری لنکن آل راﺅنڈ ر تھیسارا پریرا نے دورہ پاکس...   ur                1
# 231  یو ای ٹی لاہورکے زیر اہتمام ڈینگی سے متعلق آگا...   ur                1
# 232  ٹی ایم اے لاچی کا بڑے پیمانے پر صفائی مہم کا ا...   ur                1
# 233  مظفرآباد،لچھراٹ ویلفئیر آرگنائزیشن آزادجموں...   ur                1
# 234  ڈینگی کے خاتمہ کے لئے بلدیات کے چیف افسران نکا...   ur                1
# 235  حکومت ڈینگی کے مکمل خاتمہ کیلئے ٹھوس عملی اقدا...   ur                1
# 236  ٹی ایم اے لاچی نے بڑے پیمانے پر صفائی مہم کا ا...   ur                1
# 237  ڈینگی کے خدشہ کے پیش نظر 3دکانداروں کے خلاف مق...   ur                1
# 238  افسران کے شہر میں صفائی ستھرائی اور ڈینگی سیمی...   ur                1
# 239  رواں سال بلوچستان کے تین اضلاع میں اب تک 1950 ...   ur                1
# 240  خیبر پختونخوا میں ڈینگی کے 55 نئے کیسز رپورٹ‘ ...   ur                1
# 241  انسداد ڈینگی مہم میں ڈپٹی کمشنر سرگودھا کا محک...   ur                1
# 242  ملک بھر میں ڈینگی سے متاثر افراد کی تعداد چوبی...   ur                1
# 243  سیکرٹری صحت کی زیر صدارت ، ڈینگی کی تازہ ترین ...   ur                1
# 244  فوزیہ نامی خاتون بے نظیر بھٹو اسپتال میں ڈینگی...   ur                1
# 245  پاکستان وآزادکشمیر کو ڈینگی وائر سے پاک بنائی...   ur                1
# 246  ڈینگی کا خاتمے کے لیے عملی اقداما ت نہیں اُٹھا...   ur                1
# 247  پمز میں ڈینگی کے 2000 مشتبہ مریضوں میں سے 200 ...   ur                1
# 248      صوبائی وزیر ملک اسد کھوکھر ڈینگی کا شکارہوگئے   ur                1
# 249  آر ڈبلیو ایم سی  کی جانب سے ڈینگی کیخلاف حفاظ...   ur                1
# 250  انسداد ڈینگی سرویلنس میں کوئی کوتاہی برداشت نہ...   ur                1
# 251  ڈی سی لاہور اصغر جوئیہ کی این ڈی بوائز ہائی سک...   ur                1
# 252  افسران ڈینگی سروئلنس، صفائی ستھرائی اور پرائس ...   ur                1
# 253  اے سی رائیونڈ عدنان بدر کا ڈینگی اور صفائی ستھ...   ur                1
# 254                  احتیاط سے ڈینگی سے بچا جا سکتا ہے   ur                1
# 255  سرویلنس ٹیمیں ڈینگی مچھر کی افزائش کے مقامات ک...   ur                1
# 256  انسداد ڈینگی مہم، کمرشل اداروں ‘دکانوں کی باقا...   ur                1
# 257  سوات:ضلعی انتظامیہ اور محکمہ صحت کی ناقص منصوب...   ur                1
# 258  اوکاڑہ،ڈسٹرکٹ انٹا مالوجسٹکا مارکیٹوں، مختلف ج...   ur                1
# 259  انسداد ڈینگی کی کارکردگی کا جائزہ لینے کے حوال...   ur                1
#
#            Label                                  preprocessed_text  \
# 0           CPEC  پیک منصوبہ ایم ایف شرائط عمل درآمد شروع امریکہ...
# 1           CPEC  حکومت پیک اکانامک زونز توجہ مرکوز رشکئی اکنامک...
# 2           CPEC  پیک کاموجودہ مرحلہ پاکستانی عوام کیلئے معاشی ف...
# 3           CPEC  وزیر اعلی خیبر پختونخوا محمود خان جمعہ روز چتر...
# 4           CPEC            غربت شرح کمی پیک مرحلے اہم ترجیحات شامل
# 5           CPEC            حکومت عوام ریلیف فراہمی عزم پیک اتھارٹی
# 6           CPEC  چین پاکستان اقتصادی راہداری منصوبہ مرحلہ غربت ...
# 7           CPEC  وزیر اعظم عمران خان دورہ چین ممالک مابین تعلقا...
# 8           CPEC              صدارتی آرڈیننس پیک اتھارٹی قائم فیصلہ
# 9           CPEC  خیبر پختونخوا حکومت متعلقہ محکموں ترقیاتی منصو...
# 10          CPEC  وزیراعظم عمران خان دورہ چین پیک منصوبوں اہم حس...
# 11          CPEC  چین پاکستان اقتصادی راہداری ملک انائی شدید بحر...
# 12          CPEC  وزیراعظم عمران خان دورہ چین چینی صدر بھارت شاہ...
# 13          CPEC  ض آر وفاقی حکومت سردمہری رویہ قابل افسوس سعید...
# 14          CPEC  خطے تنازع کوشش سعودیہ ایران غلط فہماں دور وزیر...
# 15          CPEC  پیک مرحلے تکمیل پاکستان بنیادی ڈھانچے بہتری آ...
# 16          CPEC  پیک بلوچستان اقتصادی زونز قیام مقامی صنعت ترقی...
# 17          CPEC  پیک بلوچستان تحصیل بوستان انڈسٹریل زون کام تیز...
# 18          CPEC  پیک متعلقہ منصوبوں ہزار پاکستانیوں روزگار ملا ...
# 19          CPEC    وزیراعظم پیک اتھارٹی چیئرپرسن مقرر آرڈیننس جاری
# 20          CPEC  احسن اقبال پیک اتھارٹی آرڈیننس قانون قرار دید...
# 21          CPEC  صدر مملکت عارف علوی پیک اتھارٹی آرڈیننس دستخط...
# 22          CPEC  پاکستان چین پیک معاشی و معاشی ترقی صنعتی انقلا...
# 23          CPEC  چین پاکستان قومی مفاد ایشو بھرپور تعاون یقین د...
# 24          CPEC  وفاقی حکومت سردمہری رویہ قابل افسوس سعید غنی پ...
# 25          CPEC  کراچی سرکولر ریلوے وفاقی حکومت سردمہری قابل اف...
# 26          CPEC  وفاقی حکومت پیک اتھارٹی صدارتی آرڈیننس جاری ش...
# 27          CPEC  پاکستان چین پیک اربوں ڈالر مالیت ایم ایل ون من...
# 28          CPEC  پاکستان چین قریبی دوست شراکت دار آہنی برادرز ...
# 29          CPEC  پیک مرحلے تکمیل روزگار مواقع پیدا مدد ملے حکام...
# ..           ...                                                ...
# 230  DengueFever  سری لنکن آل راﺅنڈ ر تھیسارا پریرا دورہ پاکستان...
# 231  DengueFever  یو ای ٹی لاہورکے زیر اہتمام ڈینگی متعلق آگاہی ...
# 232  DengueFever  ٹی ایم لاچی بڑے پیمانے صفائی مہم آغاز علاقے ش...
# 233  DengueFever  مظفرآباد لچھراٹ ویلفئیر آرگنائزیشن آزادجموں...
# 234  DengueFever  ڈینگی خاتمہ بلدیات چیف افسران نکاسی آب صفائی ...
# 235  DengueFever  حکومت ڈینگی خاتمہ کیلئے ٹھوس عملی اقدامات کررہ...
# 236  DengueFever  ٹی ایم لاچی بڑے پیمانے صفائی مہم آغاز علاقے ش...
# 237  DengueFever            ڈینگی خدشہ پیش نظر دکانداروں مقدمات درج
# 238  DengueFever  افسران شہر صفائی ستھرائی ڈینگی سیمینار ڈینگی ا...
# 239  DengueFever  رواں سال بلوچستان تین اضلاع اب ڈینگی وائرس کیس...
# 240  DengueFever           خیبر پختونخوا ڈینگی نئے کیسز رپورٹ تعداد
# 241  DengueFever  انسداد ڈینگی مہم ڈپٹی کمشنر سرگودھا محکموں پاپ...
# 242  DengueFever       ملک ڈینگی متاثر افراد تعداد چوبیس ہزار تجاوز
# 243  DengueFever  سیکرٹری صحت زیر صدارت ڈینگی تازہ ترین حال بریف...
# 244  DengueFever  فوزیہ نامی خاتون نظیر بھٹو اسپتال ڈینگی وائرس ...
# 245  DengueFever  پاکستان وآزادکشمیر ڈینگی وائر پاک بنائیں ڈینگ...
# 246  DengueFever  ڈینگی خاتمے عملی اقداما ت اٹھائے شیخ عقیل الرح...
# 247  DengueFever    پمز ڈینگی مشتبہ مریضوں مریضوں ڈینگی وائرس تصدیق
# 248  DengueFever         صوبائی وزیر ملک اسد کھوکھر ڈینگی شکارہوگئے
# 249  DengueFever  آر ڈبلیو ایم جانب ڈینگی کیخلاف حفاظتی اقدامات...
# 250  DengueFever   انسداد ڈینگی سرویلنس کوتاہی برداشت سیکرٹری آرٹی
# 251  DengueFever  ڈی لاہور اصغر جوئیہ این ڈی بوائز ہائی سکول اچھ...
# 252  DengueFever  افسران ڈینگی سروئلنس صفائی ستھرائی پرائس چیکنگ...
# 253  DengueFever  رائیونڈ عدنان بدر ڈینگی صفائی ستھرائی چیک کیلئ...
# 254  DengueFever                                   احتیاط ڈینگی بچا
# 255  DengueFever  سرویلنس ٹیمیں ڈینگی مچھر افزائش مقامات بھرپور ...
# 256  DengueFever  انسداد ڈینگی مہم کمرشل اداروں دکانوں باقاعدگی ...
# 257  DengueFever  سوات ضلعی انتظامیہ محکمہ صحت ناقص منصوبہ بندی ...
# 258  DengueFever  اوکاڑہ ڈسٹرکٹ انٹا مالوجسٹکا مارکیٹوں مختلف جگ...
# 259  DengueFever  انسداد ڈینگی کار کردگی جائزہ لینے حوالہ اجلاس ...
#
#                                             NounChunks
# 0    [سی پیک منصوبہ ختمآئی ایم ایف, شرائط پرعملدرآم...
# 1    [حکومت, سی پیک, تحت اکانامک زونز, توجہ, رشکئی ...
# 2    [سی پیک, کاموجودہ مرحلہ, پاکستانی عوام, معاشی ...
# 3    [وزیر, اعلیٰ خیبر پختونخوا محمود خان, جمعہ, رو...
# 4    [غربت, شرح, کمی, سی پیک, دوسرے مرحلے, اہم ترجی...
# 5    [حکومت عوام, ریلیف, فراہمی, لئے, عزم, سی پیک ا...
# 6    [چین پاکستان, اقتصادی راہداری منصوبہ, دوسرے مر...
# 7    [وزیر اعظم عمران خان, دورہ چین, ممالک, مابین ت...
# 8       [صدارتی آرڈیننس, ذریعے, سی پیک اتھارٹی, فیصلہ]
# 9    [خیبرپختونخوا حکومت, متعلقہ محکموں, ترقیاتی من...
# 10   [وزیراعظم عمران خان, دورہ چین, سی پیک منصوبوں,...
# 11   [چین پاکستان, اقتصادی راہداری, ملک, توانائی, ش...
# 12   [وزیراعظم عمران خان, دورہ چین, بعد چینی صدر بھ...
# 13   [ضکے, سی آر, وفاقی حکومت, سردمہری, رویہ, قابل...
# 14   [خطے, مزید تنازع, کوشش, سعودیہ, ایران, غلط فہم...
# 15   [سی پیک, پہلے مرحلے, تکمیل, پاکستان, بنیادی ڈھ...
# 16   [سی پیک, تحت بلوچستان, اقتصادی زونز, قیام, مقا...
# 17   [سی پیک, تحت بلوچستان, تحصیل بوستان, انڈسٹریل ...
# 18   [سی پیک, متعلقہ منصوبوں, پاکستانیوں, روزگار, ح...
# 19   [وزیراعظم, سی پیک اتھارٹی, چیئرپرسن, مقرر آرڈی...
# 20   [احسن اقبال, سی پیک اتھارٹی, آرڈیننس, خلاف قا...
# 21   [صدر مملکت عارف علوی, سی پیک اتھارٹی آرڈیننس,...
# 22   [پاکستان, چین, سی پیک, معاشی ترقی, صنعتی انقلا...
# 23   [چین, پاکستان, قومی مفاد, ایشو, بھرپور تعاون, ...
# 24   [وفاقی حکومت, سردمہری, رویہ, قابل افسوس, سعید ...
# 25   [کراچی سرکولر ریلوے, وفاقی حکومت, سردمہری قابل...
# 26   [وفاقی حکومت, سی پیک اتھارٹی بارے, صدارتی آرڈ...
# 27   [پاکستان, چین, سی پیک, تحت اربوں ڈالر مالیت, ا...
# 28   [پاکستان, چین, قریبی دوست شراکت دار, آہنی برا...
# 29   [سی پیک, دوسرے مرحلے, تکمیل, روزگار, مواقع پید...
# ..                                                 ...
# 230  [سری لنکن آل راﺅنڈ ر تھیسارا پریرا, دورہ پاکست...
# 231  [یو ای ٹی لاہورکے زیر اہتمام ڈینگی, متعلق آگاہ...
# 232  [ٹی ایم اے لاچی, بڑے پیمانے, صفائی مہم, آغاز ...
# 233  [مظفرآبادلچھراٹ ویلفئیر آرگنائزیشن آزادجموں...
# 234  [ڈینگی, خاتمہ, لئے بلدیات, چیف افسران نکاسی, ص...
# 235  [حکومت ڈینگی, مکمل خاتمہ, ٹھوس عملی اقدامات, ر...
# 236  [ٹی ایم اے لاچی, بڑے پیمانے, صفائی مہم, آغاز ...
# 237      [ڈینگی, خدشہ, پیش نظر دکانداروں, خلاف مقدمات]
# 238  [افسران, شہر, صفائی, ڈینگی سیمینار, ڈینگی انتظ...
# 239  [رواں سال بلوچستان, اضلاع, ڈینگی وائرس, کیسز ر...
# 240       [خیبر پختونخوا, ڈینگی, نئے کیسز رپورٹ تعداد]
# 241  [انسداد ڈینگی مہم, ڈپٹی کمشنر سرگودھا, محکموں ...
# 242            [ملک, ڈینگی, متاثر افراد, تعداد, تجاوز]
# 243  [سیکرٹری صحت, زیر صدارت ڈینگی, تازہ ترین صورتح...
# 244  [فوزیہ نامی خاتون بے, نظیر بھٹو اسپتال, ڈینگی ...
# 245  [پاکستان وآزادکشمیر, ڈینگی وائر, ڈینگی وائر, ...
# 246  [ڈینگی, خاتمے, عملی اقداما ت, ہیںشیخ عقیل الرح...
# 247  [پمز, ڈینگی, مشتبہ مریضوں, مریضوں, ڈینگی وائرس...
# 248      [صوبائی وزیر ملک اسد کھوکھر ڈینگی, شکارہوگئے]
# 249  [آر ڈبلیو ایم, جانب, ڈینگی کیخلاف, حفاظتی اقد...
# 250  [انسداد ڈینگی سرویلنس, کوتاہی برداشت, سیکرٹری ...
# 251  [ڈی, سی لاہور اصغر جوئیہ, این ڈی بوائز ہائی سک...
# 252  [افسران ڈینگی سروئلنس صفائی, پرائس چیکنگ, عملد...
# 253  [اے, سی رائیونڈ عدنان بدر, ڈینگی, صفائی, چیک, ...
# 254                                    [احتیاط, ڈینگی]
# 255  [سرویلنس ٹیمیں ڈینگی مچھر, افزائش, مقامات, بھر...
# 256  [انسداد ڈینگی مہم, کمرشل اداروں دکانوں, باقاعد...
# 257  [سواتضلعی انتظامیہ, محکمہ صحت, ناقص منصوبہ بند...
# 258  [اوکاڑہڈسٹرکٹ انٹا مالوجسٹکا مارکیٹوں, مختلف ج...
# 259  [انسداد ڈینگی, کارکردگی, جائزہ, حوالہ, اجلاس, ...
#
# [260 rows x 8 columns]

# %%
cnt_vectorizer = TfidfVectorizer(min_df=0.02)
vec = cnt_vectorizer.fit_transform(dataset['preprocessed_text'])

# %%
#elbow curve for optimal clusters
#Elbow curve method
X = vec.todense()
Sum_of_squared_distances = []
K = range(1,30)
for k in K:
    print('K is %s'%k)
    km = KMeans(n_clusters=k,random_state=3)
    km = km.fit(X)
    Sum_of_squared_distances.append(km.inertia_)


# In[25]:


kn = KneeLocator(K, Sum_of_squared_distances, curve='convex', direction='decreasing')
print(kn.knee)
# Out:
# K is 1
# K is 2
# K is 3
# K is 4
# K is 5
# K is 6
# K is 7
# K is 8
# K is 9
# K is 10
# K is 11
# K is 12
# K is 13
# K is 14
# K is 15
# K is 16
# K is 17
# K is 18
# K is 19
# K is 20
# K is 21
# K is 22
# K is 23
# K is 24
# K is 25
# K is 26
# K is 27
# K is 28
# K is 29
# 13

# %%
km = KMeans(kn.knee,random_state=3)
km.fit(X)
labels = km.labels_
dataset['km_label'] = labels

# %%
print(purity_score(dataset.Label,dataset['km_label']))
# Out:
# 0.9807692307692307

# %%
order_centroids = km.cluster_centers_.argsort()[:, ::-1]
terms = cnt_vectorizer.get_feature_names()

# %%
for i in range(kn.knee):
    print("Cluster %d:" % i),
    for ind in order_centroids[i, :10]:
        print(' %s' % terms[ind])
# Out:
# Cluster 0:
#  کارروائی
#  فوجی
#  شام
#  ترکی
#  غاز
#  لاروا
#  عمل
#  اجلاس
#  افراد
#  شہریوں
# Cluster 1:
#  ڈی
#  ڈینگی
#  ہسپتال
#  لاہور
#  مریضوں
#  دورہ
#  خانیوال
#  بھرپور
#  کار
#  جائزہ
# Cluster 2:
#  ڈینگی
#  حکومت
#  اقدامات
#  بچاؤ
#  کیلئے
#  سیمینار
#  ملک
#  مہم
#  پنجاب
#  لاروا
# Cluster 3:
#  پیک
#  اتھارٹی
#  حکام
#  تعاون
#  چین
#  جاری
#  عوام
#  حکومت
#  وزیراعظم
#  پاکستان
# Cluster 4:
#  پیک
#  چین
#  وزیر
#  پاکستان
#  وفاقی
#  حکومت
#  منصوبوں
#  وزیراعظم
#  دورہ
#  خان
# Cluster 5:
#  جاری
#  ضلعی
#  انتظامیہ
#  ڈینگی
#  صفائی
#  مہم
#  رپورٹ
#  انسداد
#  غاز
#  ایم
# Cluster 6:
#  باد
#  اسلام
#  ڈاکٹر
#  ڈینگی
#  عمران
#  افراد
#  کشمیر
#  انتظامیہ
#  حوالے
#  خان
# Cluster 7:
#  یکجہتی
#  اظہار
#  کشمیریوں
#  ریلی
#  کیلئے
#  کشمیری
#  کشمیر
#  انعقاد
#  عوام
#  اہتمام
# Cluster 8:
#  سری
#  لنکن
#  ٹیم
#  سیریز
#  ٹی
#  کرکٹ
#  پاکستان
#  میچ
#  ٹونٹی
#  پاک
# Cluster 9:
#  صحت
#  ڈینگی
#  وائرس
#  محکمہ
#  عوام
#  وزیر
#  ڈاکٹر
#  ہسپتال
#  سرکاری
#  کیلئے
# Cluster 10:
#  تعداد
#  مریضوں
#  ڈینگی
#  ہزار
#  خیبر
#  پنجاب
#  راولپنڈی
#  پختونخوا
#  قابو
#  مریض
# Cluster 11:
#  ڈپٹی
#  کمشنر
#  ڈینگی
#  راولپنڈی
#  انسداد
#  ممکن
#  کردار
#  ضلع
#  خاتمہ
#  سیف
# Cluster 12:
#  سیکرٹری
#  حال
#  انسداد
#  ڈینگی
#  صدارت
#  اقدامات
#  اجلاس
#  زیر
#  حوالے
#  کیلئے

# %%
vocab = list(terms)

# %%
len(vocab)
# Out:
# 112

# %%
n_clust = kn.knee

# %%
prob_clusters = []
for i in range(0,n_clust):
    prob_clusters.append(get_pd_of_cluster(dataset,i))

# %%
theta=[]
for i in range(0,n_clust):
    p_w = []
    for w in vocab:
        if w in prob_clusters[i].keys():
            p_w.append(prob_clusters[i][w])
        else:
            p_w.append(0)
    theta.append(p_w)

# %%
x = pd.DataFrame(theta)
x.columns = vocab

# %%
x.shape
# Out:
# (13, 112)

# %%
theta=x.values

# %%
theta.shape
# Out:
# (13, 112)

# %%
freq = vec.sum(axis=0)

# %%
freq = (freq/np.sum(freq))

# %%
freq.shape
# Out:
# (1, 112)

# %%
all_noun_chunks =[]

# %%
for x in dataset.NounChunks:
    for j in x:
        all_noun_chunks.append(j)

# %%
all_noun_chunks
# Out:
# ['سی پیک منصوبہ ختمآئی ایم ایف',
#  'شرائط پرعملدرآمد شروع امریکہ',
#  'خوشنودی',
#  'پاکستانی مفاد پسِ پشت',
#  'حکومت',
#  'سی پیک',
#  'تحت اکانامک زونز',
#  'توجہ',
#  'رشکئی اکنامک زون گراونڈ بریکینگ',
#  'آئندہ ماہ افتتاح',
#  'وفاقی وزیر',
#  'منصوبہ بندی',
#  'سی پیک',
#  'کاموجودہ مرحلہ',
#  'پاکستانی عوام',
#  'معاشی فوائد',
#  'سی پیک',
#  'دوسرے مرحلہ',
#  'داخل',
#  'غربت',
#  'خاتمہ زراعت',
#  'صنعتی تعاون',
#  'توجہ',
#  'وزیر',
#  'اعلیٰ خیبر پختونخوا محمود خان',
#  'جمعہ',
#  'روز چترال',
#  'سرکاری دورہ وزیر اعلیٰ',
#  'سی پیک',
#  'متبادل روٹ چترل',
#  'متاثرہ ریشن بجلی گھر',
#  'غربت',
#  'شرح',
#  'کمی',
#  'سی پیک',
#  'دوسرے مرحلے',
#  'اہم ترجیحات',
#  'حکومت عوام',
#  'ریلیف',
#  'فراہمی',
#  'لئے',
#  'عزم',
#  'سی پیک اتھارٹی',
#  'چین پاکستان',
#  'اقتصادی راہداری منصوبہ',
#  'دوسرے مرحلہ',
#  'غربت',
#  'خاتمے زراعت',
#  'صنعتی تعاون',
#  'خصوصی توجہ',
#  'حکام',
#  'سی پیک اتھارٹی',
#  'وزیر اعظم عمران خان',
#  'دورہ چین',
#  'ممالک',
#  'مابین تعلقات',
#  'نئے دور',
#  'آغاز',
#  'سی پیک',
#  'کام',
#  'رفتار',
#  'شاہد رشید',
#  'صدارتی آرڈیننس',
#  'ذریعے',
#  'سی پیک اتھارٹی',
#  'فیصلہ',
#  'خیبرپختونخوا حکومت',
#  'متعلقہ محکموں',
#  'ترقیاتی منصوبوںکی',
#  'حتمی منصوبہ بندی',
#  'ہدایت صوبے',
#  'ترقیاتی منصوبوں',
#  'پچھلی وفاقی دور حکومت',
#  'سی پیک',
#  'وزیراعظم عمران خان',
#  'دورہ چین',
#  'سی پیک منصوبوں',
#  'لئے',
#  'حسن داد',
#  'چینی سرمایہ کاروں',
#  'وفد',
#  'خیبر پختونخوا',
#  'انڈسٹریل زونز',
#  'دورہ',
#  'چین پاکستان',
#  'اقتصادی راہداری',
#  'ملک',
#  'توانائی',
#  'شدید بحران پرقابو',
#  'مدد',
#  'حکام',
#  'سی پیک اتھارٹی',
#  'وزیراعظم عمران خان',
#  'دورہ چین',
#  'بعد چینی صدر بھارت',
#  'شاہ محمود قریشی چین',
#  'اپوزیشن بلاوجہ',
#  'سی پیک',
#  'ایشو',
#  'پاکستان',
#  'ایف اے ٹی ایف',
#  'ضکے',
#  'سی آر',
#  'وفاقی حکومت',
#  'سردمہری',
#  'رویہ',
#  'قابل افسوس',
#  'ہےسعید غنی وزیر اعظم',
#  'حالیہ دورے',
#  'دوران',
#  'سی پیک',
#  'نکات',
#  'سی آر',
#  'خطے',
#  'مزید تنازع',
#  'کوشش',
#  'سعودیہ',
#  'ایران',
#  'غلط فہماں دور',
#  'وزیر خارجہ',
#  'سی پیک',
#  'چین',
#  'پاکستان',
#  'اگلے فیز',
#  'جانب آگے',
#  'سی پیک',
#  'پہلے مرحلے',
#  'تکمیل',
#  'پاکستان',
#  'بنیادی ڈھانچے',
#  'بہتری',
#  'منصوبے',
#  'افغانستان',
#  'وسطی ایشیاء',
#  'روس',
#  'رسائی',
#  'چینی سفیر یاؤچنگ',
#  'اے',
#  'سی پیک',
#  'تحت بلوچستان',
#  'اقتصادی زونز',
#  'قیام',
#  'مقامی صنعت ترقی',
#  'حکام',
#  'سی پیک اتھارٹی',
#  'سی پیک',
#  'تحت بلوچستان',
#  'تحصیل بوستان',
#  'انڈسٹریل زون',
#  'کام تیزی',
#  'سی پیک',
#  'متعلقہ منصوبوں',
#  'پاکستانیوں',
#  'روزگار',
#  'حکام',
#  'سی پیک اتھارٹی',
#  'وزیراعظم',
#  'سی پیک اتھارٹی',
#  'چیئرپرسن',
#  'مقرر آرڈیننس',
#  'احسن اقبال',
#  'سی پیک اتھارٹی',
#  'آرڈیننس',
#  'خلاف قانون قرار',
#  'سی پیک اتھارٹی',
#  'قیام',
#  'پارلیمانی کمیٹی',
#  'سفارشات',
#  'سیکرٹری',
#  'صدر مملکت عارف علوی',
#  'سی پیک اتھارٹی آرڈیننس',
#  'دستخط کردیئے',
#  'سی پیک اتھارٹی آرڈیننس',
#  'اطلاق',
#  'پورے پاکستان',
#  'وزیراعظم عمران خان اتھارٹی',
#  'سربراہ',
#  'پاکستان',
#  'چین',
#  'سی پیک',
#  'معاشی ترقی',
#  'صنعتی انقلاب',
#  'جدید زراعتی نظام',
#  'عمل انگیز',
#  'طور',
#  'پاکستان',
#  'اقتصادی سفارتکاری',
#  'خصوصی توجہ',
#  'چین',
#  'پاکستان',
#  'قومی مفاد',
#  'ایشو',
#  'بھرپور تعاون',
#  'یقین دہانی وزیراعظم',
#  'چینی',
#  'منصب',
#  'درمیان',
#  'ملاقاتمقبوضہ کشمیر',
#  'صورتحال',
#  'اورسی پیک',
#  'منصوبوں پرتبادلہ خیالچینی',
#  'وفاقی حکومت',
#  'سردمہری',
#  'رویہ',
#  'قابل افسوس',
#  'سعید غنی',
#  'سی پیک',
#  'سی آر',
#  'زیادتی',
#  'مترادف ہےصوبائی وزیر',
#  'کراچی سرکولر ریلوے',
#  'وفاقی حکومت',
#  'سردمہری قابل افسوس',
#  'ہےسعید غنی',
#  'حالیہ دورے',
#  'دوران وزیراعظم',
#  'سی پیک',
#  'نکات',
#  'سی آر',
#  'صوبہ',
#  'وفاقی حکومت',
#  'سی پیک اتھارٹی بارے',
#  'صدارتی آرڈیننس',
#  'جاری کرکے',
#  'شاندار اقدامات',
#  'کئےانوار الحق رامے',
#  'پاکستان',
#  'چین',
#  'سی پیک',
#  'تحت اربوں ڈالر مالیت',
#  'ایم ایل۔ ون منصوبے',
#  'حتمی شکل',
#  'کراچی',
#  'پشاور',
#  'ریلوے ٹریک',
#  'لمبائی',
#  'نیا سگنلنگ',
#  'پاکستان',
#  'چین',
#  'قریبی دوست شراکت دار',
#  'آہنی برادرز',
#  'پاکستان غربت',
#  'خاتمہ',
#  'چین',
#  'تجربات',
#  'استفادہ',
#  'سی پیک',
#  'تکمیل',
#  'موجودہ حکومت',
#  'سی پیک',
#  'دوسرے مرحلے',
#  'تکمیل',
#  'روزگار',
#  'مواقع پیدا',
#  'مدد',
#  'حکام',
#  'سی پیک اتھارٹی',
#  'پاک چین',
#  'صنعتی تعاون',
#  'فروغ',
#  'لئے',
#  'جامع فریم ورک',
#  'حکام',
#  'سی پیک اتھارٹی',
#  'وزیراعظم',
#  'دورہ چین',
#  'سی پیک',
#  'نئے منصوبوں',
#  'حسن دائودبٹ',
#  'چین',
#  'چیف پلانرکنگ ژی وانگ',
#  'سی پیک',
#  'تحت',
#  'جاری منصوبوں',
#  'بروقت تکمیل',
#  'اطمینان',
#  'اظہار',
#  'ترکی',
#  'شام',
#  'فوجی کارروائی',
#  'آغاز',
#  'ترکی',
#  'شام',
#  'فوجی کارروائی',
#  'آغاز',
#  'ترکی شام',
#  'کرد جنگجوؤں کیخلاف فوجی کارروائی',
#  'دےیورپی یونین',
#  'یورپی یونین شام',
#  'مجوزہ ’’سیف زون',
#  'قیام',
#  'رقم',
#  'شام',
#  'ترک فوجی کارروائی',
#  'عالمی برادری',
#  'صدر',
#  'سلامتی کونسل',
#  'ترکی',
#  'شہریوں',
#  'جان ومال',
#  'حفاظت',
#  'تحمل',
#  'مظاہرہ',
#  'مطالبہ',
#  'ترکی',
#  'فوجی کارروائی',
#  'بعد شام',
#  'بڑے پیمانے پرلوگوں',
#  'نقل مکانی ْ راس العین',
#  'نقل مکانی',
#  'افراد',
#  'جنوبی علاقے الحسکہ',
#  'طرف جنوب',
#  'طرف',
#  'عالمی برادری کیشام',
#  'ترک فوجی کارروائی',
#  'مذمت',
#  'ترک فوجی کارروائی',
#  'غور',
#  'لئے اقوام متحدہ',
#  'اجلاس آج',
#  'سلامتی کونسل',
#  'رکن',
#  'یورپی ممالک',
#  'ترکی',
#  'شام',
#  'فوجی کارروائی',
#  'مطالبہ',
#  'کشمیریوں',
#  'اظہار یکجہتی',
#  'قرارداد',
#  'پنجاب اسمبلی',
#  'سیالکوٹ کشمیریوں',
#  'اظہار یکجہتی',
#  'ریلی',
#  'ضلعی انتظامیہ',
#  'ڈسٹرکٹ ایجوکیشن اتھارٹی',
#  'اشتراک',
#  'کشمیری خواتین',
#  'وقار',
#  'بحالی',
#  'اظہار',
#  'ریلی',
#  'انعقاد',
#  'وکلاء',
#  'کشمیری مسلمانوں',
#  'اظہار',
#  'ستمبر',
#  'کنونشن',
#  'ریلی',
#  'انعقاد',
#  'محمد ارشد اعوان ایڈووکیٹ',
#  'ہرنائی',
#  'کشمیریوں',
#  'اظہار یکجہتی',
#  'ریلیاحتجاجی مظاہرہ',
#  'مقبوضہ کشمیر',
#  'مظلوم',
#  'محکوم',
#  'کشمیری خواتین',
#  'ساتھ اظہار یکجہتی',
#  'محکمہ ترقی نسواں',
#  'زیر اہتمام یکجہتی ریلی',
#  'انعقاد',
#  'ڈیرہ مرادجمالی',
#  'کشمیریوں',
#  'اظہار',
#  'ریلی',
#  'شیخوپورہ',
#  'ضلعی انتظامیہ',
#  'زیر اہتمام',
#  'کشمیری بھائیوں',
#  'اظہار یکجہتی',
#  'بھارتی مظالم',
#  'کیخلاف سیمینار',
#  'خواتین',
#  'ریلی',
#  'انعقاد',
#  'کشمیر پاکستانیوں',
#  'رگوں',
#  'خون',
#  'طرح',
#  'مسرت جمشید چیمہ چیئر پرسن قائمہ کمیٹی داخلہ',
#  'قیادت',
#  'کاشانہ ہوم',
#  'بچیوں',
#  'کشمیریوں',
#  'اظہار',
#  'ریلی',
#  'مظفرگڑھکشمیری عوام',
#  'اظہار یکجہتی',
#  'کیلئی ریلیاں',
#  'کشمیریوں',
#  'اظہار یکجہتی',
#  'عبدالوسیم پاکستان',
#  'سلامی',
#  'زندگی',
#  'شرف الدین',
#  'مقبوضہ کشمیر',
#  'خواتین',
#  'اظہار یکجہتی',
#  'لئے گورنمنٹ گرلزکالج وہاڑی',
#  'ریلی',
#  'کشمیریوں',
#  'ساتھ اظہار یکجہتی',
#  'پوری قوم',
#  'کھڑی ہےرانا شکیل احمد',
#  'کشمیریوں',
#  'اظہار یکجہتی',
#  'شعبہ خواتین',
#  'کشمیر کمیٹی',
#  'زیر اہتمام پاکپتن',
#  'ریلی',
#  'انعقاد',
#  'کوہلو کشمیریوں',
#  'اظہار',
#  'ریلی',
#  'نصیرآبادڈیرہ مرادجمالی',
#  'کشمیریوں',
#  'اظہار یکجہتی',
#  'پاک فوج',
#  'حق',
#  'قبائلی رہنماء',
#  'وڈیرہ عرض محمد جتک',
#  'قیادت',
#  'جتک ہاوس',
#  'ریلی',
#  'الپوریضلع',
#  'مختلف تنظیموںمذہبی',
#  'وسیاسی جماعتوں',
#  'مختلف سکولوں کالجوں',
#  'طلباء۔ انجمن تاجران',
#  'کشمیریوں',
#  'اظہار یکجہتی',
#  'حوالے',
#  'ریلیاں',
#  'اوراحتجاجی مظاہرے',
#  'ڈپٹی کمشنر صحبت پور محمد یونس سنجرانی',
#  'قیادت میںکشمیر',
#  'مظلوم بھائیوں',
#  'اظہار',
#  'ریلی',
#  'انعقاد',
#  'کمشنر سبی ڈویژن سید فیصل احمد',
#  'قیادت',
#  'کشمیریوں',
#  'اظہار یکجہتی',
#  'حوالے',
#  'ریلی',
#  'انعقاد',
#  'مرکزی علماء کونسل',
#  'اپیل',
#  'کشمیریوں',
#  'اظہار',
#  'ملک بھرمیں’’یوم ندائے کشمیر',
#  'جمعہ',
#  'اجتماعات',
#  'مقبوضہ کشمیر',
#  'بھارتی مظالم کیخلاف مذمتی',
#  'گورنمنٹ ڈگری کالج سکھر',
#  'کشمیری عوام کیساتھ اظہار یکجہتی',
#  'ریلی',
#  'کشمیر کمیٹی کراچی',
#  'تحت کشمیریوں',
#  'اظہار یکجہتی',
#  'عظیم الشان موٹر سائیکل ریلی',
#  'شہریوں',
#  'بڑی تعداد',
#  'شرکت دنیا',
#  'طاقت کشمیری حریت پسندوں',
#  'حمایت',
#  'اظہار یکجہتی',
#  'دکھاوا؟',
#  'پشین ۔پشین',
#  'کشمیری عوام',
#  'ساتھ اظہار',
#  'تحریک جوانان پاکستان',
#  'زیر اہتمام ریلی',
#  'انعقاد',
#  'وزیر اعظم عمران خان',
#  'مسئلہ کشمیر',
#  'بین الاقوامی فورم',
#  'حقیقی جذبے',
#  'نورالحق قادری',
#  'وفاقی وزیر',
#  'مذہبی امور کاکشمیریوں',
#  'ساتھ اظہار یکجہتی',
#  'لئے',
#  'گلوکارہ رابی پیر زادہ',
#  'کشمیری بھائیوں',
#  'اظہار یکجہتی',
#  'نیا گانا ریکارڈ',
#  'سوشل میڈیا',
#  'اپ لوڈ',
#  'صدر جے آئی یوتھ چناری',
#  'مظاہرین',
#  'اظہار',
#  'چناری',
#  'بھرپور استقبال',
#  'کشمیریوں',
#  'اظہار یکجہتی؛حکومت',
#  'اسلام',
#  'انسانی ہاتھوں',
#  'زنجیر',
#  'اعلان',
#  'مقبوضہ جموں کشمیر',
#  'مظلوموں',
#  'ساتھ اظہار یکجہتی',
#  'لئے',
#  'اسلام آباد',
#  'انسانی ہاتھوں',
#  'زنجیر',
#  'ڈاکٹر فردوس',
#  'عاشق اعوان',
#  'پہر بجے ایکسپریس چوک',
#  'حیدرآباد',
#  'شہری اکتوبر',
#  'کشمیر مارچ',
#  'بھرپور شرکت کرکے کشمیر',
#  'مظلوم عوام',
#  'اظہار یکجہتی',
#  'حافظ',
#  'طاہر مجید',
#  'نواز',
#  'چوہدری شوگر',
#  'کیس',
#  'امکان ن لیگ',
#  'رہنمائوں',
#  'کارکنوں',
#  'ممکنہ پیشی',
#  'موقع',
#  'اظہار',
#  'عدالت',
#  'باہر',
#  'ہدایت',
#  'کشمیریوں',
#  'اظہار یکجہتی',
#  'لئے اکتوبر',
#  'یوم',
#  'وزارت داخلہ',
#  'طرف',
#  'نوٹیفکیشن',
#  'پاک سری لنکن ٹی ٹوئنٹی سیریز؛ ٹکٹوں',
#  'فروخت شروع',
#  'پاک سری لنکن ٹی ٹوئنٹی سیریز؛ ٹکٹوں',
#  'فروخت شروع',
#  'سری لنکنز',
#  'استقبال کراچی',
#  'بانہیں',
#  'انشاء اللہ انگلینڈ',
#  'ٹیم جلد',
#  'پاکستان',
#  'دورہ',
#  'پاکستان',
#  'بین الاقوامی کرکٹ',
#  'سری لنکن ٹیم',
#  'دورہ',
#  'انگلش لیگ اسپنر عادل رشید',
#  'پاک سری لنکن ٹی ٹونٹی کرکٹ سیریز سکیورٹی',
#  'حسب معمول',
#  'سخت اقدمات',
#  'قذافی سٹیڈیم',
#  'جانب',
#  'سڑکوں',
#  'دوپہر',
#  'بجے',
#  'قسم',
#  'ٹریفک',
#  'لئے',
#  'گیادوپہر',
#  'ٹیم',
#  'ہارپر جواب',
#  'سری لنکن ٹیم',
#  'بائولنگ بیٹنگ',
#  'اچھی پرفارمنس',
#  'شعبوں',
#  'ہار',
#  'بعد ٹیم',
#  'خامیوں',
#  'پتہ',
#  'مضبوط ٹیم',
#  'پاکستان',
#  'سری لنکا',
#  'درمیان',
#  'آخری ٹی ٹونٹی انٹرنیشنل کرکٹ میچ آج',
#  'سری لنکن ٹیم',
#  'پاکستان',
#  'خلاف سیریز',
#  'فیصلہ',
#  'برتری',
#  'حاصل مہمان',
#  'پاکستان',
#  'سری لنکن',
#  'کرکٹ ٹیموں',
#  'درمیان',
#  'آخری ٹی ٹوئنٹی میچ',
#  'میچ شام بجکر منٹ',
#  'شروع',
#  'ہوگابرقی قمقموں',
#  'روشنی',
#  'سری',
#  'پاک سری لنکن ٹی ٹونٹی کرکٹ سیریز',
#  'آخری میچ',
#  'پاکستان',
#  'سری لنکا',
#  'درمیان',
#  'آخری ٹی ٹونٹی انٹرنیشنل کرکٹ میچ',
#  'سری لنکن ٹیم',
#  'پاکستان',
#  'خلاف سیریز',
#  'فیصلہ',
#  'برتری',
#  'حاصل مہمان',
#  'سری لنکن آل راﺅنڈ ر تھیسارا پریرا',
#  'دورہ پاکستان',
#  'انکار',
#  'وجہ',
#  'کیریبئن لیگ',
#  'دوران ڈینگی بخار ہوگیاڈاکٹر',
#  'ایڈوائس',
#  'آرام کررہا ہوںآل راﺅنڈر',
#  'چھاتی',
#  'سرطان',
#  'حوالے',
#  'پنک ربن ڈے پاکستان کرکٹ بورڈ',
#  'قذافی سٹیڈیم',
#  'پاک سری لنکن ٹی ٹونٹی سیریز',
#  'آخری میچ',
#  'پنک ربن',
#  'میچ',
#  '’میچ',
#  'ٹکٹ',
#  'لان',
#  'سوٹ',
#  'سری لنکن ٹیم',
#  'ٹی ٹوئنٹی سیریز',
#  'بعد',
#  'سوشل میڈیا صارفین',
#  'قومی ٹیم',
#  'خراب کارکردگی',
#  'دلچسپ تبصرے',
#  'سری لنکن کرکٹ ٹیم',
#  'کوچ',
#  'پنجاب سیف سٹیز اتھارٹی',
#  'دورہ',
#  'سیکورٹی بارے بریفنگ',
#  'سری لنکن ”ریلوکٹوں“',
#  'پاکستان کےخلاف ٹی ٹونٹی سیریز',
#  'وائٹ واش',
#  'مکمل کرلیا گرین شرٹسرنز',
#  'ہدف',
#  'ناکامبلے بازوں',
#  'ناقص کھیل',
#  'سرفراز احمد',
#  'قومی ٹیم',
#  'کپتانی',
#  'قرارداد',
#  'پنجاب اسمبلی',
#  'جمع سری لنکن ٹیم',
#  'ٹی ٹونٹی سیریز',
#  'وائٹ واش',
#  'تحقیقات',
#  'جائیںمتن',
#  'سری لنکن ٹیم',
#  'سکیورٹی اہلکاروں',
#  'خراج تحسین مہمان کھلاڑیوں',
#  'سٹیڈیم',
#  'سکیورٹی اہلکاروں',
#  'ساتھ',
#  'خصوصی تصاویر',
#  'وزیر',
#  'اعلیٰ پنجاب',
#  'پاکستان',
#  'کرکٹ سیریز',
#  'سری لنکن ٹیم',
#  'کھلاڑیوں',
#  'مینجمنٹ',
#  'اظہار تشکر انٹرنیشنل کرکٹ',
#  'بحالی',
#  'خوش آئندامید',
#  'دیگر',
#  'غیر ملکی ٹیمیں',
#  'سری لنکن ٹیم',
#  'کوچ',
#  'اُردو',
#  'سری لنکن ٹیم',
#  'کوچ',
#  'اُردو',
#  'محبتوں',
#  'پھول',
#  'سری لنکن ٹیم',
#  'واپسی',
#  'ملک',
#  'ڈینگی',
#  'متاثرہ مریضوں',
#  'تعداد',
#  'محکمہ صحت',
#  'راولپنڈی اسلام آباد',
#  'ڈینگی',
#  'خطرات',
#  'پیشِ نظر ریورگارڈن اوردیگر',
#  'رہائشی آبادیوں',
#  'انسدادِڈینگی سپرے',
#  'ریورگارڈن اوراردگرد',
#  'رہائشی آبادیوں',
#  'انسدادِ ڈینگی سپرے رکنِ',
#  'قومی اسمبلی',
#  'ڈپٹی کمشنراسلام آباد اورایڈیشنل',
#  'ڈپٹی کمشنر',
#  'خصوصی اقدامات',
#  'ڈینگی',
#  'خاتمہ',
#  'مشن ہےڈپٹی کمشنر بہاولنگر',
#  'فیصل آباد روڈ',
#  'ٹائر شاپس',
#  'ڈینگی لاوا',
#  'مالک دکان',
#  'خلاف مقدمہ',
#  'راولپنڈی گھنٹوں',
#  'مزید شہری ڈینگی بخار',
#  'مبتلامریضوں',
#  'تعداد',
#  'پمز',
#  'آئسولیشن وارڈ',
#  'ڈینگی',
#  'مریض داخل',
#  'بچے',
#  'حالت تشویشناک',
#  'کنگ عبدالله ہسپتال',
#  'ڈینگی',
#  'مریضوں',
#  'بیڈ',
#  'مشتمل وارڈ',
#  'راولپنڈی',
#  'انسداد ڈینگی سرگرمیاں',
#  'ڈینگی',
#  'گھر گھر',
#  'عوامی آگاہی',
#  'ساتھ',
#  'سا تھ',
#  'ہنگامی بنیادوں',
#  'ڈور',
#  'آئوٹ ڈور سرولنس',
#  'ڈینگی',
#  'بچائو',
#  'لئے',
#  'موثر طریقہ',
#  'حفاظتی تدابیر',
#  'عمل',
#  'ڈاکٹر اعجاز وہرا',
#  'مسلم لیگ ن',
#  'ترجمان مریم اورنگزیب',
#  'ڈینگی',
#  'مریضوں',
#  'تعداد',
#  'اضافہ',
#  'اظہار تشویش',
#  'پاکستان',
#  'ڈینگی',
#  'اموات کیسز',
#  'تجاوز',
#  'ڈپٹی کمشنر جہلم محمد سیف انور جپہ',
#  'زیر صدارت ڈینگی',
#  'بچاؤ',
#  'حوالے',
#  'اہم اجلاس',
#  'انعقاد',
#  'سیکرٹری پرائمری اینڈ سیکنڈری ہیلتھ کیئر کیپٹن عثمان',
#  'ہیڈ کوارٹر ہسپتال',
#  'دورہ انتظامات',
#  'سیکرٹری ہیلتھ',
#  'ڈینگی',
#  'مرض',
#  'مبتلا مریضوں',
#  'عیادت',
#  'ہسپتال',
#  'ڈینگی مچھر سیکرٹری پرائمری اینڈ سکینڈری ہیلتھ کئیر',
#  'غلط گھروں',
#  'ہسٹری',
#  'سی او راولپنڈی',
#  'سخت سرزنش وکیل کالونی',
#  'راول ٹائون',
#  'لاروا برآمد',
#  'پنجاب',
#  'ڈینگی',
#  'مزید کیسز تعداد',
#  'تجاوز',
#  'عوام ڈینگی مہم',
#  'مامور ٹیموں',
#  'ساتھ تعاون کریںڈاکٹر شاہد صد یق اپوز یشن انسا نی صحت',
#  'معا',
#  'ست',
#  'بازآ جائےرہنما تحریک انصاف',
#  'سندھ',
#  'رواں برس کانگو',
#  'نگلیریا',
#  'ڈینگی',
#  'افراد جان',
#  'بازی',
#  'ہیںڈاکٹر عمران شاہ',
#  'سندھ',
#  'رواں برس کانگو',
#  'نگلیریا',
#  'ڈینگی',
#  'افراد جان',
#  'بازی',
#  'ڈاکٹر عمران شاہ',
#  'حکومت پنجاب ڈینگی',
#  'روک تھام',
#  'اقدامات',
#  'ہےسردارعبدالحئی',
#  'ڈینگی لاروا برآمد',
#  'نوٹس',
#  'صورت',
#  'ادارے',
#  'سربراہ',
#  'فیصلہ',
#  'اسلام آباد انتظامیہ صحت فائونڈیشن',
#  'تعاون',
#  'گائوں جنڈیالہ',
#  'مفت ڈینگی آگاہی میڈیکل کیمپ',
#  'ڈینگی',
#  'بچاؤ مہم',
#  'شہری حصہ',
#  'شہباز شاہین',
#  'ڈینگی',
#  'بچاؤ مہم',
#  'شہری حصہ',
#  'شہباز شاہین',
#  'ڈپٹی کمشنر عرفان علی کاٹھیا',
#  'زیر صدارت انسداد ڈینگی',
#  'حوالے',
#  'اہم اجلاس',
#  'انعقاد',
#  'ضلعی انتظامیہ',
#  'کالجوں سکولوں',
#  'یونیورسٹیوں',
#  'ڈینگی',
#  'آگاہی',
#  'پرگرامز',
#  'سیمینار',
#  'صالحہ',
#  'سعید طالبات',
#  'گھروںمیں صفائی',
#  'ضلعی انتظامیہ لاہو ر',
#  'انسداد ڈینگی',
#  'گزشتہ روز',
#  'رپورٹ',
#  'جاری کردی',
#  'پنجاب',
#  'ڈینگی',
#  'مزید کیسز تعداد',
#  'تجاوز',
#  'الپوریشانگلہ',
#  'ڈینگی بے قابو ہوگیا مریضوں',
#  'مسلسل اضافے',
#  'عوام',
#  'تشویش۔محکمہ صحت وباء',
#  'روک تھام',
#  'ناکام بشام',
#  'مزیدافراد',
#  'ڈینگی وائرس',
#  'تصدیق',
#  'ساہیوال ڈینگی',
#  'وائرس',
#  'سبب',
#  'افرادڈسٹر کٹ ھیڈ کوارٹر ہسپتال ساہیوال ڈینگی وارڈ دا خل',
#  'پنجاب حکومت',
#  'ڈینگی',
#  'ٹیسٹ فری',
#  'ڈینگی',
#  'ٹیسٹ',
#  'علاج',
#  'سیکرٹری صحت کیپٹن ر محمد عثمان',
#  'ڈائریکٹرجنرل ہیلتھ سروسز ڈاکٹر کمالان گچکی',
#  'زیرصدارت لسبیلا',
#  'دیگر اضلاع',
#  'ڈینگی وائرس',
#  'پیدا',
#  'صورتحال',
#  'سدباب',
#  'حفاظتی اقدامات',
#  'پیش رفت',
#  'حوالے',
#  'ڈینگی۔۔۔',
#  'اموات',
#  '۔۔۔',
#  'ضلعی انتظامیہ',
#  'ڈینگی',
#  'بچائومہم کاآغازکردیا',
#  'وزیر اعظم',
#  'معاون',
#  'خصوصی برائے صحت ڈاکٹر ظفر مرزا',
#  'راولپنڈی',
#  'اسلام آباد',
#  'ڈینگی وائرس',
#  'پیش نظر',
#  'نجی ہسپتالوں',
#  'صحت سہولت پروگرام',
#  'پینل',
#  'راولپنڈیڈینگی مریضوں',
#  'فوری تشخیص',
#  'علاج',
#  'لئے راولپنڈی',
#  'علاقے',
#  'کوٹھہ کلاں مورگاہ',
#  'پہلے فلٹر کلینک',
#  'افتتاح',
#  'قڈینگی',
#  'قابو',
#  'روایتی طریقہ کار اختیار',
#  'نسیم صادق',
#  'علاقے',
#  'ڈینگی مریض رپورٹ',
#  'ڈینگی',
#  'معلومات',
#  'پیپلزپارٹی سندھ',
#  'رہنمائوں',
#  'پنجاب',
#  'خیبرپختوانخواہ',
#  'ڈینگی',
#  'بگڑتی صورتحال',
#  'تشویش کااظہار',
#  'بلوچستان',
#  'ڈینگی',
#  'مرض',
#  'تدارک',
#  'اقدامات',
#  'متاثرہ علاقوں',
#  'ٹیمیں تشکیل',
#  'وزیر صحت',
#  'میر نصیب اللہ مری',
#  'ڈپٹی کمشنر حیدرآباد',
#  'متعلقہ افسران',
#  'شہر',
#  'صفائی ستھرائی',
#  'موثر انتظامات',
#  'ڈینگی',
#  'بچاؤ',
#  'اسپرے',
#  'ہدایت',
#  'پنجاب',
#  'بعد خیبرپختونخوا',
#  'ڈینگی بے قابو',
#  'سیکنڈری بورڈ سرگودھا میں’’ ڈینگی',
#  'خاتمہ مہم',
#  'حوالے',
#  'تقریب',
#  'انعقاد',
#  'راولپنڈی',
#  'اسلام آباد',
#  'ڈینگی مریضوں',
#  'تعداد',
#  'تجاوز',
#  'شہریوں کیساتھ',
#  'ضلعی انتظامیہ',
#  'خوف',
#  'زدہ بیڈز',
#  'کم عملہ',
#  'ادویات',
#  'قلت',
#  'سرکاری ہسپتالوں',
#  'خانیوال',
#  'تعلیمی اداروں',
#  'ڈینگی مچھر',
#  'بچاؤ',
#  'اوراحتیاطی تدابیر بارے',
#  'آگاہی کیلئے زیرو پیریڈز',
#  'آغاز',
#  'خانیوال',
#  'فرد',
#  'کردار ادا',
#  'وقت',
#  'ڈینگی',
#  'مکمل خاتمہ',
#  'ڈپٹی کمشنر',
#  'ڈینگی',
#  'خلاف مہم',
#  'لئے ایمرجنسی',
#  'شہباز',
#  'ڈینگی برادران',
#  'قابو',
#  'بابا محمد اسحاق',
#  'فیصل آباد ڈویژن',
#  'ڈینگی',
#  'بچائو کیلئے فول',
#  'پروف انتظامات',
#  'ہیںاحتیاطی',
#  'حفاظتی تدارکی اقدامات',
#  'تحت',
#  'انسدادی صورتحال تسلی',
#  'ڈویژنل کمشنر محمود',
#  'جہلم انسداد ڈینگی',
#  'سلسلہ',
#  'ڈپٹی کمشنر',
#  'زیر صدارت',
#  'پرائیویٹ اسکول ایسوسی ایشن',
#  'ساتھ اعلیٰ',
#  'سطحی اجلاس',
#  'ڈپٹی کمشنر محمد سیف انور جپہ',
#  ...]

# %%
allnounchunks = pd.DataFrame({'NounChunks':all_noun_chunks})

# %%
allnounchunks.to_csv('allnounchunksUrduDS.csv',index=False)

# %%
#allnounchunks = pd.read_csv('allnounchunks20NewsGroup.csv')

# %%
all_noun_chunks = allnounchunks.NounChunks
print(len(all_noun_chunks))
# Out:
# 1758

# %%
from collections import Counter

# %%
freq_all_noun_chunks = Counter(all_noun_chunks)

# %%
freq_all_noun_chunks.most_common(1000)
# Out:
# [('ڈینگی', 74),
#  ('سی پیک', 22),
#  ('پاکستان', 17),
#  ('اظہار یکجہتی', 16),
#  ('انعقاد', 15),
#  ('حوالے', 14),
#  ('کشمیریوں', 13),
#  ('ریلی', 13),
#  ('تعداد', 12),
#  ('لئے', 11),
#  ('سی پیک اتھارٹی', 11),
#  ('اظہار', 11),
#  ('سری لنکن ٹیم', 10),
#  ('ڈینگی وائرس', 10),
#  ('مریضوں', 9),
#  ('ضلعی انتظامیہ', 8),
#  ('پنجاب', 8),
#  ('چین', 7),
#  ('خاتمہ', 7),
#  ('قابو', 7),
#  ('حکام', 6),
#  ('ڈپٹی کمشنر', 6),
#  ('ڈی', 6),
#  ('صفائی', 6),
#  ('دورہ', 5),
#  ('ملک', 5),
#  ('وفاقی حکومت', 5),
#  ('ترکی', 5),
#  ('اسلام آباد', 5),
#  ('وجہ', 5),
#  ('تجاوز', 5),
#  ('بچاؤ', 5),
#  ('انسداد ڈینگی', 5),
#  ('عوام', 5),
#  ('انسداد ڈینگی مہم', 5),
#  ('دورہ چین', 4),
#  ('آغاز', 4),
#  ('فیصلہ', 4),
#  ('سی آر', 4),
#  ('درمیان', 4),
#  ('شام', 4),
#  ('فوجی کارروائی', 4),
#  ('قرارداد', 4),
#  ('پنجاب اسمبلی', 4),
#  ('ساتھ اظہار یکجہتی', 4),
#  ('جانب', 4),
#  ('ساتھ', 4),
#  ('عیادت', 4),
#  ('اقدامات', 4),
#  ('آگاہی', 4),
#  ('تصدیق', 4),
#  ('سرکاری ہسپتالوں', 4),
#  ('کنٹرول', 4),
#  ('کارکردگی', 4),
#  ('جائزہ', 4),
#  ('بڑے پیمانے', 4),
#  ('داخل', 3),
#  ('غربت', 3),
#  ('صنعتی تعاون', 3),
#  ('وزیر', 3),
#  ('دوران', 3),
#  ('تکمیل', 3),
#  ('قیام', 3),
#  ('سفارشات', 3),
#  ('صورتحال', 3),
#  ('صوبہ', 3),
#  ('تحت', 3),
#  ('ترک فوجی کارروائی', 3),
#  ('شہریوں', 3),
#  ('طرف', 3),
#  ('مقبوضہ کشمیر', 3),
#  ('قیادت', 3),
#  ('کوچ', 3),
#  ('محکمہ صحت', 3),
#  ('راولپنڈی', 3),
#  ('بچائو', 3),
#  ('اہم اجلاس', 3),
#  ('مرض', 3),
#  ('تعاون', 3),
#  ('رپورٹ', 3),
#  ('جاری کردی', 3),
#  ('پنجاب حکومت', 3),
#  ('شہر', 3),
#  ('ڈینگی مریضوں', 3),
#  ('ڈینگی مچھر', 3),
#  ('کردار ادا', 3),
#  ('مکمل خاتمہ', 3),
#  ('افزائش', 3),
#  ('احتیاطی تدابیر', 3),
#  ('ضرورت', 3),
#  ('تشخیص', 3),
#  ('ممکن حکمت', 3),
#  ('توجہ', 2),
#  ('وفاقی وزیر', 2),
#  ('دوسرے مرحلہ', 2),
#  ('جمعہ', 2),
#  ('کمی', 2),
#  ('دوسرے مرحلے', 2),
#  ('چین پاکستان', 2),
#  ('خصوصی توجہ', 2),
#  ('وزیر اعظم عمران خان', 2),
#  ('کام', 2),
#  ('ذریعے', 2),
#  ('وزیراعظم عمران خان', 2),
#  ('وفد', 2),
#  ('خیبر پختونخوا', 2),
#  ('مدد', 2),
#  ('ایشو', 2),
#  ('سردمہری', 2),
#  ('رویہ', 2),
#  ('قابل افسوس', 2),
#  ('حالیہ دورے', 2),
#  ('نکات', 2),
#  ('بہتری', 2),
#  ('اے', 2),
#  ('تحت بلوچستان', 2),
#  ('روزگار', 2),
#  ('وزیراعظم', 2),
#  ('سی پیک اتھارٹی آرڈیننس', 2),
#  ('سربراہ', 2),
#  ('کراچی', 2),
#  ('سلامتی کونسل', 2),
#  ('مطالبہ', 2),
#  ('افراد', 2),
#  ('کشمیری خواتین', 2),
#  ('بحالی', 2),
#  ('کشمیری بھائیوں', 2),
#  ('خواتین', 2),
#  ('انسانی ہاتھوں', 2),
#  ('زنجیر', 2),
#  ('رہنمائوں', 2),
#  ('ہدایت', 2),
#  ('پاک سری لنکن ٹی ٹوئنٹی سیریز؛ ٹکٹوں', 2),
#  ('فروخت شروع', 2),
#  ('قذافی سٹیڈیم', 2),
#  ('سری لنکا', 2),
#  ('خلاف سیریز', 2),
#  ('برتری', 2),
#  ('حاصل مہمان', 2),
#  ('آخری میچ', 2),
#  ('سری لنکن آل راﺅنڈ ر تھیسارا پریرا', 2),
#  ('دورہ پاکستان', 2),
#  ('انکار', 2),
#  ('کیریبئن لیگ', 2),
#  ('دوران ڈینگی بخار ہوگیاڈاکٹر', 2),
#  ('ایڈوائس', 2),
#  ('آرام کررہا ہوںآل راﺅنڈر', 2),
#  ('قومی ٹیم', 2),
#  ('وائٹ واش', 2),
#  ('سکیورٹی اہلکاروں', 2),
#  ('دیگر', 2),
#  ('اُردو', 2),
#  ('راولپنڈی اسلام آباد', 2),
#  ('رہائشی آبادیوں', 2),
#  ('خلاف مقدمہ', 2),
#  ('پمز', 2),
#  ('حفاظتی تدابیر', 2),
#  ('عمل', 2),
#  ('اظہار تشویش', 2),
#  ('زیر صدارت ڈینگی', 2),
#  ('مبتلا مریضوں', 2),
#  ('مزید کیسز تعداد', 2),
#  ('سندھ', 2),
#  ('رواں برس کانگو', 2),
#  ('نگلیریا', 2),
#  ('افراد جان', 2),
#  ('بازی', 2),
#  ('روک تھام', 2),
#  ('ڈینگی لاروا برآمد', 2),
#  ('بچاؤ مہم', 2),
#  ('شہری حصہ', 2),
#  ('شہباز شاہین', 2),
#  ('زیر صدارت انسداد ڈینگی', 2),
#  ('گزشتہ روز', 2),
#  ('ٹیسٹ', 2),
#  ('علاج', 2),
#  ('حفاظتی اقدامات', 2),
#  ('علاقے', 2),
#  ('وزیر صحت', 2),
#  ('بعد خیبرپختونخوا', 2),
#  ('تقریب', 2),
#  ('ادویات', 2),
#  ('خانیوال', 2),
#  ('فرد', 2),
#  ('وقت', 2),
#  ('افسران', 2),
#  ('مریض', 2),
#  ('شعور', 2),
#  ('حد', 2),
#  ('خلاف مقدمات', 2),
#  ('وسائل', 2),
#  ('کار', 2),
#  ('ڈینگی لاروا', 2),
#  ('چیک', 2),
#  ('بھرپور طریقے', 2),
#  ('عوام ڈینگی', 2),
#  ('آزادکشمیر', 2),
#  ('خیبر پختون خوا', 2),
#  ('ڈینگی بے قابو گھنٹوں', 2),
#  ('مزید مریض اسپتال', 2),
#  ('سی لاہور', 2),
#  ('ممکنہ مضراثرات او راس', 2),
#  ('حکومت ڈینگی', 2),
#  ('لاہور', 2),
#  ('زیر علاج', 2),
#  ('ڈپٹی کمشنر سید امان انور قدوائی', 2),
#  ('آل پاکستان پرائیویٹ سکولز مینجمنٹ', 2),
#  ('رکنی وفد', 2),
#  ('ڈپٹی کمشنر راولپنڈی', 2),
#  ('ملاقات سیف اللہ ڈوگر', 2),
#  ('ضلعی انتظامیہ راولپنڈی', 2),
#  ('مشین', 2),
#  ('عطیہ', 2),
#  ('۷ملاقات', 2),
#  ('پرویز مشرف', 2),
#  ('درخواست', 2),
#  ('صورتحال قابو', 2),
#  ('فوگنگ', 2),
#  ('موثر اقدامات', 2),
#  ('وبا', 2),
#  ('خلاف', 2),
#  ('لوگ', 2),
#  ('نیشنل ہائی ویز اینڈ موٹروے پولیس', 2),
#  ('متعلق سیمینار', 2),
#  ('خیبرپختونخوا', 2),
#  ('عملدرآمد', 2),
#  ('ٹی ایم اے لاچی', 2),
#  ('صفائی مہم', 2),
#  ('شجر کاری', 2),
#  ('گھر گھر ڈینگی', 2),
#  ('سپرے', 2),
#  ('سی خانیوال', 2),
#  ('ڈینگی سیمینار', 2),
#  ('چیکنگ', 2),
#  ('ڈینگی وائر', 2),
#  ('سی پیک منصوبہ ختمآئی ایم ایف', 1),
#  ('شرائط پرعملدرآمد شروع امریکہ', 1),
#  ('خوشنودی', 1),
#  ('پاکستانی مفاد پسِ پشت', 1),
#  ('حکومت', 1),
#  ('تحت اکانامک زونز', 1),
#  ('رشکئی اکنامک زون گراونڈ بریکینگ', 1),
#  ('آئندہ ماہ افتتاح', 1),
#  ('منصوبہ بندی', 1),
#  ('کاموجودہ مرحلہ', 1),
#  ('پاکستانی عوام', 1),
#  ('معاشی فوائد', 1),
#  ('خاتمہ زراعت', 1),
#  ('اعلیٰ خیبر پختونخوا محمود خان', 1),
#  ('روز چترال', 1),
#  ('سرکاری دورہ وزیر اعلیٰ', 1),
#  ('متبادل روٹ چترل', 1),
#  ('متاثرہ ریشن بجلی گھر', 1),
#  ('شرح', 1),
#  ('اہم ترجیحات', 1),
#  ('حکومت عوام', 1),
#  ('ریلیف', 1),
#  ('فراہمی', 1),
#  ('عزم', 1),
#  ('اقتصادی راہداری منصوبہ', 1),
#  ('خاتمے زراعت', 1),
#  ('ممالک', 1),
#  ('مابین تعلقات', 1),
#  ('نئے دور', 1),
#  ('رفتار', 1),
#  ('شاہد رشید', 1),
#  ('صدارتی آرڈیننس', 1),
#  ('خیبرپختونخوا حکومت', 1),
#  ('متعلقہ محکموں', 1),
#  ('ترقیاتی منصوبوںکی', 1),
#  ('حتمی منصوبہ بندی', 1),
#  ('ہدایت صوبے', 1),
#  ('ترقیاتی منصوبوں', 1),
#  ('پچھلی وفاقی دور حکومت', 1),
#  ('سی پیک منصوبوں', 1),
#  ('حسن داد', 1),
#  ('چینی سرمایہ کاروں', 1),
#  ('انڈسٹریل زونز', 1),
#  ('اقتصادی راہداری', 1),
#  ('توانائی', 1),
#  ('شدید بحران پرقابو', 1),
#  ('بعد چینی صدر بھارت', 1),
#  ('شاہ محمود قریشی چین', 1),
#  ('اپوزیشن بلاوجہ', 1),
#  ('ایف اے ٹی ایف', 1),
#  ('ضکے', 1),
#  ('ہےسعید غنی وزیر اعظم', 1),
#  ('خطے', 1),
#  ('مزید تنازع', 1),
#  ('کوشش', 1),
#  ('سعودیہ', 1),
#  ('ایران', 1),
#  ('غلط فہماں دور', 1),
#  ('وزیر خارجہ', 1),
#  ('اگلے فیز', 1),
#  ('جانب آگے', 1),
#  ('پہلے مرحلے', 1),
#  ('بنیادی ڈھانچے', 1),
#  ('منصوبے', 1),
#  ('افغانستان', 1),
#  ('وسطی ایشیاء', 1),
#  ('روس', 1),
#  ('رسائی', 1),
#  ('چینی سفیر یاؤچنگ', 1),
#  ('اقتصادی زونز', 1),
#  ('مقامی صنعت ترقی', 1),
#  ('تحصیل بوستان', 1),
#  ('انڈسٹریل زون', 1),
#  ('کام تیزی', 1),
#  ('متعلقہ منصوبوں', 1),
#  ('پاکستانیوں', 1),
#  ('چیئرپرسن', 1),
#  ('مقرر آرڈیننس', 1),
#  ('احسن اقبال', 1),
#  ('آرڈیننس', 1),
#  ('خلاف قانون قرار', 1),
#  ('پارلیمانی کمیٹی', 1),
#  ('سیکرٹری', 1),
#  ('صدر مملکت عارف علوی', 1),
#  ('دستخط کردیئے', 1),
#  ('اطلاق', 1),
#  ('پورے پاکستان', 1),
#  ('وزیراعظم عمران خان اتھارٹی', 1),
#  ('معاشی ترقی', 1),
#  ('صنعتی انقلاب', 1),
#  ('جدید زراعتی نظام', 1),
#  ('عمل انگیز', 1),
#  ('طور', 1),
#  ('اقتصادی سفارتکاری', 1),
#  ('قومی مفاد', 1),
#  ('بھرپور تعاون', 1),
#  ('یقین دہانی وزیراعظم', 1),
#  ('چینی', 1),
#  ('منصب', 1),
#  ('ملاقاتمقبوضہ کشمیر', 1),
#  ('اورسی پیک', 1),
#  ('منصوبوں پرتبادلہ خیالچینی', 1),
#  ('سعید غنی', 1),
#  ('زیادتی', 1),
#  ('مترادف ہےصوبائی وزیر', 1),
#  ('کراچی سرکولر ریلوے', 1),
#  ('سردمہری قابل افسوس', 1),
#  ('ہےسعید غنی', 1),
#  ('دوران وزیراعظم', 1),
#  ('سی پیک اتھارٹی بارے', 1),
#  ('صدارتی آرڈیننس', 1),
#  ('جاری کرکے', 1),
#  ('شاندار اقدامات', 1),
#  ('کئےانوار الحق رامے', 1),
#  ('تحت اربوں ڈالر مالیت', 1),
#  ('ایم ایل۔ ون منصوبے', 1),
#  ('حتمی شکل', 1),
#  ('پشاور', 1),
#  ('ریلوے ٹریک', 1),
#  ('لمبائی', 1),
#  ('نیا سگنلنگ', 1),
#  ('قریبی دوست شراکت دار', 1),
#  ('آہنی برادرز', 1),
#  ('پاکستان غربت', 1),
#  ('تجربات', 1),
#  ('استفادہ', 1),
#  ('موجودہ حکومت', 1),
#  ('مواقع پیدا', 1),
#  ('پاک چین', 1),
#  ('فروغ', 1),
#  ('جامع فریم ورک', 1),
#  ('نئے منصوبوں', 1),
#  ('حسن دائودبٹ', 1),
#  ('چیف پلانرکنگ ژی وانگ', 1),
#  ('جاری منصوبوں', 1),
#  ('بروقت تکمیل', 1),
#  ('اطمینان', 1),
#  ('ترکی شام', 1),
#  ('کرد جنگجوؤں کیخلاف فوجی کارروائی', 1),
#  ('دےیورپی یونین', 1),
#  ('یورپی یونین شام', 1),
#  ('مجوزہ ’’سیف زون', 1),
#  ('رقم', 1),
#  ('عالمی برادری', 1),
#  ('صدر', 1),
#  ('جان ومال', 1),
#  ('حفاظت', 1),
#  ('تحمل', 1),
#  ('مظاہرہ', 1),
#  ('بعد شام', 1),
#  ('بڑے پیمانے پرلوگوں', 1),
#  ('نقل مکانی ْ راس العین', 1),
#  ('نقل مکانی', 1),
#  ('جنوبی علاقے الحسکہ', 1),
#  ('طرف جنوب', 1),
#  ('عالمی برادری کیشام', 1),
#  ('مذمت', 1),
#  ('غور', 1),
#  ('لئے اقوام متحدہ', 1),
#  ('اجلاس آج', 1),
#  ('رکن', 1),
#  ('یورپی ممالک', 1),
#  ('سیالکوٹ کشمیریوں', 1),
#  ('ڈسٹرکٹ ایجوکیشن اتھارٹی', 1),
#  ('اشتراک', 1),
#  ('وقار', 1),
#  ('وکلاء', 1),
#  ('کشمیری مسلمانوں', 1),
#  ('ستمبر', 1),
#  ('کنونشن', 1),
#  ('محمد ارشد اعوان ایڈووکیٹ', 1),
#  ('ہرنائی', 1),
#  ('ریلیاحتجاجی مظاہرہ', 1),
#  ('مظلوم', 1),
#  ('محکوم', 1),
#  ('محکمہ ترقی نسواں', 1),
#  ('زیر اہتمام یکجہتی ریلی', 1),
#  ('ڈیرہ مرادجمالی', 1),
#  ('شیخوپورہ', 1),
#  ('زیر اہتمام', 1),
#  ('بھارتی مظالم', 1),
#  ('کیخلاف سیمینار', 1),
#  ('کشمیر پاکستانیوں', 1),
#  ('رگوں', 1),
#  ('خون', 1),
#  ('طرح', 1),
#  ('مسرت جمشید چیمہ چیئر پرسن قائمہ کمیٹی داخلہ', 1),
#  ('کاشانہ ہوم', 1),
#  ('بچیوں', 1),
#  ('مظفرگڑھکشمیری عوام', 1),
#  ('کیلئی ریلیاں', 1),
#  ('عبدالوسیم پاکستان', 1),
#  ('سلامی', 1),
#  ('زندگی', 1),
#  ('شرف الدین', 1),
#  ('لئے گورنمنٹ گرلزکالج وہاڑی', 1),
#  ('پوری قوم', 1),
#  ('کھڑی ہےرانا شکیل احمد', 1),
#  ('شعبہ خواتین', 1),
#  ('کشمیر کمیٹی', 1),
#  ('زیر اہتمام پاکپتن', 1),
#  ('کوہلو کشمیریوں', 1),
#  ('نصیرآبادڈیرہ مرادجمالی', 1),
#  ('پاک فوج', 1),
#  ('حق', 1),
#  ('قبائلی رہنماء', 1),
#  ('وڈیرہ عرض محمد جتک', 1),
#  ('جتک ہاوس', 1),
#  ('الپوریضلع', 1),
#  ('مختلف تنظیموںمذہبی', 1),
#  ('وسیاسی جماعتوں', 1),
#  ('مختلف سکولوں کالجوں', 1),
#  ('طلباء۔ انجمن تاجران', 1),
#  ('ریلیاں', 1),
#  ('اوراحتجاجی مظاہرے', 1),
#  ('ڈپٹی کمشنر صحبت پور محمد یونس سنجرانی', 1),
#  ('قیادت میںکشمیر', 1),
#  ('مظلوم بھائیوں', 1),
#  ('کمشنر سبی ڈویژن سید فیصل احمد', 1),
#  ('مرکزی علماء کونسل', 1),
#  ('اپیل', 1),
#  ('ملک بھرمیں’’یوم ندائے کشمیر', 1),
#  ('اجتماعات', 1),
#  ('بھارتی مظالم کیخلاف مذمتی', 1),
#  ('گورنمنٹ ڈگری کالج سکھر', 1),
#  ('کشمیری عوام کیساتھ اظہار یکجہتی', 1),
#  ('کشمیر کمیٹی کراچی', 1),
#  ('تحت کشمیریوں', 1),
#  ('عظیم الشان موٹر سائیکل ریلی', 1),
#  ('بڑی تعداد', 1),
#  ('شرکت دنیا', 1),
#  ('طاقت کشمیری حریت پسندوں', 1),
#  ('حمایت', 1),
#  ('دکھاوا؟', 1),
#  ('پشین ۔پشین', 1),
#  ('کشمیری عوام', 1),
#  ('ساتھ اظہار', 1),
#  ('تحریک جوانان پاکستان', 1),
#  ('زیر اہتمام ریلی', 1),
#  ('مسئلہ کشمیر', 1),
#  ('بین الاقوامی فورم', 1),
#  ('حقیقی جذبے', 1),
#  ('نورالحق قادری', 1),
#  ('مذہبی امور کاکشمیریوں', 1),
#  ('گلوکارہ رابی پیر زادہ', 1),
#  ('نیا گانا ریکارڈ', 1),
#  ('سوشل میڈیا', 1),
#  ('اپ لوڈ', 1),
#  ('صدر جے آئی یوتھ چناری', 1),
#  ('مظاہرین', 1),
#  ('چناری', 1),
#  ('بھرپور استقبال', 1),
#  ('اظہار یکجہتی؛حکومت', 1),
#  ('اسلام', 1),
#  ('اعلان', 1),
#  ('مقبوضہ جموں کشمیر', 1),
#  ('مظلوموں', 1),
#  ('ڈاکٹر فردوس', 1),
#  ('عاشق اعوان', 1),
#  ('پہر بجے ایکسپریس چوک', 1),
#  ('حیدرآباد', 1),
#  ('شہری اکتوبر', 1),
#  ('کشمیر مارچ', 1),
#  ('بھرپور شرکت کرکے کشمیر', 1),
#  ('مظلوم عوام', 1),
#  ('حافظ', 1),
#  ('طاہر مجید', 1),
#  ('نواز', 1),
#  ('چوہدری شوگر', 1),
#  ('کیس', 1),
#  ('امکان ن لیگ', 1),
#  ('کارکنوں', 1),
#  ('ممکنہ پیشی', 1),
#  ('موقع', 1),
#  ('عدالت', 1),
#  ('باہر', 1),
#  ('لئے اکتوبر', 1),
#  ('یوم', 1),
#  ('وزارت داخلہ', 1),
#  ('نوٹیفکیشن', 1),
#  ('سری لنکنز', 1),
#  ('استقبال کراچی', 1),
#  ('بانہیں', 1),
#  ('انشاء اللہ انگلینڈ', 1),
#  ('ٹیم جلد', 1),
#  ('بین الاقوامی کرکٹ', 1),
#  ('انگلش لیگ اسپنر عادل رشید', 1),
#  ('پاک سری لنکن ٹی ٹونٹی کرکٹ سیریز سکیورٹی', 1),
#  ('حسب معمول', 1),
#  ('سخت اقدمات', 1),
#  ('سڑکوں', 1),
#  ('دوپہر', 1),
#  ('بجے', 1),
#  ('قسم', 1),
#  ('ٹریفک', 1),
#  ('گیادوپہر', 1),
#  ('ٹیم', 1),
#  ('ہارپر جواب', 1),
#  ('بائولنگ بیٹنگ', 1),
#  ('اچھی پرفارمنس', 1),
#  ('شعبوں', 1),
#  ('ہار', 1),
#  ('بعد ٹیم', 1),
#  ('خامیوں', 1),
#  ('پتہ', 1),
#  ('مضبوط ٹیم', 1),
#  ('آخری ٹی ٹونٹی انٹرنیشنل کرکٹ میچ آج', 1),
#  ('سری لنکن', 1),
#  ('کرکٹ ٹیموں', 1),
#  ('آخری ٹی ٹوئنٹی میچ', 1),
#  ('میچ شام بجکر منٹ', 1),
#  ('شروع', 1),
#  ('ہوگابرقی قمقموں', 1),
#  ('روشنی', 1),
#  ('سری', 1),
#  ('پاک سری لنکن ٹی ٹونٹی کرکٹ سیریز', 1),
#  ('آخری ٹی ٹونٹی انٹرنیشنل کرکٹ میچ', 1),
#  ('چھاتی', 1),
#  ('سرطان', 1),
#  ('پنک ربن ڈے پاکستان کرکٹ بورڈ', 1),
#  ('پاک سری لنکن ٹی ٹونٹی سیریز', 1),
#  ('پنک ربن', 1),
#  ('میچ', 1),
#  ('’میچ', 1),
#  ('ٹکٹ', 1),
#  ('لان', 1),
#  ('سوٹ', 1),
#  ('ٹی ٹوئنٹی سیریز', 1),
#  ('بعد', 1),
#  ('سوشل میڈیا صارفین', 1),
#  ('خراب کارکردگی', 1),
#  ('دلچسپ تبصرے', 1),
#  ('سری لنکن کرکٹ ٹیم', 1),
#  ('پنجاب سیف سٹیز اتھارٹی', 1),
#  ('سیکورٹی بارے بریفنگ', 1),
#  ('سری لنکن ”ریلوکٹوں“', 1),
#  ('پاکستان کےخلاف ٹی ٹونٹی سیریز', 1),
#  ('مکمل کرلیا گرین شرٹسرنز', 1),
#  ('ہدف', 1),
#  ('ناکامبلے بازوں', 1),
#  ('ناقص کھیل', 1),
#  ('سرفراز احمد', 1),
#  ('کپتانی', 1),
#  ('جمع سری لنکن ٹیم', 1),
#  ('ٹی ٹونٹی سیریز', 1),
#  ('تحقیقات', 1),
#  ('جائیںمتن', 1),
#  ('خراج تحسین مہمان کھلاڑیوں', 1),
#  ('سٹیڈیم', 1),
#  ('خصوصی تصاویر', 1),
#  ('اعلیٰ پنجاب', 1),
#  ('کرکٹ سیریز', 1),
#  ('کھلاڑیوں', 1),
#  ('مینجمنٹ', 1),
#  ('اظہار تشکر انٹرنیشنل کرکٹ', 1),
#  ('خوش آئندامید', 1),
#  ('غیر ملکی ٹیمیں', 1),
#  ('محبتوں', 1),
#  ('پھول', 1),
#  ('واپسی', 1),
#  ('متاثرہ مریضوں', 1),
#  ('خطرات', 1),
#  ('پیشِ نظر ریورگارڈن اوردیگر', 1),
#  ('انسدادِڈینگی سپرے', 1),
#  ('ریورگارڈن اوراردگرد', 1),
#  ('انسدادِ ڈینگی سپرے رکنِ', 1),
#  ('قومی اسمبلی', 1),
#  ('ڈپٹی کمشنراسلام آباد اورایڈیشنل', 1),
#  ('خصوصی اقدامات', 1),
#  ('مشن ہےڈپٹی کمشنر بہاولنگر', 1),
#  ('فیصل آباد روڈ', 1),
#  ('ٹائر شاپس', 1),
#  ('ڈینگی لاوا', 1),
#  ('مالک دکان', 1),
#  ('راولپنڈی گھنٹوں', 1),
#  ('مزید شہری ڈینگی بخار', 1),
#  ('مبتلامریضوں', 1),
#  ('آئسولیشن وارڈ', 1),
#  ('مریض داخل', 1),
#  ('بچے', 1),
#  ('حالت تشویشناک', 1),
#  ('کنگ عبدالله ہسپتال', 1),
#  ('بیڈ', 1),
#  ('مشتمل وارڈ', 1),
#  ('انسداد ڈینگی سرگرمیاں', 1),
#  ('گھر گھر', 1),
#  ('عوامی آگاہی', 1),
#  ('سا تھ', 1),
#  ('ہنگامی بنیادوں', 1),
#  ('ڈور', 1),
#  ('آئوٹ ڈور سرولنس', 1),
#  ('موثر طریقہ', 1),
#  ('ڈاکٹر اعجاز وہرا', 1),
#  ('مسلم لیگ ن', 1),
#  ('ترجمان مریم اورنگزیب', 1),
#  ('اضافہ', 1),
#  ('اموات کیسز', 1),
#  ('ڈپٹی کمشنر جہلم محمد سیف انور جپہ', 1),
#  ('سیکرٹری پرائمری اینڈ سیکنڈری ہیلتھ کیئر کیپٹن عثمان', 1),
#  ('ہیڈ کوارٹر ہسپتال', 1),
#  ('دورہ انتظامات', 1),
#  ('سیکرٹری ہیلتھ', 1),
#  ('ہسپتال', 1),
#  ('ڈینگی مچھر سیکرٹری پرائمری اینڈ سکینڈری ہیلتھ کئیر', 1),
#  ('غلط گھروں', 1),
#  ('ہسٹری', 1),
#  ('سی او راولپنڈی', 1),
#  ('سخت سرزنش وکیل کالونی', 1),
#  ('راول ٹائون', 1),
#  ('لاروا برآمد', 1),
#  ('عوام ڈینگی مہم', 1),
#  ('مامور ٹیموں', 1),
#  ('ساتھ تعاون کریںڈاکٹر شاہد صد یق اپوز یشن انسا نی صحت', 1),
#  ('معا', 1),
#  ('ست', 1),
#  ('بازآ جائےرہنما تحریک انصاف', 1),
#  ('ہیںڈاکٹر عمران شاہ', 1),
#  ('ڈاکٹر عمران شاہ', 1),
#  ('حکومت پنجاب ڈینگی', 1),
#  ('ہےسردارعبدالحئی', 1),
#  ('نوٹس', 1),
#  ('صورت', 1),
#  ('ادارے', 1),
#  ('اسلام آباد انتظامیہ صحت فائونڈیشن', 1),
#  ('گائوں جنڈیالہ', 1),
#  ('مفت ڈینگی آگاہی میڈیکل کیمپ', 1),
#  ('ڈپٹی کمشنر عرفان علی کاٹھیا', 1),
#  ('کالجوں سکولوں', 1),
#  ('یونیورسٹیوں', 1),
#  ('پرگرامز', 1),
#  ('سیمینار', 1),
#  ('صالحہ', 1),
#  ('سعید طالبات', 1),
#  ('گھروںمیں صفائی', 1),
#  ('ضلعی انتظامیہ لاہو ر', 1),
#  ('الپوریشانگلہ', 1),
#  ('ڈینگی بے قابو ہوگیا مریضوں', 1),
#  ('مسلسل اضافے', 1),
#  ('تشویش۔محکمہ صحت وباء', 1),
#  ('ناکام بشام', 1),
#  ('مزیدافراد', 1),
#  ('ساہیوال ڈینگی', 1),
#  ('وائرس', 1),
#  ('سبب', 1),
#  ('افرادڈسٹر کٹ ھیڈ کوارٹر ہسپتال ساہیوال ڈینگی وارڈ دا خل', 1),
#  ('ٹیسٹ فری', 1),
#  ('سیکرٹری صحت کیپٹن ر محمد عثمان', 1),
#  ('ڈائریکٹرجنرل ہیلتھ سروسز ڈاکٹر کمالان گچکی', 1),
#  ('زیرصدارت لسبیلا', 1),
#  ('دیگر اضلاع', 1),
#  ('پیدا', 1),
#  ('سدباب', 1),
#  ('پیش رفت', 1),
#  ('ڈینگی۔۔۔', 1),
#  ('اموات', 1),
#  ('۔۔۔', 1),
#  ('بچائومہم کاآغازکردیا', 1),
#  ('وزیر اعظم', 1),
#  ('معاون', 1),
#  ('خصوصی برائے صحت ڈاکٹر ظفر مرزا', 1),
#  ('پیش نظر', 1),
#  ('نجی ہسپتالوں', 1),
#  ('صحت سہولت پروگرام', 1),
#  ('پینل', 1),
#  ('راولپنڈیڈینگی مریضوں', 1),
#  ('فوری تشخیص', 1),
#  ('لئے راولپنڈی', 1),
#  ('کوٹھہ کلاں مورگاہ', 1),
#  ('پہلے فلٹر کلینک', 1),
#  ('افتتاح', 1),
#  ('قڈینگی', 1),
#  ('روایتی طریقہ کار اختیار', 1),
#  ('نسیم صادق', 1),
#  ('ڈینگی مریض رپورٹ', 1),
#  ('معلومات', 1),
#  ('پیپلزپارٹی سندھ', 1),
#  ('خیبرپختوانخواہ', 1),
#  ('بگڑتی صورتحال', 1),
#  ('تشویش کااظہار', 1),
#  ('بلوچستان', 1),
#  ('تدارک', 1),
#  ('متاثرہ علاقوں', 1),
#  ('ٹیمیں تشکیل', 1),
#  ('میر نصیب اللہ مری', 1),
#  ('ڈپٹی کمشنر حیدرآباد', 1),
#  ('متعلقہ افسران', 1),
#  ('صفائی ستھرائی', 1),
#  ('موثر انتظامات', 1),
#  ('اسپرے', 1),
#  ('ڈینگی بے قابو', 1),
#  ('سیکنڈری بورڈ سرگودھا میں’’ ڈینگی', 1),
#  ('خاتمہ مہم', 1),
#  ('شہریوں کیساتھ', 1),
#  ('خوف', 1),
#  ('زدہ بیڈز', 1),
#  ('کم عملہ', 1),
#  ('قلت', 1),
#  ('تعلیمی اداروں', 1),
#  ('اوراحتیاطی تدابیر بارے', 1),
#  ('آگاہی کیلئے زیرو پیریڈز', 1),
#  ('خلاف مہم', 1),
#  ('لئے ایمرجنسی', 1),
#  ('شہباز', 1),
#  ('ڈینگی برادران', 1),
#  ('بابا محمد اسحاق', 1),
#  ('فیصل آباد ڈویژن', 1),
#  ('بچائو کیلئے فول', 1),
#  ('پروف انتظامات', 1),
#  ('ہیںاحتیاطی', 1),
#  ('حفاظتی تدارکی اقدامات', 1),
#  ('انسدادی صورتحال تسلی', 1),
#  ('ڈویژنل کمشنر محمود', 1),
#  ('جہلم انسداد ڈینگی', 1),
#  ('سلسلہ', 1),
#  ('زیر صدارت', 1),
#  ('پرائیویٹ اسکول ایسوسی ایشن', 1),
#  ('ساتھ اعلیٰ', 1),
#  ('سطحی اجلاس', 1),
#  ('ڈپٹی کمشنر محمد سیف انور جپہ', 1),
#  ('محکمہ تعلیم', 1),
#  ('ضلع کوٹلی', 1),
#  ('ڈسٹرکٹ ہیلتھ آفیسر کوٹلی محکمہ صحت عامہ ڈینگی', 1),
#  ('غرض', 1),
#  ('وہاڑیڈپٹی کمشنر عرفان علی کاٹھیا', 1),
#  ('ڈی ایچ کیو ہسپتال وہاڑی کادورہ ہسپتال', 1),
#  ('بارے', 1),
#  ('دریافت', 1),
#  ('گذشتہ گھنٹوں', 1),
#  ('دوران ڈینگی', 1),
#  ('اضافہ پنجاب', 1),
#  ('فیصد مریضوں', 1),
#  ('تعلق خطہ پوٹھوہار', 1),
#  ('وزارت نیشنل ہیلتھ سروسز', 1),
#  ('خانیوال ۔جب', 1),
#  ('ممکن نہیںڈپٹی کمشنرخانیوال', 1),
#  ('خانیوال ۔ضلع خانیوال', 1),
#  ('مریض سامنے', 1),
#  ('سی ای او ہیلتھ خانیوال', 1),
#  ('وہاڑی', 1),
#  ('احتیاطی تدابیر اختیار', 1),
#  ('مچھر', 1),
#  ('لاروے', 1),
#  ('ہےڈپٹی کمشنر عرفان علی کاٹھیا انسداد', 1),
#  ('ڈپٹی کمشنر آفس', 1),
#  ('ڈینگی بے قابو ہوگیاہسپتالوں', 1),
#  ('ساہیوال', 1),
#  ('ڈینگی فری', 1),
#  ('سخت اقدامات شروع', 1),
#  ('ہیںڈپٹی کمشنرساہیوال محمدزمان وٹو', 1),
#  ('نلیگ', 1),
#  ('میو ہسپتال', 1),
#  ('دورہ مریضوں', 1),
#  ('سہولیات', 1),
#  ('ذمہ', 1),
#  ('داروزیر اعلیٰ', 1),
#  ('ہیںوزیر صحت', 1),
#  ('ضلع', 1),
#  ('مکمل طور', 1),
#  ('ہےڈاکٹر', 1),
#  ('عبدالستار محکمہ صحت', 1),
#  ('علاقوں', 1),
#  ('ڈینگی مہم', 1),
#  ('ڈسٹرکٹ ہیلتھ', 1),
#  ('انسداد گندگی مہم خلاف ورزی', 1),
#  ('سروس سٹیشن', 1),
#  ('سیل', 1),
#  ('محکمہ صحت ڈینگی وائرس', 1),
#  ('راجہ محمد فاروق حیدر آزادکشمیر', 1),
#  ('ادارے محکمہ صحت', 1),
#  ('سرویلنس', 1),
#  ('آ ڈ ٹ', 1),
#  ('چاررکنی تھرڈ پارٹی تشکیل', 1),
#  ('جھنگ محکمہ', 1),
#  ('سوشل ویلفیئر', 1),
#  ('بیت الما ل', 1),
#  ('زیر اہتمام انسداد ڈینگی سیمینار', 1),
#  ('نرسیں ڈینگی بخار', 1),
#  ('رہنمائی', 1),
#  ('حوصلہ', 1),
#  ('ڈی جی نرسنگ', 1),
#  ('نرس', 1),
#  ('لواحقین', 1),
#  ('اچھا رویہ اختیار', 1),
#  ('قانون', 1),
#  ('مطابق', 1),
#  ('سی لاہور اصغر جوئیہ کاکوئینز روڈ', 1),
#  ('دورہ انسدادِ ڈینگی', 1),
#  ('ٹیموں', 1),
#  ('اصغر جوئیہ افسران ڈینگی ٹیموں', 1),
#  ('ہیںجہاں', 1),
#  ('ڈینگی لارا', 1),
#  ('مقدمات', 1),
#  ('لالہ', 1),
#  ('موسیٰ شہریوں', 1),
#  ('ڈینگی بارے شعور', 1),
#  ('بھرپورتو جہ', 1),
#  ('اعلیٰ وزیر صحت', 1),
#  ('پنجاب عوام', 1),
#  ('جان', 1),
#  ('مال', 1),
#  ('تحفظ', 1),
#  ('ناکامی', 1),
#  ('پرویز ملک پنجاب', 1),
#  ('پولیو', 1),
#  ('شدید تکلیف اوراذیت', 1),
#  ('میڈیسن', 1),
#  ('خاتمے کیلئے', 1),
#  ('بھرپور کاوشوں', 1),
#  ('مصروف عمل', 1),
#  ('ہیںایم ڈی راولپنڈی ویسٹ مینجمنٹ کمپنی اویس', 1),
#  ('منظور تارڑ', 1),
#  ('وزیراعلیٰ کاڈینگی', 1),
#  ('اضافے', 1),
#  ('سی بی', 1),
#  ('سی سمیت ڈینگی', 1),
#  ('اعلان راولپنڈی', 1),
#  ('فوری طور', 1),
#  ('موبائل ہیلتھ', 1),
#  ('قصور محکمہ صحت ڈینگی', 1),
#  ('ملک بدر', 1),
#  ('مرکزی کردار ادا', 1),
#  ('۔کراچی', 1),
#  ('کچرے', 1),
#  ('بات', 1),
#  ('پی ٹی آئی حکومت عمران خان', 1),
#  ('حلقے', 1),
#  ('خاموش اہلیان علاقہ', 1),
#  ('پریشان عمران خان', 1),
#  ('سابق حلقہ گندگی', 1),
#  ('سہولتیں فلفور', 1),
#  ('لاروا', 1),
#  ('اینٹی ڈینگی ٹیمیں', 1),
#  ('بھرپور کردار ادا', 1),
#  ('حافظ آباد ضلع', 1),
#  ('رواں سال', 1),
#  ('دوران ڈینگی لاروا', 1),
#  ('شخص', 1),
#  ('ہواڈپٹی کمشنر', 1),
#  ('نوید شہزاد مرزا', 1),
#  ('شہری ڈینگی', 1),
#  ('اختیار کریںساجد علی قریشی', 1),
#  ('ڈینگی کیسز', 1),
#  ('واضح فرق', 1),
#  ('ہےصوبائی وزیر صحت ڈینگی', 1),
#  ('مریضوںکی', 1),
#  ('بھال کیلئے ہولی فیملی ہسپتال', 1),
#  ('خصوصی آئوٹ', 1),
#  ('فیصل آباد', 1),
#  ('کیس سامنے', 1),
#  ('آیا ڈاکٹر معصومہ سردار', 1),
#  ('آگہی', 1),
#  ('بغیر ڈینگی', 1),
#  ('کاشف نثار', 1),
#  ('نجی ہائوسنگ سوسائٹی', 1),
#  ('مالکان', 1),
#  ('ڈینگی ایکٹ', 1),
#  ('دفعہکے نفاذ', 1),
#  ('تحریک', 1),
#  ('ڈی جی صحت آزاد کشمیر', 1),
#  ('سی لاہورکا سروسز ہسپتال', 1),
#  ('دورہ ڈینگی انتظامات', 1),
#  ('چھٹکارا', 1),
#  ('محکموں', 1),
#  ('ایڈیشنل', 1),
#  ('اسسٹنٹ کمشنرز', 1),
#  ('صفائی مہم بارے دورے', 1),
#  ('لوگ ڈینگی', 1),
#  ('کوآرڈنیٹر نیشنل پروگرام وڈائریکٹر', 1),
#  ('سی ڈی', 1),
#  ('عوام الناس', 1),
#  ('بچاؤ بارے', 1),
#  ('آگہی سیمینار', 1),
#  ('چیچہ وطنی ڈینگی', 1),
#  ('ذمہ داری', 1),
#  ('ہےصوبائی سیکرٹری', 1),
#  ('سوشل ویلفیئر عنبرین رضا', 1),
#  ('صوبائی وزیر صحت ڈاکٹر یاسمین راشد', 1),
#  ('ہولی فیملی ہسپتال', 1),
#  ('ڈینگی آئوٹ ڈور', 1),
#  ('دورہ ڈینگی', 1),
#  ('شکار مریضوں', 1),
#  ('طبی سہولیات', 1),
#  ('جان لیواء مرض', 1),
#  ('احیتاط', 1),
#  ('بھاری فنڈز خرچ', 1),
#  ('مقصد شہریوں', 1),
#  ('ڈینگی بے قا بو', 1),
#  ('حکومتی اقدامات افسران', 1),
#  ('تبادلوں', 1),
#  ('محدودحکومت', 1),
#  ('طرح صحت', 1),
#  ('بجٹ', 1),
#  ('خمیازہ آج عوام', 1),
#  ('ہیںایم ساجد عباسی ڈیل', 1),
#  ('ضلع چنیوٹ ڈینگی', 1),
#  ('خطرہ', 1),
#  ('ڈینگی مریضوںکیلئے صحت', 1),
#  ('بہترین سہولیات', 1),
#  ('ہیںیاسمین راشد ہسپتالوںمیں', 1),
#  ('اضافی بیڈز', 1),
#  ('ساتھ ساتھ', 1),
#  ('ڈاکٹروںاور پیرا میڈیکل سٹاف', 1),
#  ('تعیناتی', 1),
#  ('راولپنڈی ویسٹ مینجمنٹ کمپنی', 1),
#  ('البائراک', 1),
#  ('آگاہی مہم', 1),
#  ('خیبر پختو نخوا', 1),
#  ('متاثرہ افراد', 1),
#  ('غداری کیس', 1),
#  ('جسٹس وقار احمد سیٹھ', 1),
#  ('خصوصی عدالت', 1),
#  ('نیا سربراہ', 1),
#  ('وکیل رضا بشیر ڈینگی', 1),
#  ('شکار', 1),
#  ('التواء', 1),
#  ('وفاقی سیکرٹری صحت', 1),
#  ('زیرصدارت اجلاس', 1),
#  ('مؤثر اقدامات', 1),
#  ('شدہ مریضوں', 1),
#  ('کمر', 1),
#  ('ہےآصف محمود سرگودھا', 1),
#  ('بچائو بارے', 1),
#  ('آگاہی سیمینارسے مشیر وزیراعلی', 1),
#  ('خطاب', 1),
#  ('ہےکمشنر راولپنڈی ڈینگی ماہرین', 1),
#  ('یونین کونسلوں', 1),
#  ('کیس رسپانس', 1),
#  ('جڑواں شہر', 1),
#  ('سیکرٹری صحت افسران', 1),
#  ('ایمانداری لگن', 1),
#  ('جزبے', 1),
#  ('سر انجام دیںآفیشل بزنس', 1),
#  ('بنیاد', 1),
#  ('ڈینگی صحت', 1),
#  ('سوشل مسئلہ', 1),
#  ('کمیونٹی', 1),
#  ('شرکت لازم', 1),
#  ('ْڈینگی', 1),
#  ('انسٹی ٹیوٹ آف پبلک ہیلتھ', 1),
#  ('سٹوڈنٹس', 1),
#  ('ڈینگی کنٹرول', 1),
#  ('رپورٹ طلب', 1),
#  ('آر ایم یو', 1),
#  ('یونیورسٹی آف جارجیا', 1),
#  ('ڈینگی ماڈلنگ شروع', 1),
#  ('ہےکمشنر راولپنڈی ڈویژن', 1),
#  ('ضلعی انتظامیہ لاہور', 1),
#  ('اربن یونین کونسلز', 1),
#  ('کھیتوں', 1),
#  ('ڈینگی سرویلنس', 1),
#  ('عامرخٹک', 1),
#  ('چکوال', 1),
#  ('چمکیلی دھوپ', 1),
#  ('وار', 1),
#  ('وہاڑی۔ڈینگی', 1),
#  ('ٹیمیں گھر گھر', 1),
#  ('سرولنس', 1),
#  ('ہیںسی ای او ہیلتھ ڈاکٹر ارشد ملک', 1),
#  ('گھروں', 1),
#  ('ڈینگی ہاٹ سپاٹس', 1),
#  ('ڈاکٹر زرفشاں طاہر', 1),
#  ('موٹروے پولیس افسران', 1),
#  ('ملازمان', 1),
#  ('لئے ڈینگی', 1),
#  ('سیکرٹری ٹرانسپورٹ', 1)]

# %%
# Take top 1000 frequent noun phrases as Candidate labels as suggested by Mei et al.
top_1000_candid = freq_all_noun_chunks.most_common(1000)

# %%
candidate_labels_with_freq = []
for u,v in top_1000_candid:
    candidate_labels_with_freq.append((u,v))

# %%
candidate_labels_with_freq
# Out:
# [('ڈینگی', 74),
#  ('سی پیک', 22),
#  ('پاکستان', 17),
#  ('اظہار یکجہتی', 16),
#  ('انعقاد', 15),
#  ('حوالے', 14),
#  ('کشمیریوں', 13),
#  ('ریلی', 13),
#  ('تعداد', 12),
#  ('لئے', 11),
#  ('سی پیک اتھارٹی', 11),
#  ('اظہار', 11),
#  ('سری لنکن ٹیم', 10),
#  ('ڈینگی وائرس', 10),
#  ('مریضوں', 9),
#  ('ضلعی انتظامیہ', 8),
#  ('پنجاب', 8),
#  ('چین', 7),
#  ('خاتمہ', 7),
#  ('قابو', 7),
#  ('حکام', 6),
#  ('ڈپٹی کمشنر', 6),
#  ('ڈی', 6),
#  ('صفائی', 6),
#  ('دورہ', 5),
#  ('ملک', 5),
#  ('وفاقی حکومت', 5),
#  ('ترکی', 5),
#  ('اسلام آباد', 5),
#  ('وجہ', 5),
#  ('تجاوز', 5),
#  ('بچاؤ', 5),
#  ('انسداد ڈینگی', 5),
#  ('عوام', 5),
#  ('انسداد ڈینگی مہم', 5),
#  ('دورہ چین', 4),
#  ('آغاز', 4),
#  ('فیصلہ', 4),
#  ('سی آر', 4),
#  ('درمیان', 4),
#  ('شام', 4),
#  ('فوجی کارروائی', 4),
#  ('قرارداد', 4),
#  ('پنجاب اسمبلی', 4),
#  ('ساتھ اظہار یکجہتی', 4),
#  ('جانب', 4),
#  ('ساتھ', 4),
#  ('عیادت', 4),
#  ('اقدامات', 4),
#  ('آگاہی', 4),
#  ('تصدیق', 4),
#  ('سرکاری ہسپتالوں', 4),
#  ('کنٹرول', 4),
#  ('کارکردگی', 4),
#  ('جائزہ', 4),
#  ('بڑے پیمانے', 4),
#  ('داخل', 3),
#  ('غربت', 3),
#  ('صنعتی تعاون', 3),
#  ('وزیر', 3),
#  ('دوران', 3),
#  ('تکمیل', 3),
#  ('قیام', 3),
#  ('سفارشات', 3),
#  ('صورتحال', 3),
#  ('صوبہ', 3),
#  ('تحت', 3),
#  ('ترک فوجی کارروائی', 3),
#  ('شہریوں', 3),
#  ('طرف', 3),
#  ('مقبوضہ کشمیر', 3),
#  ('قیادت', 3),
#  ('کوچ', 3),
#  ('محکمہ صحت', 3),
#  ('راولپنڈی', 3),
#  ('بچائو', 3),
#  ('اہم اجلاس', 3),
#  ('مرض', 3),
#  ('تعاون', 3),
#  ('رپورٹ', 3),
#  ('جاری کردی', 3),
#  ('پنجاب حکومت', 3),
#  ('شہر', 3),
#  ('ڈینگی مریضوں', 3),
#  ('ڈینگی مچھر', 3),
#  ('کردار ادا', 3),
#  ('مکمل خاتمہ', 3),
#  ('افزائش', 3),
#  ('احتیاطی تدابیر', 3),
#  ('ضرورت', 3),
#  ('تشخیص', 3),
#  ('ممکن حکمت', 3),
#  ('توجہ', 2),
#  ('وفاقی وزیر', 2),
#  ('دوسرے مرحلہ', 2),
#  ('جمعہ', 2),
#  ('کمی', 2),
#  ('دوسرے مرحلے', 2),
#  ('چین پاکستان', 2),
#  ('خصوصی توجہ', 2),
#  ('وزیر اعظم عمران خان', 2),
#  ('کام', 2),
#  ('ذریعے', 2),
#  ('وزیراعظم عمران خان', 2),
#  ('وفد', 2),
#  ('خیبر پختونخوا', 2),
#  ('مدد', 2),
#  ('ایشو', 2),
#  ('سردمہری', 2),
#  ('رویہ', 2),
#  ('قابل افسوس', 2),
#  ('حالیہ دورے', 2),
#  ('نکات', 2),
#  ('بہتری', 2),
#  ('اے', 2),
#  ('تحت بلوچستان', 2),
#  ('روزگار', 2),
#  ('وزیراعظم', 2),
#  ('سی پیک اتھارٹی آرڈیننس', 2),
#  ('سربراہ', 2),
#  ('کراچی', 2),
#  ('سلامتی کونسل', 2),
#  ('مطالبہ', 2),
#  ('افراد', 2),
#  ('کشمیری خواتین', 2),
#  ('بحالی', 2),
#  ('کشمیری بھائیوں', 2),
#  ('خواتین', 2),
#  ('انسانی ہاتھوں', 2),
#  ('زنجیر', 2),
#  ('رہنمائوں', 2),
#  ('ہدایت', 2),
#  ('پاک سری لنکن ٹی ٹوئنٹی سیریز؛ ٹکٹوں', 2),
#  ('فروخت شروع', 2),
#  ('قذافی سٹیڈیم', 2),
#  ('سری لنکا', 2),
#  ('خلاف سیریز', 2),
#  ('برتری', 2),
#  ('حاصل مہمان', 2),
#  ('آخری میچ', 2),
#  ('سری لنکن آل راﺅنڈ ر تھیسارا پریرا', 2),
#  ('دورہ پاکستان', 2),
#  ('انکار', 2),
#  ('کیریبئن لیگ', 2),
#  ('دوران ڈینگی بخار ہوگیاڈاکٹر', 2),
#  ('ایڈوائس', 2),
#  ('آرام کررہا ہوںآل راﺅنڈر', 2),
#  ('قومی ٹیم', 2),
#  ('وائٹ واش', 2),
#  ('سکیورٹی اہلکاروں', 2),
#  ('دیگر', 2),
#  ('اُردو', 2),
#  ('راولپنڈی اسلام آباد', 2),
#  ('رہائشی آبادیوں', 2),
#  ('خلاف مقدمہ', 2),
#  ('پمز', 2),
#  ('حفاظتی تدابیر', 2),
#  ('عمل', 2),
#  ('اظہار تشویش', 2),
#  ('زیر صدارت ڈینگی', 2),
#  ('مبتلا مریضوں', 2),
#  ('مزید کیسز تعداد', 2),
#  ('سندھ', 2),
#  ('رواں برس کانگو', 2),
#  ('نگلیریا', 2),
#  ('افراد جان', 2),
#  ('بازی', 2),
#  ('روک تھام', 2),
#  ('ڈینگی لاروا برآمد', 2),
#  ('بچاؤ مہم', 2),
#  ('شہری حصہ', 2),
#  ('شہباز شاہین', 2),
#  ('زیر صدارت انسداد ڈینگی', 2),
#  ('گزشتہ روز', 2),
#  ('ٹیسٹ', 2),
#  ('علاج', 2),
#  ('حفاظتی اقدامات', 2),
#  ('علاقے', 2),
#  ('وزیر صحت', 2),
#  ('بعد خیبرپختونخوا', 2),
#  ('تقریب', 2),
#  ('ادویات', 2),
#  ('خانیوال', 2),
#  ('فرد', 2),
#  ('وقت', 2),
#  ('افسران', 2),
#  ('مریض', 2),
#  ('شعور', 2),
#  ('حد', 2),
#  ('خلاف مقدمات', 2),
#  ('وسائل', 2),
#  ('کار', 2),
#  ('ڈینگی لاروا', 2),
#  ('چیک', 2),
#  ('بھرپور طریقے', 2),
#  ('عوام ڈینگی', 2),
#  ('آزادکشمیر', 2),
#  ('خیبر پختون خوا', 2),
#  ('ڈینگی بے قابو گھنٹوں', 2),
#  ('مزید مریض اسپتال', 2),
#  ('سی لاہور', 2),
#  ('ممکنہ مضراثرات او راس', 2),
#  ('حکومت ڈینگی', 2),
#  ('لاہور', 2),
#  ('زیر علاج', 2),
#  ('ڈپٹی کمشنر سید امان انور قدوائی', 2),
#  ('آل پاکستان پرائیویٹ سکولز مینجمنٹ', 2),
#  ('رکنی وفد', 2),
#  ('ڈپٹی کمشنر راولپنڈی', 2),
#  ('ملاقات سیف اللہ ڈوگر', 2),
#  ('ضلعی انتظامیہ راولپنڈی', 2),
#  ('مشین', 2),
#  ('عطیہ', 2),
#  ('۷ملاقات', 2),
#  ('پرویز مشرف', 2),
#  ('درخواست', 2),
#  ('صورتحال قابو', 2),
#  ('فوگنگ', 2),
#  ('موثر اقدامات', 2),
#  ('وبا', 2),
#  ('خلاف', 2),
#  ('لوگ', 2),
#  ('نیشنل ہائی ویز اینڈ موٹروے پولیس', 2),
#  ('متعلق سیمینار', 2),
#  ('خیبرپختونخوا', 2),
#  ('عملدرآمد', 2),
#  ('ٹی ایم اے لاچی', 2),
#  ('صفائی مہم', 2),
#  ('شجر کاری', 2),
#  ('گھر گھر ڈینگی', 2),
#  ('سپرے', 2),
#  ('سی خانیوال', 2),
#  ('ڈینگی سیمینار', 2),
#  ('چیکنگ', 2),
#  ('ڈینگی وائر', 2),
#  ('سی پیک منصوبہ ختمآئی ایم ایف', 1),
#  ('شرائط پرعملدرآمد شروع امریکہ', 1),
#  ('خوشنودی', 1),
#  ('پاکستانی مفاد پسِ پشت', 1),
#  ('حکومت', 1),
#  ('تحت اکانامک زونز', 1),
#  ('رشکئی اکنامک زون گراونڈ بریکینگ', 1),
#  ('آئندہ ماہ افتتاح', 1),
#  ('منصوبہ بندی', 1),
#  ('کاموجودہ مرحلہ', 1),
#  ('پاکستانی عوام', 1),
#  ('معاشی فوائد', 1),
#  ('خاتمہ زراعت', 1),
#  ('اعلیٰ خیبر پختونخوا محمود خان', 1),
#  ('روز چترال', 1),
#  ('سرکاری دورہ وزیر اعلیٰ', 1),
#  ('متبادل روٹ چترل', 1),
#  ('متاثرہ ریشن بجلی گھر', 1),
#  ('شرح', 1),
#  ('اہم ترجیحات', 1),
#  ('حکومت عوام', 1),
#  ('ریلیف', 1),
#  ('فراہمی', 1),
#  ('عزم', 1),
#  ('اقتصادی راہداری منصوبہ', 1),
#  ('خاتمے زراعت', 1),
#  ('ممالک', 1),
#  ('مابین تعلقات', 1),
#  ('نئے دور', 1),
#  ('رفتار', 1),
#  ('شاہد رشید', 1),
#  ('صدارتی آرڈیننس', 1),
#  ('خیبرپختونخوا حکومت', 1),
#  ('متعلقہ محکموں', 1),
#  ('ترقیاتی منصوبوںکی', 1),
#  ('حتمی منصوبہ بندی', 1),
#  ('ہدایت صوبے', 1),
#  ('ترقیاتی منصوبوں', 1),
#  ('پچھلی وفاقی دور حکومت', 1),
#  ('سی پیک منصوبوں', 1),
#  ('حسن داد', 1),
#  ('چینی سرمایہ کاروں', 1),
#  ('انڈسٹریل زونز', 1),
#  ('اقتصادی راہداری', 1),
#  ('توانائی', 1),
#  ('شدید بحران پرقابو', 1),
#  ('بعد چینی صدر بھارت', 1),
#  ('شاہ محمود قریشی چین', 1),
#  ('اپوزیشن بلاوجہ', 1),
#  ('ایف اے ٹی ایف', 1),
#  ('ضکے', 1),
#  ('ہےسعید غنی وزیر اعظم', 1),
#  ('خطے', 1),
#  ('مزید تنازع', 1),
#  ('کوشش', 1),
#  ('سعودیہ', 1),
#  ('ایران', 1),
#  ('غلط فہماں دور', 1),
#  ('وزیر خارجہ', 1),
#  ('اگلے فیز', 1),
#  ('جانب آگے', 1),
#  ('پہلے مرحلے', 1),
#  ('بنیادی ڈھانچے', 1),
#  ('منصوبے', 1),
#  ('افغانستان', 1),
#  ('وسطی ایشیاء', 1),
#  ('روس', 1),
#  ('رسائی', 1),
#  ('چینی سفیر یاؤچنگ', 1),
#  ('اقتصادی زونز', 1),
#  ('مقامی صنعت ترقی', 1),
#  ('تحصیل بوستان', 1),
#  ('انڈسٹریل زون', 1),
#  ('کام تیزی', 1),
#  ('متعلقہ منصوبوں', 1),
#  ('پاکستانیوں', 1),
#  ('چیئرپرسن', 1),
#  ('مقرر آرڈیننس', 1),
#  ('احسن اقبال', 1),
#  ('آرڈیننس', 1),
#  ('خلاف قانون قرار', 1),
#  ('پارلیمانی کمیٹی', 1),
#  ('سیکرٹری', 1),
#  ('صدر مملکت عارف علوی', 1),
#  ('دستخط کردیئے', 1),
#  ('اطلاق', 1),
#  ('پورے پاکستان', 1),
#  ('وزیراعظم عمران خان اتھارٹی', 1),
#  ('معاشی ترقی', 1),
#  ('صنعتی انقلاب', 1),
#  ('جدید زراعتی نظام', 1),
#  ('عمل انگیز', 1),
#  ('طور', 1),
#  ('اقتصادی سفارتکاری', 1),
#  ('قومی مفاد', 1),
#  ('بھرپور تعاون', 1),
#  ('یقین دہانی وزیراعظم', 1),
#  ('چینی', 1),
#  ('منصب', 1),
#  ('ملاقاتمقبوضہ کشمیر', 1),
#  ('اورسی پیک', 1),
#  ('منصوبوں پرتبادلہ خیالچینی', 1),
#  ('سعید غنی', 1),
#  ('زیادتی', 1),
#  ('مترادف ہےصوبائی وزیر', 1),
#  ('کراچی سرکولر ریلوے', 1),
#  ('سردمہری قابل افسوس', 1),
#  ('ہےسعید غنی', 1),
#  ('دوران وزیراعظم', 1),
#  ('سی پیک اتھارٹی بارے', 1),
#  ('صدارتی آرڈیننس', 1),
#  ('جاری کرکے', 1),
#  ('شاندار اقدامات', 1),
#  ('کئےانوار الحق رامے', 1),
#  ('تحت اربوں ڈالر مالیت', 1),
#  ('ایم ایل۔ ون منصوبے', 1),
#  ('حتمی شکل', 1),
#  ('پشاور', 1),
#  ('ریلوے ٹریک', 1),
#  ('لمبائی', 1),
#  ('نیا سگنلنگ', 1),
#  ('قریبی دوست شراکت دار', 1),
#  ('آہنی برادرز', 1),
#  ('پاکستان غربت', 1),
#  ('تجربات', 1),
#  ('استفادہ', 1),
#  ('موجودہ حکومت', 1),
#  ('مواقع پیدا', 1),
#  ('پاک چین', 1),
#  ('فروغ', 1),
#  ('جامع فریم ورک', 1),
#  ('نئے منصوبوں', 1),
#  ('حسن دائودبٹ', 1),
#  ('چیف پلانرکنگ ژی وانگ', 1),
#  ('جاری منصوبوں', 1),
#  ('بروقت تکمیل', 1),
#  ('اطمینان', 1),
#  ('ترکی شام', 1),
#  ('کرد جنگجوؤں کیخلاف فوجی کارروائی', 1),
#  ('دےیورپی یونین', 1),
#  ('یورپی یونین شام', 1),
#  ('مجوزہ ’’سیف زون', 1),
#  ('رقم', 1),
#  ('عالمی برادری', 1),
#  ('صدر', 1),
#  ('جان ومال', 1),
#  ('حفاظت', 1),
#  ('تحمل', 1),
#  ('مظاہرہ', 1),
#  ('بعد شام', 1),
#  ('بڑے پیمانے پرلوگوں', 1),
#  ('نقل مکانی ْ راس العین', 1),
#  ('نقل مکانی', 1),
#  ('جنوبی علاقے الحسکہ', 1),
#  ('طرف جنوب', 1),
#  ('عالمی برادری کیشام', 1),
#  ('مذمت', 1),
#  ('غور', 1),
#  ('لئے اقوام متحدہ', 1),
#  ('اجلاس آج', 1),
#  ('رکن', 1),
#  ('یورپی ممالک', 1),
#  ('سیالکوٹ کشمیریوں', 1),
#  ('ڈسٹرکٹ ایجوکیشن اتھارٹی', 1),
#  ('اشتراک', 1),
#  ('وقار', 1),
#  ('وکلاء', 1),
#  ('کشمیری مسلمانوں', 1),
#  ('ستمبر', 1),
#  ('کنونشن', 1),
#  ('محمد ارشد اعوان ایڈووکیٹ', 1),
#  ('ہرنائی', 1),
#  ('ریلیاحتجاجی مظاہرہ', 1),
#  ('مظلوم', 1),
#  ('محکوم', 1),
#  ('محکمہ ترقی نسواں', 1),
#  ('زیر اہتمام یکجہتی ریلی', 1),
#  ('ڈیرہ مرادجمالی', 1),
#  ('شیخوپورہ', 1),
#  ('زیر اہتمام', 1),
#  ('بھارتی مظالم', 1),
#  ('کیخلاف سیمینار', 1),
#  ('کشمیر پاکستانیوں', 1),
#  ('رگوں', 1),
#  ('خون', 1),
#  ('طرح', 1),
#  ('مسرت جمشید چیمہ چیئر پرسن قائمہ کمیٹی داخلہ', 1),
#  ('کاشانہ ہوم', 1),
#  ('بچیوں', 1),
#  ('مظفرگڑھکشمیری عوام', 1),
#  ('کیلئی ریلیاں', 1),
#  ('عبدالوسیم پاکستان', 1),
#  ('سلامی', 1),
#  ('زندگی', 1),
#  ('شرف الدین', 1),
#  ('لئے گورنمنٹ گرلزکالج وہاڑی', 1),
#  ('پوری قوم', 1),
#  ('کھڑی ہےرانا شکیل احمد', 1),
#  ('شعبہ خواتین', 1),
#  ('کشمیر کمیٹی', 1),
#  ('زیر اہتمام پاکپتن', 1),
#  ('کوہلو کشمیریوں', 1),
#  ('نصیرآبادڈیرہ مرادجمالی', 1),
#  ('پاک فوج', 1),
#  ('حق', 1),
#  ('قبائلی رہنماء', 1),
#  ('وڈیرہ عرض محمد جتک', 1),
#  ('جتک ہاوس', 1),
#  ('الپوریضلع', 1),
#  ('مختلف تنظیموںمذہبی', 1),
#  ('وسیاسی جماعتوں', 1),
#  ('مختلف سکولوں کالجوں', 1),
#  ('طلباء۔ انجمن تاجران', 1),
#  ('ریلیاں', 1),
#  ('اوراحتجاجی مظاہرے', 1),
#  ('ڈپٹی کمشنر صحبت پور محمد یونس سنجرانی', 1),
#  ('قیادت میںکشمیر', 1),
#  ('مظلوم بھائیوں', 1),
#  ('کمشنر سبی ڈویژن سید فیصل احمد', 1),
#  ('مرکزی علماء کونسل', 1),
#  ('اپیل', 1),
#  ('ملک بھرمیں’’یوم ندائے کشمیر', 1),
#  ('اجتماعات', 1),
#  ('بھارتی مظالم کیخلاف مذمتی', 1),
#  ('گورنمنٹ ڈگری کالج سکھر', 1),
#  ('کشمیری عوام کیساتھ اظہار یکجہتی', 1),
#  ('کشمیر کمیٹی کراچی', 1),
#  ('تحت کشمیریوں', 1),
#  ('عظیم الشان موٹر سائیکل ریلی', 1),
#  ('بڑی تعداد', 1),
#  ('شرکت دنیا', 1),
#  ('طاقت کشمیری حریت پسندوں', 1),
#  ('حمایت', 1),
#  ('دکھاوا؟', 1),
#  ('پشین ۔پشین', 1),
#  ('کشمیری عوام', 1),
#  ('ساتھ اظہار', 1),
#  ('تحریک جوانان پاکستان', 1),
#  ('زیر اہتمام ریلی', 1),
#  ('مسئلہ کشمیر', 1),
#  ('بین الاقوامی فورم', 1),
#  ('حقیقی جذبے', 1),
#  ('نورالحق قادری', 1),
#  ('مذہبی امور کاکشمیریوں', 1),
#  ('گلوکارہ رابی پیر زادہ', 1),
#  ('نیا گانا ریکارڈ', 1),
#  ('سوشل میڈیا', 1),
#  ('اپ لوڈ', 1),
#  ('صدر جے آئی یوتھ چناری', 1),
#  ('مظاہرین', 1),
#  ('چناری', 1),
#  ('بھرپور استقبال', 1),
#  ('اظہار یکجہتی؛حکومت', 1),
#  ('اسلام', 1),
#  ('اعلان', 1),
#  ('مقبوضہ جموں کشمیر', 1),
#  ('مظلوموں', 1),
#  ('ڈاکٹر فردوس', 1),
#  ('عاشق اعوان', 1),
#  ('پہر بجے ایکسپریس چوک', 1),
#  ('حیدرآباد', 1),
#  ('شہری اکتوبر', 1),
#  ('کشمیر مارچ', 1),
#  ('بھرپور شرکت کرکے کشمیر', 1),
#  ('مظلوم عوام', 1),
#  ('حافظ', 1),
#  ('طاہر مجید', 1),
#  ('نواز', 1),
#  ('چوہدری شوگر', 1),
#  ('کیس', 1),
#  ('امکان ن لیگ', 1),
#  ('کارکنوں', 1),
#  ('ممکنہ پیشی', 1),
#  ('موقع', 1),
#  ('عدالت', 1),
#  ('باہر', 1),
#  ('لئے اکتوبر', 1),
#  ('یوم', 1),
#  ('وزارت داخلہ', 1),
#  ('نوٹیفکیشن', 1),
#  ('سری لنکنز', 1),
#  ('استقبال کراچی', 1),
#  ('بانہیں', 1),
#  ('انشاء اللہ انگلینڈ', 1),
#  ('ٹیم جلد', 1),
#  ('بین الاقوامی کرکٹ', 1),
#  ('انگلش لیگ اسپنر عادل رشید', 1),
#  ('پاک سری لنکن ٹی ٹونٹی کرکٹ سیریز سکیورٹی', 1),
#  ('حسب معمول', 1),
#  ('سخت اقدمات', 1),
#  ('سڑکوں', 1),
#  ('دوپہر', 1),
#  ('بجے', 1),
#  ('قسم', 1),
#  ('ٹریفک', 1),
#  ('گیادوپہر', 1),
#  ('ٹیم', 1),
#  ('ہارپر جواب', 1),
#  ('بائولنگ بیٹنگ', 1),
#  ('اچھی پرفارمنس', 1),
#  ('شعبوں', 1),
#  ('ہار', 1),
#  ('بعد ٹیم', 1),
#  ('خامیوں', 1),
#  ('پتہ', 1),
#  ('مضبوط ٹیم', 1),
#  ('آخری ٹی ٹونٹی انٹرنیشنل کرکٹ میچ آج', 1),
#  ('سری لنکن', 1),
#  ('کرکٹ ٹیموں', 1),
#  ('آخری ٹی ٹوئنٹی میچ', 1),
#  ('میچ شام بجکر منٹ', 1),
#  ('شروع', 1),
#  ('ہوگابرقی قمقموں', 1),
#  ('روشنی', 1),
#  ('سری', 1),
#  ('پاک سری لنکن ٹی ٹونٹی کرکٹ سیریز', 1),
#  ('آخری ٹی ٹونٹی انٹرنیشنل کرکٹ میچ', 1),
#  ('چھاتی', 1),
#  ('سرطان', 1),
#  ('پنک ربن ڈے پاکستان کرکٹ بورڈ', 1),
#  ('پاک سری لنکن ٹی ٹونٹی سیریز', 1),
#  ('پنک ربن', 1),
#  ('میچ', 1),
#  ('’میچ', 1),
#  ('ٹکٹ', 1),
#  ('لان', 1),
#  ('سوٹ', 1),
#  ('ٹی ٹوئنٹی سیریز', 1),
#  ('بعد', 1),
#  ('سوشل میڈیا صارفین', 1),
#  ('خراب کارکردگی', 1),
#  ('دلچسپ تبصرے', 1),
#  ('سری لنکن کرکٹ ٹیم', 1),
#  ('پنجاب سیف سٹیز اتھارٹی', 1),
#  ('سیکورٹی بارے بریفنگ', 1),
#  ('سری لنکن ”ریلوکٹوں“', 1),
#  ('پاکستان کےخلاف ٹی ٹونٹی سیریز', 1),
#  ('مکمل کرلیا گرین شرٹسرنز', 1),
#  ('ہدف', 1),
#  ('ناکامبلے بازوں', 1),
#  ('ناقص کھیل', 1),
#  ('سرفراز احمد', 1),
#  ('کپتانی', 1),
#  ('جمع سری لنکن ٹیم', 1),
#  ('ٹی ٹونٹی سیریز', 1),
#  ('تحقیقات', 1),
#  ('جائیںمتن', 1),
#  ('خراج تحسین مہمان کھلاڑیوں', 1),
#  ('سٹیڈیم', 1),
#  ('خصوصی تصاویر', 1),
#  ('اعلیٰ پنجاب', 1),
#  ('کرکٹ سیریز', 1),
#  ('کھلاڑیوں', 1),
#  ('مینجمنٹ', 1),
#  ('اظہار تشکر انٹرنیشنل کرکٹ', 1),
#  ('خوش آئندامید', 1),
#  ('غیر ملکی ٹیمیں', 1),
#  ('محبتوں', 1),
#  ('پھول', 1),
#  ('واپسی', 1),
#  ('متاثرہ مریضوں', 1),
#  ('خطرات', 1),
#  ('پیشِ نظر ریورگارڈن اوردیگر', 1),
#  ('انسدادِڈینگی سپرے', 1),
#  ('ریورگارڈن اوراردگرد', 1),
#  ('انسدادِ ڈینگی سپرے رکنِ', 1),
#  ('قومی اسمبلی', 1),
#  ('ڈپٹی کمشنراسلام آباد اورایڈیشنل', 1),
#  ('خصوصی اقدامات', 1),
#  ('مشن ہےڈپٹی کمشنر بہاولنگر', 1),
#  ('فیصل آباد روڈ', 1),
#  ('ٹائر شاپس', 1),
#  ('ڈینگی لاوا', 1),
#  ('مالک دکان', 1),
#  ('راولپنڈی گھنٹوں', 1),
#  ('مزید شہری ڈینگی بخار', 1),
#  ('مبتلامریضوں', 1),
#  ('آئسولیشن وارڈ', 1),
#  ('مریض داخل', 1),
#  ('بچے', 1),
#  ('حالت تشویشناک', 1),
#  ('کنگ عبدالله ہسپتال', 1),
#  ('بیڈ', 1),
#  ('مشتمل وارڈ', 1),
#  ('انسداد ڈینگی سرگرمیاں', 1),
#  ('گھر گھر', 1),
#  ('عوامی آگاہی', 1),
#  ('سا تھ', 1),
#  ('ہنگامی بنیادوں', 1),
#  ('ڈور', 1),
#  ('آئوٹ ڈور سرولنس', 1),
#  ('موثر طریقہ', 1),
#  ('ڈاکٹر اعجاز وہرا', 1),
#  ('مسلم لیگ ن', 1),
#  ('ترجمان مریم اورنگزیب', 1),
#  ('اضافہ', 1),
#  ('اموات کیسز', 1),
#  ('ڈپٹی کمشنر جہلم محمد سیف انور جپہ', 1),
#  ('سیکرٹری پرائمری اینڈ سیکنڈری ہیلتھ کیئر کیپٹن عثمان', 1),
#  ('ہیڈ کوارٹر ہسپتال', 1),
#  ('دورہ انتظامات', 1),
#  ('سیکرٹری ہیلتھ', 1),
#  ('ہسپتال', 1),
#  ('ڈینگی مچھر سیکرٹری پرائمری اینڈ سکینڈری ہیلتھ کئیر', 1),
#  ('غلط گھروں', 1),
#  ('ہسٹری', 1),
#  ('سی او راولپنڈی', 1),
#  ('سخت سرزنش وکیل کالونی', 1),
#  ('راول ٹائون', 1),
#  ('لاروا برآمد', 1),
#  ('عوام ڈینگی مہم', 1),
#  ('مامور ٹیموں', 1),
#  ('ساتھ تعاون کریںڈاکٹر شاہد صد یق اپوز یشن انسا نی صحت', 1),
#  ('معا', 1),
#  ('ست', 1),
#  ('بازآ جائےرہنما تحریک انصاف', 1),
#  ('ہیںڈاکٹر عمران شاہ', 1),
#  ('ڈاکٹر عمران شاہ', 1),
#  ('حکومت پنجاب ڈینگی', 1),
#  ('ہےسردارعبدالحئی', 1),
#  ('نوٹس', 1),
#  ('صورت', 1),
#  ('ادارے', 1),
#  ('اسلام آباد انتظامیہ صحت فائونڈیشن', 1),
#  ('گائوں جنڈیالہ', 1),
#  ('مفت ڈینگی آگاہی میڈیکل کیمپ', 1),
#  ('ڈپٹی کمشنر عرفان علی کاٹھیا', 1),
#  ('کالجوں سکولوں', 1),
#  ('یونیورسٹیوں', 1),
#  ('پرگرامز', 1),
#  ('سیمینار', 1),
#  ('صالحہ', 1),
#  ('سعید طالبات', 1),
#  ('گھروںمیں صفائی', 1),
#  ('ضلعی انتظامیہ لاہو ر', 1),
#  ('الپوریشانگلہ', 1),
#  ('ڈینگی بے قابو ہوگیا مریضوں', 1),
#  ('مسلسل اضافے', 1),
#  ('تشویش۔محکمہ صحت وباء', 1),
#  ('ناکام بشام', 1),
#  ('مزیدافراد', 1),
#  ('ساہیوال ڈینگی', 1),
#  ('وائرس', 1),
#  ('سبب', 1),
#  ('افرادڈسٹر کٹ ھیڈ کوارٹر ہسپتال ساہیوال ڈینگی وارڈ دا خل', 1),
#  ('ٹیسٹ فری', 1),
#  ('سیکرٹری صحت کیپٹن ر محمد عثمان', 1),
#  ('ڈائریکٹرجنرل ہیلتھ سروسز ڈاکٹر کمالان گچکی', 1),
#  ('زیرصدارت لسبیلا', 1),
#  ('دیگر اضلاع', 1),
#  ('پیدا', 1),
#  ('سدباب', 1),
#  ('پیش رفت', 1),
#  ('ڈینگی۔۔۔', 1),
#  ('اموات', 1),
#  ('۔۔۔', 1),
#  ('بچائومہم کاآغازکردیا', 1),
#  ('وزیر اعظم', 1),
#  ('معاون', 1),
#  ('خصوصی برائے صحت ڈاکٹر ظفر مرزا', 1),
#  ('پیش نظر', 1),
#  ('نجی ہسپتالوں', 1),
#  ('صحت سہولت پروگرام', 1),
#  ('پینل', 1),
#  ('راولپنڈیڈینگی مریضوں', 1),
#  ('فوری تشخیص', 1),
#  ('لئے راولپنڈی', 1),
#  ('کوٹھہ کلاں مورگاہ', 1),
#  ('پہلے فلٹر کلینک', 1),
#  ('افتتاح', 1),
#  ('قڈینگی', 1),
#  ('روایتی طریقہ کار اختیار', 1),
#  ('نسیم صادق', 1),
#  ('ڈینگی مریض رپورٹ', 1),
#  ('معلومات', 1),
#  ('پیپلزپارٹی سندھ', 1),
#  ('خیبرپختوانخواہ', 1),
#  ('بگڑتی صورتحال', 1),
#  ('تشویش کااظہار', 1),
#  ('بلوچستان', 1),
#  ('تدارک', 1),
#  ('متاثرہ علاقوں', 1),
#  ('ٹیمیں تشکیل', 1),
#  ('میر نصیب اللہ مری', 1),
#  ('ڈپٹی کمشنر حیدرآباد', 1),
#  ('متعلقہ افسران', 1),
#  ('صفائی ستھرائی', 1),
#  ('موثر انتظامات', 1),
#  ('اسپرے', 1),
#  ('ڈینگی بے قابو', 1),
#  ('سیکنڈری بورڈ سرگودھا میں’’ ڈینگی', 1),
#  ('خاتمہ مہم', 1),
#  ('شہریوں کیساتھ', 1),
#  ('خوف', 1),
#  ('زدہ بیڈز', 1),
#  ('کم عملہ', 1),
#  ('قلت', 1),
#  ('تعلیمی اداروں', 1),
#  ('اوراحتیاطی تدابیر بارے', 1),
#  ('آگاہی کیلئے زیرو پیریڈز', 1),
#  ('خلاف مہم', 1),
#  ('لئے ایمرجنسی', 1),
#  ('شہباز', 1),
#  ('ڈینگی برادران', 1),
#  ('بابا محمد اسحاق', 1),
#  ('فیصل آباد ڈویژن', 1),
#  ('بچائو کیلئے فول', 1),
#  ('پروف انتظامات', 1),
#  ('ہیںاحتیاطی', 1),
#  ('حفاظتی تدارکی اقدامات', 1),
#  ('انسدادی صورتحال تسلی', 1),
#  ('ڈویژنل کمشنر محمود', 1),
#  ('جہلم انسداد ڈینگی', 1),
#  ('سلسلہ', 1),
#  ('زیر صدارت', 1),
#  ('پرائیویٹ اسکول ایسوسی ایشن', 1),
#  ('ساتھ اعلیٰ', 1),
#  ('سطحی اجلاس', 1),
#  ('ڈپٹی کمشنر محمد سیف انور جپہ', 1),
#  ('محکمہ تعلیم', 1),
#  ('ضلع کوٹلی', 1),
#  ('ڈسٹرکٹ ہیلتھ آفیسر کوٹلی محکمہ صحت عامہ ڈینگی', 1),
#  ('غرض', 1),
#  ('وہاڑیڈپٹی کمشنر عرفان علی کاٹھیا', 1),
#  ('ڈی ایچ کیو ہسپتال وہاڑی کادورہ ہسپتال', 1),
#  ('بارے', 1),
#  ('دریافت', 1),
#  ('گذشتہ گھنٹوں', 1),
#  ('دوران ڈینگی', 1),
#  ('اضافہ پنجاب', 1),
#  ('فیصد مریضوں', 1),
#  ('تعلق خطہ پوٹھوہار', 1),
#  ('وزارت نیشنل ہیلتھ سروسز', 1),
#  ('خانیوال ۔جب', 1),
#  ('ممکن نہیںڈپٹی کمشنرخانیوال', 1),
#  ('خانیوال ۔ضلع خانیوال', 1),
#  ('مریض سامنے', 1),
#  ('سی ای او ہیلتھ خانیوال', 1),
#  ('وہاڑی', 1),
#  ('احتیاطی تدابیر اختیار', 1),
#  ('مچھر', 1),
#  ('لاروے', 1),
#  ('ہےڈپٹی کمشنر عرفان علی کاٹھیا انسداد', 1),
#  ('ڈپٹی کمشنر آفس', 1),
#  ('ڈینگی بے قابو ہوگیاہسپتالوں', 1),
#  ('ساہیوال', 1),
#  ('ڈینگی فری', 1),
#  ('سخت اقدامات شروع', 1),
#  ('ہیںڈپٹی کمشنرساہیوال محمدزمان وٹو', 1),
#  ('نلیگ', 1),
#  ('میو ہسپتال', 1),
#  ('دورہ مریضوں', 1),
#  ('سہولیات', 1),
#  ('ذمہ', 1),
#  ('داروزیر اعلیٰ', 1),
#  ('ہیںوزیر صحت', 1),
#  ('ضلع', 1),
#  ('مکمل طور', 1),
#  ('ہےڈاکٹر', 1),
#  ('عبدالستار محکمہ صحت', 1),
#  ('علاقوں', 1),
#  ('ڈینگی مہم', 1),
#  ('ڈسٹرکٹ ہیلتھ', 1),
#  ('انسداد گندگی مہم خلاف ورزی', 1),
#  ('سروس سٹیشن', 1),
#  ('سیل', 1),
#  ('محکمہ صحت ڈینگی وائرس', 1),
#  ('راجہ محمد فاروق حیدر آزادکشمیر', 1),
#  ('ادارے محکمہ صحت', 1),
#  ('سرویلنس', 1),
#  ('آ ڈ ٹ', 1),
#  ('چاررکنی تھرڈ پارٹی تشکیل', 1),
#  ('جھنگ محکمہ', 1),
#  ('سوشل ویلفیئر', 1),
#  ('بیت الما ل', 1),
#  ('زیر اہتمام انسداد ڈینگی سیمینار', 1),
#  ('نرسیں ڈینگی بخار', 1),
#  ('رہنمائی', 1),
#  ('حوصلہ', 1),
#  ('ڈی جی نرسنگ', 1),
#  ('نرس', 1),
#  ('لواحقین', 1),
#  ('اچھا رویہ اختیار', 1),
#  ('قانون', 1),
#  ('مطابق', 1),
#  ('سی لاہور اصغر جوئیہ کاکوئینز روڈ', 1),
#  ('دورہ انسدادِ ڈینگی', 1),
#  ('ٹیموں', 1),
#  ('اصغر جوئیہ افسران ڈینگی ٹیموں', 1),
#  ('ہیںجہاں', 1),
#  ('ڈینگی لارا', 1),
#  ('مقدمات', 1),
#  ('لالہ', 1),
#  ('موسیٰ شہریوں', 1),
#  ('ڈینگی بارے شعور', 1),
#  ('بھرپورتو جہ', 1),
#  ('اعلیٰ وزیر صحت', 1),
#  ('پنجاب عوام', 1),
#  ('جان', 1),
#  ('مال', 1),
#  ('تحفظ', 1),
#  ('ناکامی', 1),
#  ('پرویز ملک پنجاب', 1),
#  ('پولیو', 1),
#  ('شدید تکلیف اوراذیت', 1),
#  ('میڈیسن', 1),
#  ('خاتمے کیلئے', 1),
#  ('بھرپور کاوشوں', 1),
#  ('مصروف عمل', 1),
#  ('ہیںایم ڈی راولپنڈی ویسٹ مینجمنٹ کمپنی اویس', 1),
#  ('منظور تارڑ', 1),
#  ('وزیراعلیٰ کاڈینگی', 1),
#  ('اضافے', 1),
#  ('سی بی', 1),
#  ('سی سمیت ڈینگی', 1),
#  ('اعلان راولپنڈی', 1),
#  ('فوری طور', 1),
#  ('موبائل ہیلتھ', 1),
#  ('قصور محکمہ صحت ڈینگی', 1),
#  ('ملک بدر', 1),
#  ('مرکزی کردار ادا', 1),
#  ('۔کراچی', 1),
#  ('کچرے', 1),
#  ('بات', 1),
#  ('پی ٹی آئی حکومت عمران خان', 1),
#  ('حلقے', 1),
#  ('خاموش اہلیان علاقہ', 1),
#  ('پریشان عمران خان', 1),
#  ('سابق حلقہ گندگی', 1),
#  ('سہولتیں فلفور', 1),
#  ('لاروا', 1),
#  ('اینٹی ڈینگی ٹیمیں', 1),
#  ('بھرپور کردار ادا', 1),
#  ('حافظ آباد ضلع', 1),
#  ('رواں سال', 1),
#  ('دوران ڈینگی لاروا', 1),
#  ('شخص', 1),
#  ('ہواڈپٹی کمشنر', 1),
#  ('نوید شہزاد مرزا', 1),
#  ('شہری ڈینگی', 1),
#  ('اختیار کریںساجد علی قریشی', 1),
#  ('ڈینگی کیسز', 1),
#  ('واضح فرق', 1),
#  ('ہےصوبائی وزیر صحت ڈینگی', 1),
#  ('مریضوںکی', 1),
#  ('بھال کیلئے ہولی فیملی ہسپتال', 1),
#  ('خصوصی آئوٹ', 1),
#  ('فیصل آباد', 1),
#  ('کیس سامنے', 1),
#  ('آیا ڈاکٹر معصومہ سردار', 1),
#  ('آگہی', 1),
#  ('بغیر ڈینگی', 1),
#  ('کاشف نثار', 1),
#  ('نجی ہائوسنگ سوسائٹی', 1),
#  ('مالکان', 1),
#  ('ڈینگی ایکٹ', 1),
#  ('دفعہکے نفاذ', 1),
#  ('تحریک', 1),
#  ('ڈی جی صحت آزاد کشمیر', 1),
#  ('سی لاہورکا سروسز ہسپتال', 1),
#  ('دورہ ڈینگی انتظامات', 1),
#  ('چھٹکارا', 1),
#  ('محکموں', 1),
#  ('ایڈیشنل', 1),
#  ('اسسٹنٹ کمشنرز', 1),
#  ('صفائی مہم بارے دورے', 1),
#  ('لوگ ڈینگی', 1),
#  ('کوآرڈنیٹر نیشنل پروگرام وڈائریکٹر', 1),
#  ('سی ڈی', 1),
#  ('عوام الناس', 1),
#  ('بچاؤ بارے', 1),
#  ('آگہی سیمینار', 1),
#  ('چیچہ وطنی ڈینگی', 1),
#  ('ذمہ داری', 1),
#  ('ہےصوبائی سیکرٹری', 1),
#  ('سوشل ویلفیئر عنبرین رضا', 1),
#  ('صوبائی وزیر صحت ڈاکٹر یاسمین راشد', 1),
#  ('ہولی فیملی ہسپتال', 1),
#  ('ڈینگی آئوٹ ڈور', 1),
#  ('دورہ ڈینگی', 1),
#  ('شکار مریضوں', 1),
#  ('طبی سہولیات', 1),
#  ('جان لیواء مرض', 1),
#  ('احیتاط', 1),
#  ('بھاری فنڈز خرچ', 1),
#  ('مقصد شہریوں', 1),
#  ('ڈینگی بے قا بو', 1),
#  ('حکومتی اقدامات افسران', 1),
#  ('تبادلوں', 1),
#  ('محدودحکومت', 1),
#  ('طرح صحت', 1),
#  ('بجٹ', 1),
#  ('خمیازہ آج عوام', 1),
#  ('ہیںایم ساجد عباسی ڈیل', 1),
#  ('ضلع چنیوٹ ڈینگی', 1),
#  ('خطرہ', 1),
#  ('ڈینگی مریضوںکیلئے صحت', 1),
#  ('بہترین سہولیات', 1),
#  ('ہیںیاسمین راشد ہسپتالوںمیں', 1),
#  ('اضافی بیڈز', 1),
#  ('ساتھ ساتھ', 1),
#  ('ڈاکٹروںاور پیرا میڈیکل سٹاف', 1),
#  ('تعیناتی', 1),
#  ('راولپنڈی ویسٹ مینجمنٹ کمپنی', 1),
#  ('البائراک', 1),
#  ('آگاہی مہم', 1),
#  ('خیبر پختو نخوا', 1),
#  ('متاثرہ افراد', 1),
#  ('غداری کیس', 1),
#  ('جسٹس وقار احمد سیٹھ', 1),
#  ('خصوصی عدالت', 1),
#  ('نیا سربراہ', 1),
#  ('وکیل رضا بشیر ڈینگی', 1),
#  ('شکار', 1),
#  ('التواء', 1),
#  ('وفاقی سیکرٹری صحت', 1),
#  ('زیرصدارت اجلاس', 1),
#  ('مؤثر اقدامات', 1),
#  ('شدہ مریضوں', 1),
#  ('کمر', 1),
#  ('ہےآصف محمود سرگودھا', 1),
#  ('بچائو بارے', 1),
#  ('آگاہی سیمینارسے مشیر وزیراعلی', 1),
#  ('خطاب', 1),
#  ('ہےکمشنر راولپنڈی ڈینگی ماہرین', 1),
#  ('یونین کونسلوں', 1),
#  ('کیس رسپانس', 1),
#  ('جڑواں شہر', 1),
#  ('سیکرٹری صحت افسران', 1),
#  ('ایمانداری لگن', 1),
#  ('جزبے', 1),
#  ('سر انجام دیںآفیشل بزنس', 1),
#  ('بنیاد', 1),
#  ('ڈینگی صحت', 1),
#  ('سوشل مسئلہ', 1),
#  ('کمیونٹی', 1),
#  ('شرکت لازم', 1),
#  ('ْڈینگی', 1),
#  ('انسٹی ٹیوٹ آف پبلک ہیلتھ', 1),
#  ('سٹوڈنٹس', 1),
#  ('ڈینگی کنٹرول', 1),
#  ('رپورٹ طلب', 1),
#  ('آر ایم یو', 1),
#  ('یونیورسٹی آف جارجیا', 1),
#  ('ڈینگی ماڈلنگ شروع', 1),
#  ('ہےکمشنر راولپنڈی ڈویژن', 1),
#  ('ضلعی انتظامیہ لاہور', 1),
#  ('اربن یونین کونسلز', 1),
#  ('کھیتوں', 1),
#  ('ڈینگی سرویلنس', 1),
#  ('عامرخٹک', 1),
#  ('چکوال', 1),
#  ('چمکیلی دھوپ', 1),
#  ('وار', 1),
#  ('وہاڑی۔ڈینگی', 1),
#  ('ٹیمیں گھر گھر', 1),
#  ('سرولنس', 1),
#  ('ہیںسی ای او ہیلتھ ڈاکٹر ارشد ملک', 1),
#  ('گھروں', 1),
#  ('ڈینگی ہاٹ سپاٹس', 1),
#  ('ڈاکٹر زرفشاں طاہر', 1),
#  ('موٹروے پولیس افسران', 1),
#  ('ملازمان', 1),
#  ('لئے ڈینگی', 1),
#  ('سیکرٹری ٹرانسپورٹ', 1)]

# %%
def string_contains(str1,str2):
    lst1 = str1.split(' ')
    lst2 = str2.split(' ')

    if len(lst1) <= len(lst2):
        return lst1 == lst2[:len(lst1)]

    return False
def compute_c_value(row):
    #if non-nested
    if len(row.Containing_Strings) == 0:
        CValue = math.log2(len(row.Candidate_Label.split(' '))) * row.Frequency
    else:
        sum_f=0
        for i in range(0,len(row.Containing_Strings)):
             sum_f = sum_f+row.Containing_Strings[i][1]
        CValue = math.log2(len(row.Candidate_Label.split(' '))) * (row.Frequency - 1/len(row.Containing_Strings) * sum_f)
    return CValue
def find_if_short_term(row,df):
#To introduce the notion of “termhood” [11], we define that a
#term t is a short term if it is nested in a longer term t' that has a bigger value
#for some base measure of termhood (e.g., c-value).
    short_term = False
    if len(row.Containing_Strings) > 0:
        for i in range(0,len(row.Containing_Strings)):
            x = df[df['Candidate_Label']==row.Containing_Strings[i][0]].index.values
            index_of_bigger_term=x[0]
            if df.iloc[index_of_bigger_term]['CValue'] > row.CValue:
                short_term = True
                break
    return short_term

# %%
#Computing C-values
containing_strings = []
candidate_labels=[]
freq_candidate_labels=[]
for i in range(0,len(candidate_labels_with_freq)):
    candidate_labels.append(candidate_labels_with_freq[i][0])
    freq_candidate_labels.append(candidate_labels_with_freq[i][1])
    containing_strings_for_i=[]
    for j in range(0,len(candidate_labels_with_freq)):
        if string_contains(candidate_labels_with_freq[i][0],candidate_labels_with_freq[j][0]) and len(candidate_labels_with_freq[j][0]) > len(candidate_labels_with_freq[i][0]):
            containing_strings_for_i.append(candidate_labels_with_freq[j])
    containing_strings.append(containing_strings_for_i)

# %%
c_value_pd = pd.DataFrame({'Candidate_Label':candidate_labels,'Frequency':freq_candidate_labels,'Containing_Strings':containing_strings})

# %%
c_value_pd
# Out:
#                       Candidate_Label  Frequency  \
# 0                               ڈینگی         74
# 1                              سی پیک         22
# 2                             پاکستان         17
# 3                        اظہار یکجہتی         16
# 4                              انعقاد         15
# 5                               حوالے         14
# 6                            کشمیریوں         13
# 7                                ریلی         13
# 8                               تعداد         12
# 9                                 لئے         11
# 10                     سی پیک اتھارٹی         11
# 11                              اظہار         11
# 12                       سری لنکن ٹیم         10
# 13                        ڈینگی وائرس         10
# 14                             مریضوں          9
# 15                      ضلعی انتظامیہ          8
# 16                              پنجاب          8
# 17                                چین          7
# 18                              خاتمہ          7
# 19                               قابو          7
# 20                               حکام          6
# 21                         ڈپٹی کمشنر          6
# 22                                 ڈی          6
# 23                              صفائی          6
# 24                               دورہ          5
# 25                                ملک          5
# 26                        وفاقی حکومت          5
# 27                               ترکی          5
# 28                        اسلام آباد          5
# 29                                وجہ          5
# ..                                ...        ...
# 970                           کمیونٹی          1
# 971                         شرکت لازم          1
# 972                            ْڈینگی          1
# 973          انسٹی ٹیوٹ آف پبلک ہیلتھ          1
# 974                           سٹوڈنٹس          1
# 975                      ڈینگی کنٹرول          1
# 976                         رپورٹ طلب          1
# 977                        آر ایم یو          1
# 978              یونیورسٹی آف جارجیا          1
# 979                 ڈینگی ماڈلنگ شروع          1
# 980            ہےکمشنر راولپنڈی ڈویژن          1
# 981               ضلعی انتظامیہ لاہور          1
# 982                 اربن یونین کونسلز          1
# 983                            کھیتوں          1
# 984                     ڈینگی سرویلنس          1
# 985                           عامرخٹک          1
# 986                             چکوال          1
# 987                       چمکیلی دھوپ          1
# 988                               وار          1
# 989                       وہاڑی۔ڈینگی          1
# 990                     ٹیمیں گھر گھر          1
# 991                            سرولنس          1
# 992  ہیںسی ای او ہیلتھ ڈاکٹر ارشد ملک          1
# 993                             گھروں          1
# 994                   ڈینگی ہاٹ سپاٹس          1
# 995                 ڈاکٹر زرفشاں طاہر          1
# 996               موٹروے پولیس افسران          1
# 997                           ملازمان          1
# 998                         لئے ڈینگی          1
# 999                 سیکرٹری ٹرانسپورٹ          1
#
#                                     Containing_Strings
# 0    [(ڈینگی وائرس, 10), (ڈینگی مریضوں, 3), (ڈینگی ...
# 1    [(سی پیک اتھارٹی, 11), (سی پیک اتھارٹی آرڈینن...
# 2    [(پاکستان غربت, 1), (پاکستان کےخلاف ٹی ٹونٹی س...
# 3                                                   []
# 4                                                   []
# 5                                                   []
# 6                                                   []
# 7                                                   []
# 8                                                   []
# 9    [(لئے اقوام متحدہ, 1), (لئے گورنمنٹ گرلزکالج و...
# 10   [(سی پیک اتھارٹی آرڈیننس, 2), (سی پیک اتھارٹی...
# 11   [(اظہار یکجہتی, 16), (اظہار تشویش, 2), (اظہار ...
# 12                                                  []
# 13                                                  []
# 14                                                  []
# 15   [(ضلعی انتظامیہ راولپنڈی, 2), (ضلعی انتظامیہ ل...
# 16   [(پنجاب اسمبلی, 4), (پنجاب حکومت, 3), (پنجاب س...
# 17                                  [(چین پاکستان, 2)]
# 18                  [(خاتمہ زراعت, 1), (خاتمہ مہم, 1)]
# 19                                                  []
# 20                                                  []
# 21   [(ڈپٹی کمشنر سید امان انور قدوائی, 2), (ڈپٹی ک...
# 22   [(ڈی ایچ کیو ہسپتال وہاڑی کادورہ ہسپتال, 1), (...
# 23   [(صفائی مہم, 2), (صفائی ستھرائی, 1), (صفائی مہ...
# 24   [(دورہ چین, 4), (دورہ پاکستان, 2), (دورہ انتظا...
# 25    [(ملک بھرمیں’’یوم ندائے کشمیر, 1), (ملک بدر, 1)]
# 26                                                  []
# 27                                     [(ترکی شام, 1)]
# 28           [(اسلام آباد انتظامیہ صحت فائونڈیشن, 1)]
# 29                                                  []
# ..                                                 ...
# 970                                                 []
# 971                                                 []
# 972                                                 []
# 973                                                 []
# 974                                                 []
# 975                                                 []
# 976                                                 []
# 977                                                 []
# 978                                                 []
# 979                                                 []
# 980                                                 []
# 981                                                 []
# 982                                                 []
# 983                                                 []
# 984                                                 []
# 985                                                 []
# 986                                                 []
# 987                                                 []
# 988                                                 []
# 989                                                 []
# 990                                                 []
# 991                                                 []
# 992                                                 []
# 993                                                 []
# 994                                                 []
# 995                                                 []
# 996                                                 []
# 997                                                 []
# 998                                                 []
# 999                                                 []
#
# [1000 rows x 3 columns]

# %%
c_values =[]
for index,row in c_value_pd.iterrows():
    c_values.append(compute_c_value(row))

# %%
c_value_pd['CValue'] = c_values

# %%
is_short_term =[]
for index,row in c_value_pd.iterrows():
    is_short_term.append(find_if_short_term(row,c_value_pd))

# %%
c_value_pd['ShortTerm'] = is_short_term

# %%
c_value_pd
# Out:
#                       Candidate_Label  Frequency  \
# 0                               ڈینگی         74
# 1                              سی پیک         22
# 2                             پاکستان         17
# 3                        اظہار یکجہتی         16
# 4                              انعقاد         15
# 5                               حوالے         14
# 6                            کشمیریوں         13
# 7                                ریلی         13
# 8                               تعداد         12
# 9                                 لئے         11
# 10                     سی پیک اتھارٹی         11
# 11                              اظہار         11
# 12                       سری لنکن ٹیم         10
# 13                        ڈینگی وائرس         10
# 14                             مریضوں          9
# 15                      ضلعی انتظامیہ          8
# 16                              پنجاب          8
# 17                                چین          7
# 18                              خاتمہ          7
# 19                               قابو          7
# 20                               حکام          6
# 21                         ڈپٹی کمشنر          6
# 22                                 ڈی          6
# 23                              صفائی          6
# 24                               دورہ          5
# 25                                ملک          5
# 26                        وفاقی حکومت          5
# 27                               ترکی          5
# 28                        اسلام آباد          5
# 29                                وجہ          5
# ..                                ...        ...
# 970                           کمیونٹی          1
# 971                         شرکت لازم          1
# 972                            ْڈینگی          1
# 973          انسٹی ٹیوٹ آف پبلک ہیلتھ          1
# 974                           سٹوڈنٹس          1
# 975                      ڈینگی کنٹرول          1
# 976                         رپورٹ طلب          1
# 977                        آر ایم یو          1
# 978              یونیورسٹی آف جارجیا          1
# 979                 ڈینگی ماڈلنگ شروع          1
# 980            ہےکمشنر راولپنڈی ڈویژن          1
# 981               ضلعی انتظامیہ لاہور          1
# 982                 اربن یونین کونسلز          1
# 983                            کھیتوں          1
# 984                     ڈینگی سرویلنس          1
# 985                           عامرخٹک          1
# 986                             چکوال          1
# 987                       چمکیلی دھوپ          1
# 988                               وار          1
# 989                       وہاڑی۔ڈینگی          1
# 990                     ٹیمیں گھر گھر          1
# 991                            سرولنس          1
# 992  ہیںسی ای او ہیلتھ ڈاکٹر ارشد ملک          1
# 993                             گھروں          1
# 994                   ڈینگی ہاٹ سپاٹس          1
# 995                 ڈاکٹر زرفشاں طاہر          1
# 996               موٹروے پولیس افسران          1
# 997                           ملازمان          1
# 998                         لئے ڈینگی          1
# 999                 سیکرٹری ٹرانسپورٹ          1
#
#                                     Containing_Strings     CValue  ShortTerm
# 0    [(ڈینگی وائرس, 10), (ڈینگی مریضوں, 3), (ڈینگی ...   0.000000       True
# 1    [(سی پیک اتھارٹی, 11), (سی پیک اتھارٹی آرڈینن...  18.800000      False
# 2    [(پاکستان غربت, 1), (پاکستان کےخلاف ٹی ٹونٹی س...   0.000000       True
# 3                                                   []  16.000000      False
# 4                                                   []   0.000000      False
# 5                                                   []   0.000000      False
# 6                                                   []   0.000000      False
# 7                                                   []   0.000000      False
# 8                                                   []   0.000000      False
# 9    [(لئے اقوام متحدہ, 1), (لئے گورنمنٹ گرلزکالج و...   0.000000       True
# 10   [(سی پیک اتھارٹی آرڈیننس, 2), (سی پیک اتھارٹی...  15.057144      False
# 11   [(اظہار یکجہتی, 16), (اظہار تشویش, 2), (اظہار ...   0.000000       True
# 12                                                  []  15.849625      False
# 13                                                  []  10.000000      False
# 14                                                  []   0.000000      False
# 15   [(ضلعی انتظامیہ راولپنڈی, 2), (ضلعی انتظامیہ ل...   6.666667      False
# 16   [(پنجاب اسمبلی, 4), (پنجاب حکومت, 3), (پنجاب س...   0.000000       True
# 17                                  [(چین پاکستان, 2)]   0.000000       True
# 18                  [(خاتمہ زراعت, 1), (خاتمہ مہم, 1)]   0.000000       True
# 19                                                  []   0.000000      False
# 20                                                  []   0.000000      False
# 21   [(ڈپٹی کمشنر سید امان انور قدوائی, 2), (ڈپٹی ک...   4.750000       True
# 22   [(ڈی ایچ کیو ہسپتال وہاڑی کادورہ ہسپتال, 1), (...   0.000000       True
# 23   [(صفائی مہم, 2), (صفائی ستھرائی, 1), (صفائی مہ...   0.000000       True
# 24   [(دورہ چین, 4), (دورہ پاکستان, 2), (دورہ انتظا...   0.000000       True
# 25    [(ملک بھرمیں’’یوم ندائے کشمیر, 1), (ملک بدر, 1)]   0.000000       True
# 26                                                  []   5.000000      False
# 27                                     [(ترکی شام, 1)]   0.000000       True
# 28           [(اسلام آباد انتظامیہ صحت فائونڈیشن, 1)]   4.000000      False
# 29                                                  []   0.000000      False
# ..                                                 ...        ...        ...
# 970                                                 []   0.000000      False
# 971                                                 []   1.000000      False
# 972                                                 []   0.000000      False
# 973                                                 []   2.321928      False
# 974                                                 []   0.000000      False
# 975                                                 []   1.000000      False
# 976                                                 []   1.000000      False
# 977                                                 []   1.584963      False
# 978                                                 []   1.584963      False
# 979                                                 []   1.584963      False
# 980                                                 []   1.584963      False
# 981                                                 []   1.584963      False
# 982                                                 []   1.584963      False
# 983                                                 []   0.000000      False
# 984                                                 []   1.000000      False
# 985                                                 []   0.000000      False
# 986                                                 []   0.000000      False
# 987                                                 []   1.000000      False
# 988                                                 []   0.000000      False
# 989                                                 []   0.000000      False
# 990                                                 []   1.584963      False
# 991                                                 []   0.000000      False
# 992                                                 []   2.807355      False
# 993                                                 []   0.000000      False
# 994                                                 []   1.584963      False
# 995                                                 []   1.584963      False
# 996                                                 []   1.584963      False
# 997                                                 []   0.000000      False
# 998                                                 []   1.000000      False
# 999                                                 []   1.000000      False
#
# [1000 rows x 5 columns]

# %%
def t_order(freq,theta,c_value_pd,k,totaltopics):
    # bob la liste qui contient tous les numéros de topic (lignes), sauf celui du topic selectionné
    bob =list(range(totaltopics))
    del bob[k]
    
    # M la moyenne des proba d'avoir le mot, sachant qu'on est pas dans le topic k
    M=theta[bob,:].mean(axis=0)
    #print(M)
    #W matrice qui contient le score de chaque mot pour chaque topic
    W=np.log(theta[k]/M)
    
    score=[]
    for indice in range (len(c_value_pd)):
        if c_value_pd.iloc[indice]['ShortTerm'] == True:
            score.append(0)
        else:
            lCandidat = c_value_pd.Candidate_Label

            candidat=lCandidat[indice].split(" ")
            sum_w=[]
            #print(candidat)
            for w in candidat:
                if w in vocab:
                    i=vocab.index(w)
                    sum_w.append(W[i])
                else:
                    sum_w.append(0)
            #i=id2word.doc2idx(candidat)
            # supprime les -1 (qui signifie pas trouvé)
            #i[:] = [v for v in i if v != -1]
            score.append(np.sum(sum_w))

    #topValue, topCandidate = top10Score(score,lCandidat)
    dicti=pd.DataFrame({'Labels':lCandidat,'Score':score})
  
    return dicti

def m_order(freq,theta,lCandidat,k,totaltopics):
    """
    Calculate the M-Order Relevance

    Parameters:
    ----------
    freq : Array containing the frequency of occurrences of each word in the whole corpus
    theta : Array containing the frequency of occurrences of each word in each topic
    lcandidat: Array containing each label candidate
    k : The number of the topic
    
    Returns:
    -------
    topCandidate : Array containing the name of the top 10 score candidate for a given topic
    """
    # bob la liste qui contient tous les numéros de topic (lignes), sauf celui du topic selectionné
    bob =list(range(totaltopics))
    del bob[k]
    
    # M la moyenne des proba d'avoir le mot, sachant qu'on est pas dans le topic k
    M=theta[bob,:].mean(axis=0)
    #print(M)
    #W matrice qui contient le score de chaque mot pour chaque topic
    W=np.log(theta[k]/M)
    
    score=[]
    for indice in range (len(lCandidat)):
        candidat=lCandidat[indice].split(" ")
        sum_w=[]
        #print(candidat)
        for w in candidat:
            if w in vocab:
                i=vocab.index(w)
                sum_w.append(W[i])
            else:
                sum_w.append(0)
        #i=id2word.doc2idx(candidat)
        # supprime les -1 (qui signifie pas trouvé)
        #i[:] = [v for v in i if v != -1]
        score.append(np.sum(sum_w))
        
    #topValue, topCandidate = top10Score(score,lCandidat)
    dicti=pd.DataFrame({'Labels':lCandidat,'Score':score})
  
    return dicti

def zero_order(freq,theta,lCandidat,NumTopic):
    """
    Calculate the Zero-Order Relevance

    Parameters:
    ----------
    freq : Array containing the frequency of occurrences of each word in the whole corpus
    theta : Array containing the frequency of occurrences of each word in each topic
    lcandidat: Array containing each label candidate
    NumTopic : The number of the topic
    
    Returns:
    -------
    topCandidate : Array containing the name of the top 10 score candidate for a given topic
    """
    
    #W matrice qui contient le score de chaque mot pour chaque topic
    W=np.log(theta/freq)
    
    # score des tous les candidats pour le topic NumTopic
    score=[]
    
    for indice in range (len(lCandidat)):
        candidat=lCandidat[indice].split(" ")
        sum_w=[]
        #print(candidat)
        for w in candidat:
            if w in vocab:
                i=vocab.index(w)
                sum_w.append(W[k,i])
            else:
                sum_w.append(0)
        #i=id2word.doc2idx(candidat)
        # supprime les -1 (qui signifie pas trouvé)
        #i[:] = [v for v in i if v != -1]
        
        score.append(np.sum(sum_w))
        
    #topValue, topCandidate = top10Score(score,lCandidat)
    dicti=pd.DataFrame({'Labels':lCandidat,'Score':score})
  
    return dicti

# %%
labels_zero_order=[]
for k in range(0,kn.knee):
    print("Topic %d"%k)
    candid_for_topic_k = zero_order(freq,theta,c_value_pd.Candidate_Label,k)
    candid_for_topic_k = candid_for_topic_k.sort_values('Score',ascending=False)
    print(candid_for_topic_k.head(3))
    print("=======================")
    labels_zero_order.append(candid_for_topic_k.iloc[0]['Labels'])
# Out:
# Topic 0
# C:\Users\Zarmeen\Anaconda2\envs\py36\lib\site-packages\ipykernel_launcher.py:101: RuntimeWarning: divide by zero encountered in log
#                 Labels     Score
# 372           ترکی شام  5.027776
# 67   ترک فوجی کارروائی  4.933145
# 41       فوجی کارروائی  4.933145
# =======================
# Topic 1
#                                     Labels     Score
# 759  ڈی ایچ کیو ہسپتال وہاڑی کادورہ ہسپتال  4.439810
# 814                            ڈی جی نرسنگ  1.756092
# 22                                      ڈی  1.756092
# =======================
# Topic 2
#                     Labels     Score
# 84              ڈینگی مچھر  0.982508
# 201  ممکنہ مضراثرات او راس  0.936505
# 232          ڈینگی سیمینار  0.870673
# =======================
# Topic 3
#                       Labels     Score
# 344      سی پیک اتھارٹی بارے  3.473964
# 118  سی پیک اتھارٹی آرڈیننس  3.473964
# 10            سی پیک اتھارٹی  3.473964
# =======================
# Topic 4
#                   Labels     Score
# 103   وزیراعظم عمران خان  2.955903
# 100  وزیر اعظم عمران خان  2.630050
# 274       سی پیک منصوبوں  1.915823
# =======================
# Topic 5
#                    Labels     Score
# 981   ضلعی انتظامیہ لاہور  3.064963
# 15          ضلعی انتظامیہ  2.988207
# 669  ضلعی انتظامیہ لاہو ر  2.988207
# =======================
# Topic 6
#                Labels     Score
# 862  پریشان عمران خان  2.487230
# 652   ڈاکٹر عمران شاہ  2.154811
# 28        اسلام آباد  1.639035
# =======================
# Topic 7
#                               Labels     Score
# 460  کشمیری عوام کیساتھ اظہار یکجہتی  3.539747
# 411           زیر اہتمام یکجہتی ریلی  3.233888
# 44                 ساتھ اظہار یکجہتی  2.527236
# =======================
# Topic 8
#                                        Labels     Score
# 522  پاک سری لنکن ٹی ٹونٹی کرکٹ سیریز سکیورٹی  9.762020
# 550          پاک سری لنکن ٹی ٹونٹی کرکٹ سیریز  9.762020
# 555               پاک سری لنکن ٹی ٹونٹی سیریز  8.241967
# =======================
# Topic 9
#                                              Labels     Score
# 801                           محکمہ صحت ڈینگی وائرس  3.444152
# 756  ڈسٹرکٹ ہیلتھ آفیسر کوٹلی محکمہ صحت عامہ ڈینگی  2.803092
# 853                            قصور محکمہ صحت ڈینگی  2.517847
# =======================
# Topic 10
#                          Labels     Score
# 105               خیبر پختونخوا  3.050361
# 671  ڈینگی بے قابو ہوگیا مریضوں  2.607418
# 161             مزید کیسز تعداد  2.584622
# =======================
# Topic 11
#                                 Labels     Score
# 753       ڈپٹی کمشنر محمد سیف انور جپہ  4.372490
# 632  ڈپٹی کمشنر جہلم محمد سیف انور جپہ  4.372490
# 208                ڈپٹی کمشنر راولپنڈی  3.543787
# =======================
# Topic 12
#                      Labels     Score
# 172  زیر صدارت انسداد ڈینگی  4.026273
# 159         زیر صدارت ڈینگی  3.164819
# 749               زیر صدارت  3.019254
# =======================

# %%
labels_zero_order
# Out:
# ['ترکی شام',
#  'ڈی ایچ کیو ہسپتال وہاڑی کادورہ ہسپتال',
#  'ڈینگی مچھر',
#  'سی پیک اتھارٹی بارے',
#  'وزیراعظم عمران خان',
#  'ضلعی انتظامیہ لاہور',
#  'پریشان عمران خان',
#  'کشمیری عوام کیساتھ اظہار یکجہتی',
#  'پاک سری لنکن ٹی ٹونٹی کرکٹ سیریز سکیورٹی',
#  'محکمہ صحت ڈینگی وائرس',
#  'خیبر پختونخوا',
#  'ڈپٹی کمشنر محمد سیف انور جپہ',
#  'زیر صدارت انسداد ڈینگی']

# %%
labels_m_order=[]
for k in range(0,kn.knee):
    print("Topic %d"%k)
    candid_for_topic_k = m_order(freq,theta,c_value_pd.Candidate_Label,k,kn.knee)
    candid_for_topic_k = candid_for_topic_k.sort_values('Score',ascending=False)
    print(candid_for_topic_k.head(3))
    print("=======================")
    labels_m_order.append(candid_for_topic_k.iloc[0]['Labels'])
# Out:
# Topic 0
# C:\Users\Zarmeen\Anaconda2\envs\py36\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: divide by zero encountered in true_divide
# C:\Users\Zarmeen\Anaconda2\envs\py36\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: divide by zero encountered in log
#                                Labels  Score
# 67                  ترک فوجی کارروائی    inf
# 373  کرد جنگجوؤں کیخلاف فوجی کارروائی    inf
# 372                          ترکی شام    inf
# =======================
# Topic 1
#                                     Labels      Score
# 759  ڈی ایچ کیو ہسپتال وہاڑی کادورہ ہسپتال  12.992933
# 893                  ڈی جی صحت آزاد کشمیر   6.261112
# 814                            ڈی جی نرسنگ   6.167146
# =======================
# Topic 2
#                                Labels  Score
# 772            سی ای او ہیلتھ خانیوال    inf
# 201             ممکنہ مضراثرات او راس    inf
# 992  ہیںسی ای او ہیلتھ ڈاکٹر ارشد ملک    inf
# =======================
# Topic 3
#                          Labels     Score
# 20                         حکام       inf
# 322  وزیراعظم عمران خان اتھارٹی  8.813702
# 118     سی پیک اتھارٹی آرڈیننس  8.396886
# =======================
# Topic 4
#                          Labels     Score
# 103          وزیراعظم عمران خان  6.605659
# 100         وزیر اعظم عمران خان  6.191853
# 859  پی ٹی آئی حکومت عمران خان  5.305260
# =======================
# Topic 5
#                      Labels     Score
# 981     ضلعی انتظامیہ لاہور  6.758603
# 210  ضلعی انتظامیہ راولپنڈی  5.872559
# 669    ضلعی انتظامیہ لاہو ر  5.670414
# =======================
# Topic 6
#                          Labels     Score
# 859  پی ٹی آئی حکومت عمران خان  5.714334
# 652             ڈاکٹر عمران شاہ  5.032417
# 862            پریشان عمران خان  4.889810
# =======================
# Topic 7
#                       Labels  Score
# 466  طاقت کشمیری حریت پسندوں    inf
# 126           کشمیری بھائیوں    inf
# 473          زیر اہتمام ریلی    inf
# =======================
# Topic 8
#        Labels  Score
# 542  سری لنکن    inf
# 557       میچ    inf
# 135  سری لنکا    inf
# =======================
# Topic 9
#                                              Labels      Score
# 801                           محکمہ صحت ڈینگی وائرس  10.150554
# 756  ڈسٹرکٹ ہیلتھ آفیسر کوٹلی محکمہ صحت عامہ ڈینگی   8.028257
# 853                            قصور محکمہ صحت ڈینگی   6.681417
# =======================
# Topic 10
#                          Labels     Score
# 161             مزید کیسز تعداد  8.279220
# 105               خیبر پختونخوا  7.310890
# 671  ڈینگی بے قابو ہوگیا مریضوں  5.922404
# =======================
# Topic 11
#                                     Labels      Score
# 632      ڈپٹی کمشنر جہلم محمد سیف انور جپہ  11.433446
# 753           ڈپٹی کمشنر محمد سیف انور جپہ  11.433446
# 450  ڈپٹی کمشنر صحبت پور محمد یونس سنجرانی   8.899070
# =======================
# Topic 12
#                      Labels     Score
# 172  زیر صدارت انسداد ڈینگی  8.886913
# 159         زیر صدارت ڈینگی  7.046001
# 749               زیر صدارت  6.634840
# =======================

# %%
labels_t_order=[]
for k in range(0,kn.knee):
    print("Topic %d"%k)
    candid_for_topic_k = t_order(freq,theta,c_value_pd,k,kn.knee)
    candid_for_topic_k = candid_for_topic_k.sort_values('Score',ascending=False)
    print(candid_for_topic_k.head(3))
    print("=======================")
    labels_t_order.append(candid_for_topic_k.iloc[0]['Labels'])
# Out:
# Topic 0
# C:\Users\Zarmeen\Anaconda2\envs\py36\lib\site-packages\ipykernel_launcher.py:10: RuntimeWarning: divide by zero encountered in true_divide
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\Zarmeen\Anaconda2\envs\py36\lib\site-packages\ipykernel_launcher.py:10: RuntimeWarning: divide by zero encountered in log
#   # Remove the CWD from sys.path while we load stuff.
#                 Labels  Score
# 372           ترکی شام    inf
# 67   ترک فوجی کارروائی    inf
# 41       فوجی کارروائی    inf
# =======================
# Topic 1
#                                     Labels      Score
# 759  ڈی ایچ کیو ہسپتال وہاڑی کادورہ ہسپتال  12.992933
# 893                  ڈی جی صحت آزاد کشمیر   6.261112
# 814                            ڈی جی نرسنگ   6.167146
# =======================
# Topic 2
#                      Labels  Score
# 772  سی ای او ہیلتھ خانیوال    inf
# 641          سی او راولپنڈی    inf
# 201   ممکنہ مضراثرات او راس    inf
# =======================
# Topic 3
#                          Labels     Score
# 20                         حکام       inf
# 322  وزیراعظم عمران خان اتھارٹی  8.813702
# 344         سی پیک اتھارٹی بارے  8.396886
# =======================
# Topic 4
#                          Labels     Score
# 100         وزیر اعظم عمران خان  6.191853
# 859  پی ٹی آئی حکومت عمران خان  5.305260
# 93                   وفاقی وزیر  5.234032
# =======================
# Topic 5
#                      Labels     Score
# 981     ضلعی انتظامیہ لاہور  6.758603
# 210  ضلعی انتظامیہ راولپنڈی  5.872559
# 669    ضلعی انتظامیہ لاہو ر  5.670414
# =======================
# Topic 6
#                          Labels     Score
# 859  پی ٹی آئی حکومت عمران خان  5.714334
# 652             ڈاکٹر عمران شاہ  5.032417
# 862            پریشان عمران خان  4.889810
# =======================
# Topic 7
#                               Labels  Score
# 460  کشمیری عوام کیساتھ اظہار یکجہتی    inf
# 466          طاقت کشمیری حریت پسندوں    inf
# 473                  زیر اہتمام ریلی    inf
# =======================
# Topic 8
#         Labels  Score
# 135   سری لنکا    inf
# 540  مضبوط ٹیم    inf
# 515  سری لنکنز    inf
# =======================
# Topic 9
#                                              Labels      Score
# 801                           محکمہ صحت ڈینگی وائرس  10.150554
# 756  ڈسٹرکٹ ہیلتھ آفیسر کوٹلی محکمہ صحت عامہ ڈینگی   8.028257
# 853                            قصور محکمہ صحت ڈینگی   6.681417
# =======================
# Topic 10
#                          Labels     Score
# 161             مزید کیسز تعداد  8.279220
# 105               خیبر پختونخوا  7.310890
# 671  ڈینگی بے قابو ہوگیا مریضوں  5.922404
# =======================
# Topic 11
#                                     Labels      Score
# 753           ڈپٹی کمشنر محمد سیف انور جپہ  11.433446
# 632      ڈپٹی کمشنر جہلم محمد سیف انور جپہ  11.433446
# 450  ڈپٹی کمشنر صحبت پور محمد یونس سنجرانی   8.899070
# =======================
# Topic 12
#                      Labels     Score
# 172  زیر صدارت انسداد ڈینگی  8.886913
# 159         زیر صدارت ڈینگی  7.046001
# 950       وفاقی سیکرٹری صحت  5.195220
# =======================

# %%
dataset.to_csv('dataset_urdu_kmeans.csv',sep='\t',index=False)

# %%
dataset
# Out:
#                 DateTime       Source  \
# 0    2019-09-20 00:54:51    UrduPoint
# 1    2019-09-20 05:45:20    UrduPoint
# 2    2019-09-20 18:53:21    UrduPoint
# 3    2019-09-21 09:28:12    UrduPoint
# 4    2019-09-23 06:40:21    UrduPoint
# 5    2019-09-23 06:40:21    UrduPoint
# 6    2019-09-24 06:20:17    UrduPoint
# 7    2019-10-07 11:01:26    UrduPoint
# 8    2019-10-07 11:08:21  ExpressNews
# 9    2019-10-07 15:09:59    UrduPoint
# 10   2019-10-07 15:52:35    UrduPoint
# 11   2019-10-07 15:52:35    UrduPoint
# 12   2019-10-07 16:39:41    UrduPoint
# 13   2019-10-07 17:05:18    UrduPoint
# 14   2019-10-07 18:09:03    UrduPoint
# 15   2019-10-08 06:40:10    UrduPoint
# 16   2019-10-08 06:40:10    UrduPoint
# 17   2019-10-08 07:08:35    UrduPoint
# 18   2019-10-08 07:08:36    UrduPoint
# 19   2019-10-08 07:20:52  ExpressNews
# 20   2019-10-08 09:39:20    UrduPoint
# 21   2019-10-08 09:39:21    UrduPoint
# 22   2019-10-08 13:42:49    UrduPoint
# 23   2019-10-08 14:49:21    UrduPoint
# 24   2019-10-08 15:40:54    UrduPoint
# 25   2019-10-08 15:59:06    UrduPoint
# 26   2019-10-08 16:43:10    UrduPoint
# 27   2019-10-09 14:28:52    UrduPoint
# 28   2019-10-09 14:30:33    UrduPoint
# 29   2019-10-10 09:31:52    UrduPoint
# ..                   ...          ...
# 230  2019-10-09 12:33:16    UrduPoint
# 231  2019-10-09 12:45:56    UrduPoint
# 232  2019-10-09 13:52:07    UrduPoint
# 233  2019-10-09 13:54:53    UrduPoint
# 234  2019-10-09 14:25:44    UrduPoint
# 235  2019-10-09 14:30:34    UrduPoint
# 236  2019-10-09 14:45:48    UrduPoint
# 237  2019-10-09 14:57:16    UrduPoint
# 238  2019-10-09 15:14:25    UrduPoint
# 239  2019-10-09 17:00:35    UrduPoint
# 240  2019-10-10 07:11:26    UrduPoint
# 241  2019-10-10 08:24:36    UrduPoint
# 242  2019-10-10 08:52:11    UrduPoint
# 243  2019-10-10 08:52:11    UrduPoint
# 244  2019-10-10 08:52:11    UrduPoint
# 245  2019-10-10 09:52:09    UrduPoint
# 246  2019-10-10 09:52:12    UrduPoint
# 247  2019-10-10 12:29:12    UrduPoint
# 248  2019-10-10 12:45:23    UrduPoint
# 249  2019-10-10 12:49:26    UrduPoint
# 250  2019-10-10 13:31:15    UrduPoint
# 251  2019-10-10 13:35:04    UrduPoint
# 252  2019-10-10 13:35:04    UrduPoint
# 253  2019-10-10 13:37:07    UrduPoint
# 254  2019-10-10 13:49:13    UrduPoint
# 255  2019-10-10 14:12:00    UrduPoint
# 256  2019-10-10 14:52:48    UrduPoint
# 257  2019-10-10 16:59:47    UrduPoint
# 258  2019-10-10 18:09:47    UrduPoint
# 259  2019-10-10 18:10:50    UrduPoint
#
#                                                  Title lang  search_keywords  \
# 0    سی پیک منصوبہ ختم،آئی ایم ایف کی شرائط پرعملدر...   ur                1
# 1    حکومت نے سی پیک کے تحت اکانامک زونز پر توجہ مر...   ur                1
# 2    سی پیک کاموجودہ مرحلہ پاکستانی عوام کیلئے معاش...   ur                1
# 3    وزیر اعلیٰ خیبر پختونخوا محمود خان کا جمعہ کے ...   ur                1
# 4    غربت کی شرح میں کمی  سی پیک دوسرے مرحلے کی اہم...   ur                1
# 5    حکومت عوام کو ریلیف کی فراہمی کے لئے پر عزم ہے...   ur                1
# 6    چین پاکستان اقتصادی راہداری منصوبہ کے دوسرے مر...   ur                1
# 7    وزیر اعظم عمران خان کے دورہ چین سے دونوں ممالک...   ur                1
# 8    صدارتی آرڈیننس کے ذریعے سی پیک اتھارٹی قائم کر...   ur                1
# 9    خیبرپختونخوا حکومت کی تمام متعلقہ محکموں کو تر...   ur                1
# 10   وزیراعظم عمران خان کا دورہ چین سی پیک منصوبوں ...   ur                1
# 11   چین پاکستان اقتصادی راہداری سے ملک میں توانائی...   ur                1
# 12   وزیراعظم عمران خان کے دورہ چین کے بعد چینی صدر...   ur                1
# 13   ض*کے سی آر پر وفاقی حکومت کی سردمہری اور ان ک...   ur                1
# 14   خطے میں مزید تنازع نہیں چاہتے، کوشش ہے سعودیہ ...   ur                1
# 15   سی پیک کے پہلے مرحلے کی تکمیل سے پاکستان میں ب...   ur                1
# 16   سی پیک سے کے تحت بلوچستان میں اقتصادی زونز کے ...   ur                1
# 17   سی پیک کے تحت بلوچستان کی تحصیل بوستان میں انڈ...   ur                1
# 18   سی پیک سے متعلقہ منصوبوں میں70 ہزار پاکستانیوں...   ur                1
# 19   وزیراعظم سی پیک اتھارٹی کے چیئرپرسن مقرر، آرڈی...   ur                1
# 20   احسن اقبال نے سی پیک اتھارٹی کے آرڈیننس کو خل...   ur                1
# 21   صدر مملکت عارف علوی نے سی پیک اتھارٹی آرڈیننس...   ur                1
# 22   پاکستان اور چین سی پیک کو معاشی و معاشی ترقی، ...   ur                1
# 23   چین کی پاکستان کو قومی مفاد کے ایشو میں بھرپور...   ur                1
# 24   وفاقی حکومت کی سردمہری اور ان کا رویہ قابل افس...   ur                1
# 25   کراچی سرکولر ریلوے پر وفاقی حکومت کی سردمہری ق...   ur                1
# 26   وفاقی حکومت نے سی پیک اتھارٹی  بارے صدارتی آر...   ur                1
# 27   پاکستان اور چین نے سی پیک کے تحت اربوں ڈالر ما...   ur                1
# 28   پاکستان اور چین قریبی دوست، شراکت دار اور آہن...   ur                1
# 29   سی پیک کے دوسرے مرحلے کی تکمیل سے روزگار کے مو...   ur                1
# ..                                                 ...  ...              ...
# 230  سری لنکن آل راﺅنڈ ر تھیسارا پریرا نے دورہ پاکس...   ur                1
# 231  یو ای ٹی لاہورکے زیر اہتمام ڈینگی سے متعلق آگا...   ur                1
# 232  ٹی ایم اے لاچی کا بڑے پیمانے پر صفائی مہم کا ا...   ur                1
# 233  مظفرآباد،لچھراٹ ویلفئیر آرگنائزیشن آزادجموں...   ur                1
# 234  ڈینگی کے خاتمہ کے لئے بلدیات کے چیف افسران نکا...   ur                1
# 235  حکومت ڈینگی کے مکمل خاتمہ کیلئے ٹھوس عملی اقدا...   ur                1
# 236  ٹی ایم اے لاچی نے بڑے پیمانے پر صفائی مہم کا ا...   ur                1
# 237  ڈینگی کے خدشہ کے پیش نظر 3دکانداروں کے خلاف مق...   ur                1
# 238  افسران کے شہر میں صفائی ستھرائی اور ڈینگی سیمی...   ur                1
# 239  رواں سال بلوچستان کے تین اضلاع میں اب تک 1950 ...   ur                1
# 240  خیبر پختونخوا میں ڈینگی کے 55 نئے کیسز رپورٹ‘ ...   ur                1
# 241  انسداد ڈینگی مہم میں ڈپٹی کمشنر سرگودھا کا محک...   ur                1
# 242  ملک بھر میں ڈینگی سے متاثر افراد کی تعداد چوبی...   ur                1
# 243  سیکرٹری صحت کی زیر صدارت ، ڈینگی کی تازہ ترین ...   ur                1
# 244  فوزیہ نامی خاتون بے نظیر بھٹو اسپتال میں ڈینگی...   ur                1
# 245  پاکستان وآزادکشمیر کو ڈینگی وائر سے پاک بنائی...   ur                1
# 246  ڈینگی کا خاتمے کے لیے عملی اقداما ت نہیں اُٹھا...   ur                1
# 247  پمز میں ڈینگی کے 2000 مشتبہ مریضوں میں سے 200 ...   ur                1
# 248      صوبائی وزیر ملک اسد کھوکھر ڈینگی کا شکارہوگئے   ur                1
# 249  آر ڈبلیو ایم سی  کی جانب سے ڈینگی کیخلاف حفاظ...   ur                1
# 250  انسداد ڈینگی سرویلنس میں کوئی کوتاہی برداشت نہ...   ur                1
# 251  ڈی سی لاہور اصغر جوئیہ کی این ڈی بوائز ہائی سک...   ur                1
# 252  افسران ڈینگی سروئلنس، صفائی ستھرائی اور پرائس ...   ur                1
# 253  اے سی رائیونڈ عدنان بدر کا ڈینگی اور صفائی ستھ...   ur                1
# 254                  احتیاط سے ڈینگی سے بچا جا سکتا ہے   ur                1
# 255  سرویلنس ٹیمیں ڈینگی مچھر کی افزائش کے مقامات ک...   ur                1
# 256  انسداد ڈینگی مہم، کمرشل اداروں ‘دکانوں کی باقا...   ur                1
# 257  سوات:ضلعی انتظامیہ اور محکمہ صحت کی ناقص منصوب...   ur                1
# 258  اوکاڑہ،ڈسٹرکٹ انٹا مالوجسٹکا مارکیٹوں، مختلف ج...   ur                1
# 259  انسداد ڈینگی کی کارکردگی کا جائزہ لینے کے حوال...   ur                1
#
#            Label                                  preprocessed_text  \
# 0           CPEC  پیک منصوبہ ایم ایف شرائط عمل درآمد شروع امریکہ...
# 1           CPEC  حکومت پیک اکانامک زونز توجہ مرکوز رشکئی اکنامک...
# 2           CPEC  پیک کاموجودہ مرحلہ پاکستانی عوام کیلئے معاشی ف...
# 3           CPEC  وزیر اعلی خیبر پختونخوا محمود خان جمعہ روز چتر...
# 4           CPEC            غربت شرح کمی پیک مرحلے اہم ترجیحات شامل
# 5           CPEC            حکومت عوام ریلیف فراہمی عزم پیک اتھارٹی
# 6           CPEC  چین پاکستان اقتصادی راہداری منصوبہ مرحلہ غربت ...
# 7           CPEC  وزیر اعظم عمران خان دورہ چین ممالک مابین تعلقا...
# 8           CPEC              صدارتی آرڈیننس پیک اتھارٹی قائم فیصلہ
# 9           CPEC  خیبر پختونخوا حکومت متعلقہ محکموں ترقیاتی منصو...
# 10          CPEC  وزیراعظم عمران خان دورہ چین پیک منصوبوں اہم حس...
# 11          CPEC  چین پاکستان اقتصادی راہداری ملک انائی شدید بحر...
# 12          CPEC  وزیراعظم عمران خان دورہ چین چینی صدر بھارت شاہ...
# 13          CPEC  ض آر وفاقی حکومت سردمہری رویہ قابل افسوس سعید...
# 14          CPEC  خطے تنازع کوشش سعودیہ ایران غلط فہماں دور وزیر...
# 15          CPEC  پیک مرحلے تکمیل پاکستان بنیادی ڈھانچے بہتری آ...
# 16          CPEC  پیک بلوچستان اقتصادی زونز قیام مقامی صنعت ترقی...
# 17          CPEC  پیک بلوچستان تحصیل بوستان انڈسٹریل زون کام تیز...
# 18          CPEC  پیک متعلقہ منصوبوں ہزار پاکستانیوں روزگار ملا ...
# 19          CPEC    وزیراعظم پیک اتھارٹی چیئرپرسن مقرر آرڈیننس جاری
# 20          CPEC  احسن اقبال پیک اتھارٹی آرڈیننس قانون قرار دید...
# 21          CPEC  صدر مملکت عارف علوی پیک اتھارٹی آرڈیننس دستخط...
# 22          CPEC  پاکستان چین پیک معاشی و معاشی ترقی صنعتی انقلا...
# 23          CPEC  چین پاکستان قومی مفاد ایشو بھرپور تعاون یقین د...
# 24          CPEC  وفاقی حکومت سردمہری رویہ قابل افسوس سعید غنی پ...
# 25          CPEC  کراچی سرکولر ریلوے وفاقی حکومت سردمہری قابل اف...
# 26          CPEC  وفاقی حکومت پیک اتھارٹی صدارتی آرڈیننس جاری ش...
# 27          CPEC  پاکستان چین پیک اربوں ڈالر مالیت ایم ایل ون من...
# 28          CPEC  پاکستان چین قریبی دوست شراکت دار آہنی برادرز ...
# 29          CPEC  پیک مرحلے تکمیل روزگار مواقع پیدا مدد ملے حکام...
# ..           ...                                                ...
# 230  DengueFever  سری لنکن آل راﺅنڈ ر تھیسارا پریرا دورہ پاکستان...
# 231  DengueFever  یو ای ٹی لاہورکے زیر اہتمام ڈینگی متعلق آگاہی ...
# 232  DengueFever  ٹی ایم لاچی بڑے پیمانے صفائی مہم آغاز علاقے ش...
# 233  DengueFever  مظفرآباد لچھراٹ ویلفئیر آرگنائزیشن آزادجموں...
# 234  DengueFever  ڈینگی خاتمہ بلدیات چیف افسران نکاسی آب صفائی ...
# 235  DengueFever  حکومت ڈینگی خاتمہ کیلئے ٹھوس عملی اقدامات کررہ...
# 236  DengueFever  ٹی ایم لاچی بڑے پیمانے صفائی مہم آغاز علاقے ش...
# 237  DengueFever            ڈینگی خدشہ پیش نظر دکانداروں مقدمات درج
# 238  DengueFever  افسران شہر صفائی ستھرائی ڈینگی سیمینار ڈینگی ا...
# 239  DengueFever  رواں سال بلوچستان تین اضلاع اب ڈینگی وائرس کیس...
# 240  DengueFever           خیبر پختونخوا ڈینگی نئے کیسز رپورٹ تعداد
# 241  DengueFever  انسداد ڈینگی مہم ڈپٹی کمشنر سرگودھا محکموں پاپ...
# 242  DengueFever       ملک ڈینگی متاثر افراد تعداد چوبیس ہزار تجاوز
# 243  DengueFever  سیکرٹری صحت زیر صدارت ڈینگی تازہ ترین حال بریف...
# 244  DengueFever  فوزیہ نامی خاتون نظیر بھٹو اسپتال ڈینگی وائرس ...
# 245  DengueFever  پاکستان وآزادکشمیر ڈینگی وائر پاک بنائیں ڈینگ...
# 246  DengueFever  ڈینگی خاتمے عملی اقداما ت اٹھائے شیخ عقیل الرح...
# 247  DengueFever    پمز ڈینگی مشتبہ مریضوں مریضوں ڈینگی وائرس تصدیق
# 248  DengueFever         صوبائی وزیر ملک اسد کھوکھر ڈینگی شکارہوگئے
# 249  DengueFever  آر ڈبلیو ایم جانب ڈینگی کیخلاف حفاظتی اقدامات...
# 250  DengueFever   انسداد ڈینگی سرویلنس کوتاہی برداشت سیکرٹری آرٹی
# 251  DengueFever  ڈی لاہور اصغر جوئیہ این ڈی بوائز ہائی سکول اچھ...
# 252  DengueFever  افسران ڈینگی سروئلنس صفائی ستھرائی پرائس چیکنگ...
# 253  DengueFever  رائیونڈ عدنان بدر ڈینگی صفائی ستھرائی چیک کیلئ...
# 254  DengueFever                                   احتیاط ڈینگی بچا
# 255  DengueFever  سرویلنس ٹیمیں ڈینگی مچھر افزائش مقامات بھرپور ...
# 256  DengueFever  انسداد ڈینگی مہم کمرشل اداروں دکانوں باقاعدگی ...
# 257  DengueFever  سوات ضلعی انتظامیہ محکمہ صحت ناقص منصوبہ بندی ...
# 258  DengueFever  اوکاڑہ ڈسٹرکٹ انٹا مالوجسٹکا مارکیٹوں مختلف جگ...
# 259  DengueFever  انسداد ڈینگی کار کردگی جائزہ لینے حوالہ اجلاس ...
#
#                                             NounChunks  km_label
# 0    [سی پیک منصوبہ ختمآئی ایم ایف, شرائط پرعملدرآم...         3
# 1    [حکومت, سی پیک, تحت اکانامک زونز, توجہ, رشکئی ...         4
# 2    [سی پیک, کاموجودہ مرحلہ, پاکستانی عوام, معاشی ...         3
# 3    [وزیر, اعلیٰ خیبر پختونخوا محمود خان, جمعہ, رو...         4
# 4    [غربت, شرح, کمی, سی پیک, دوسرے مرحلے, اہم ترجی...         3
# 5    [حکومت عوام, ریلیف, فراہمی, لئے, عزم, سی پیک ا...         3
# 6    [چین پاکستان, اقتصادی راہداری منصوبہ, دوسرے مر...         3
# 7    [وزیر اعظم عمران خان, دورہ چین, ممالک, مابین ت...         4
# 8       [صدارتی آرڈیننس, ذریعے, سی پیک اتھارٹی, فیصلہ]         3
# 9    [خیبرپختونخوا حکومت, متعلقہ محکموں, ترقیاتی من...         4
# 10   [وزیراعظم عمران خان, دورہ چین, سی پیک منصوبوں,...         4
# 11   [چین پاکستان, اقتصادی راہداری, ملک, توانائی, ش...         3
# 12   [وزیراعظم عمران خان, دورہ چین, بعد چینی صدر بھ...         4
# 13   [ضکے, سی آر, وفاقی حکومت, سردمہری, رویہ, قابل...         4
# 14   [خطے, مزید تنازع, کوشش, سعودیہ, ایران, غلط فہم...         4
# 15   [سی پیک, پہلے مرحلے, تکمیل, پاکستان, بنیادی ڈھ...         4
# 16   [سی پیک, تحت بلوچستان, اقتصادی زونز, قیام, مقا...         3
# 17   [سی پیک, تحت بلوچستان, تحصیل بوستان, انڈسٹریل ...         5
# 18   [سی پیک, متعلقہ منصوبوں, پاکستانیوں, روزگار, ح...         3
# 19   [وزیراعظم, سی پیک اتھارٹی, چیئرپرسن, مقرر آرڈی...         3
# 20   [احسن اقبال, سی پیک اتھارٹی, آرڈیننس, خلاف قا...         3
# 21   [صدر مملکت عارف علوی, سی پیک اتھارٹی آرڈیننس,...         3
# 22   [پاکستان, چین, سی پیک, معاشی ترقی, صنعتی انقلا...         4
# 23   [چین, پاکستان, قومی مفاد, ایشو, بھرپور تعاون, ...         4
# 24   [وفاقی حکومت, سردمہری, رویہ, قابل افسوس, سعید ...         4
# 25   [کراچی سرکولر ریلوے, وفاقی حکومت, سردمہری قابل...         4
# 26   [وفاقی حکومت, سی پیک اتھارٹی بارے, صدارتی آرڈ...         3
# 27   [پاکستان, چین, سی پیک, تحت اربوں ڈالر مالیت, ا...         4
# 28   [پاکستان, چین, قریبی دوست شراکت دار, آہنی برا...         4
# 29   [سی پیک, دوسرے مرحلے, تکمیل, روزگار, مواقع پید...         3
# ..                                                 ...       ...
# 230  [سری لنکن آل راﺅنڈ ر تھیسارا پریرا, دورہ پاکست...         8
# 231  [یو ای ٹی لاہورکے زیر اہتمام ڈینگی, متعلق آگاہ...         2
# 232  [ٹی ایم اے لاچی, بڑے پیمانے, صفائی مہم, آغاز ...         5
# 233  [مظفرآبادلچھراٹ ویلفئیر آرگنائزیشن آزادجموں...         6
# 234  [ڈینگی, خاتمہ, لئے بلدیات, چیف افسران نکاسی, ص...         1
# 235  [حکومت ڈینگی, مکمل خاتمہ, ٹھوس عملی اقدامات, ر...         2
# 236  [ٹی ایم اے لاچی, بڑے پیمانے, صفائی مہم, آغاز ...         5
# 237      [ڈینگی, خدشہ, پیش نظر دکانداروں, خلاف مقدمات]         2
# 238  [افسران, شہر, صفائی, ڈینگی سیمینار, ڈینگی انتظ...         2
# 239  [رواں سال بلوچستان, اضلاع, ڈینگی وائرس, کیسز ر...         9
# 240       [خیبر پختونخوا, ڈینگی, نئے کیسز رپورٹ تعداد]        10
# 241  [انسداد ڈینگی مہم, ڈپٹی کمشنر سرگودھا, محکموں ...        11
# 242            [ملک, ڈینگی, متاثر افراد, تعداد, تجاوز]        10
# 243  [سیکرٹری صحت, زیر صدارت ڈینگی, تازہ ترین صورتح...        12
# 244  [فوزیہ نامی خاتون بے, نظیر بھٹو اسپتال, ڈینگی ...         9
# 245  [پاکستان وآزادکشمیر, ڈینگی وائر, ڈینگی وائر, ...         2
# 246  [ڈینگی, خاتمے, عملی اقداما ت, ہیںشیخ عقیل الرح...         2
# 247  [پمز, ڈینگی, مشتبہ مریضوں, مریضوں, ڈینگی وائرس...        10
# 248      [صوبائی وزیر ملک اسد کھوکھر ڈینگی, شکارہوگئے]         2
# 249  [آر ڈبلیو ایم, جانب, ڈینگی کیخلاف, حفاظتی اقد...         2
# 250  [انسداد ڈینگی سرویلنس, کوتاہی برداشت, سیکرٹری ...        12
# 251  [ڈی, سی لاہور اصغر جوئیہ, این ڈی بوائز ہائی سک...         1
# 252  [افسران ڈینگی سروئلنس صفائی, پرائس چیکنگ, عملد...         1
# 253  [اے, سی رائیونڈ عدنان بدر, ڈینگی, صفائی, چیک, ...         2
# 254                                    [احتیاط, ڈینگی]         2
# 255  [سرویلنس ٹیمیں ڈینگی مچھر, افزائش, مقامات, بھر...         1
# 256  [انسداد ڈینگی مہم, کمرشل اداروں دکانوں, باقاعد...        12
# 257  [سواتضلعی انتظامیہ, محکمہ صحت, ناقص منصوبہ بند...         9
# 258  [اوکاڑہڈسٹرکٹ انٹا مالوجسٹکا مارکیٹوں, مختلف ج...         2
# 259  [انسداد ڈینگی, کارکردگی, جائزہ, حوالہ, اجلاس, ...        12
#
# [260 rows x 9 columns]

# %% [markdown]
# ## Proposed Topic labeling

# %%
def list_phrases_cluster(cluster_idx,df,key):
    df_sub = df[df[key] == cluster_idx]
    hashs = []
    for index,row in df_sub.iterrows():
        row.Noun_Phrases = row.NounChunks
        for x in row.Noun_Phrases:
            hashs.append(x)
    
    return collections.Counter(hashs)
def return_clusters_title(cluster_idx,dataset,col):
    hash_cluster1 = list_phrases_cluster(cluster_idx,dataset,col) 
    top10  = hash_cluster1.most_common(3)
    dataset_sub = dataset[dataset[col] == cluster_idx]
    cnt_vectorizer = TfidfVectorizer(ngram_range=(3,8))
    vec = cnt_vectorizer.fit_transform(dataset_sub['Title'])
    scores = (vec.toarray()) 
    # Getting top ranking features 
    sums = vec.sum(axis = 0) 
    data1 = [] 
    features = cnt_vectorizer.get_feature_names()
    for col, term in enumerate(features): 
        data1.append((term, sums[0, col] )) 
    ranking = pd.DataFrame(data1, columns = ['term', 'rank'])
    ranking['wCount'] = ranking['term'].apply(lambda x: len(x.split()))
    ranking = ranking.sort_values(['rank','wCount'],ascending=[False,True])
    print(ranking.head(5))
    my_top_4=[]
    for u,v in top10:
        my_top_4.append(u)
    my_top_4 = " ".join(my_top_4)
    my_top_4 = my_top_4.replace("_"," ")

    #print(my_top_4)
    test_list = (my_top_4.split())
    df = pd.DataFrame(columns=ranking.columns) #empty dataframe to add filtered rows
    for index,row in ranking.iterrows():
        # using list comprehension 
        # checking if string contains list element 
        res = all(ele in row['term'] for ele in test_list) 

        # print result 
        if res == True:
            df.loc[len(df)]=[row['term'],row['rank'],row['wCount']] 
    df = df.sort_values(['rank','wCount'],ascending=[False,True])
    #df = df.sort_values(['wCount'])
    if len(df)>0:
        return df.iloc[0]['term']
    else:
        return "No title constructed"

# %%
dataset
# Out:
#                 DateTime       Source  \
# 0    2019-09-20 00:54:51    UrduPoint
# 1    2019-09-20 05:45:20    UrduPoint
# 2    2019-09-20 18:53:21    UrduPoint
# 3    2019-09-21 09:28:12    UrduPoint
# 4    2019-09-23 06:40:21    UrduPoint
# 5    2019-09-23 06:40:21    UrduPoint
# 6    2019-09-24 06:20:17    UrduPoint
# 7    2019-10-07 11:01:26    UrduPoint
# 8    2019-10-07 11:08:21  ExpressNews
# 9    2019-10-07 15:09:59    UrduPoint
# 10   2019-10-07 15:52:35    UrduPoint
# 11   2019-10-07 15:52:35    UrduPoint
# 12   2019-10-07 16:39:41    UrduPoint
# 13   2019-10-07 17:05:18    UrduPoint
# 14   2019-10-07 18:09:03    UrduPoint
# 15   2019-10-08 06:40:10    UrduPoint
# 16   2019-10-08 06:40:10    UrduPoint
# 17   2019-10-08 07:08:35    UrduPoint
# 18   2019-10-08 07:08:36    UrduPoint
# 19   2019-10-08 07:20:52  ExpressNews
# 20   2019-10-08 09:39:20    UrduPoint
# 21   2019-10-08 09:39:21    UrduPoint
# 22   2019-10-08 13:42:49    UrduPoint
# 23   2019-10-08 14:49:21    UrduPoint
# 24   2019-10-08 15:40:54    UrduPoint
# 25   2019-10-08 15:59:06    UrduPoint
# 26   2019-10-08 16:43:10    UrduPoint
# 27   2019-10-09 14:28:52    UrduPoint
# 28   2019-10-09 14:30:33    UrduPoint
# 29   2019-10-10 09:31:52    UrduPoint
# ..                   ...          ...
# 230  2019-10-09 12:33:16    UrduPoint
# 231  2019-10-09 12:45:56    UrduPoint
# 232  2019-10-09 13:52:07    UrduPoint
# 233  2019-10-09 13:54:53    UrduPoint
# 234  2019-10-09 14:25:44    UrduPoint
# 235  2019-10-09 14:30:34    UrduPoint
# 236  2019-10-09 14:45:48    UrduPoint
# 237  2019-10-09 14:57:16    UrduPoint
# 238  2019-10-09 15:14:25    UrduPoint
# 239  2019-10-09 17:00:35    UrduPoint
# 240  2019-10-10 07:11:26    UrduPoint
# 241  2019-10-10 08:24:36    UrduPoint
# 242  2019-10-10 08:52:11    UrduPoint
# 243  2019-10-10 08:52:11    UrduPoint
# 244  2019-10-10 08:52:11    UrduPoint
# 245  2019-10-10 09:52:09    UrduPoint
# 246  2019-10-10 09:52:12    UrduPoint
# 247  2019-10-10 12:29:12    UrduPoint
# 248  2019-10-10 12:45:23    UrduPoint
# 249  2019-10-10 12:49:26    UrduPoint
# 250  2019-10-10 13:31:15    UrduPoint
# 251  2019-10-10 13:35:04    UrduPoint
# 252  2019-10-10 13:35:04    UrduPoint
# 253  2019-10-10 13:37:07    UrduPoint
# 254  2019-10-10 13:49:13    UrduPoint
# 255  2019-10-10 14:12:00    UrduPoint
# 256  2019-10-10 14:52:48    UrduPoint
# 257  2019-10-10 16:59:47    UrduPoint
# 258  2019-10-10 18:09:47    UrduPoint
# 259  2019-10-10 18:10:50    UrduPoint
#
#                                                  Title lang  search_keywords  \
# 0    سی پیک منصوبہ ختم،آئی ایم ایف کی شرائط پرعملدر...   ur                1
# 1    حکومت نے سی پیک کے تحت اکانامک زونز پر توجہ مر...   ur                1
# 2    سی پیک کاموجودہ مرحلہ پاکستانی عوام کیلئے معاش...   ur                1
# 3    وزیر اعلیٰ خیبر پختونخوا محمود خان کا جمعہ کے ...   ur                1
# 4    غربت کی شرح میں کمی  سی پیک دوسرے مرحلے کی اہم...   ur                1
# 5    حکومت عوام کو ریلیف کی فراہمی کے لئے پر عزم ہے...   ur                1
# 6    چین پاکستان اقتصادی راہداری منصوبہ کے دوسرے مر...   ur                1
# 7    وزیر اعظم عمران خان کے دورہ چین سے دونوں ممالک...   ur                1
# 8    صدارتی آرڈیننس کے ذریعے سی پیک اتھارٹی قائم کر...   ur                1
# 9    خیبرپختونخوا حکومت کی تمام متعلقہ محکموں کو تر...   ur                1
# 10   وزیراعظم عمران خان کا دورہ چین سی پیک منصوبوں ...   ur                1
# 11   چین پاکستان اقتصادی راہداری سے ملک میں توانائی...   ur                1
# 12   وزیراعظم عمران خان کے دورہ چین کے بعد چینی صدر...   ur                1
# 13   ض*کے سی آر پر وفاقی حکومت کی سردمہری اور ان ک...   ur                1
# 14   خطے میں مزید تنازع نہیں چاہتے، کوشش ہے سعودیہ ...   ur                1
# 15   سی پیک کے پہلے مرحلے کی تکمیل سے پاکستان میں ب...   ur                1
# 16   سی پیک سے کے تحت بلوچستان میں اقتصادی زونز کے ...   ur                1
# 17   سی پیک کے تحت بلوچستان کی تحصیل بوستان میں انڈ...   ur                1
# 18   سی پیک سے متعلقہ منصوبوں میں70 ہزار پاکستانیوں...   ur                1
# 19   وزیراعظم سی پیک اتھارٹی کے چیئرپرسن مقرر، آرڈی...   ur                1
# 20   احسن اقبال نے سی پیک اتھارٹی کے آرڈیننس کو خل...   ur                1
# 21   صدر مملکت عارف علوی نے سی پیک اتھارٹی آرڈیننس...   ur                1
# 22   پاکستان اور چین سی پیک کو معاشی و معاشی ترقی، ...   ur                1
# 23   چین کی پاکستان کو قومی مفاد کے ایشو میں بھرپور...   ur                1
# 24   وفاقی حکومت کی سردمہری اور ان کا رویہ قابل افس...   ur                1
# 25   کراچی سرکولر ریلوے پر وفاقی حکومت کی سردمہری ق...   ur                1
# 26   وفاقی حکومت نے سی پیک اتھارٹی  بارے صدارتی آر...   ur                1
# 27   پاکستان اور چین نے سی پیک کے تحت اربوں ڈالر ما...   ur                1
# 28   پاکستان اور چین قریبی دوست، شراکت دار اور آہن...   ur                1
# 29   سی پیک کے دوسرے مرحلے کی تکمیل سے روزگار کے مو...   ur                1
# ..                                                 ...  ...              ...
# 230  سری لنکن آل راﺅنڈ ر تھیسارا پریرا نے دورہ پاکس...   ur                1
# 231  یو ای ٹی لاہورکے زیر اہتمام ڈینگی سے متعلق آگا...   ur                1
# 232  ٹی ایم اے لاچی کا بڑے پیمانے پر صفائی مہم کا ا...   ur                1
# 233  مظفرآباد،لچھراٹ ویلفئیر آرگنائزیشن آزادجموں...   ur                1
# 234  ڈینگی کے خاتمہ کے لئے بلدیات کے چیف افسران نکا...   ur                1
# 235  حکومت ڈینگی کے مکمل خاتمہ کیلئے ٹھوس عملی اقدا...   ur                1
# 236  ٹی ایم اے لاچی نے بڑے پیمانے پر صفائی مہم کا ا...   ur                1
# 237  ڈینگی کے خدشہ کے پیش نظر 3دکانداروں کے خلاف مق...   ur                1
# 238  افسران کے شہر میں صفائی ستھرائی اور ڈینگی سیمی...   ur                1
# 239  رواں سال بلوچستان کے تین اضلاع میں اب تک 1950 ...   ur                1
# 240  خیبر پختونخوا میں ڈینگی کے 55 نئے کیسز رپورٹ‘ ...   ur                1
# 241  انسداد ڈینگی مہم میں ڈپٹی کمشنر سرگودھا کا محک...   ur                1
# 242  ملک بھر میں ڈینگی سے متاثر افراد کی تعداد چوبی...   ur                1
# 243  سیکرٹری صحت کی زیر صدارت ، ڈینگی کی تازہ ترین ...   ur                1
# 244  فوزیہ نامی خاتون بے نظیر بھٹو اسپتال میں ڈینگی...   ur                1
# 245  پاکستان وآزادکشمیر کو ڈینگی وائر سے پاک بنائی...   ur                1
# 246  ڈینگی کا خاتمے کے لیے عملی اقداما ت نہیں اُٹھا...   ur                1
# 247  پمز میں ڈینگی کے 2000 مشتبہ مریضوں میں سے 200 ...   ur                1
# 248      صوبائی وزیر ملک اسد کھوکھر ڈینگی کا شکارہوگئے   ur                1
# 249  آر ڈبلیو ایم سی  کی جانب سے ڈینگی کیخلاف حفاظ...   ur                1
# 250  انسداد ڈینگی سرویلنس میں کوئی کوتاہی برداشت نہ...   ur                1
# 251  ڈی سی لاہور اصغر جوئیہ کی این ڈی بوائز ہائی سک...   ur                1
# 252  افسران ڈینگی سروئلنس، صفائی ستھرائی اور پرائس ...   ur                1
# 253  اے سی رائیونڈ عدنان بدر کا ڈینگی اور صفائی ستھ...   ur                1
# 254                  احتیاط سے ڈینگی سے بچا جا سکتا ہے   ur                1
# 255  سرویلنس ٹیمیں ڈینگی مچھر کی افزائش کے مقامات ک...   ur                1
# 256  انسداد ڈینگی مہم، کمرشل اداروں ‘دکانوں کی باقا...   ur                1
# 257  سوات:ضلعی انتظامیہ اور محکمہ صحت کی ناقص منصوب...   ur                1
# 258  اوکاڑہ،ڈسٹرکٹ انٹا مالوجسٹکا مارکیٹوں، مختلف ج...   ur                1
# 259  انسداد ڈینگی کی کارکردگی کا جائزہ لینے کے حوال...   ur                1
#
#            Label                                  preprocessed_text  \
# 0           CPEC  پیک منصوبہ ایم ایف شرائط عمل درآمد شروع امریکہ...
# 1           CPEC  حکومت پیک اکانامک زونز توجہ مرکوز رشکئی اکنامک...
# 2           CPEC  پیک کاموجودہ مرحلہ پاکستانی عوام کیلئے معاشی ف...
# 3           CPEC  وزیر اعلی خیبر پختونخوا محمود خان جمعہ روز چتر...
# 4           CPEC            غربت شرح کمی پیک مرحلے اہم ترجیحات شامل
# 5           CPEC            حکومت عوام ریلیف فراہمی عزم پیک اتھارٹی
# 6           CPEC  چین پاکستان اقتصادی راہداری منصوبہ مرحلہ غربت ...
# 7           CPEC  وزیر اعظم عمران خان دورہ چین ممالک مابین تعلقا...
# 8           CPEC              صدارتی آرڈیننس پیک اتھارٹی قائم فیصلہ
# 9           CPEC  خیبر پختونخوا حکومت متعلقہ محکموں ترقیاتی منصو...
# 10          CPEC  وزیراعظم عمران خان دورہ چین پیک منصوبوں اہم حس...
# 11          CPEC  چین پاکستان اقتصادی راہداری ملک انائی شدید بحر...
# 12          CPEC  وزیراعظم عمران خان دورہ چین چینی صدر بھارت شاہ...
# 13          CPEC  ض آر وفاقی حکومت سردمہری رویہ قابل افسوس سعید...
# 14          CPEC  خطے تنازع کوشش سعودیہ ایران غلط فہماں دور وزیر...
# 15          CPEC  پیک مرحلے تکمیل پاکستان بنیادی ڈھانچے بہتری آ...
# 16          CPEC  پیک بلوچستان اقتصادی زونز قیام مقامی صنعت ترقی...
# 17          CPEC  پیک بلوچستان تحصیل بوستان انڈسٹریل زون کام تیز...
# 18          CPEC  پیک متعلقہ منصوبوں ہزار پاکستانیوں روزگار ملا ...
# 19          CPEC    وزیراعظم پیک اتھارٹی چیئرپرسن مقرر آرڈیننس جاری
# 20          CPEC  احسن اقبال پیک اتھارٹی آرڈیننس قانون قرار دید...
# 21          CPEC  صدر مملکت عارف علوی پیک اتھارٹی آرڈیننس دستخط...
# 22          CPEC  پاکستان چین پیک معاشی و معاشی ترقی صنعتی انقلا...
# 23          CPEC  چین پاکستان قومی مفاد ایشو بھرپور تعاون یقین د...
# 24          CPEC  وفاقی حکومت سردمہری رویہ قابل افسوس سعید غنی پ...
# 25          CPEC  کراچی سرکولر ریلوے وفاقی حکومت سردمہری قابل اف...
# 26          CPEC  وفاقی حکومت پیک اتھارٹی صدارتی آرڈیننس جاری ش...
# 27          CPEC  پاکستان چین پیک اربوں ڈالر مالیت ایم ایل ون من...
# 28          CPEC  پاکستان چین قریبی دوست شراکت دار آہنی برادرز ...
# 29          CPEC  پیک مرحلے تکمیل روزگار مواقع پیدا مدد ملے حکام...
# ..           ...                                                ...
# 230  DengueFever  سری لنکن آل راﺅنڈ ر تھیسارا پریرا دورہ پاکستان...
# 231  DengueFever  یو ای ٹی لاہورکے زیر اہتمام ڈینگی متعلق آگاہی ...
# 232  DengueFever  ٹی ایم لاچی بڑے پیمانے صفائی مہم آغاز علاقے ش...
# 233  DengueFever  مظفرآباد لچھراٹ ویلفئیر آرگنائزیشن آزادجموں...
# 234  DengueFever  ڈینگی خاتمہ بلدیات چیف افسران نکاسی آب صفائی ...
# 235  DengueFever  حکومت ڈینگی خاتمہ کیلئے ٹھوس عملی اقدامات کررہ...
# 236  DengueFever  ٹی ایم لاچی بڑے پیمانے صفائی مہم آغاز علاقے ش...
# 237  DengueFever            ڈینگی خدشہ پیش نظر دکانداروں مقدمات درج
# 238  DengueFever  افسران شہر صفائی ستھرائی ڈینگی سیمینار ڈینگی ا...
# 239  DengueFever  رواں سال بلوچستان تین اضلاع اب ڈینگی وائرس کیس...
# 240  DengueFever           خیبر پختونخوا ڈینگی نئے کیسز رپورٹ تعداد
# 241  DengueFever  انسداد ڈینگی مہم ڈپٹی کمشنر سرگودھا محکموں پاپ...
# 242  DengueFever       ملک ڈینگی متاثر افراد تعداد چوبیس ہزار تجاوز
# 243  DengueFever  سیکرٹری صحت زیر صدارت ڈینگی تازہ ترین حال بریف...
# 244  DengueFever  فوزیہ نامی خاتون نظیر بھٹو اسپتال ڈینگی وائرس ...
# 245  DengueFever  پاکستان وآزادکشمیر ڈینگی وائر پاک بنائیں ڈینگ...
# 246  DengueFever  ڈینگی خاتمے عملی اقداما ت اٹھائے شیخ عقیل الرح...
# 247  DengueFever    پمز ڈینگی مشتبہ مریضوں مریضوں ڈینگی وائرس تصدیق
# 248  DengueFever         صوبائی وزیر ملک اسد کھوکھر ڈینگی شکارہوگئے
# 249  DengueFever  آر ڈبلیو ایم جانب ڈینگی کیخلاف حفاظتی اقدامات...
# 250  DengueFever   انسداد ڈینگی سرویلنس کوتاہی برداشت سیکرٹری آرٹی
# 251  DengueFever  ڈی لاہور اصغر جوئیہ این ڈی بوائز ہائی سکول اچھ...
# 252  DengueFever  افسران ڈینگی سروئلنس صفائی ستھرائی پرائس چیکنگ...
# 253  DengueFever  رائیونڈ عدنان بدر ڈینگی صفائی ستھرائی چیک کیلئ...
# 254  DengueFever                                   احتیاط ڈینگی بچا
# 255  DengueFever  سرویلنس ٹیمیں ڈینگی مچھر افزائش مقامات بھرپور ...
# 256  DengueFever  انسداد ڈینگی مہم کمرشل اداروں دکانوں باقاعدگی ...
# 257  DengueFever  سوات ضلعی انتظامیہ محکمہ صحت ناقص منصوبہ بندی ...
# 258  DengueFever  اوکاڑہ ڈسٹرکٹ انٹا مالوجسٹکا مارکیٹوں مختلف جگ...
# 259  DengueFever  انسداد ڈینگی کار کردگی جائزہ لینے حوالہ اجلاس ...
#
#                                             NounChunks  km_label
# 0    [سی پیک منصوبہ ختمآئی ایم ایف, شرائط پرعملدرآم...         3
# 1    [حکومت, سی پیک, تحت اکانامک زونز, توجہ, رشکئی ...         4
# 2    [سی پیک, کاموجودہ مرحلہ, پاکستانی عوام, معاشی ...         3
# 3    [وزیر, اعلیٰ خیبر پختونخوا محمود خان, جمعہ, رو...         4
# 4    [غربت, شرح, کمی, سی پیک, دوسرے مرحلے, اہم ترجی...         3
# 5    [حکومت عوام, ریلیف, فراہمی, لئے, عزم, سی پیک ا...         3
# 6    [چین پاکستان, اقتصادی راہداری منصوبہ, دوسرے مر...         3
# 7    [وزیر اعظم عمران خان, دورہ چین, ممالک, مابین ت...         4
# 8       [صدارتی آرڈیننس, ذریعے, سی پیک اتھارٹی, فیصلہ]         3
# 9    [خیبرپختونخوا حکومت, متعلقہ محکموں, ترقیاتی من...         4
# 10   [وزیراعظم عمران خان, دورہ چین, سی پیک منصوبوں,...         4
# 11   [چین پاکستان, اقتصادی راہداری, ملک, توانائی, ش...         3
# 12   [وزیراعظم عمران خان, دورہ چین, بعد چینی صدر بھ...         4
# 13   [ضکے, سی آر, وفاقی حکومت, سردمہری, رویہ, قابل...         4
# 14   [خطے, مزید تنازع, کوشش, سعودیہ, ایران, غلط فہم...         4
# 15   [سی پیک, پہلے مرحلے, تکمیل, پاکستان, بنیادی ڈھ...         4
# 16   [سی پیک, تحت بلوچستان, اقتصادی زونز, قیام, مقا...         3
# 17   [سی پیک, تحت بلوچستان, تحصیل بوستان, انڈسٹریل ...         5
# 18   [سی پیک, متعلقہ منصوبوں, پاکستانیوں, روزگار, ح...         3
# 19   [وزیراعظم, سی پیک اتھارٹی, چیئرپرسن, مقرر آرڈی...         3
# 20   [احسن اقبال, سی پیک اتھارٹی, آرڈیننس, خلاف قا...         3
# 21   [صدر مملکت عارف علوی, سی پیک اتھارٹی آرڈیننس,...         3
# 22   [پاکستان, چین, سی پیک, معاشی ترقی, صنعتی انقلا...         4
# 23   [چین, پاکستان, قومی مفاد, ایشو, بھرپور تعاون, ...         4
# 24   [وفاقی حکومت, سردمہری, رویہ, قابل افسوس, سعید ...         4
# 25   [کراچی سرکولر ریلوے, وفاقی حکومت, سردمہری قابل...         4
# 26   [وفاقی حکومت, سی پیک اتھارٹی بارے, صدارتی آرڈ...         3
# 27   [پاکستان, چین, سی پیک, تحت اربوں ڈالر مالیت, ا...         4
# 28   [پاکستان, چین, قریبی دوست شراکت دار, آہنی برا...         4
# 29   [سی پیک, دوسرے مرحلے, تکمیل, روزگار, مواقع پید...         3
# ..                                                 ...       ...
# 230  [سری لنکن آل راﺅنڈ ر تھیسارا پریرا, دورہ پاکست...         8
# 231  [یو ای ٹی لاہورکے زیر اہتمام ڈینگی, متعلق آگاہ...         2
# 232  [ٹی ایم اے لاچی, بڑے پیمانے, صفائی مہم, آغاز ...         5
# 233  [مظفرآبادلچھراٹ ویلفئیر آرگنائزیشن آزادجموں...         6
# 234  [ڈینگی, خاتمہ, لئے بلدیات, چیف افسران نکاسی, ص...         1
# 235  [حکومت ڈینگی, مکمل خاتمہ, ٹھوس عملی اقدامات, ر...         2
# 236  [ٹی ایم اے لاچی, بڑے پیمانے, صفائی مہم, آغاز ...         5
# 237      [ڈینگی, خدشہ, پیش نظر دکانداروں, خلاف مقدمات]         2
# 238  [افسران, شہر, صفائی, ڈینگی سیمینار, ڈینگی انتظ...         2
# 239  [رواں سال بلوچستان, اضلاع, ڈینگی وائرس, کیسز ر...         9
# 240       [خیبر پختونخوا, ڈینگی, نئے کیسز رپورٹ تعداد]        10
# 241  [انسداد ڈینگی مہم, ڈپٹی کمشنر سرگودھا, محکموں ...        11
# 242            [ملک, ڈینگی, متاثر افراد, تعداد, تجاوز]        10
# 243  [سیکرٹری صحت, زیر صدارت ڈینگی, تازہ ترین صورتح...        12
# 244  [فوزیہ نامی خاتون بے, نظیر بھٹو اسپتال, ڈینگی ...         9
# 245  [پاکستان وآزادکشمیر, ڈینگی وائر, ڈینگی وائر, ...         2
# 246  [ڈینگی, خاتمے, عملی اقداما ت, ہیںشیخ عقیل الرح...         2
# 247  [پمز, ڈینگی, مشتبہ مریضوں, مریضوں, ڈینگی وائرس...        10
# 248      [صوبائی وزیر ملک اسد کھوکھر ڈینگی, شکارہوگئے]         2
# 249  [آر ڈبلیو ایم, جانب, ڈینگی کیخلاف, حفاظتی اقد...         2
# 250  [انسداد ڈینگی سرویلنس, کوتاہی برداشت, سیکرٹری ...        12
# 251  [ڈی, سی لاہور اصغر جوئیہ, این ڈی بوائز ہائی سک...         1
# 252  [افسران ڈینگی سروئلنس صفائی, پرائس چیکنگ, عملد...         1
# 253  [اے, سی رائیونڈ عدنان بدر, ڈینگی, صفائی, چیک, ...         2
# 254                                    [احتیاط, ڈینگی]         2
# 255  [سرویلنس ٹیمیں ڈینگی مچھر, افزائش, مقامات, بھر...         1
# 256  [انسداد ڈینگی مہم, کمرشل اداروں دکانوں, باقاعد...        12
# 257  [سواتضلعی انتظامیہ, محکمہ صحت, ناقص منصوبہ بند...         9
# 258  [اوکاڑہڈسٹرکٹ انٹا مالوجسٹکا مارکیٹوں, مختلف ج...         2
# 259  [انسداد ڈینگی, کارکردگی, جائزہ, حوالہ, اجلاس, ...        12
#
# [260 rows x 9 columns]

# %%
top_elements_topics = []
for i in range(0,kn.knee):
    hash_cluster1 = list_phrases_cluster(i,dataset,'km_label')
    top_elements_topics.append(hash_cluster1.most_common(10))

# %%
top_elements_topics
# Out:
# [[('ترکی', 5),
#   ('شام', 4),
#   ('فوجی کارروائی', 4),
#   ('ترک فوجی کارروائی', 3),
#   ('آغاز', 2),
#   ('سلامتی کونسل', 2),
#   ('مطالبہ', 2),
#   ('ترکی شام', 1),
#   ('کرد جنگجوؤں کیخلاف فوجی کارروائی', 1),
#   ('دےیورپی یونین', 1)],
#  [('ڈینگی', 7),
#   ('ڈی', 6),
#   ('مریضوں', 2),
#   ('مبتلا مریضوں', 2),
#   ('عیادت', 2),
#   ('آزادکشمیر', 2),
#   ('سی لاہور', 2),
#   ('سی خانیوال', 2),
#   ('کنگ عبدالله ہسپتال', 1),
#   ('بیڈ', 1)],
#  [('ڈینگی', 22),
#   ('قابو', 4),
#   ('انعقاد', 4),
#   ('ڈینگی مچھر', 3),
#   ('بچاؤ', 3),
#   ('بچائو', 2),
#   ('لئے', 2),
#   ('بچاؤ مہم', 2),
#   ('شہری حصہ', 2),
#   ('شہباز شاہین', 2)],
#  [('سی پیک اتھارٹی', 11),
#   ('سی پیک', 6),
#   ('حکام', 6),
#   ('غربت', 3),
#   ('صنعتی تعاون', 3),
#   ('دوسرے مرحلہ', 2),
#   ('دوسرے مرحلے', 2),
#   ('لئے', 2),
#   ('چین پاکستان', 2),
#   ('مدد', 2)],
#  [('سی پیک', 15),
#   ('پاکستان', 8),
#   ('چین', 7),
#   ('دورہ چین', 4),
#   ('سی آر', 4),
#   ('وفاقی حکومت', 3),
#   ('وفاقی وزیر', 2),
#   ('وزیر اعظم عمران خان', 2),
#   ('وزیراعظم عمران خان', 2),
#   ('لئے', 2)],
#  [('ڈینگی', 5),
#   ('ضلعی انتظامیہ', 4),
#   ('رپورٹ', 3),
#   ('جاری کردی', 3),
#   ('انسداد ڈینگی', 2),
#   ('گزشتہ روز', 2),
#   ('صفائی', 2),
#   ('ٹی ایم اے لاچی', 2),
#   ('بڑے پیمانے', 2),
#   ('صفائی مہم', 2)],
#  [('ڈینگی', 6),
#   ('اسلام آباد', 3),
#   ('سندھ', 2),
#   ('رواں برس کانگو', 2),
#   ('نگلیریا', 2),
#   ('افراد جان', 2),
#   ('بازی', 2),
#   ('مقبوضہ جموں کشمیر', 1),
#   ('مظلوموں', 1),
#   ('ساتھ اظہار یکجہتی', 1)],
#  [('اظہار یکجہتی', 16),
#   ('کشمیریوں', 13),
#   ('ریلی', 13),
#   ('اظہار', 9),
#   ('انعقاد', 8),
#   ('مقبوضہ کشمیر', 3),
#   ('قیادت', 3),
#   ('ضلعی انتظامیہ', 2),
#   ('کشمیری خواتین', 2),
#   ('ساتھ اظہار یکجہتی', 2)],
#  [('سری لنکن ٹیم', 10),
#   ('پاکستان', 8),
#   ('دورہ', 3),
#   ('درمیان', 3),
#   ('کوچ', 3),
#   ('پاک سری لنکن ٹی ٹوئنٹی سیریز؛ ٹکٹوں', 2),
#   ('فروخت شروع', 2),
#   ('قذافی سٹیڈیم', 2),
#   ('سری لنکا', 2),
#   ('خلاف سیریز', 2)],
#  [('ڈینگی', 9),
#   ('ڈینگی وائرس', 8),
#   ('محکمہ صحت', 3),
#   ('عوام', 3),
#   ('کنٹرول', 3),
#   ('تصدیق', 2),
#   ('وزیر صحت', 2),
#   ('لئے', 2),
#   ('حوالے', 2),
#   ('عیادت', 2)],
#  [('تعداد', 11),
#   ('ڈینگی', 11),
#   ('مریضوں', 6),
#   ('پنجاب', 6),
#   ('تجاوز', 4),
#   ('ڈینگی مریضوں', 3),
#   ('پمز', 2),
#   ('اظہار تشویش', 2),
#   ('مزید کیسز تعداد', 2),
#   ('بعد خیبرپختونخوا', 2)],
#  [('ڈینگی', 9),
#   ('ڈپٹی کمشنر', 6),
#   ('بچاؤ', 2),
#   ('حوالے', 2),
#   ('فرد', 2),
#   ('کردار ادا', 2),
#   ('وقت', 2),
#   ('مکمل خاتمہ', 2),
#   ('حد', 2),
#   ('ڈپٹی کمشنر سید امان انور قدوائی', 2)],
#  [('ڈینگی', 5),
#   ('حوالے', 3),
#   ('زیر صدارت انسداد ڈینگی', 2),
#   ('اہم اجلاس', 2),
#   ('انعقاد', 2),
#   ('صورتحال', 2),
#   ('اقدامات', 2),
#   ('جائزہ', 2),
#   ('وجہ', 2),
#   ('صورتحال قابو', 2)]]

# %%
# initializing list of lists 
test_list = top_elements_topics
single_list = []
for x in test_list:
    for u,v in x:
        single_list.append(u)
freq = collections.Counter(single_list)

# %%
freq
# Out:
# Counter({'ترکی': 1,
#          'شام': 1,
#          'فوجی کارروائی': 1,
#          'ترک فوجی کارروائی': 1,
#          'آغاز': 1,
#          'سلامتی کونسل': 1,
#          'مطالبہ': 1,
#          'ترکی شام': 1,
#          'کرد جنگجوؤں کیخلاف فوجی کارروائی': 1,
#          'دےیورپی یونین': 1,
#          'ڈینگی': 8,
#          'ڈی': 1,
#          'مریضوں': 2,
#          'مبتلا مریضوں': 1,
#          'عیادت': 2,
#          'آزادکشمیر': 1,
#          'سی لاہور': 1,
#          'سی خانیوال': 1,
#          'کنگ عبدالله ہسپتال': 1,
#          'بیڈ': 1,
#          'قابو': 1,
#          'انعقاد': 3,
#          'ڈینگی مچھر': 1,
#          'بچاؤ': 2,
#          'بچائو': 1,
#          'لئے': 4,
#          'بچاؤ مہم': 1,
#          'شہری حصہ': 1,
#          'شہباز شاہین': 1,
#          'سی پیک اتھارٹی': 1,
#          'سی پیک': 2,
#          'حکام': 1,
#          'غربت': 1,
#          'صنعتی تعاون': 1,
#          'دوسرے مرحلہ': 1,
#          'دوسرے مرحلے': 1,
#          'چین پاکستان': 1,
#          'مدد': 1,
#          'پاکستان': 2,
#          'چین': 1,
#          'دورہ چین': 1,
#          'سی آر': 1,
#          'وفاقی حکومت': 1,
#          'وفاقی وزیر': 1,
#          'وزیر اعظم عمران خان': 1,
#          'وزیراعظم عمران خان': 1,
#          'ضلعی انتظامیہ': 2,
#          'رپورٹ': 1,
#          'جاری کردی': 1,
#          'انسداد ڈینگی': 1,
#          'گزشتہ روز': 1,
#          'صفائی': 1,
#          'ٹی ایم اے لاچی': 1,
#          'بڑے پیمانے': 1,
#          'صفائی مہم': 1,
#          'اسلام آباد': 1,
#          'سندھ': 1,
#          'رواں برس کانگو': 1,
#          'نگلیریا': 1,
#          'افراد جان': 1,
#          'بازی': 1,
#          'مقبوضہ جموں کشمیر': 1,
#          'مظلوموں': 1,
#          'ساتھ اظہار یکجہتی': 2,
#          'اظہار یکجہتی': 1,
#          'کشمیریوں': 1,
#          'ریلی': 1,
#          'اظہار': 1,
#          'مقبوضہ کشمیر': 1,
#          'قیادت': 1,
#          'کشمیری خواتین': 1,
#          'سری لنکن ٹیم': 1,
#          'دورہ': 1,
#          'درمیان': 1,
#          'کوچ': 1,
#          'پاک سری لنکن ٹی ٹوئنٹی سیریز؛ ٹکٹوں': 1,
#          'فروخت شروع': 1,
#          'قذافی سٹیڈیم': 1,
#          'سری لنکا': 1,
#          'خلاف سیریز': 1,
#          'ڈینگی وائرس': 1,
#          'محکمہ صحت': 1,
#          'عوام': 1,
#          'کنٹرول': 1,
#          'تصدیق': 1,
#          'وزیر صحت': 1,
#          'حوالے': 3,
#          'تعداد': 1,
#          'پنجاب': 1,
#          'تجاوز': 1,
#          'ڈینگی مریضوں': 1,
#          'پمز': 1,
#          'اظہار تشویش': 1,
#          'مزید کیسز تعداد': 1,
#          'بعد خیبرپختونخوا': 1,
#          'ڈپٹی کمشنر': 1,
#          'فرد': 1,
#          'کردار ادا': 1,
#          'وقت': 1,
#          'مکمل خاتمہ': 1,
#          'حد': 1,
#          'ڈپٹی کمشنر سید امان انور قدوائی': 1,
#          'زیر صدارت انسداد ڈینگی': 1,
#          'اہم اجلاس': 1,
#          'صورتحال': 1,
#          'اقدامات': 1,
#          'جائزہ': 1,
#          'وجہ': 1,
#          'صورتحال قابو': 1})

# %%
common_element=[]
for u,v in freq.items():
    if v>1:
        common_element.append(u)
common_element
# Out:
# ['ڈینگی',
#  'مریضوں',
#  'عیادت',
#  'انعقاد',
#  'بچاؤ',
#  'لئے',
#  'سی پیک',
#  'پاکستان',
#  'ضلعی انتظامیہ',
#  'ساتھ اظہار یکجہتی',
#  'حوالے']

# %%
new_top_elements_topics = []
for top10_in_topic in top_elements_topics:
    new_list_topic = []
    for u,v in top10_in_topic:
        if u not in common_element:
            new_list_topic.append((u,v))
    new_top_elements_topics.append(new_list_topic)

# %%
new_top_elements_topics[12]
# Out:
# [('زیر صدارت انسداد ڈینگی', 2),
#  ('اہم اجلاس', 2),
#  ('صورتحال', 2),
#  ('اقدامات', 2),
#  ('جائزہ', 2),
#  ('وجہ', 2),
#  ('صورتحال قابو', 2)]

# %%
top_elements_topics[12]
# Out:
# [('ڈینگی', 5),
#  ('حوالے', 3),
#  ('زیر صدارت انسداد ڈینگی', 2),
#  ('اہم اجلاس', 2),
#  ('انعقاد', 2),
#  ('صورتحال', 2),
#  ('اقدامات', 2),
#  ('جائزہ', 2),
#  ('وجہ', 2),
#  ('صورتحال قابو', 2)]

# %%
labels_proposed=[]
for i in range(0,kn.knee):
    labels_proposed.append(return_clusters_title(i,dataset,'km_label'))
# Out:
#                       term      rank  wCount
# 238           شام میں فوجی  0.399441       3
# 423      میں فوجی کارروائی  0.399441       3
# 239  شام میں فوجی کارروائی  0.399441       4
# 334       فوجی کارروائی کا  0.356475       3
# 569        کارروائی کا غاز  0.356475       3
#                     term      rank  wCount
# 953          ڈی سی لاہور  0.333053       3
# 751         میں ڈینگی کے  0.274766       3
# 401        سی لاہور اصغر  0.198980       3
# 572     لاہور اصغر جوئیہ  0.198980       3
# 402  سی لاہور اصغر جوئیہ  0.198980       4
#                term      rank  wCount
# 2755  ڈینگی سے بچاؤ  0.437364       3
# 516    بچاؤ مہم میں  0.321283       3
# 819    حصہ لے شہباز  0.321283       3
# 1374    سے بچاؤ مہم  0.321283       3
# 1527    شہری حصہ لے  0.321283       3
#                      term      rank  wCount
# 433        سی پیک اتھارٹی  0.609845       3
# 238           حکام سی پیک  0.372439       3
# 239   حکام سی پیک اتھارٹی  0.372439       4
# 1074       پیک اتھارٹی کے  0.239567       3
# 457     سی پیک اتھارٹی کے  0.239567       4
#                term      rank  wCount
# 1068      سی پیک کے  0.323730       3
# 2090     چین سی پیک  0.218732       3
# 1029      سی پیک پر  0.217546       3
# 2020     پیک کے تحت  0.192714       3
# 1069  سی پیک کے تحت  0.192714       4
#                    term      rank  wCount
# 402    ضلعی انتظامیہ نے  0.410946       3
# 257     رپورٹ جاری کردی  0.403145       3
# 874       کی رپورٹ جاری  0.403145       3
# 875  کی رپورٹ جاری کردی  0.403145       4
# 37    انتظامیہ نے ڈینگی  0.394274       3
#               term     rank  wCount
# 161  باد میں ڈینگی  0.20799       3
# 0      13 ڈینگی سے  0.19518       3
# 6    18 نگلیریا سے  0.19518       3
# 58    افراد جان کی  0.19518       3
# 175   بازی ہار چکے  0.19518       3
#                           term      rank  wCount
# 736            سے اظہار یکجہتی  0.986678       3
# 1770         کشمیریوں سے اظہار  0.904005       3
# 1771  کشمیریوں سے اظہار یکجہتی  0.904005       4
# 97          اظہار یکجہتی کیلئے  0.755323       3
# 768      سے اظہار یکجہتی کیلئے  0.627716       4
#                  term      rank  wCount
# 650      سری لنکن ٹیم  0.548829       3
# 633       سری لنکن ٹی  0.459467       3
# 1559     پاک سری لنکن  0.459467       3
# 1560  پاک سری لنکن ٹی  0.459467       4
# 1422  ٹی ٹوئنٹی سیریز  0.380523       3
#                  term      rank  wCount
# 1836  میں ڈینگی وائرس  0.367520       3
# 2443   ڈینگی وائرس کے  0.243535       3
# 339     بھر میں ڈینگی  0.191952       3
# 2013   وائرس کی تصدیق  0.187029       3
# 2439   ڈینگی وائرس کی  0.187029       3
#                  term      rank  wCount
# 695   مریضوں کی تعداد  0.458951       3
# 910      میں ڈینگی کے  0.445279       3
# 1084    ڈینگی بے قابو  0.438706       3
# 1492    ہزار سے تجاوز  0.385276       3
# 1157  ڈینگی کے مریضوں  0.341174       3
#                 term      rank  wCount
# 1849   ہے ڈپٹی کمشنر  0.306955       3
# 44     ادا نہیں کرتا  0.199268       3
# 52         اس وقت تک  0.199268       3
# 219   اپنا کردار ادا  0.199268       3
# 363      تک ڈینگی کا  0.199268       3
#                         term      rank  wCount
# 1109            کی زیر صدارت  0.325577       3
# 383         زیر صدارت انسداد  0.303766       3
# 585       صدارت انسداد ڈینگی  0.303766       3
# 384   زیر صدارت انسداد ڈینگی  0.303766       4
# 1110     کی زیر صدارت انسداد  0.303766       4

# %%
all_labels = pd.DataFrame({'Cluster':range(0,kn.knee),'Zero-Order': labels_zero_order,'M-Order':labels_m_order,'T-Order':labels_t_order,'ProposedMethod':labels_proposed})

# %%
all_labels
# Out:
#     Cluster                                Zero-Order  \
# 0         0                                  ترکی شام
# 1         1     ڈی ایچ کیو ہسپتال وہاڑی کادورہ ہسپتال
# 2         2                                ڈینگی مچھر
# 3         3                       سی پیک اتھارٹی بارے
# 4         4                        وزیراعظم عمران خان
# 5         5                       ضلعی انتظامیہ لاہور
# 6         6                          پریشان عمران خان
# 7         7           کشمیری عوام کیساتھ اظہار یکجہتی
# 8         8  پاک سری لنکن ٹی ٹونٹی کرکٹ سیریز سکیورٹی
# 9         9                     محکمہ صحت ڈینگی وائرس
# 10       10                             خیبر پختونخوا
# 11       11              ڈپٹی کمشنر محمد سیف انور جپہ
# 12       12                    زیر صدارت انسداد ڈینگی
#
#                                   M-Order  \
# 0                       ترک فوجی کارروائی
# 1   ڈی ایچ کیو ہسپتال وہاڑی کادورہ ہسپتال
# 2                  سی ای او ہیلتھ خانیوال
# 3                                    حکام
# 4                      وزیراعظم عمران خان
# 5                     ضلعی انتظامیہ لاہور
# 6              پی ٹی آئی حکومت عمران خان
# 7                 طاقت کشمیری حریت پسندوں
# 8                                سری لنکن
# 9                   محکمہ صحت ڈینگی وائرس
# 10                        مزید کیسز تعداد
# 11      ڈپٹی کمشنر جہلم محمد سیف انور جپہ
# 12                 زیر صدارت انسداد ڈینگی
#
#                                   T-Order  \
# 0                                ترکی شام
# 1   ڈی ایچ کیو ہسپتال وہاڑی کادورہ ہسپتال
# 2                  سی ای او ہیلتھ خانیوال
# 3                                    حکام
# 4                     وزیر اعظم عمران خان
# 5                     ضلعی انتظامیہ لاہور
# 6              پی ٹی آئی حکومت عمران خان
# 7         کشمیری عوام کیساتھ اظہار یکجہتی
# 8                                سری لنکا
# 9                   محکمہ صحت ڈینگی وائرس
# 10                        مزید کیسز تعداد
# 11           ڈپٹی کمشنر محمد سیف انور جپہ
# 12                 زیر صدارت انسداد ڈینگی
#
#                                  ProposedMethod
# 0                 ترکی کی شام میں فوجی کارروائی
# 1                               ڈینگی کے مریضوں
# 2   انعقاد احتیاطی تدابیر اپنا کر ڈینگی پر قابو
# 3                           حکام سی پیک اتھارٹی
# 4                        پاکستان اور چین سی پیک
# 5               ضلعی انتظامیہ نے ڈینگی کی رپورٹ
# 6                          No title constructed
# 7           کشمیریوں سے اظہار یکجہتی کیلئے ریلی
# 8                          No title constructed
# 9                         محکمہ صحت ڈینگی وائرس
# 10                     ڈینگی کے مریضوں کی تعداد
# 11                         No title constructed
# 12              زیر صدارت انسداد ڈینگی کے حوالے

# %%
all_labels.to_csv('all_labels_comparison.csv',sep='\t',encoding='utf-8',index=False)
