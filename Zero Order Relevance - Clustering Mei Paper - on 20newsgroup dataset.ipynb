# %%
import re
from ast import literal_eval
import numpy as np
import pandas as pd
from pprint import pprint
import collections
import math
# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
#scipy
import scipy 
from sklearn.cluster import KMeans
# spacy for lemmatization
import spacy
import os
from sklearn.datasets import fetch_20newsgroups
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
# NLTK Stop words
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
# Extract noun chunks from corpus
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
newsgroups_train = fetch_20newsgroups(subset='train', shuffle = True)
newsgroups_test = fetch_20newsgroups(subset='test', shuffle = True)

# %%
print(list(newsgroups_train.target_names))
# Out:
# ['alt.atheism', 'comp.graphics', 'comp.os.ms-windows.misc', 'comp.sys.ibm.pc.hardware', 'comp.sys.mac.hardware', 'comp.windows.x', 'misc.forsale', 'rec.autos', 'rec.motorcycles', 'rec.sport.baseball', 'rec.sport.hockey', 'sci.crypt', 'sci.electronics', 'sci.med', 'sci.space', 'soc.religion.christian', 'talk.politics.guns', 'talk.politics.mideast', 'talk.politics.misc', 'talk.religion.misc']

# %%
print(newsgroups_train.filenames.shape, newsgroups_train.target.shape)
# Out:
# (11314,) (11314,)

# %%
def lemmatization(text):
    """https://spacy.io/api/annotation"""
    texts_out = []
    doc = nlp(" ".join(text)) 
    texts_out = [token.lemma_ for token in doc]
    return texts_out


# Tokenize and lemmatize
def preprocess(text):
    result=[]
    for token in gensim.utils.simple_preprocess(text) :
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
            result.append(token)
    #print(result)
    lemmatized = lemmatization(result)
            
    return lemmatized
def candidate_label_lemmatized(label):
    w_labels = label.split()
    lemmatized = lemmatization(w_labels)
    return " ".join(lemmatized)

def news_group_target_names(k):
    return newsgroups_train.target_names[k]
def return_preprocessed_text(words):
    x = literal_eval(words)
    return " ".join(x)
def get_pd_of_cluster(dataset,cluster_idx):
    dataset_sub = dataset[dataset['k_means'] == cluster_idx]
    cnt = CountVectorizer()
    voc = cnt.fit_transform(dataset_sub.preprocessed_text)
    vocab = list(cnt.get_feature_names())
    counts = voc.sum(axis=0).A1
    freq_distribution = Counter(dict(zip(vocab, counts)))
    prob = {}
    for w in vocab:
        prob[w] = freq_distribution[w]/np.sum(counts)
    return prob

# %%
candidate_label_lemmatized('a eating rabbit')
# Out:
# 'a eat rabbit'

# %%
document_num = 50
doc_sample = 'This disk has failed many times. I would like to get it replaced.'

print("Original document: ")
words = []
for word in doc_sample.split(' '):
    words.append(word)
print(words)
print("\n\nTokenized and lemmatized document: ")
print(preprocess(doc_sample))
# Out:
# Original document:
# ['This', 'disk', 'has', 'failed', 'many', 'times.', 'I', 'would', 'like', 'to', 'get', 'it', 'replaced.']
#
#
# Tokenized and lemmatized document:
# ['disk', 'fail', 'time', 'like', 'replace']

# %%
dataset = pd.read_csv('dataset_lda_20_newsgroup_withNounPhrases.csv',sep='\t')

# %%
dataset['preprocessed_text'] = dataset['preprocessed'].apply(return_preprocessed_text)

# %%
#apply k-means
n_clust=20
cnt = TfidfVectorizer(stop_words='english')
voc = cnt.fit_transform(dataset.preprocessed_text)

# %%
model = KMeans(n_clusters=n_clust, 
               init='k-means++', 
               random_state=0,
               max_iter=100, # Maximum number of iterations of the k-means algorithm for a single run.
               n_init=1)  # Number of time the k-means algorithm will be run with different centroid seeds. The final results will be the best output of n_init consecutive runs in terms of inertia.

model.fit(voc)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=100,
#     n_clusters=20, n_init=1, n_jobs=1, precompute_distances='auto',
#     random_state=0, tol=0.0001, verbose=0)

# %%
dataset['k_means'] = model.labels_

# %%
ct = pd.crosstab(dataset['Topic'], dataset['k_means'])

# %%
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = cnt.get_feature_names()

# %%
for i in range(n_clust):
    print("Cluster %d:" % i),
    for ind in order_centroids[i, :10]:
        print(' %s' % terms[ind])
# Out:
# Cluster 0:
#  jesus
#  bible
#  christ
#  church
#  christian
#  people
#  believe
#  christians
#  faith
#  say
# Cluster 1:
#  government
#  people
#  gun
#  weapon
#  right
#  firearm
#  crime
#  batf
#  state
#  think
# Cluster 2:
#  game
#  team
#  player
#  play
#  year
#  hockey
#  season
#  baseball
#  score
#  league
# Cluster 3:
#  card
#  driver
#  video
#  diamond
#  port
#  mode
#  graphic
#  vesa
#  monitor
#  nubus
# Cluster 4:
#  drive
#  scsi
#  pitt
#  gordon
#  disk
#  banks
#  controller
#  hard
#  floppy
#  problem
# Cluster 5:
#  sale
#  ohio
#  price
#  state
#  magnus
#  offer
#  simms
#  sell
#  university
#  line
# Cluster 6:
#  nasa
#  space
#  henry
#  alaska
#  moon
#  toronto
#  launch
#  orbit
#  shuttle
#  lunar
# Cluster 7:
#  clipper
#  chip
#  encryption
#  escrow
#  key
#  government
#  phone
#  crypto
#  algorithm
#  secure
# Cluster 8:
#  access
#  digex
#  online
#  communication
#  express
#  greenbelt
#  nntp
#  host
#  post
#  steve
# Cluster 9:
#  gatech
#  prism
#  georgia
#  institute
#  hrivnak
#  technology
#  atlanta
#  internet
#  mule
#  hplabs
# Cluster 10:
#  printer
#  print
#  font
#  deskjet
#  laser
#  driver
#  bubblejet
#  canon
#  grayscale
#  postscript
# Cluster 11:
#  line
#  subject
#  organization
#  post
#  university
#  host
#  nntp
#  thank
#  write
#  know
# Cluster 12:
#  write
#  article
#  bike
#  like
#  think
#  people
#  know
#  subject
#  organization
#  time
# Cluster 13:
#  monitor
#  color
#  screen
#  display
#  image
#  xterm
#  problem
#  line
#  window
#  dresden
# Cluster 14:
#  file
#  format
#  program
#  window
#  windows
#  directory
#  cview
#  image
#  disk
#  help
# Cluster 15:
#  keith
#  caltech
#  morality
#  objective
#  livesey
#  moral
#  schneider
#  solntze
#  allan
#  atheist
# Cluster 16:
#  virginia
#  cramer
#  optilink
#  clayton
#  homosexual
#  kaldis
#  clas
#  sexual
#  university
#  male
# Cluster 17:
#  israel
#  israeli
#  armenian
#  turkish
#  jews
#  arab
#  armenia
#  people
#  bony
#  kill
# Cluster 18:
#  window
#  mouse
#  windows
#  motif
#  application
#  widget
#  program
#  manager
#  problem
#  server
# Cluster 19:
#  religion
#  atheist
#  sandvik
#  believe
#  christian
#  islam
#  people
#  christianity
#  atheism
#  truth

# %%
vocab = list(terms)

# %%
len(vocab)
# Out:
# 72688

# %%
prob_clusters = []
for i in range(0,n_clust):
    prob_clusters.append(get_pd_of_cluster(dataset,i))

# %%
theta=[]
for i in range(0,n_clust):
    p_w = []
    for w in vocab:
        if w in prob_clusters[i].keys():
            p_w.append(prob_clusters[i][w])
        else:
            p_w.append(0)
    theta.append(p_w)

# %%
x = pd.DataFrame(theta)
x.columns = vocab

# %%
x.shape
# Out:
# (20, 72688)

# %%
theta=x.values

# %%
theta.shape
# Out:
# (20, 72688)

# %%
freq = voc.sum(axis=0)

# %%
freq = (freq/np.sum(freq))

# %%
freq.shape
# Out:
# (1, 72688)

# %%
#function taken from Textacy library to identify noun, verb and prepositional phrases
def pos_regex_matches(doc, pattern):
    """
    Extract sequences of consecutive tokens from a spacy-parsed doc whose
    part-of-speech tags match the specified regex pattern.

    Args:
        doc (``textacy.Doc`` or ``spacy.Doc`` or ``spacy.Span``)
        pattern (str): Pattern of consecutive POS tags whose corresponding words
            are to be extracted, inspired by the regex patterns used in NLTK's
            `nltk.chunk.regexp`. Tags are uppercase, from the universal tag set;
            delimited by < and >, which are basically converted to parentheses
            with spaces as needed to correctly extract matching word sequences;
            white space in the input doesn't matter.

            Examples (see ``constants.POS_REGEX_PATTERNS``):

            * noun phrase: r'<DET>? (<NOUN>+ <ADP|CONJ>)* <NOUN>+'
            * compound nouns: r'<NOUN>+'
            * verb phrase: r'<VERB>?<ADV>*<VERB>+'
            * prepositional phrase: r'<PREP> <DET>? (<NOUN>+<ADP>)* <NOUN>+'

    Yields:
        ``spacy.Span``: the next span of consecutive tokens from ``doc`` whose
        parts-of-speech match ``pattern``, in order of apperance
    """
    # standardize and transform the regular expression pattern...
    pattern = re.sub(r'\s', '', pattern)
    pattern = re.sub(r'<([A-Z]+)\|([A-Z]+)>', r'( (\1|\2))', pattern)
    pattern = re.sub(r'<([A-Z]+)>', r'( \1)', pattern)

    tags = ' ' + ' '.join(tok.pos_ for tok in doc)

    for m in re.finditer(pattern, tags):
        yield doc[tags[0:m.start()].count(' '):tags[0:m.end()].count(' ')]

# %%
pattern = r'<DET>? (<NOUN>+ <ADP|CONJ>)* <NOUN>+'

# %%
all_noun_chunks =[]

# %%
for x in newsgroups_train.data:
    doc = nlp(x)
    lists = pos_regex_matches(doc, pattern)
    for j in lists:
        all_noun_chunks.append(j.text.lower().strip())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-87b975513e2e> in <module>()
#       1 for x in newsgroups_train.data:
# ----> 2     doc = nlp(x)
#       3     lists = pos_regex_matches(doc, pattern)
#       4     for j in lists:
#       5         all_noun_chunks.append(j.text.lower().strip())
#
# ~\Anaconda2\envs\py36\lib\site-packages\spacy\language.py in __call__(self, text, disable, component_cfg)
#     436             if not hasattr(proc, "__call__"):
#     437                 raise ValueError(Errors.E003.format(component=type(proc), name=name))
# --> 438             doc = proc(doc, **component_cfg.get(name, {}))
#     439             if doc is None:
#     440                 raise ValueError(Errors.E005.format(name=name))
#
# pipes.pyx in spacy.pipeline.pipes.Tagger.__call__()
#
# pipes.pyx in spacy.pipeline.pipes.Tagger.predict()
#
# ~\Anaconda2\envs\py36\lib\site-packages\thinc\neural\_classes\model.py in __call__(self, x)
#     167             Must match expected shape
#     168         """
# --> 169         return self.predict(x)
#     170
#     171     def pipe(self, stream, batch_size=128):
#
# ~\Anaconda2\envs\py36\lib\site-packages\thinc\neural\_classes\feed_forward.py in predict(self, X)
#      38     def predict(self, X):
#      39         for layer in self._layers:
# ---> 40             X = layer(X)
#      41         return X
#      42
#
# ~\Anaconda2\envs\py36\lib\site-packages\thinc\neural\_classes\model.py in __call__(self, x)
#     167             Must match expected shape
#     168         """
# --> 169         return self.predict(x)
#     170
#     171     def pipe(self, stream, batch_size=128):
#
# ~\Anaconda2\envs\py36\lib\site-packages\thinc\api.py in predict(seqs_in)
#     308     def predict(seqs_in):
#     309         lengths = layer.ops.asarray([len(seq) for seq in seqs_in])
# --> 310         X = layer(layer.ops.flatten(seqs_in, pad=pad))
#     311         return layer.ops.unflatten(X, lengths, pad=pad)
#     312
#
# ~\Anaconda2\envs\py36\lib\site-packages\thinc\neural\_classes\model.py in __call__(self, x)
#     167             Must match expected shape
#     168         """
# --> 169         return self.predict(x)
#     170
#     171     def pipe(self, stream, batch_size=128):
#
# ~\Anaconda2\envs\py36\lib\site-packages\thinc\neural\_classes\feed_forward.py in predict(self, X)
#      38     def predict(self, X):
#      39         for layer in self._layers:
# ---> 40             X = layer(X)
#      41         return X
#      42
#
# ~\Anaconda2\envs\py36\lib\site-packages\thinc\neural\_classes\model.py in __call__(self, x)
#     167             Must match expected shape
#     168         """
# --> 169         return self.predict(x)
#     170
#     171     def pipe(self, stream, batch_size=128):
#
# ~\Anaconda2\envs\py36\lib\site-packages\thinc\neural\_classes\model.py in predict(self, X)
#     131
#     132     def predict(self, X):
# --> 133         y, _ = self.begin_update(X, drop=None)
#     134         return y
#     135
#
# ~\Anaconda2\envs\py36\lib\site-packages\thinc\api.py in uniqued_fwd(X, drop)
#     374             keys = keys.get()
#     375         uniq_keys, ind, inv, counts = numpy.unique(
# --> 376             keys, return_index=True, return_inverse=True, return_counts=True
#     377         )
#     378         X_uniq = layer.ops.xp.ascontiguousarray(X[ind])
#
# ~\Anaconda2\envs\py36\lib\site-packages\numpy\lib\arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     221     ar = np.asanyarray(ar)
#     222     if axis is None:
# --> 223         return _unique1d(ar, return_index, return_inverse, return_counts)
#     224     if not (-ar.ndim <= axis < ar.ndim):
#     225         raise ValueError('Invalid axis kwarg specified for unique')
#
# ~\Anaconda2\envs\py36\lib\site-packages\numpy\lib\arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
#     278
#     279     if optional_indices:
# --> 280         perm = ar.argsort(kind='mergesort' if return_index else 'quicksort')
#     281         aux = ar[perm]
#     282     else:
#
# KeyboardInterrupt:

# %%
# Out:
# 517135

# %%
allnounchunks = pd.DataFrame({'NounChunks':all_noun_chunks})

# %%
#allnounchunks.to_csv('allnounchunks20NewsGroup.csv',index=False)

# %%
allnounchunks = pd.read_csv('allnounchunks20NewsGroup.csv')

# %%
all_noun_chunks = allnounchunks.NounChunks
print(len(all_noun_chunks))
# Out:
# 517135

# %%
from collections import Counter

# %%
freq_all_noun_chunks = Counter(all_noun_chunks)

# %%
freq_all_noun_chunks.most_common(500)
# Out:
# [('lines', 11263),
#  ('subject', 10916),
#  ('article', 6258),
#  ('host', 4841),
#  ('people', 4234),
#  ('distribution', 2625),
#  ('|', 2085),
#  ('time', 1898),
#  ('%', 1810),
#  ('x', 1725),
#  ('years', 1618),
#  ('things', 1324),
#  ('thanks', 1188),
#  ('way', 1136),
#  ('world', 1089),
#  ('thing', 1075),
#  ('version', 1059),
#  ('information', 1047),
#  ('system', 1036),
#  ('part', 1035),
#  ('year', 956),
#  ('question', 919),
#  ('life', 778),
#  ('example', 776),
#  ('others', 765),
#  ('government', 746),
#  ('the way', 730),
#  ('file', 724),
#  ('today', 711),
#  ('problem', 711),
#  ('fact', 707),
#  ('name', 703),
#  ('#', 680),
#  ('a lot', 637),
#  ('day', 626),
#  ('the problem', 615),
#  ('use', 614),
#  ('problems', 614),
#  ('email', 600),
#  ('the time', 586),
#  ('times', 581),
#  ('case', 577),
#  ('course', 574),
#  ('number', 573),
#  ('the people', 565),
#  ('point', 559),
#  ('-newsreader', 558),
#  ('files', 558),
#  ('program', 557),
#  ('questions', 556),
#  ('place', 551),
#  ('line', 540),
#  ('order', 540),
#  ('drive', 539),
#  ('work', 538),
#  ('days', 534),
#  ('opinions', 530),
#  ('children', 527),
#  ('internet', 525),
#  ('power', 523),
#  ('data', 521),
#  ('the fact', 518),
#  ('_', 518),
#  ('reply', 516),
#  ('one', 513),
#  ('the world', 511),
#  ('hand', 506),
#  ('software', 500),
#  ('mail', 493),
#  ('evidence', 492),
#  ('reason', 487),
#  ('money', 485),
#  ('games', 484),
#  ('team', 473),
#  ('car', 465),
#  ('the government', 460),
#  ('law', 444),
#  ('message', 434),
#  ('stuff', 433),
#  ('a bit', 432),
#  ('side', 430),
#  ('men', 428),
#  ('person', 423),
#  ('e-mail', 421),
#  ('phone', 421),
#  ('help', 420),
#  ('game', 415),
#  ('mind', 411),
#  ('rights', 409),
#  ('opinion', 404),
#  ('faith', 397),
#  ('man', 389),
#  ('card', 385),
#  ('the end', 381),
#  ('chip', 380),
#  ('g)r', 380),
#  ('source', 379),
#  ('state', 379),
#  ('code', 374),
#  ('words', 374),
#  ('key', 372),
#  ('months', 368),
#  ('the rest', 364),
#  ('info', 364),
#  ('players', 361),
#  ('religion', 359),
#  ('women', 354),
#  ('death', 353),
#  ('memory', 352),
#  ('access', 351),
#  ('drivers', 348),
#  ('home', 348),
#  ('none', 345),
#  ('systems', 343),
#  ('sale', 338),
#  ('sense', 338),
#  ('support', 338),
#  ('the point', 334),
#  ('the question', 333),
#  ('points', 331),
#  ('period', 331),
#  ('experience', 330),
#  ('programs', 329),
#  ('no one', 329),
#  ('stephanopoulos', 327),
#  ('q', 326),
#  ('weeks', 321),
#  ('machine', 320),
#  ('the net', 320),
#  ('pc', 319),
#  ('science', 319),
#  ('groups', 319),
#  ('a problem', 319),
#  ('price', 318),
#  ('end', 317),
#  ('thanks in advance', 317),
#  ('weapons', 315),
#  ('idea', 314),
#  ('the system', 313),
#  ('keys', 311),
#  ('guns', 311),
#  ('self', 310),
#  ('issue', 310),
#  ('ones', 310),
#  ('mb', 307),
#  ('history', 306),
#  ('fax', 306),
#  ('position', 304),
#  ('a', 301),
#  ('the right', 300),
#  ('date', 300),
#  ('book', 299),
#  ('text', 298),
#  ('encryption', 297),
#  ('speed', 295),
#  ('g', 294),
#  ('cars', 294),
#  ('the case', 294),
#  ('members', 291),
#  ('word', 291),
#  ('space', 287),
#  ('disk', 286),
#  ('windows', 286),
#  ('numbers', 286),
#  ('computer', 283),
#  ('the game', 283),
#  ('knowledge', 282),
#  ('argument', 281),
#  ('night', 281),
#  ('season', 280),
#  ('the car', 279),
#  ('statement', 278),
#  ('right', 275),
#  ('list', 275),
#  ('users', 275),
#  ('bit', 275),
#  ('this year', 274),
#  ('address', 273),
#  ('size', 273),
#  ('group', 273),
#  ('post', 266),
#  ('head', 264),
#  ('the idea', 264),
#  ('machines', 263),
#  ('truth', 262),
#  ('comments', 262),
#  ('citizens', 260),
#  ('parts', 260),
#  ('a while', 260),
#  ('control', 257),
#  ('area', 257),
#  ('mode', 256),
#  ('wife', 256),
#  ('laws', 256),
#  ('news', 254),
#  ('p', 254),
#  ('cases', 253),
#  ('the name', 253),
#  ('contact', 251),
#  ('country', 250),
#  ('addition', 248),
#  ('level', 248),
#  ('details', 247),
#  ('condition', 246),
#  ('teams', 238),
#  ('applications', 237),
#  ('response', 237),
#  ('window', 236),
#  ('drives', 235),
#  ('value', 235),
#  ('reasons', 235),
#  ('the internet', 235),
#  ('application', 234),
#  ('technology', 234),
#  ('w', 234),
#  ('atheists', 234),
#  ('some people', 233),
#  ('peace', 233),
#  ('ways', 233),
#  ('graphics', 232),
#  ('hours', 232),
#  ('type', 230),
#  ('job', 230),
#  ('organization', 229),
#  ('package', 229),
#  ('image', 228),
#  ('friends', 227),
#  ('defense', 227),
#  ('discussion', 227),
#  ('posting', 226),
#  ('images', 226),
#  ('answer', 225),
#  ('this group', 225),
#  ('note', 225),
#  ('body', 224),
#  ('section', 224),
#  ('places', 223),
#  ('food', 223),
#  ('population', 222),
#  ('c', 222),
#  ('the law', 221),
#  ('minutes', 220),
#  ('a year', 219),
#  ('business', 219),
#  ('bus', 218),
#  ('drugs', 218),
#  ('books', 218),
#  ('site', 217),
#  ('interest', 217),
#  ('-', 217),
#  ('freenet', 217),
#  ('arms', 217),
#  ('miles', 216),
#  ('week', 216),
#  ('k', 216),
#  ('the number', 216),
#  ('r', 216),
#  ('bits', 216),
#  ('server', 215),
#  ('cards', 214),
#  ('advice', 214),
#  ('the truth', 213),
#  ('format', 211),
#  ('dod', 210),
#  ('views', 209),
#  ('u', 208),
#  ('hardware', 208),
#  ('friend', 207),
#  ('performance', 206),
#  ('purpose', 206),
#  ('bike', 206),
#  ('originator', 206),
#  ('color', 206),
#  ('error', 205),
#  ('the word', 205),
#  ('sources', 205),
#  ('view', 204),
#  ('war', 203),
#  ('belief', 203),
#  ('the difference', 202),
#  ('folks', 201),
#  ('nature', 201),
#  ('e', 201),
#  ('atheism', 201),
#  ('ideas', 200),
#  ('values', 199),
#  ('company', 199),
#  ('cost', 198),
#  ('society', 198),
#  ('action', 198),
#  ('gun', 198),
#  ('a person', 197),
#  ('the book', 197),
#  ('soldiers', 197),
#  ('monitor', 196),
#  ('family', 196),
#  ('morality', 195),
#  ('driver', 195),
#  ('the program', 195),
#  ('countries', 195),
#  ('screen', 194),
#  ('model', 193),
#  ('a way', 192),
#  ('results', 192),
#  ('face', 192),
#  ('o', 191),
#  ('output', 190),
#  ('a copy', 190),
#  ('the team', 190),
#  ('hands', 189),
#  ('trouble', 189),
#  ('privacy', 188),
#  ('crime', 188),
#  ('any help', 187),
#  ('com', 187),
#  ('actions', 186),
#  ('port', 186),
#  ('v', 186),
#  ('existence', 186),
#  ('entry', 185),
#  ('research', 185),
#  ('situation', 184),
#  ('display', 183),
#  ('b', 183),
#  ('the issue', 182),
#  ('names', 182),
#  ('effect', 181),
#  ('lives', 181),
#  ('water', 180),
#  ('the user', 180),
#  ('arguments', 180),
#  ('difference', 179),
#  ('goal', 179),
#  ('areas', 179),
#  ('the day', 178),
#  ('language', 177),
#  ('the one', 177),
#  ('versions', 176),
#  ('claim', 176),
#  ('devices', 175),
#  ('the window', 175),
#  ('a car', 175),
#  ('shipping', 175),
#  ('deal', 174),
#  ('theory', 174),
#  ('guest', 173),
#  ('beliefs', 173),
#  ('the reason', 172),
#  ('request', 172),
#  ('re', 172),
#  ('issues', 172),
#  ('the body', 171),
#  ('a couple', 171),
#  ('states', 171),
#  ('sites', 171),
#  ('user', 171),
#  ('posts', 171),
#  ('criminals', 171),
#  ('force', 171),
#  ('love', 170),
#  ('story', 170),
#  ('volume', 169),
#  ('runs', 169),
#  ('the situation', 169),
#  ('heart', 169),
#  ('sex', 169),
#  ('standard', 168),
#  ('genocide', 168),
#  ('a friend', 167),
#  ('the list', 166),
#  ('controller', 166),
#  ('choice', 166),
#  ('the price', 165),
#  ('articles', 165),
#  ('chips', 165),
#  ('land', 165),
#  ('community', 165),
#  ('page', 164),
#  ('light', 164),
#  ('office', 164),
#  ('safety', 164),
#  ('son', 164),
#  ('the state', 164),
#  ('care', 164),
#  ('understanding', 163),
#  ('study', 163),
#  ('solution', 162),
#  ('terms', 162),
#  ('cd', 162),
#  ('directory', 162),
#  ('activities', 161),
#  ('the screen', 161),
#  ('the subject', 161),
#  ('events', 160),
#  ('copies', 160),
#  ('security', 159),
#  ('series', 159),
#  ('eyes', 159),
#  ('references', 158),
#  ('orbit', 158),
#  ('insurance', 158),
#  ('a man', 158),
#  ('the power', 158),
#  ('the answer', 158),
#  ('luck', 157),
#  ('the person', 157),
#  ('approach', 157),
#  ('keyboard', 157),
#  ('this time', 156),
#  ('copy', 155),
#  ('m', 155),
#  ('the line', 155),
#  ('the use', 155),
#  ('responsibility', 155),
#  ('rules', 155),
#  ('companies', 154),
#  ('record', 154),
#  ('account', 154),
#  ('device', 154),
#  ('colors', 154),
#  ('education', 154),
#  ('offer', 153),
#  ('fans', 153),
#  ('guys', 153),
#  ('this point', 152),
#  ('t', 152),
#  ('player', 152),
#  ('errors', 151),
#  ('service', 151),
#  ('reality', 151),
#  ('the road', 151),
#  ('the drive', 151),
#  ('gas', 150),
#  ('this case', 150),
#  ('police', 150),
#  ('sin', 150),
#  ('a program', 149),
#  ('lots', 149),
#  ('top', 149),
#  ('fan', 149),
#  ('school', 149),
#  ('video', 149),
#  ('this one', 149),
#  ('the file', 149),
#  ('individuals', 148),
#  ('board', 148),
#  ('products', 148),
#  ('kids', 148),
#  ('keywords', 148),
#  ('goals', 148),
#  ('feet', 147),
#  ('context', 147),
#  ('disks', 147),
#  ('murder', 146),
#  ('employer', 146),
#  ('hell', 146),
#  ('postings', 146),
#  ('functions', 145),
#  ('fire', 145),
#  ('class', 144),
#  ('sera@zuma', 144),
#  ('instance', 144),
#  ('freedom', 144),
#  ('troops', 144),
#  ('the key', 144),
#  ('the opinions', 143),
#  ('a number', 143),
#  ('the universe', 143),
#  ('humans', 143),
#  ('no way', 143),
#  ('the data', 143),
#  ('answers', 143),
#  ('this problem', 142),
#  ('fonts', 142),
#  ('attention', 142),
#  ('church', 142),
#  ('a gun', 142),
#  ('definition', 142),
#  ('studies', 141),
#  ('baseball', 140),
#  ('the back', 140),
#  ('mother', 140),
#  ('term', 139),
#  ('standards', 139),
#  ('modem', 139),
#  ('authority', 139),
#  ('ability', 139),
#  ('blood', 138),
#  ('the ground', 138),
#  ('hockey', 138),
#  ('the article', 137),
#  ('logic', 137),
#  ('s', 136),
#  ('examples', 136),
#  ('models', 136),
#  ('meaning', 135),
#  ('the bike', 135),
#  ('front', 135),
#  ('patients', 135),
#  ('chance', 135)]

# %%
# Take top 1000 frequent noun phrases as Candidate labels as suggested by Mei et al.
top_3000_candid = freq_all_noun_chunks.most_common(3000)

# %%
candidate_labels = []
for u,v in top_3000_candid:
    candidate_labels.append(u)

# %%
candidate_labels
# Out:
# ['lines',
#  'subject',
#  'article',
#  'host',
#  'people',
#  'distribution',
#  '|',
#  'time',
#  '%',
#  'x',
#  'years',
#  'things',
#  'thanks',
#  'way',
#  'world',
#  'thing',
#  'version',
#  'information',
#  'system',
#  'part',
#  'year',
#  'question',
#  'life',
#  'example',
#  'others',
#  'government',
#  'the way',
#  'file',
#  'today',
#  'problem',
#  'fact',
#  'name',
#  '#',
#  'a lot',
#  'day',
#  'the problem',
#  'use',
#  'problems',
#  'email',
#  'the time',
#  'times',
#  'case',
#  'course',
#  'number',
#  'the people',
#  'point',
#  '-newsreader',
#  'files',
#  'program',
#  'questions',
#  'place',
#  'line',
#  'order',
#  'drive',
#  'work',
#  'days',
#  'opinions',
#  'children',
#  'internet',
#  'power',
#  'data',
#  'the fact',
#  '_',
#  'reply',
#  'one',
#  'the world',
#  'hand',
#  'software',
#  'mail',
#  'evidence',
#  'reason',
#  'money',
#  'games',
#  'team',
#  'car',
#  'the government',
#  'law',
#  'message',
#  'stuff',
#  'a bit',
#  'side',
#  'men',
#  'person',
#  'e-mail',
#  'phone',
#  'help',
#  'game',
#  'mind',
#  'rights',
#  'opinion',
#  'faith',
#  'man',
#  'card',
#  'the end',
#  'chip',
#  'g)r',
#  'source',
#  'state',
#  'code',
#  'words',
#  'key',
#  'months',
#  'the rest',
#  'info',
#  'players',
#  'religion',
#  'women',
#  'death',
#  'memory',
#  'access',
#  'drivers',
#  'home',
#  'none',
#  'systems',
#  'sale',
#  'sense',
#  'support',
#  'the point',
#  'the question',
#  'points',
#  'period',
#  'experience',
#  'programs',
#  'no one',
#  'stephanopoulos',
#  'q',
#  'weeks',
#  'machine',
#  'the net',
#  'pc',
#  'science',
#  'groups',
#  'a problem',
#  'price',
#  'end',
#  'thanks in advance',
#  'weapons',
#  'idea',
#  'the system',
#  'keys',
#  'guns',
#  'self',
#  'issue',
#  'ones',
#  'mb',
#  'history',
#  'fax',
#  'position',
#  'a',
#  'the right',
#  'date',
#  'book',
#  'text',
#  'encryption',
#  'speed',
#  'g',
#  'cars',
#  'the case',
#  'members',
#  'word',
#  'space',
#  'disk',
#  'windows',
#  'numbers',
#  'computer',
#  'the game',
#  'knowledge',
#  'argument',
#  'night',
#  'season',
#  'the car',
#  'statement',
#  'right',
#  'list',
#  'users',
#  'bit',
#  'this year',
#  'address',
#  'size',
#  'group',
#  'post',
#  'head',
#  'the idea',
#  'machines',
#  'truth',
#  'comments',
#  'citizens',
#  'parts',
#  'a while',
#  'control',
#  'area',
#  'mode',
#  'wife',
#  'laws',
#  'news',
#  'p',
#  'cases',
#  'the name',
#  'contact',
#  'country',
#  'addition',
#  'level',
#  'details',
#  'condition',
#  'teams',
#  'applications',
#  'response',
#  'window',
#  'drives',
#  'value',
#  'reasons',
#  'the internet',
#  'application',
#  'technology',
#  'w',
#  'atheists',
#  'some people',
#  'peace',
#  'ways',
#  'graphics',
#  'hours',
#  'type',
#  'job',
#  'organization',
#  'package',
#  'image',
#  'friends',
#  'defense',
#  'discussion',
#  'posting',
#  'images',
#  'answer',
#  'this group',
#  'note',
#  'body',
#  'section',
#  'places',
#  'food',
#  'population',
#  'c',
#  'the law',
#  'minutes',
#  'a year',
#  'business',
#  'bus',
#  'drugs',
#  'books',
#  'site',
#  'interest',
#  '-',
#  'freenet',
#  'arms',
#  'miles',
#  'week',
#  'k',
#  'the number',
#  'r',
#  'bits',
#  'server',
#  'cards',
#  'advice',
#  'the truth',
#  'format',
#  'dod',
#  'views',
#  'u',
#  'hardware',
#  'friend',
#  'performance',
#  'purpose',
#  'bike',
#  'originator',
#  'color',
#  'error',
#  'the word',
#  'sources',
#  'view',
#  'war',
#  'belief',
#  'the difference',
#  'folks',
#  'nature',
#  'e',
#  'atheism',
#  'ideas',
#  'values',
#  'company',
#  'cost',
#  'society',
#  'action',
#  'gun',
#  'a person',
#  'the book',
#  'soldiers',
#  'monitor',
#  'family',
#  'morality',
#  'driver',
#  'the program',
#  'countries',
#  'screen',
#  'model',
#  'a way',
#  'results',
#  'face',
#  'o',
#  'output',
#  'a copy',
#  'the team',
#  'hands',
#  'trouble',
#  'privacy',
#  'crime',
#  'any help',
#  'com',
#  'actions',
#  'port',
#  'v',
#  'existence',
#  'entry',
#  'research',
#  'situation',
#  'display',
#  'b',
#  'the issue',
#  'names',
#  'effect',
#  'lives',
#  'water',
#  'the user',
#  'arguments',
#  'difference',
#  'goal',
#  'areas',
#  'the day',
#  'language',
#  'the one',
#  'versions',
#  'claim',
#  'devices',
#  'the window',
#  'a car',
#  'shipping',
#  'deal',
#  'theory',
#  'guest',
#  'beliefs',
#  'the reason',
#  'request',
#  're',
#  'issues',
#  'the body',
#  'a couple',
#  'states',
#  'sites',
#  'user',
#  'posts',
#  'criminals',
#  'force',
#  'love',
#  'story',
#  'volume',
#  'runs',
#  'the situation',
#  'heart',
#  'sex',
#  'standard',
#  'genocide',
#  'a friend',
#  'the list',
#  'controller',
#  'choice',
#  'the price',
#  'articles',
#  'chips',
#  'land',
#  'community',
#  'page',
#  'light',
#  'office',
#  'safety',
#  'son',
#  'the state',
#  'care',
#  'understanding',
#  'study',
#  'solution',
#  'terms',
#  'cd',
#  'directory',
#  'activities',
#  'the screen',
#  'the subject',
#  'events',
#  'copies',
#  'security',
#  'series',
#  'eyes',
#  'references',
#  'orbit',
#  'insurance',
#  'a man',
#  'the power',
#  'the answer',
#  'luck',
#  'the person',
#  'approach',
#  'keyboard',
#  'this time',
#  'copy',
#  'm',
#  'the line',
#  'the use',
#  'responsibility',
#  'rules',
#  'companies',
#  'record',
#  'account',
#  'device',
#  'colors',
#  'education',
#  'offer',
#  'fans',
#  'guys',
#  'this point',
#  't',
#  'player',
#  'errors',
#  'service',
#  'reality',
#  'the road',
#  'the drive',
#  'gas',
#  'this case',
#  'police',
#  'sin',
#  'a program',
#  'lots',
#  'top',
#  'fan',
#  'school',
#  'video',
#  'this one',
#  'the file',
#  'individuals',
#  'board',
#  'products',
#  'kids',
#  'keywords',
#  'goals',
#  'feet',
#  'context',
#  'disks',
#  'murder',
#  'employer',
#  'hell',
#  'postings',
#  'functions',
#  'fire',
#  'class',
#  'sera@zuma',
#  'instance',
#  'freedom',
#  'troops',
#  'the key',
#  'the opinions',
#  'a number',
#  'the universe',
#  'humans',
#  'no way',
#  'the data',
#  'answers',
#  'this problem',
#  'fonts',
#  'attention',
#  'church',
#  'a gun',
#  'definition',
#  'studies',
#  'baseball',
#  'the back',
#  'mother',
#  'term',
#  'standards',
#  'modem',
#  'authority',
#  'ability',
#  'blood',
#  'the ground',
#  'hockey',
#  'the article',
#  'logic',
#  's',
#  'examples',
#  'models',
#  'meaning',
#  'the bike',
#  'front',
#  'patients',
#  'chance',
#  'a time',
#  'reference',
#  'product',
#  'features',
#  'ground',
#  'firearms',
#  'yesterday',
#  'a question',
#  'the source',
#  'the server',
#  'interface',
#  'that way',
#  'rate',
#  'percent',
#  'warning',
#  'the author',
#  'function',
#  'escrow',
#  'analysis',
#  'any information',
#  'voice',
#  'the existence',
#  'the message',
#  'property',
#  'options',
#  'form',
#  'will',
#  'behavior',
#  'messages',
#  'resources',
#  'return',
#  'the chip',
#  'the ones',
#  'forces',
#  'the country',
#  'mhz',
#  'equipment',
#  'summary',
#  'call',
#  'authorities',
#  'the season',
#  'method',
#  'house',
#  'cause',
#  'quality',
#  'organizations',
#  'methods',
#  'cable',
#  'title',
#  'policy',
#  'comment',
#  'pages',
#  'future',
#  'step',
#  'month',
#  'h',
#  'the children',
#  'input',
#  'suggestions',
#  'conclusion',
#  'respect',
#  'tv',
#  'soul',
#  'the fire',
#  'taxes',
#  'author',
#  'this country',
#  'shots',
#  'practice',
#  'material',
#  'religions',
#  'bytes',
#  'statements',
#  'any way',
#  'treatment',
#  'father',
#  'pm',
#  'base',
#  'wire',
#  'interpretation',
#  'the past',
#  'process',
#  'effort',
#  'mouse',
#  'claims',
#  'character',
#  'half',
#  'parents',
#  'this newsgroup',
#  'child',
#  'seconds',
#  'attack',
#  'the police',
#  'ftp',
#  'matter',
#  'p.',
#  'tools',
#  'good',
#  'facts',
#  'guy',
#  'an example',
#  'attacks',
#  'the process',
#  'the future',
#  'pain',
#  'animals',
#  'uucp',
#  'change',
#  'the card',
#  'myers',
#  'trial',
#  'age',
#  'this way',
#  'a.',
#  'development',
#  'an article',
#  'environment',
#  'project',
#  'the money',
#  'the city',
#  'earth',
#  'cities',
#  'box',
#  'a result',
#  'administration',
#  'the algorithm',
#  'media',
#  'entries',
#  'range',
#  'basis',
#  'objects',
#  'advantage',
#  'jobs',
#  'every time',
#  'the puck',
#  'any info',
#  'option',
#  'newsgroups',
#  'governments',
#  'air',
#  'the guy',
#  'test',
#  'advance',
#  'the year',
#  'computers',
#  'a chance',
#  'the keys',
#  'room',
#  'some sort',
#  'magazine',
#  'event',
#  'documentation',
#  'algorithm',
#  'a message',
#  'thinking',
#  'char',
#  'civilians',
#  'militia',
#  'tape',
#  'attempt',
#  'charge',
#  'protection',
#  'disease',
#  'cover',
#  'no',
#  'the moon',
#  'villages',
#  'dollars',
#  'domain',
#  'd',
#  'industry',
#  'paper',
#  'weight',
#  'court',
#  'art',
#  'the words',
#  'a system',
#  'rom',
#  'race',
#  'the work',
#  'poster',
#  'daughter',
#  'the machine',
#  'report',
#  'design',
#  'purposes',
#  'works',
#  'a list',
#  'brother',
#  'these people',
#  'the earth',
#  'reports',
#  'the area',
#  'engine',
#  'letter',
#  'the result',
#  'a day',
#  'trade',
#  'the security',
#  'e-',
#  'the top',
#  'coverage',
#  'operation',
#  'proof',
#  'role',
#  'mph',
#  'tradition',
#  'unit',
#  'widget',
#  'description',
#  'plan',
#  'simms',
#  'owners',
#  'rule',
#  'readers',
#  'this program',
#  'command',
#  'a team',
#  'training',
#  'heads',
#  'communications',
#  'status',
#  'the league',
#  'changes',
#  'a thing',
#  'the cost',
#  'thoughts',
#  'the results',
#  'direction',
#  'notes',
#  'century',
#  'prices',
#  'network',
#  'effects',
#  'some time',
#  'types',
#  'the numbers',
#  'fault',
#  'library',
#  'style',
#  'the beginning',
#  'market',
#  'the man',
#  'means',
#  'the purpose',
#  'cryptography',
#  'the driver',
#  'these things',
#  'agents',
#  'no idea',
#  'power play',
#  'the evidence',
#  'pub',
#  'experiences',
#  'the things',
#  'every day',
#  'building',
#  'guess',
#  'z',
#  'conditions',
#  'a window',
#  'homosexuals',
#  'situations',
#  'resolution',
#  'the engine',
#  'a group',
#  'ignorance',
#  'stats',
#  'the hell',
#  'woman',
#  'ram',
#  'town',
#  '\\',
#  'traffic',
#  'permission',
#  'persons',
#  'the mouse',
#  'a file',
#  'printer',
#  'division',
#  'papers',
#  'lot',
#  'the ability',
#  'party',
#  'the door',
#  'x11r5',
#  'efforts',
#  'the media',
#  'medicine',
#  'skepticism',
#  'apartment',
#  'field',
#  'monitors',
#  'eye',
#  'act',
#  'this message',
#  'bikes',
#  'concern',
#  'widgets',
#  'kind',
#  'services',
#  'look',
#  'decision',
#  'a woman',
#  'clients',
#  'win',
#  'pressure',
#  'holes',
#  'the roads',
#  'leaders',
#  'officials',
#  'marriage',
#  'announcement',
#  'items',
#  'the size',
#  'the information',
#  'the market',
#  'crypto',
#  'manual',
#  'that time',
#  'agencies',
#  'the compound',
#  'a bunch',
#  'punishment',
#  'the need',
#  'sound',
#  'differences',
#  'hope',
#  'member',
#  'pin',
#  'costs',
#  'attitude',
#  'release',
#  'the rules',
#  'bitnet',
#  'parties',
#  'positions',
#  'path',
#  'the majority',
#  'turn',
#  'homosexuality',
#  'doctor',
#  'need',
#  'i',
#  'the history',
#  'export',
#  'owner',
#  'implementation',
#  'majority',
#  'documents',
#  'funds',
#  'the church',
#  'door',
#  'the computer',
#  'this article',
#  'explanation',
#  'reasoning',
#  'the argument',
#  'activity',
#  'experts',
#  'policies',
#  'the land',
#  'student',
#  'shape',
#  'beings',
#  'setup',
#  'newsgroup',
#  'ports',
#  'proposal',
#  'discussions',
#  'wrong',
#  'justice',
#  'degrees',
#  'the batf',
#  'comparison',
#  'doubt',
#  'translation',
#  'the intellect',
#  'resistance',
#  'a book',
#  'any suggestions',
#  'the head',
#  'interests',
#  'the company',
#  'acts',
#  'armenians',
#  'disclaimer',
#  'bodies',
#  'the story',
#  'success',
#  'city',
#  'press',
#  'play',
#  'wisdom',
#  'ad',
#  'chapter',
#  'the basis',
#  'the middle',
#  'weapon',
#  'any case',
#  'no problem',
#  'operations',
#  'wars',
#  'army',
#  'the part',
#  'a pc',
#  'a game',
#  'needs',
#  'picture',
#  'mistake',
#  'this thread',
#  'brain',
#  'this posting',
#  'center',
#  'oname',
#  '# p',
#  'edition',
#  'brand',
#  'nation',
#  'thousands',
#  'a member',
#  'scale',
#  'manager',
#  'the chastity',
#  'pictures',
#  'risk',
#  'tool',
#  'being',
#  'the population',
#  'the sky',
#  'motherboard',
#  'radio',
#  'the image',
#  'statistics',
#  'characters',
#  'speech',
#  'the group',
#  'the playoffs',
#  'salvation',
#  'requests',
#  'the term',
#  'gun control',
#  'energy',
#  'concept',
#  'letters',
#  'doctors',
#  'run',
#  'handguns',
#  'sins',
#  'meeting',
#  'law enforcement',
#  'packages',
#  'the code',
#  'a line',
#  'background',
#  'health',
#  'no.',
#  'the package',
#  'the moment',
#  'fun',
#  'the thing',
#  'the sun',
#  'crimes',
#  'public',
#  'km',
#  'any ideas',
#  'this issue',
#  'boards',
#  'citizen',
#  'music',
#  'an atheist',
#  'a look',
#  'rates',
#  'detail',
#  'official',
#  'net',
#  'mountain',
#  'tonight',
#  'stage',
#  'aid',
#  'the press',
#  'diseases',
#  'mouth',
#  'mission',
#  'the possibility',
#  'tin',
#  'noise',
#  'the order',
#  'consideration',
#  'mine',
#  'neighbors',
#  'scientists',
#  'chances',
#  'no reason',
#  'dealer',
#  'foot',
#  'projects',
#  'boxes',
#  'kings',
#  'politics',
#  ...]

# %%
lemmatized_labels = [candidate_label_lemmatized(w) for w in candidate_labels]

# %%
lemmatized_labels
# Out:
# ['line',
#  'subject',
#  'article',
#  'host',
#  'people',
#  'distribution',
#  '|',
#  'time',
#  '%',
#  'x',
#  'year',
#  'thing',
#  'thank',
#  'way',
#  'world',
#  'thing',
#  'version',
#  'information',
#  'system',
#  'part',
#  'year',
#  'question',
#  'life',
#  'example',
#  'other',
#  'government',
#  'the way',
#  'file',
#  'today',
#  'problem',
#  'fact',
#  'name',
#  '#',
#  'a lot',
#  'day',
#  'the problem',
#  'use',
#  'problem',
#  'email',
#  'the time',
#  'time',
#  'case',
#  'course',
#  'number',
#  'the people',
#  'point',
#  '-newsreader',
#  'file',
#  'program',
#  'question',
#  'place',
#  'line',
#  'order',
#  'drive',
#  'work',
#  'day',
#  'opinion',
#  'child',
#  'internet',
#  'power',
#  'datum',
#  'the fact',
#  '_',
#  'reply',
#  'one',
#  'the world',
#  'hand',
#  'software',
#  'mail',
#  'evidence',
#  'reason',
#  'money',
#  'game',
#  'team',
#  'car',
#  'the government',
#  'law',
#  'message',
#  'stuff',
#  'a bit',
#  'side',
#  'man',
#  'person',
#  'e - mail',
#  'phone',
#  'help',
#  'game',
#  'mind',
#  'right',
#  'opinion',
#  'faith',
#  'man',
#  'card',
#  'the end',
#  'chip',
#  'g)r',
#  'source',
#  'state',
#  'code',
#  'word',
#  'key',
#  'month',
#  'the rest',
#  'info',
#  'player',
#  'religion',
#  'woman',
#  'death',
#  'memory',
#  'access',
#  'driver',
#  'home',
#  'none',
#  'system',
#  'sale',
#  'sense',
#  'support',
#  'the point',
#  'the question',
#  'point',
#  'period',
#  'experience',
#  'program',
#  'no one',
#  'stephanopoulos',
#  'q',
#  'week',
#  'machine',
#  'the net',
#  'pc',
#  'science',
#  'group',
#  'a problem',
#  'price',
#  'end',
#  'thank in advance',
#  'weapon',
#  'idea',
#  'the system',
#  'key',
#  'gun',
#  'self',
#  'issue',
#  'one',
#  'mb',
#  'history',
#  'fax',
#  'position',
#  'a',
#  'the right',
#  'date',
#  'book',
#  'text',
#  'encryption',
#  'speed',
#  'g',
#  'car',
#  'the case',
#  'member',
#  'word',
#  'space',
#  'disk',
#  'windows',
#  'number',
#  'computer',
#  'the game',
#  'knowledge',
#  'argument',
#  'night',
#  'season',
#  'the car',
#  'statement',
#  'right',
#  'list',
#  'user',
#  'bit',
#  'this year',
#  'address',
#  'size',
#  'group',
#  'post',
#  'head',
#  'the idea',
#  'machine',
#  'truth',
#  'comment',
#  'citizen',
#  'part',
#  'a while',
#  'control',
#  'area',
#  'mode',
#  'wife',
#  'law',
#  'news',
#  'p',
#  'case',
#  'the name',
#  'contact',
#  'country',
#  'addition',
#  'level',
#  'detail',
#  'condition',
#  'team',
#  'application',
#  'response',
#  'window',
#  'drives',
#  'value',
#  'reason',
#  'the internet',
#  'application',
#  'technology',
#  'w',
#  'atheist',
#  'some people',
#  'peace',
#  'way',
#  'graphic',
#  'hour',
#  'type',
#  'job',
#  'organization',
#  'package',
#  'image',
#  'friend',
#  'defense',
#  'discussion',
#  'post',
#  'image',
#  'answer',
#  'this group',
#  'note',
#  'body',
#  'section',
#  'place',
#  'food',
#  'population',
#  'c',
#  'the law',
#  'minute',
#  'a year',
#  'business',
#  'bus',
#  'drug',
#  'book',
#  'site',
#  'interest',
#  '-',
#  'freenet',
#  'arm',
#  'mile',
#  'week',
#  'k',
#  'the number',
#  'r',
#  'bit',
#  'server',
#  'card',
#  'advice',
#  'the truth',
#  'format',
#  'dod',
#  'views',
#  'u',
#  'hardware',
#  'friend',
#  'performance',
#  'purpose',
#  'bike',
#  'originator',
#  'color',
#  'error',
#  'the word',
#  'source',
#  'view',
#  'war',
#  'belief',
#  'the difference',
#  'folk',
#  'nature',
#  'e',
#  'atheism',
#  'idea',
#  'value',
#  'company',
#  'cost',
#  'society',
#  'action',
#  'gun',
#  'a person',
#  'the book',
#  'soldier',
#  'monitor',
#  'family',
#  'morality',
#  'driver',
#  'the program',
#  'country',
#  'screen',
#  'model',
#  'a way',
#  'result',
#  'face',
#  'o',
#  'output',
#  'a copy',
#  'the team',
#  'hand',
#  'trouble',
#  'privacy',
#  'crime',
#  'any help',
#  'com',
#  'action',
#  'port',
#  'v',
#  'existence',
#  'entry',
#  'research',
#  'situation',
#  'display',
#  'b',
#  'the issue',
#  'name',
#  'effect',
#  'life',
#  'water',
#  'the user',
#  'argument',
#  'difference',
#  'goal',
#  'area',
#  'the day',
#  'language',
#  'the one',
#  'version',
#  'claim',
#  'device',
#  'the window',
#  'a car',
#  'shipping',
#  'deal',
#  'theory',
#  'guest',
#  'beliefs',
#  'the reason',
#  'request',
#  're',
#  'issue',
#  'the body',
#  'a couple',
#  'states',
#  'site',
#  'user',
#  'post',
#  'criminal',
#  'force',
#  'love',
#  'story',
#  'volume',
#  'run',
#  'the situation',
#  'heart',
#  'sex',
#  'standard',
#  'genocide',
#  'a friend',
#  'the list',
#  'controller',
#  'choice',
#  'the price',
#  'article',
#  'chip',
#  'land',
#  'community',
#  'page',
#  'light',
#  'office',
#  'safety',
#  'son',
#  'the state',
#  'care',
#  'understanding',
#  'study',
#  'solution',
#  'term',
#  'cd',
#  'directory',
#  'activity',
#  'the screen',
#  'the subject',
#  'event',
#  'copy',
#  'security',
#  'series',
#  'eye',
#  'reference',
#  'orbit',
#  'insurance',
#  'a man',
#  'the power',
#  'the answer',
#  'luck',
#  'the person',
#  'approach',
#  'keyboard',
#  'this time',
#  'copy',
#  'm',
#  'the line',
#  'the use',
#  'responsibility',
#  'rule',
#  'company',
#  'record',
#  'account',
#  'device',
#  'color',
#  'education',
#  'offer',
#  'fan',
#  'guy',
#  'this point',
#  't',
#  'player',
#  'error',
#  'service',
#  'reality',
#  'the road',
#  'the drive',
#  'gas',
#  'this case',
#  'police',
#  'sin',
#  'a program',
#  'lot',
#  'top',
#  'fan',
#  'school',
#  'video',
#  'this one',
#  'the file',
#  'individual',
#  'board',
#  'product',
#  'kid',
#  'keywords',
#  'goal',
#  'foot',
#  'context',
#  'disk',
#  'murder',
#  'employer',
#  'hell',
#  'posting',
#  'function',
#  'fire',
#  'class',
#  'sera@zuma',
#  'instance',
#  'freedom',
#  'troop',
#  'the key',
#  'the opinion',
#  'a number',
#  'the universe',
#  'human',
#  'no way',
#  'the datum',
#  'answer',
#  'this problem',
#  'font',
#  'attention',
#  'church',
#  'a gun',
#  'definition',
#  'study',
#  'baseball',
#  'the back',
#  'mother',
#  'term',
#  'standards',
#  'modem',
#  'authority',
#  'ability',
#  'blood',
#  'the ground',
#  'hockey',
#  'the article',
#  'logic',
#  's',
#  'example',
#  'model',
#  'meaning',
#  'the bike',
#  'front',
#  'patient',
#  'chance',
#  'a time',
#  'reference',
#  'product',
#  'feature',
#  'ground',
#  'firearm',
#  'yesterday',
#  'a question',
#  'the source',
#  'the server',
#  'interface',
#  'that way',
#  'rate',
#  'percent',
#  'warning',
#  'the author',
#  'function',
#  'escrow',
#  'analysis',
#  'any information',
#  'voice',
#  'the existence',
#  'the message',
#  'property',
#  'option',
#  'form',
#  'will',
#  'behavior',
#  'message',
#  'resource',
#  'return',
#  'the chip',
#  'the one',
#  'force',
#  'the country',
#  'mhz',
#  'equipment',
#  'summary',
#  'call',
#  'authority',
#  'the season',
#  'method',
#  'house',
#  'cause',
#  'quality',
#  'organization',
#  'method',
#  'cable',
#  'title',
#  'policy',
#  'comment',
#  'page',
#  'future',
#  'step',
#  'month',
#  'h',
#  'the child',
#  'input',
#  'suggestion',
#  'conclusion',
#  'respect',
#  'tv',
#  'soul',
#  'the fire',
#  'taxis',
#  'author',
#  'this country',
#  'shot',
#  'practice',
#  'material',
#  'religion',
#  'bytes',
#  'statement',
#  'any way',
#  'treatment',
#  'father',
#  'pm',
#  'base',
#  'wire',
#  'interpretation',
#  'the past',
#  'process',
#  'effort',
#  'mouse',
#  'claim',
#  'character',
#  'half',
#  'parent',
#  'this newsgroup',
#  'child',
#  'second',
#  'attack',
#  'the police',
#  'ftp',
#  'matter',
#  'p.',
#  'tool',
#  'good',
#  'fact',
#  'guy',
#  'an example',
#  'attack',
#  'the process',
#  'the future',
#  'pain',
#  'animal',
#  'uucp',
#  'change',
#  'the card',
#  'myers',
#  'trial',
#  'age',
#  'this way',
#  'a.',
#  'development',
#  'an article',
#  'environment',
#  'project',
#  'the money',
#  'the city',
#  'earth',
#  'city',
#  'box',
#  'a result',
#  'administration',
#  'the algorithm',
#  'medium',
#  'entry',
#  'range',
#  'basis',
#  'object',
#  'advantage',
#  'job',
#  'every time',
#  'the puck',
#  'any info',
#  'option',
#  'newsgroup',
#  'government',
#  'air',
#  'the guy',
#  'test',
#  'advance',
#  'the year',
#  'computer',
#  'a chance',
#  'the key',
#  'room',
#  'some sort',
#  'magazine',
#  'event',
#  'documentation',
#  'algorithm',
#  'a message',
#  'think',
#  'char',
#  'civilians',
#  'militia',
#  'tape',
#  'attempt',
#  'charge',
#  'protection',
#  'disease',
#  'cover',
#  'no',
#  'the moon',
#  'village',
#  'dollar',
#  'domain',
#  'd',
#  'industry',
#  'paper',
#  'weight',
#  'court',
#  'art',
#  'the word',
#  'a system',
#  'rom',
#  'race',
#  'the work',
#  'poster',
#  'daughter',
#  'the machine',
#  'report',
#  'design',
#  'purpose',
#  'works',
#  'a list',
#  'brother',
#  'these people',
#  'the earth',
#  'report',
#  'the area',
#  'engine',
#  'letter',
#  'the result',
#  'a day',
#  'trade',
#  'the security',
#  'e-',
#  'the top',
#  'coverage',
#  'operation',
#  'proof',
#  'role',
#  'mph',
#  'tradition',
#  'unit',
#  'widget',
#  'description',
#  'plan',
#  'simms',
#  'owner',
#  'rule',
#  'reader',
#  'this program',
#  'command',
#  'a team',
#  'training',
#  'head',
#  'communication',
#  'status',
#  'the league',
#  'change',
#  'a thing',
#  'the cost',
#  'thought',
#  'the result',
#  'direction',
#  'note',
#  'century',
#  'price',
#  'network',
#  'effect',
#  'some time',
#  'type',
#  'the number',
#  'fault',
#  'library',
#  'style',
#  'the beginning',
#  'market',
#  'the man',
#  'mean',
#  'the purpose',
#  'cryptography',
#  'the driver',
#  'these thing',
#  'agent',
#  'no idea',
#  'power play',
#  'the evidence',
#  'pub',
#  'experience',
#  'the thing',
#  'every day',
#  'building',
#  'guess',
#  'z',
#  'condition',
#  'a window',
#  'homosexual',
#  'situation',
#  'resolution',
#  'the engine',
#  'a group',
#  'ignorance',
#  'stat',
#  'the hell',
#  'woman',
#  'ram',
#  'town',
#  '\\',
#  'traffic',
#  'permission',
#  'person',
#  'the mouse',
#  'a file',
#  'printer',
#  'division',
#  'paper',
#  'lot',
#  'the ability',
#  'party',
#  'the door',
#  'x11r5',
#  'effort',
#  'the medium',
#  'medicine',
#  'skepticism',
#  'apartment',
#  'field',
#  'monitor',
#  'eye',
#  'act',
#  'this message',
#  'bike',
#  'concern',
#  'widget',
#  'kind',
#  'service',
#  'look',
#  'decision',
#  'a woman',
#  'client',
#  'win',
#  'pressure',
#  'hole',
#  'the road',
#  'leader',
#  'official',
#  'marriage',
#  'announcement',
#  'item',
#  'the size',
#  'the information',
#  'the market',
#  'crypto',
#  'manual',
#  'that time',
#  'agency',
#  'the compound',
#  'a bunch',
#  'punishment',
#  'the need',
#  'sound',
#  'difference',
#  'hope',
#  'member',
#  'pin',
#  'cost',
#  'attitude',
#  'release',
#  'the rule',
#  'bitnet',
#  'party',
#  'position',
#  'path',
#  'the majority',
#  'turn',
#  'homosexuality',
#  'doctor',
#  'need',
#  'i',
#  'the history',
#  'export',
#  'owner',
#  'implementation',
#  'majority',
#  'document',
#  'fund',
#  'the church',
#  'door',
#  'the computer',
#  'this article',
#  'explanation',
#  'reasoning',
#  'the argument',
#  'activity',
#  'expert',
#  'policy',
#  'the land',
#  'student',
#  'shape',
#  'being',
#  'setup',
#  'newsgroup',
#  'port',
#  'proposal',
#  'discussion',
#  'wrong',
#  'justice',
#  'degree',
#  'the batf',
#  'comparison',
#  'doubt',
#  'translation',
#  'the intellect',
#  'resistance',
#  'a book',
#  'any suggestion',
#  'the head',
#  'interest',
#  'the company',
#  'act',
#  'armenian',
#  'disclaimer',
#  'body',
#  'the story',
#  'success',
#  'city',
#  'press',
#  'play',
#  'wisdom',
#  'ad',
#  'chapter',
#  'the basis',
#  'the middle',
#  'weapon',
#  'any case',
#  'no problem',
#  'operation',
#  'war',
#  'army',
#  'the part',
#  'a pc',
#  'a game',
#  'need',
#  'picture',
#  'mistake',
#  'this thread',
#  'brain',
#  'this posting',
#  'center',
#  'oname',
#  '# p',
#  'edition',
#  'brand',
#  'nation',
#  'thousand',
#  'a member',
#  'scale',
#  'manager',
#  'the chastity',
#  'picture',
#  'risk',
#  'tool',
#  'be',
#  'the population',
#  'the sky',
#  'motherboard',
#  'radio',
#  'the image',
#  'statistic',
#  'character',
#  'speech',
#  'the group',
#  'the playoff',
#  'salvation',
#  'request',
#  'the term',
#  'gun control',
#  'energy',
#  'concept',
#  'letter',
#  'doctor',
#  'run',
#  'handgun',
#  'sin',
#  'meeting',
#  'law enforcement',
#  'package',
#  'the code',
#  'a line',
#  'background',
#  'health',
#  'no .',
#  'the package',
#  'the moment',
#  'fun',
#  'the thing',
#  'the sun',
#  'crime',
#  'public',
#  'km',
#  'any idea',
#  'this issue',
#  'board',
#  'citizen',
#  'music',
#  'an atheist',
#  'a look',
#  'rate',
#  'detail',
#  'official',
#  'net',
#  'mountain',
#  'tonight',
#  'stage',
#  'aid',
#  'the press',
#  'disease',
#  'mouth',
#  'mission',
#  'the possibility',
#  'tin',
#  'noise',
#  'the order',
#  'consideration',
#  'mine',
#  'neighbor',
#  'scientist',
#  'chance',
#  'no reason',
#  'dealer',
#  'foot',
#  'project',
#  'box',
#  'king',
#  'politic',
#  ...]

# %%
vocab.index("xcx")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-2570a5a93a61> in <module>()
# ----> 1 vocab.index("xcx")
#
# ValueError: 'xcx' is not in list

# %%
def zero_order(freq,theta,lCandidat,NumTopic):
    """
    Calculate the Zero-Order Relevance

    Parameters:
    ----------
    freq : Array containing the frequency of occurrences of each word in the whole corpus
    theta : Array containing the frequency of occurrences of each word in each topic
    lcandidat: Array containing each label candidate
    NumTopic : The number of the topic
    
    Returns:
    -------
    topCandidate : Array containing the name of the top 10 score candidate for a given topic
    """
    
    #W matrice qui contient le score de chaque mot pour chaque topic
    W=np.log(theta/freq)
    
    # score des tous les candidats pour le topic NumTopic
    score=[]
    
    for indice in range (len(lCandidat)):
        candidat=lCandidat[indice].split(" ")
        sum_w=[]
        #print(candidat)
        for w in candidat:
            if w in vocab:
                i=vocab.index(w)
                sum_w.append(W[k,i])
            else:
                sum_w.append(0)
        #i=id2word.doc2idx(candidat)
        # supprime les -1 (qui signifie pas trouvé)
        #i[:] = [v for v in i if v != -1]
        
        score.append(np.sum(sum_w))
        
    #topValue, topCandidate = top10Score(score,lCandidat)
    dicti=pd.DataFrame({'Labels':lCandidat,'Score':score})
  
    return dicti

# %%
lemmatized_labels
# Out:
# ['line',
#  'subject',
#  'article',
#  'host',
#  'people',
#  'distribution',
#  '|',
#  'time',
#  '%',
#  'x',
#  'year',
#  'thing',
#  'thank',
#  'way',
#  'world',
#  'thing',
#  'version',
#  'information',
#  'system',
#  'part',
#  'year',
#  'question',
#  'life',
#  'example',
#  'other',
#  'government',
#  'the way',
#  'file',
#  'today',
#  'problem',
#  'fact',
#  'name',
#  '#',
#  'a lot',
#  'day',
#  'the problem',
#  'use',
#  'problem',
#  'email',
#  'the time',
#  'time',
#  'case',
#  'course',
#  'number',
#  'the people',
#  'point',
#  '-newsreader',
#  'file',
#  'program',
#  'question',
#  'place',
#  'line',
#  'order',
#  'drive',
#  'work',
#  'day',
#  'opinion',
#  'child',
#  'internet',
#  'power',
#  'datum',
#  'the fact',
#  '_',
#  'reply',
#  'one',
#  'the world',
#  'hand',
#  'software',
#  'mail',
#  'evidence',
#  'reason',
#  'money',
#  'game',
#  'team',
#  'car',
#  'the government',
#  'law',
#  'message',
#  'stuff',
#  'a bit',
#  'side',
#  'man',
#  'person',
#  'e - mail',
#  'phone',
#  'help',
#  'game',
#  'mind',
#  'right',
#  'opinion',
#  'faith',
#  'man',
#  'card',
#  'the end',
#  'chip',
#  'g)r',
#  'source',
#  'state',
#  'code',
#  'word',
#  'key',
#  'month',
#  'the rest',
#  'info',
#  'player',
#  'religion',
#  'woman',
#  'death',
#  'memory',
#  'access',
#  'driver',
#  'home',
#  'none',
#  'system',
#  'sale',
#  'sense',
#  'support',
#  'the point',
#  'the question',
#  'point',
#  'period',
#  'experience',
#  'program',
#  'no one',
#  'stephanopoulos',
#  'q',
#  'week',
#  'machine',
#  'the net',
#  'pc',
#  'science',
#  'group',
#  'a problem',
#  'price',
#  'end',
#  'thank in advance',
#  'weapon',
#  'idea',
#  'the system',
#  'key',
#  'gun',
#  'self',
#  'issue',
#  'one',
#  'mb',
#  'history',
#  'fax',
#  'position',
#  'a',
#  'the right',
#  'date',
#  'book',
#  'text',
#  'encryption',
#  'speed',
#  'g',
#  'car',
#  'the case',
#  'member',
#  'word',
#  'space',
#  'disk',
#  'windows',
#  'number',
#  'computer',
#  'the game',
#  'knowledge',
#  'argument',
#  'night',
#  'season',
#  'the car',
#  'statement',
#  'right',
#  'list',
#  'user',
#  'bit',
#  'this year',
#  'address',
#  'size',
#  'group',
#  'post',
#  'head',
#  'the idea',
#  'machine',
#  'truth',
#  'comment',
#  'citizen',
#  'part',
#  'a while',
#  'control',
#  'area',
#  'mode',
#  'wife',
#  'law',
#  'news',
#  'p',
#  'case',
#  'the name',
#  'contact',
#  'country',
#  'addition',
#  'level',
#  'detail',
#  'condition',
#  'team',
#  'application',
#  'response',
#  'window',
#  'drives',
#  'value',
#  'reason',
#  'the internet',
#  'application',
#  'technology',
#  'w',
#  'atheist',
#  'some people',
#  'peace',
#  'way',
#  'graphic',
#  'hour',
#  'type',
#  'job',
#  'organization',
#  'package',
#  'image',
#  'friend',
#  'defense',
#  'discussion',
#  'post',
#  'image',
#  'answer',
#  'this group',
#  'note',
#  'body',
#  'section',
#  'place',
#  'food',
#  'population',
#  'c',
#  'the law',
#  'minute',
#  'a year',
#  'business',
#  'bus',
#  'drug',
#  'book',
#  'site',
#  'interest',
#  '-',
#  'freenet',
#  'arm',
#  'mile',
#  'week',
#  'k',
#  'the number',
#  'r',
#  'bit',
#  'server',
#  'card',
#  'advice',
#  'the truth',
#  'format',
#  'dod',
#  'views',
#  'u',
#  'hardware',
#  'friend',
#  'performance',
#  'purpose',
#  'bike',
#  'originator',
#  'color',
#  'error',
#  'the word',
#  'source',
#  'view',
#  'war',
#  'belief',
#  'the difference',
#  'folk',
#  'nature',
#  'e',
#  'atheism',
#  'idea',
#  'value',
#  'company',
#  'cost',
#  'society',
#  'action',
#  'gun',
#  'a person',
#  'the book',
#  'soldier',
#  'monitor',
#  'family',
#  'morality',
#  'driver',
#  'the program',
#  'country',
#  'screen',
#  'model',
#  'a way',
#  'result',
#  'face',
#  'o',
#  'output',
#  'a copy',
#  'the team',
#  'hand',
#  'trouble',
#  'privacy',
#  'crime',
#  'any help',
#  'com',
#  'action',
#  'port',
#  'v',
#  'existence',
#  'entry',
#  'research',
#  'situation',
#  'display',
#  'b',
#  'the issue',
#  'name',
#  'effect',
#  'life',
#  'water',
#  'the user',
#  'argument',
#  'difference',
#  'goal',
#  'area',
#  'the day',
#  'language',
#  'the one',
#  'version',
#  'claim',
#  'device',
#  'the window',
#  'a car',
#  'shipping',
#  'deal',
#  'theory',
#  'guest',
#  'beliefs',
#  'the reason',
#  'request',
#  're',
#  'issue',
#  'the body',
#  'a couple',
#  'states',
#  'site',
#  'user',
#  'post',
#  'criminal',
#  'force',
#  'love',
#  'story',
#  'volume',
#  'run',
#  'the situation',
#  'heart',
#  'sex',
#  'standard',
#  'genocide',
#  'a friend',
#  'the list',
#  'controller',
#  'choice',
#  'the price',
#  'article',
#  'chip',
#  'land',
#  'community',
#  'page',
#  'light',
#  'office',
#  'safety',
#  'son',
#  'the state',
#  'care',
#  'understanding',
#  'study',
#  'solution',
#  'term',
#  'cd',
#  'directory',
#  'activity',
#  'the screen',
#  'the subject',
#  'event',
#  'copy',
#  'security',
#  'series',
#  'eye',
#  'reference',
#  'orbit',
#  'insurance',
#  'a man',
#  'the power',
#  'the answer',
#  'luck',
#  'the person',
#  'approach',
#  'keyboard',
#  'this time',
#  'copy',
#  'm',
#  'the line',
#  'the use',
#  'responsibility',
#  'rule',
#  'company',
#  'record',
#  'account',
#  'device',
#  'color',
#  'education',
#  'offer',
#  'fan',
#  'guy',
#  'this point',
#  't',
#  'player',
#  'error',
#  'service',
#  'reality',
#  'the road',
#  'the drive',
#  'gas',
#  'this case',
#  'police',
#  'sin',
#  'a program',
#  'lot',
#  'top',
#  'fan',
#  'school',
#  'video',
#  'this one',
#  'the file',
#  'individual',
#  'board',
#  'product',
#  'kid',
#  'keywords',
#  'goal',
#  'foot',
#  'context',
#  'disk',
#  'murder',
#  'employer',
#  'hell',
#  'posting',
#  'function',
#  'fire',
#  'class',
#  'sera@zuma',
#  'instance',
#  'freedom',
#  'troop',
#  'the key',
#  'the opinion',
#  'a number',
#  'the universe',
#  'human',
#  'no way',
#  'the datum',
#  'answer',
#  'this problem',
#  'font',
#  'attention',
#  'church',
#  'a gun',
#  'definition',
#  'study',
#  'baseball',
#  'the back',
#  'mother',
#  'term',
#  'standards',
#  'modem',
#  'authority',
#  'ability',
#  'blood',
#  'the ground',
#  'hockey',
#  'the article',
#  'logic',
#  's',
#  'example',
#  'model',
#  'meaning',
#  'the bike',
#  'front',
#  'patient',
#  'chance',
#  'a time',
#  'reference',
#  'product',
#  'feature',
#  'ground',
#  'firearm',
#  'yesterday',
#  'a question',
#  'the source',
#  'the server',
#  'interface',
#  'that way',
#  'rate',
#  'percent',
#  'warning',
#  'the author',
#  'function',
#  'escrow',
#  'analysis',
#  'any information',
#  'voice',
#  'the existence',
#  'the message',
#  'property',
#  'option',
#  'form',
#  'will',
#  'behavior',
#  'message',
#  'resource',
#  'return',
#  'the chip',
#  'the one',
#  'force',
#  'the country',
#  'mhz',
#  'equipment',
#  'summary',
#  'call',
#  'authority',
#  'the season',
#  'method',
#  'house',
#  'cause',
#  'quality',
#  'organization',
#  'method',
#  'cable',
#  'title',
#  'policy',
#  'comment',
#  'page',
#  'future',
#  'step',
#  'month',
#  'h',
#  'the child',
#  'input',
#  'suggestion',
#  'conclusion',
#  'respect',
#  'tv',
#  'soul',
#  'the fire',
#  'taxis',
#  'author',
#  'this country',
#  'shot',
#  'practice',
#  'material',
#  'religion',
#  'bytes',
#  'statement',
#  'any way',
#  'treatment',
#  'father',
#  'pm',
#  'base',
#  'wire',
#  'interpretation',
#  'the past',
#  'process',
#  'effort',
#  'mouse',
#  'claim',
#  'character',
#  'half',
#  'parent',
#  'this newsgroup',
#  'child',
#  'second',
#  'attack',
#  'the police',
#  'ftp',
#  'matter',
#  'p.',
#  'tool',
#  'good',
#  'fact',
#  'guy',
#  'an example',
#  'attack',
#  'the process',
#  'the future',
#  'pain',
#  'animal',
#  'uucp',
#  'change',
#  'the card',
#  'myers',
#  'trial',
#  'age',
#  'this way',
#  'a.',
#  'development',
#  'an article',
#  'environment',
#  'project',
#  'the money',
#  'the city',
#  'earth',
#  'city',
#  'box',
#  'a result',
#  'administration',
#  'the algorithm',
#  'medium',
#  'entry',
#  'range',
#  'basis',
#  'object',
#  'advantage',
#  'job',
#  'every time',
#  'the puck',
#  'any info',
#  'option',
#  'newsgroup',
#  'government',
#  'air',
#  'the guy',
#  'test',
#  'advance',
#  'the year',
#  'computer',
#  'a chance',
#  'the key',
#  'room',
#  'some sort',
#  'magazine',
#  'event',
#  'documentation',
#  'algorithm',
#  'a message',
#  'think',
#  'char',
#  'civilians',
#  'militia',
#  'tape',
#  'attempt',
#  'charge',
#  'protection',
#  'disease',
#  'cover',
#  'no',
#  'the moon',
#  'village',
#  'dollar',
#  'domain',
#  'd',
#  'industry',
#  'paper',
#  'weight',
#  'court',
#  'art',
#  'the word',
#  'a system',
#  'rom',
#  'race',
#  'the work',
#  'poster',
#  'daughter',
#  'the machine',
#  'report',
#  'design',
#  'purpose',
#  'works',
#  'a list',
#  'brother',
#  'these people',
#  'the earth',
#  'report',
#  'the area',
#  'engine',
#  'letter',
#  'the result',
#  'a day',
#  'trade',
#  'the security',
#  'e-',
#  'the top',
#  'coverage',
#  'operation',
#  'proof',
#  'role',
#  'mph',
#  'tradition',
#  'unit',
#  'widget',
#  'description',
#  'plan',
#  'simms',
#  'owner',
#  'rule',
#  'reader',
#  'this program',
#  'command',
#  'a team',
#  'training',
#  'head',
#  'communication',
#  'status',
#  'the league',
#  'change',
#  'a thing',
#  'the cost',
#  'thought',
#  'the result',
#  'direction',
#  'note',
#  'century',
#  'price',
#  'network',
#  'effect',
#  'some time',
#  'type',
#  'the number',
#  'fault',
#  'library',
#  'style',
#  'the beginning',
#  'market',
#  'the man',
#  'mean',
#  'the purpose',
#  'cryptography',
#  'the driver',
#  'these thing',
#  'agent',
#  'no idea',
#  'power play',
#  'the evidence',
#  'pub',
#  'experience',
#  'the thing',
#  'every day',
#  'building',
#  'guess',
#  'z',
#  'condition',
#  'a window',
#  'homosexual',
#  'situation',
#  'resolution',
#  'the engine',
#  'a group',
#  'ignorance',
#  'stat',
#  'the hell',
#  'woman',
#  'ram',
#  'town',
#  '\\',
#  'traffic',
#  'permission',
#  'person',
#  'the mouse',
#  'a file',
#  'printer',
#  'division',
#  'paper',
#  'lot',
#  'the ability',
#  'party',
#  'the door',
#  'x11r5',
#  'effort',
#  'the medium',
#  'medicine',
#  'skepticism',
#  'apartment',
#  'field',
#  'monitor',
#  'eye',
#  'act',
#  'this message',
#  'bike',
#  'concern',
#  'widget',
#  'kind',
#  'service',
#  'look',
#  'decision',
#  'a woman',
#  'client',
#  'win',
#  'pressure',
#  'hole',
#  'the road',
#  'leader',
#  'official',
#  'marriage',
#  'announcement',
#  'item',
#  'the size',
#  'the information',
#  'the market',
#  'crypto',
#  'manual',
#  'that time',
#  'agency',
#  'the compound',
#  'a bunch',
#  'punishment',
#  'the need',
#  'sound',
#  'difference',
#  'hope',
#  'member',
#  'pin',
#  'cost',
#  'attitude',
#  'release',
#  'the rule',
#  'bitnet',
#  'party',
#  'position',
#  'path',
#  'the majority',
#  'turn',
#  'homosexuality',
#  'doctor',
#  'need',
#  'i',
#  'the history',
#  'export',
#  'owner',
#  'implementation',
#  'majority',
#  'document',
#  'fund',
#  'the church',
#  'door',
#  'the computer',
#  'this article',
#  'explanation',
#  'reasoning',
#  'the argument',
#  'activity',
#  'expert',
#  'policy',
#  'the land',
#  'student',
#  'shape',
#  'being',
#  'setup',
#  'newsgroup',
#  'port',
#  'proposal',
#  'discussion',
#  'wrong',
#  'justice',
#  'degree',
#  'the batf',
#  'comparison',
#  'doubt',
#  'translation',
#  'the intellect',
#  'resistance',
#  'a book',
#  'any suggestion',
#  'the head',
#  'interest',
#  'the company',
#  'act',
#  'armenian',
#  'disclaimer',
#  'body',
#  'the story',
#  'success',
#  'city',
#  'press',
#  'play',
#  'wisdom',
#  'ad',
#  'chapter',
#  'the basis',
#  'the middle',
#  'weapon',
#  'any case',
#  'no problem',
#  'operation',
#  'war',
#  'army',
#  'the part',
#  'a pc',
#  'a game',
#  'need',
#  'picture',
#  'mistake',
#  'this thread',
#  'brain',
#  'this posting',
#  'center',
#  'oname',
#  '# p',
#  'edition',
#  'brand',
#  'nation',
#  'thousand',
#  'a member',
#  'scale',
#  'manager',
#  'the chastity',
#  'picture',
#  'risk',
#  'tool',
#  'be',
#  'the population',
#  'the sky',
#  'motherboard',
#  'radio',
#  'the image',
#  'statistic',
#  'character',
#  'speech',
#  'the group',
#  'the playoff',
#  'salvation',
#  'request',
#  'the term',
#  'gun control',
#  'energy',
#  'concept',
#  'letter',
#  'doctor',
#  'run',
#  'handgun',
#  'sin',
#  'meeting',
#  'law enforcement',
#  'package',
#  'the code',
#  'a line',
#  'background',
#  'health',
#  'no .',
#  'the package',
#  'the moment',
#  'fun',
#  'the thing',
#  'the sun',
#  'crime',
#  'public',
#  'km',
#  'any idea',
#  'this issue',
#  'board',
#  'citizen',
#  'music',
#  'an atheist',
#  'a look',
#  'rate',
#  'detail',
#  'official',
#  'net',
#  'mountain',
#  'tonight',
#  'stage',
#  'aid',
#  'the press',
#  'disease',
#  'mouth',
#  'mission',
#  'the possibility',
#  'tin',
#  'noise',
#  'the order',
#  'consideration',
#  'mine',
#  'neighbor',
#  'scientist',
#  'chance',
#  'no reason',
#  'dealer',
#  'foot',
#  'project',
#  'box',
#  'king',
#  'politic',
#  ...]

# %%
for k in range(0,20):
    print("Topic %d"%k)
    candid_for_topic_k = zero_order(freq,theta,lemmatized_labels,k)
    candid_for_topic_k = candid_for_topic_k.sort_values('Score',ascending=False)
    print(candid_for_topic_k.head(3))
    print("=======================")
# Out:
# Topic 0
# C:\Users\Zarmeen\Anaconda2\envs\py36\lib\site-packages\ipykernel_launcher.py:18: RuntimeWarning: divide by zero encountered in log
#        Labels     Score
# 2726   schism  3.240709
# 2335  passage  2.900605
# 1642  passage  2.900605
# =======================
# Topic 1
#                       Labels     Score
# 941              gun control  3.863974
# 2810  law enforcement agency  3.405538
# 657                  militia  2.744172
# =======================
# Topic 2
#           Labels     Score
# 750   power play  3.407615
# 1493  defenseman  2.726862
# 73          team  2.678519
# =======================
# Topic 3
#           Labels     Score
# 1190  video card  6.421991
# 1398         cpu  5.497844
# 1491          os  5.497844
# =======================
# Topic 4
#            Labels     Score
# 2358   disk drive  6.261851
# 2617   tape drive  5.982684
# 1365  disk drives  5.657680
# =======================
# Topic 5
#              Labels     Score
# 2225  amateur radio  2.952223
# 114            sale  2.765084
# 1714           sale  2.765084
# =======================
# Topic 6
#          Labels     Score
# 1151  satellite  3.411588
# 1037  satellite  3.411588
# 2128     launch  3.226621
# =======================
# Topic 7
#                       Labels     Score
# 2810  law enforcement agency  6.223605
# 1510         chip encryption  5.873976
# 2913        the wiretap chip  5.422757
# =======================
# Topic 8
#              Labels     Score
# 109          access  3.847368
# 1835  communication  3.193028
# 720   communication  3.193028
# =======================
# Topic 9
#       Labels     Score
# 2562  goalie  3.694069
# 1246  hitter  3.445532
# 2549    mask  3.230216
# =======================
# Topic 10
#            Labels    Score
# 778       printer  4.59367
# 1534  the printer  4.59367
# 1739      printer  4.59367
# =======================
# Topic 11
#                Labels     Score
# 1960        conductor  2.563408
# 1798  allocation unit  2.435943
# 1150           wiring  2.092929
# =======================
# Topic 12
#               Labels     Score
# 124   stephanopoulos  3.427433
# 1226       anonymity  2.612884
# 1978     health care  2.523325
# =======================
# Topic 13
#          Labels     Score
# 1512     pixels  3.361407
# 932   the image  3.261388
# 225       image  3.261388
# =======================
# Topic 14
#          Labels     Score
# 2072  swap file  5.755863
# 914       oname  5.517439
# 2719  info file  5.091295
# =======================
# Topic 15
#          Labels     Score
# 2924  objective  4.085042
# 296    morality  4.032469
# 1703      moral  3.814940
# =======================
# Topic 16
#           Labels     Score
# 761   homosexual  3.991610
# 1425     consent  3.924406
# 2100     slavery  3.783664
# =======================
# Topic 17
#                          Labels     Score
# 2533              turkish plane  4.674509
# 1007              way of escape  3.561826
# 1069  the work of extermination  3.286685
# =======================
# Topic 18
#                   Labels     Score
# 2147  the window manager  5.608054
# 1520      window manager  5.608054
# 798               widget  3.458380
# =======================
# Topic 19
#        Labels     Score
# 283   atheism  2.960327
# 1270  atheist  2.816743
# 215   atheist  2.816743
# =======================

# %%
dataset.to_csv('dataset_20_newsgroup_kmeans.csv',sep='\t',index=False)

# %% [markdown]
# ## Proposed Topic labeling

# %%
def filter_noun_adj_from_phrase(text):
    noun_phrases = []
    doc = nlp(text)
    #for np in doc.noun_chunks:
     #   noun_phrases.append(np.text.lower().strip())
    lists = pos_regex_matches(doc, pattern)
    for j in lists:
        noun_phrases.append(j.text.lower().strip())
    return noun_phrases
def list_phrases_cluster(cluster_idx,df,key):
    df_sub = df[df[key] == cluster_idx]
    hashs = []
    for index,row in df_sub.iterrows():
        row.Noun_Phrases = literal_eval(row.Noun_Phrases)
        for x in row.Noun_Phrases:
            hashs.append(x.lower())
    
    return collections.Counter(hashs)
def return_clusters_title(cluster_idx,dataset,col):
    hash_cluster1 = list_phrases_cluster(cluster_idx,dataset,col) 
    top10  = hash_cluster1.most_common(3)
    dataset_sub = dataset[dataset[col] == cluster_idx]
    cnt_vectorizer = TfidfVectorizer(ngram_range=(3,15))
    vec = cnt_vectorizer.fit_transform(dataset_sub['Text'])
    scores = (vec.toarray()) 
    # Getting top ranking features 
    sums = vec.sum(axis = 0) 
    data1 = [] 
    features = cnt_vectorizer.get_feature_names()
    for col, term in enumerate(features): 
        data1.append((term, sums[0, col] )) 
    ranking = pd.DataFrame(data1, columns = ['term', 'rank'])
    ranking['wCount'] = ranking['term'].apply(lambda x: len(x.split()))
    ranking = ranking.sort_values(['rank','wCount'],ascending=[False,True])
    print(ranking.head(5))
    my_top_4=[]
    for u,v in top10:
        my_top_4.append(u)
    my_top_4 = " ".join(my_top_4)
    my_top_4 = my_top_4.replace("_"," ")

    #print(my_top_4)
    test_list = (my_top_4.split())
    df = pd.DataFrame(columns=ranking.columns) #empty dataframe to add filtered rows
    for index,row in ranking.iterrows():
        # using list comprehension 
        # checking if string contains list element 
        res = all(ele in row['term'] for ele in test_list) 

        # print result 
        if res == True:
            df.loc[len(df)]=[row['term'],row['rank'],row['wCount']] 
    df = df.sort_values(['rank','wCount'],ascending=[False,True])
    #df = df.sort_values(['wCount'])
    if len(df)>0:
        return df.iloc[0]['term']
    else:
        return "No title constructed"

# %%
#Assign Topic to the dataset
dataset = pd.DataFrame({'Text':newsgroups_train.data})

# %%
dataset['preprocessed'] = processed_docs

# %%
dataset['Topic'] = newsgroups_train.target

# %%
dataset['Topic_label'] = dataset['Topic'].apply(news_group_target_names)

# %%
topic_list = []
prob_list = []
topic_distribution = lda_model.get_document_topics(lda_model[corpus])
for i,j in enumerate(topic_distribution):
    row = sorted(j, key=lambda x: (x[1]), reverse=True)
    topic_num,prop_topic = row[0]
    topic_list.append(topic_num)
    prob_list.append(prop_topic)

dataset['LDA_topic_list'] = topic_list
dataset['prob_list'] = prob_list

# %%
dataset
# Out:
#                                                     Text  \
# 0      From: lerxst@wam.umd.edu (where's my thing)\nS...
# 1      From: guykuo@carson.u.washington.edu (Guy Kuo)...
# 2      From: twillis@ec.ecn.purdue.edu (Thomas E Will...
# 3      From: jgreen@amber (Joe Green)\nSubject: Re: W...
# 4      From: jcm@head-cfa.harvard.edu (Jonathan McDow...
# 5      From: dfo@vttoulu.tko.vtt.fi (Foxvog Douglas)\...
# 6      From: bmdelane@quads.uchicago.edu (brian manni...
# 7      From: bgrubb@dante.nmsu.edu (GRUBB)\nSubject: ...
# 8      From: holmes7000@iscsvax.uni.edu\nSubject: WIn...
# 9      From: kerr@ux1.cso.uiuc.edu (Stan Kerr)\nSubje...
# 10     From: irwin@cmptrc.lonestar.org (Irwin Arnstei...
# 11     From: david@terminus.ericsson.se (David Bold)\...
# 12     From: rodc@fc.hp.com (Rod Cerkoney)\nSubject: ...
# 13     From: dbm0000@tm0006.lerc.nasa.gov (David B. M...
# 14     From: jllee@acsu.buffalo.edu (Johnny L Lee)\nS...
# 15     From: mathew <mathew@mantis.co.uk>\nSubject: R...
# 16     From: ab@nova.cc.purdue.edu (Allen B)\nSubject...
# 17     From: CPKJP@vm.cc.latech.edu (Kevin Parker)\nS...
# 18     From: ritley@uimrl7.mrl.uiuc.edu ()\nSubject: ...
# 19     From: abarden@tybse1.uucp (Ann Marie Barden)\n...
# 20     From: keith@cco.caltech.edu (Keith Allan Schne...
# 21     From: leunggm@odin.control.utoronto.ca (Gary L...
# 22     From: rpwhite@cs.nps.navy.mil (rpwhite)\nSubje...
# 23     From: csyphers@uafhp..uark.edu (Chris Syphers)...
# 24     From: nodine@lcs.mit.edu (Mark H. Nodine)\nSub...
# 25     From: kph2q@onyx.cs.Virginia.EDU (Kenneth Hinc...
# 26     From: nagle@netcom.com (John Nagle)\nSubject: ...
# 27     From: r4938585@joplin.biosci.arizona.edu (Doug...
# 28     From: jonh@david.wheaton.edu (Jonathan Hayward...
# 29     From: jimf@centerline.com (Jim Frost)\nSubject...
# ...                                                  ...
# 11284  Distribution: world\nFrom: elenay_creations@tc...
# 11285  From: re4@prism.gatech.EDU (RUSSELL EARNEST)\n...
# 11286  From: looper@cco.caltech.edu (Mark D. Looper)\...
# 11287  From: gballent@hudson.UVic.CA (Greg  Ballentin...
# 11288  From: cka52397@uxa.cso.uiuc.edu (OrioleFan@uiu...
# 11289  From: max@slinky.NYU.EDU (David Max)\nSubject:...
# 11290  From: hades@coos.dartmouth.edu (Brian V. Hughe...
# 11291  From: c23reg@kocrsv01.delcoelect.com (Ron Gask...
# 11292  From: callison@uokmax.ecn.uoknor.edu (James P....
# 11293  From: bigelos@hobo.ECE.ORST.EDU (Space Gigolo)...
# 11294  From: LMARSHA@cms.cc.wayne.edu (Laurie Marshal...
# 11295  From: gt5735a@prism.gatech.EDU (Mark Devaney)\...
# 11296  From: pkeenan@s.psych.uiuc.edu (Patricia Keena...
# 11297  From: CCMB <CCMB@MUSICA.MCGILL.CA>\nSubject: W...
# 11298  From: cbetz@radioman.cray.com (Charles Betz  {...
# 11299  From: 2120788@hydra.maths.unsw.EDU.AU ()\nSubj...
# 11300  From: aa888@freenet.carleton.ca (Mark Baker)\n...
# 11301  From: zmed16@trc.amoco.com (Michael)\nSubject:...
# 11302  From: rdippold@qualcomm.com (Ron "Asbestos" Di...
# 11303  From: bchuang@css.itd.umich.edu (Ben Chuang)\n...
# 11304  From: Pegasus@aaa.uoregon.edu (Pegasus)\nSubje...
# 11305  From: shaig@composer.think.com (Shai Guday)\nS...
# 11306  From: mrj@cs.su.oz.au (Mark James)\nSubject: R...
# 11307  From: chein@eng.auburn.edu (Tsan Heui)\nSubjec...
# 11308  From: adrian@ora.COM (Adrian Nye)\nSubject: im...
# 11309  From: jim.zisfein@factory.com (Jim Zisfein) \n...
# 11310  From: ebodin@pearl.tufts.edu\nSubject: Screen ...
# 11311  From: westes@netcom.com (Will Estes)\nSubject:...
# 11312  From: steve@hcrlgw (Steven Collins)\nSubject: ...
# 11313  From: gunning@cco.caltech.edu (Kevin J. Gunnin...
#
#                                             preprocessed  Topic  \
# 0      [lerxst, thing, subject, nntp, post, host, org...      7
# 1      [guykuo, carson, washington, subject, clock, p...      4
# 2      [twillis, purdue, thomas, willis, subject, que...      4
# 3      [jgreen, amber, green, subject, weitek, organi...      1
# 4      [head, harvard, jonathan, mcdowell, subject, s...     14
# 5      [vttoulu, foxvog, douglas, subject, reword, se...     16
# 6      [bmdelane, quad, uchicago, brian, manning, del...     13
# 7      [bgrubb, dante, nmsu, grubb, subject, scsi, or...      3
# 8      [holmes, iscsvax, subject, icon, help, organiz...      2
# 9      [kerr, uiuc, stan, kerr, subject, sigma, desig...      4
# 10     [irwin, cmptrc, lonestar, irwin, arnstein, sub...      8
# 11     [david, terminus, ericsson, david, bold, subje...     19
# 12     [rodc, cerkoney, subject, fekvh, nntp, post, h...      4
# 13     [lerc, nasa, david, mckissock, subject, space,...     14
# 14     [jllee, acsu, buffalo, johnny, subject, move, ...      6
# 15     [mathew, mathew, mantis, subject, political, a...      0
# 16     [nova, purdue, allen, subject, tiff, philosoph...      1
# 17     [cpkjp, latech, kevin, parker, subject, insura...      7
# 18     [ritley, uimrl, uiuc, subject, seek, thermocou...     12
# 19     [abarden, tybse, uucp, marie, barden, subject,...      5
# 20     [keith, caltech, keith, allan, schneider, subj...      0
# 21     [leunggm, odin, control, utoronto, gary, leung...     10
# 22     [rpwhite, navy, rpwhite, subject, catalog, har...      6
# 23     [csyphers, uafhp, uark, chris, syphers, subjec...      2
# 24     [nodine, mark, nodine, subject, quadra, scsi, ...      4
# 25     [onyx, virginia, kenneth, hinckley, subject, v...      1
# 26     [nagle, netcom, john, nagle, subject, nuclear,...     12
# 27     [joplin, biosci, arizona, doug, roberts, subje...      9
# 28     [jonh, david, wheaton, jonathan, hayward, subj...     15
# 29     [jimf, centerline, frost, subject, saftey, imp...      7
# ...                                                  ...    ...
# 11284  [distribution, world, vegas, anthony, saxton, ...      4
# 11285  [prism, gatech, russell, earnest, subject, pla...      9
# 11286  [looper, caltech, mark, looper, subject, comma...     14
# 11287  [gballent, hudson, uvic, greg, ballentine, sub...     10
# 11288  [uiuc, oriolefan, uiuc, subject, opel, owners,...      7
# 11289  [slinky, david, subject, mode, speedstar, summ...      1
# 11290  [hades, coos, dartmouth, brian, hughes, subjec...      4
# 11291  [kocrsv, delcoelect, gaskin, subject, dumb, au...      7
# 11292  [callison, uokmax, uoknor, james, callison, su...      7
# 11293  [bigelos, hobo, orst, space, gigolo, subject, ...      6
# 11294  [lmarsha, wayne, laurie, marshall, subject, bu...     10
# 11295  [prism, gatech, mark, devaney, subject, sorry,...      3
# 11296  [pkeenan, psych, uiuc, patricia, keenan, subje...      9
# 11297  [ccmb, ccmb, musica, mcgill, subject, line, nn...      3
# 11298  [cbetz, radioman, cray, charles, betz, subject...     10
# 11299  [hydra, maths, unsw, subject, turkey, cyprus, ...     17
# 11300  [freenet, carleton, mark, baker, subject, arro...     15
# 11301  [zmed, amoco, michael, subject, sale, drum, ma...      6
# 11302  [rdippold, qualcomm, asbestos, dippold, subjec...     11
# 11303  [bchuang, umich, chuang, subject, route, local...      4
# 11304  [pegasus, uoregon, pegasus, subject, merlin, m...     19
# 11305  [shaig, composer, think, shai, guday, subject,...     17
# 11306  [mark, james, subject, scsi, busmastere, slow,...      3
# 11307  [chein, auburn, tsan, heui, subject, case, dea...      6
# 11308  [adrian, adrian, subject, imake, book, review,...      5
# 11309  [zisfein, factory, zisfein, subject, migraine,...     13
# 11310  [ebodin, pearl, tufts, subject, screen, death,...      4
# 11311  [weste, netcom, este, subject, mount, cooler, ...      3
# 11312  [steve, hcrlgw, steven, collins, subject, sphe...      1
# 11313  [gun, caltech, kevin, gun, subject, steal, org...      8
#
#                     Topic_label  LDA_topic_list  prob_list
# 0                     rec.autos              13   0.298798
# 1         comp.sys.mac.hardware              13   0.303605
# 2         comp.sys.mac.hardware              13   0.286641
# 3                 comp.graphics              13   0.297614
# 4                     sci.space              13   0.297167
# 5            talk.politics.guns              15   0.297881
# 6                       sci.med              13   0.307357
# 7      comp.sys.ibm.pc.hardware              13   0.272423
# 8       comp.os.ms-windows.misc              13   0.298071
# 9         comp.sys.mac.hardware              13   0.286782
# 10              rec.motorcycles              15   0.288902
# 11           talk.religion.misc              15   0.288848
# 12        comp.sys.mac.hardware              13   0.301295
# 13                    sci.space              13   0.297771
# 14                 misc.forsale              13   0.283842
# 15                  alt.atheism              15   0.286262
# 16                comp.graphics              13   0.300641
# 17                    rec.autos              13   0.282162
# 18              sci.electronics              13   0.294132
# 19               comp.windows.x              13   0.291584
# 20                  alt.atheism              15   0.288847
# 21             rec.sport.hockey              15   0.288857
# 22                 misc.forsale              13   0.297048
# 23      comp.os.ms-windows.misc              13   0.311446
# 24        comp.sys.mac.hardware              13   0.281273
# 25                comp.graphics              13   0.299362
# 26              sci.electronics              13   0.300876
# 27           rec.sport.baseball              13   0.308381
# 28       soc.religion.christian              15   0.292459
# 29                    rec.autos              13   0.282942
# ...                         ...             ...        ...
# 11284     comp.sys.mac.hardware              13   0.287019
# 11285        rec.sport.baseball              13   0.280571
# 11286                 sci.space              13   0.287272
# 11287          rec.sport.hockey              15   0.294870
# 11288                 rec.autos              15   0.296334
# 11289             comp.graphics              13   0.306028
# 11290     comp.sys.mac.hardware              13   0.289242
# 11291                 rec.autos              13   0.288880
# 11292                 rec.autos              15   0.296326
# 11293              misc.forsale              13   0.299684
# 11294          rec.sport.hockey              13   0.296312
# 11295  comp.sys.ibm.pc.hardware              13   0.284930
# 11296        rec.sport.baseball              15   0.289027
# 11297  comp.sys.ibm.pc.hardware              13   0.297753
# 11298          rec.sport.hockey              13   0.286192
# 11299     talk.politics.mideast              15   0.288934
# 11300    soc.religion.christian              15   0.299757
# 11301              misc.forsale              13   0.305301
# 11302                 sci.crypt              13   0.292760
# 11303     comp.sys.mac.hardware              13   0.294773
# 11304        talk.religion.misc              13   0.296317
# 11305     talk.politics.mideast              15   0.285184
# 11306  comp.sys.ibm.pc.hardware              13   0.281453
# 11307              misc.forsale              15   0.291884
# 11308            comp.windows.x              13   0.305090
# 11309                   sci.med              13   0.285912
# 11310     comp.sys.mac.hardware              13   0.290751
# 11311  comp.sys.ibm.pc.hardware              13   0.293612
# 11312             comp.graphics              13   0.294825
# 11313           rec.motorcycles              13   0.295581
#
# [11314 rows x 6 columns]

# %%
dataset.to_csv('dataset_lda_20_newsgroup.csv',sep='\t',index=False)

# %%
dataset = pd.read_csv('dataset_lda_20_newsgroup_withNounPhrases.csv',sep='\t')

# %%
dataset
# Out:
#                                                     Text  \
# 0      From: lerxst@wam.umd.edu (where's my thing)\r\...
# 1      From: guykuo@carson.u.washington.edu (Guy Kuo)...
# 2      From: twillis@ec.ecn.purdue.edu (Thomas E Will...
# 3      From: jgreen@amber (Joe Green)\r\r\nSubject: R...
# 4      From: jcm@head-cfa.harvard.edu (Jonathan McDow...
# 5      From: dfo@vttoulu.tko.vtt.fi (Foxvog Douglas)\...
# 6      From: bmdelane@quads.uchicago.edu (brian manni...
# 7      From: bgrubb@dante.nmsu.edu (GRUBB)\r\r\nSubje...
# 8      From: holmes7000@iscsvax.uni.edu\r\r\nSubject:...
# 9      From: kerr@ux1.cso.uiuc.edu (Stan Kerr)\r\r\nS...
# 10     From: irwin@cmptrc.lonestar.org (Irwin Arnstei...
# 11     From: david@terminus.ericsson.se (David Bold)\...
# 12     From: rodc@fc.hp.com (Rod Cerkoney)\r\r\nSubje...
# 13     From: dbm0000@tm0006.lerc.nasa.gov (David B. M...
# 14     From: jllee@acsu.buffalo.edu (Johnny L Lee)\r\...
# 15     From: mathew <mathew@mantis.co.uk>\r\r\nSubjec...
# 16     From: ab@nova.cc.purdue.edu (Allen B)\r\r\nSub...
# 17     From: CPKJP@vm.cc.latech.edu (Kevin Parker)\r\...
# 18     From: ritley@uimrl7.mrl.uiuc.edu ()\r\r\nSubje...
# 19     From: abarden@tybse1.uucp (Ann Marie Barden)\r...
# 20     From: keith@cco.caltech.edu (Keith Allan Schne...
# 21     From: leunggm@odin.control.utoronto.ca (Gary L...
# 22     From: rpwhite@cs.nps.navy.mil (rpwhite)\r\r\nS...
# 23     From: csyphers@uafhp..uark.edu (Chris Syphers)...
# 24     From: nodine@lcs.mit.edu (Mark H. Nodine)\r\r\...
# 25     From: kph2q@onyx.cs.Virginia.EDU (Kenneth Hinc...
# 26     From: nagle@netcom.com (John Nagle)\r\r\nSubje...
# 27     From: r4938585@joplin.biosci.arizona.edu (Doug...
# 28     From: jonh@david.wheaton.edu (Jonathan Hayward...
# 29     From: jimf@centerline.com (Jim Frost)\r\r\nSub...
# ...                                                  ...
# 11284  Distribution: world\r\r\nFrom: elenay_creation...
# 11285  From: re4@prism.gatech.EDU (RUSSELL EARNEST)\r...
# 11286  From: looper@cco.caltech.edu (Mark D. Looper)\...
# 11287  From: gballent@hudson.UVic.CA (Greg  Ballentin...
# 11288  From: cka52397@uxa.cso.uiuc.edu (OrioleFan@uiu...
# 11289  From: max@slinky.NYU.EDU (David Max)\r\r\nSubj...
# 11290  From: hades@coos.dartmouth.edu (Brian V. Hughe...
# 11291  From: c23reg@kocrsv01.delcoelect.com (Ron Gask...
# 11292  From: callison@uokmax.ecn.uoknor.edu (James P....
# 11293  From: bigelos@hobo.ECE.ORST.EDU (Space Gigolo)...
# 11294  From: LMARSHA@cms.cc.wayne.edu (Laurie Marshal...
# 11295  From: gt5735a@prism.gatech.EDU (Mark Devaney)\...
# 11296  From: pkeenan@s.psych.uiuc.edu (Patricia Keena...
# 11297  From: CCMB <CCMB@MUSICA.MCGILL.CA>\r\r\nSubjec...
# 11298  From: cbetz@radioman.cray.com (Charles Betz  {...
# 11299  From: 2120788@hydra.maths.unsw.EDU.AU ()\r\r\n...
# 11300  From: aa888@freenet.carleton.ca (Mark Baker)\r...
# 11301  From: zmed16@trc.amoco.com (Michael)\r\r\nSubj...
# 11302  From: rdippold@qualcomm.com (Ron "Asbestos" Di...
# 11303  From: bchuang@css.itd.umich.edu (Ben Chuang)\r...
# 11304  From: Pegasus@aaa.uoregon.edu (Pegasus)\r\r\nS...
# 11305  From: shaig@composer.think.com (Shai Guday)\r\...
# 11306  From: mrj@cs.su.oz.au (Mark James)\r\r\nSubjec...
# 11307  From: chein@eng.auburn.edu (Tsan Heui)\r\r\nSu...
# 11308  From: adrian@ora.COM (Adrian Nye)\r\r\nSubject...
# 11309  From: jim.zisfein@factory.com (Jim Zisfein) \r...
# 11310  From: ebodin@pearl.tufts.edu\r\r\nSubject: Scr...
# 11311  From: westes@netcom.com (Will Estes)\r\r\nSubj...
# 11312  From: steve@hcrlgw (Steven Collins)\r\r\nSubje...
# 11313  From: gunning@cco.caltech.edu (Kevin J. Gunnin...
#
#                                             preprocessed  Topic  \
# 0      ['lerxst', 'thing', 'subject', 'nntp', 'post',...      7
# 1      ['guykuo', 'carson', 'washington', 'subject', ...      4
# 2      ['twillis', 'purdue', 'thomas', 'willis', 'sub...      4
# 3      ['jgreen', 'amber', 'green', 'subject', 'weite...      1
# 4      ['head', 'harvard', 'jonathan', 'mcdowell', 's...     14
# 5      ['vttoulu', 'foxvog', 'douglas', 'subject', 'r...     16
# 6      ['bmdelane', 'quad', 'uchicago', 'brian', 'man...     13
# 7      ['bgrubb', 'dante', 'nmsu', 'grubb', 'subject'...      3
# 8      ['holmes', 'iscsvax', 'subject', 'icon', 'help...      2
# 9      ['kerr', 'uiuc', 'stan', 'kerr', 'subject', 's...      4
# 10     ['irwin', 'cmptrc', 'lonestar', 'irwin', 'arns...      8
# 11     ['david', 'terminus', 'ericsson', 'david', 'bo...     19
# 12     ['rodc', 'cerkoney', 'subject', 'fekvh', 'nntp...      4
# 13     ['lerc', 'nasa', 'david', 'mckissock', 'subjec...     14
# 14     ['jllee', 'acsu', 'buffalo', 'johnny', 'subjec...      6
# 15     ['mathew', 'mathew', 'mantis', 'subject', 'pol...      0
# 16     ['nova', 'purdue', 'allen', 'subject', 'tiff',...      1
# 17     ['cpkjp', 'latech', 'kevin', 'parker', 'subjec...      7
# 18     ['ritley', 'uimrl', 'uiuc', 'subject', 'seek',...     12
# 19     ['abarden', 'tybse', 'uucp', 'marie', 'barden'...      5
# 20     ['keith', 'caltech', 'keith', 'allan', 'schnei...      0
# 21     ['leunggm', 'odin', 'control', 'utoronto', 'ga...     10
# 22     ['rpwhite', 'navy', 'rpwhite', 'subject', 'cat...      6
# 23     ['csyphers', 'uafhp', 'uark', 'chris', 'sypher...      2
# 24     ['nodine', 'mark', 'nodine', 'subject', 'quadr...      4
# 25     ['onyx', 'virginia', 'kenneth', 'hinckley', 's...      1
# 26     ['nagle', 'netcom', 'john', 'nagle', 'subject'...     12
# 27     ['joplin', 'biosci', 'arizona', 'doug', 'rober...      9
# 28     ['jonh', 'david', 'wheaton', 'jonathan', 'hayw...     15
# 29     ['jimf', 'centerline', 'frost', 'subject', 'sa...      7
# ...                                                  ...    ...
# 11284  ['distribution', 'world', 'vegas', 'anthony', ...      4
# 11285  ['prism', 'gatech', 'russell', 'earnest', 'sub...      9
# 11286  ['looper', 'caltech', 'mark', 'looper', 'subje...     14
# 11287  ['gballent', 'hudson', 'uvic', 'greg', 'ballen...     10
# 11288  ['uiuc', 'oriolefan', 'uiuc', 'subject', 'opel...      7
# 11289  ['slinky', 'david', 'subject', 'mode', 'speeds...      1
# 11290  ['hades', 'coos', 'dartmouth', 'brian', 'hughe...      4
# 11291  ['kocrsv', 'delcoelect', 'gaskin', 'subject', ...      7
# 11292  ['callison', 'uokmax', 'uoknor', 'james', 'cal...      7
# 11293  ['bigelos', 'hobo', 'orst', 'space', 'gigolo',...      6
# 11294  ['lmarsha', 'wayne', 'laurie', 'marshall', 'su...     10
# 11295  ['prism', 'gatech', 'mark', 'devaney', 'subjec...      3
# 11296  ['pkeenan', 'psych', 'uiuc', 'patricia', 'keen...      9
# 11297  ['ccmb', 'ccmb', 'musica', 'mcgill', 'subject'...      3
# 11298  ['cbetz', 'radioman', 'cray', 'charles', 'betz...     10
# 11299  ['hydra', 'maths', 'unsw', 'subject', 'turkey'...     17
# 11300  ['freenet', 'carleton', 'mark', 'baker', 'subj...     15
# 11301  ['zmed', 'amoco', 'michael', 'subject', 'sale'...      6
# 11302  ['rdippold', 'qualcomm', 'asbestos', 'dippold'...     11
# 11303  ['bchuang', 'umich', 'chuang', 'subject', 'rou...      4
# 11304  ['pegasus', 'uoregon', 'pegasus', 'subject', '...     19
# 11305  ['shaig', 'composer', 'think', 'shai', 'guday'...     17
# 11306  ['mark', 'james', 'subject', 'scsi', 'busmaste...      3
# 11307  ['chein', 'auburn', 'tsan', 'heui', 'subject',...      6
# 11308  ['adrian', 'adrian', 'subject', 'imake', 'book...      5
# 11309  ['zisfein', 'factory', 'zisfein', 'subject', '...     13
# 11310  ['ebodin', 'pearl', 'tufts', 'subject', 'scree...      4
# 11311  ['weste', 'netcom', 'este', 'subject', 'mount'...      3
# 11312  ['steve', 'hcrlgw', 'steven', 'collins', 'subj...      1
# 11313  ['gun', 'caltech', 'kevin', 'gun', 'subject', ...      8
#
#                     Topic_label  LDA_topic_list  prob_list  \
# 0                     rec.autos              13   0.298798
# 1         comp.sys.mac.hardware              13   0.303605
# 2         comp.sys.mac.hardware              13   0.286641
# 3                 comp.graphics              13   0.297614
# 4                     sci.space              13   0.297167
# 5            talk.politics.guns              15   0.297881
# 6                       sci.med              13   0.307357
# 7      comp.sys.ibm.pc.hardware              13   0.272423
# 8       comp.os.ms-windows.misc              13   0.298071
# 9         comp.sys.mac.hardware              13   0.286782
# 10              rec.motorcycles              15   0.288902
# 11           talk.religion.misc              15   0.288848
# 12        comp.sys.mac.hardware              13   0.301295
# 13                    sci.space              13   0.297771
# 14                 misc.forsale              13   0.283842
# 15                  alt.atheism              15   0.286262
# 16                comp.graphics              13   0.300641
# 17                    rec.autos              13   0.282162
# 18              sci.electronics              13   0.294132
# 19               comp.windows.x              13   0.291584
# 20                  alt.atheism              15   0.288847
# 21             rec.sport.hockey              15   0.288857
# 22                 misc.forsale              13   0.297048
# 23      comp.os.ms-windows.misc              13   0.311446
# 24        comp.sys.mac.hardware              13   0.281273
# 25                comp.graphics              13   0.299362
# 26              sci.electronics              13   0.300876
# 27           rec.sport.baseball              13   0.308381
# 28       soc.religion.christian              15   0.292459
# 29                    rec.autos              13   0.282942
# ...                         ...             ...        ...
# 11284     comp.sys.mac.hardware              13   0.287019
# 11285        rec.sport.baseball              13   0.280571
# 11286                 sci.space              13   0.287272
# 11287          rec.sport.hockey              15   0.294870
# 11288                 rec.autos              15   0.296334
# 11289             comp.graphics              13   0.306028
# 11290     comp.sys.mac.hardware              13   0.289242
# 11291                 rec.autos              13   0.288880
# 11292                 rec.autos              15   0.296326
# 11293              misc.forsale              13   0.299684
# 11294          rec.sport.hockey              13   0.296312
# 11295  comp.sys.ibm.pc.hardware              13   0.284930
# 11296        rec.sport.baseball              15   0.289027
# 11297  comp.sys.ibm.pc.hardware              13   0.297753
# 11298          rec.sport.hockey              13   0.286192
# 11299     talk.politics.mideast              15   0.288934
# 11300    soc.religion.christian              15   0.299757
# 11301              misc.forsale              13   0.305301
# 11302                 sci.crypt              13   0.292760
# 11303     comp.sys.mac.hardware              13   0.294773
# 11304        talk.religion.misc              13   0.296317
# 11305     talk.politics.mideast              15   0.285184
# 11306  comp.sys.ibm.pc.hardware              13   0.281453
# 11307              misc.forsale              15   0.291884
# 11308            comp.windows.x              13   0.305090
# 11309                   sci.med              13   0.285912
# 11310     comp.sys.mac.hardware              13   0.290751
# 11311  comp.sys.ibm.pc.hardware              13   0.293612
# 11312             comp.graphics              13   0.294825
# 11313           rec.motorcycles              13   0.295581
#
#                                             Noun_Phrases
# 0      ['lerxst@wam.umd.edu', 'thing', 'car', 'host',...
# 1      ['subject', 'call', 'summary', 'call', 'clock ...
# 2      ['subject', 'questions', 'distribution', 'folk...
# 3      ['subject', 'p9000', 'lines', 'distribution', ...
# 4      ['article', 'article', 'c5jlwx.4h9.1@cs.cmu.ed...
# 5      ['ideas', 'lines', 'article', 'article', 'arti...
# 6      ['brain', 'thanks', 'people', 'request for inf...
# 7      ['subject', 'distribution', 'world', 'posting'...
# 8      ['win', 'icon help please', 'lines', 'win', 'i...
# 9      ['designs', 'any information', 'board', 'board...
# 10     ['subject', 'recommendation', 'distribution', ...
# 11     ['subject', 'question', 'morality', 'distribut...
# 12     ['g4qxf', 'host', '-newsreader', 'version', 'l...
# 13     ['lines', 'distribution', 'world', 'posting', ...
# 14     ['sale', 'sale', 'lines', 'host', 'a list of t...
# 15     ['-newsreader', 'rusnews', 'method', 'death', ...
# 16     ['subject', 'significance', 'lines', 'article'...
# 17     ['insurance rates on performance cars summary'...
# 18     ['subject', 'thermocouple', 'ritley@uiucmrl.bi...
# 19     ['file question', 'distribution', 'question', ...
# 20     ['subject', 'ass', 'lines', 'posting', 'host',...
# 21     ['article', 'course', 'time', 'the captain', '...
# 22     ['rpwhite@cs.nps.navy.mil', 'rpwhite', 'subjec...
# 23     ['csyphers@uafhp', 'subject', 'dos font size i...
# 24     ['subject', 'problems', 'lines', 'problem', 'm...
# 25     ['vendor information', 'voice input capability...
# 26     ['subject', 'line', 'guest', 'lines', 'excerpt...
# 27     ['subject', 'lines', 'posting', 'host', 'game ...
# 28     ['article', 'this group', 'emphasis', 'environ...
# 29     ['subject', 'car', 'posting', 'host', 'safety'...
# ...                                                  ...
# 11284  ['distribution', 'world', 'subject', 'lines', ...
# 11285  ['subject', 'players', 'article', 'article', '...
# 11286  ['subject', 'lines', 'posting', 'host', 'prb@a...
# 11287  ['subject', 'wings', 'host', 'article', 'artic...
# 11288  ['subject', 'opel owners', 'article', 'c5sxi4....
# 11289  ['24bit mode', 'routines', 'bit color', '24bit...
# 11290  ['subject', 'option', 'to', 'distribution', 'a...
# 11291  ['subject', 'concepts', 'dimmer switch locatio...
# 11292  ['subject', 'warning', 'read', 'host', 'articl...
# 11293  ['bigelos@hobo', 'subject', 'distribution', 'l...
# 11294  ['lines', 'posting', 'host', 'article', 'com',...
# 11295  ['subject', 'distribution', 'thread', 'spleen'...
# 11296  ['subject', 'question', 'lines', 'question', '...
# 11297  ['ccmb@musica.mcgill.ca', 'subject', 'system',...
# 11298  ['nhl team', 'lines', 'host', 'the reports', '...
# 11299  ['subject', 'host', 'school', 'lines', 'articl...
# 11300  ['the arrogance', 'lines', 'article', 'phs431d...
# 11301  ['sale', 'drum machine for sale', 'velocity', ...
# 11302  ['asbestos', 'subject', 'code', 'originator', ...
# 11303  ['lines', 'posting', 'host', 'the story', 'a n...
# 11304  ['subject', 'distribution', 'world', 'posting'...
# 11305  ['subject', 'posting', 'host', 'reply', 'bh437...
# 11306  ['system', 'article', 'a busmaster controller'...
# 11307  ['subject', 'case', 'a deal', 'a lemon', 'host...
# 11308  ['book review', 'posting', 'host', 'thanks', '...
# 11309  ['subject', 'migraines', 'scans', 'distributio...
# 11310  ['subject', 'screen death', 'lines', 'problem'...
# 11311  ['subject', 'cpu', 'case', '-newsreader', 'ver...
# 11312  ['subject', 'points', 'host', 'article', 'poin...
# 11313  ['lines', 'distribution', 'posting', 'host', '...
#
# [11314 rows x 7 columns]

# %%
#dataset['Noun_Phrases'] = dataset['Text'].apply(filter_noun_adj_from_phrase)

# %%
type(dataset['Noun_Phrases'])
# Out:
# pandas.core.series.Series

# %%
dataset['LDA_topic_list'].value_counts()
# Out:
# 13    7876
# 15    3438
# Name: LDA_topic_list, dtype: int64

# %%
dataset.iloc[1]['Noun_Phrases']
# Out:
# "['subject', 'call', 'summary', 'call', 'clock reports', 'si', 'acceleration', 'clock', 'posting', 'host', 'number', 'souls', 'clock oscillator', 'experiences', 'this poll', 'message', 'experiences', 'the procedure', 'speed', 'speed', 'cards', 'adapters', 'heat sinks', 'hour of usage per day', 'disk', 'functionality', 'm floppies', 'days', 'the network', 'knowledge base', 'the clock', 'poll', 'thanks']"

# %%
top_elements_topics = []
for i in range(0,20):
    hash_cluster1 = list_phrases_cluster(i,dataset,'Topic')
    top_elements_topics.append(hash_cluster1.most_common(10))

# %%
top_elements_topics
# Out:
# [[('people', 451),
#   ('article', 382),
#   ('subject', 361),
#   ('lines', 350),
#   ('host', 234),
#   ('posting', 198),
#   ('atheism', 193),
#   ('atheists', 176),
#   ('things', 138),
#   ('system', 127)],
#  [('lines', 446),
#   ('subject', 354),
#   ('host', 276),
#   ('article', 183),
#   ('version', 160),
#   ('files', 151),
#   ('posting', 150),
#   ('graphics', 140),
#   ('images', 135),
#   ('image', 124)],
#  [('g)r', 437),
#   ('lines', 376),
#   ('subject', 357),
#   ('%', 270),
#   ('host', 242),
#   ('article', 225),
#   ('w', 208),
#   ('windows', 168),
#   ('#', 155),
#   ('files', 150)],
#  [('lines', 383),
#   ('subject', 325),
#   ('drive', 274),
#   ('host', 263),
#   ('article', 190),
#   ('system', 150),
#   ('drives', 147),
#   ('bus', 146),
#   ('card', 133),
#   ('posting', 123)],
#  [('lines', 373),
#   ('subject', 295),
#   ('host', 295),
#   ('article', 191),
#   ('posting', 146),
#   ('distribution', 128),
#   ('drive', 116),
#   ('problem', 79),
#   ('mb', 79),
#   ('thanks', 73)],
#  [('x', 3047),
#   ('lines', 480),
#   ('subject', 335),
#   ('host', 331),
#   ('posting', 186),
#   ('program', 185),
#   ('information', 170),
#   ('article', 166),
#   ('version', 165),
#   ('file', 160)],
#  [('lines', 356),
#   ('host', 264),
#   ('sale', 244),
#   ('subject', 242),
#   ('distribution', 185),
#   ('shipping', 124),
#   ('condition', 123),
#   ('offer', 119),
#   ('posting', 115),
#   ('price', 101)],
#  [('article', 404),
#   ('subject', 336),
#   ('lines', 331),
#   ('car', 329),
#   ('host', 270),
#   ('cars', 227),
#   ('the car', 197),
#   ('distribution', 151),
#   ('posting', 140),
#   ('people', 124)],
#  [('article', 454),
#   ('subject', 367),
#   ('lines', 342),
#   ('host', 303),
#   ('bike', 207),
#   ('dod', 197),
#   ('the bike', 134),
#   ('distribution', 128),
#   ('posting', 100),
#   ('bikes', 92)],
#  [('article', 377),
#   ('subject', 360),
#   ('lines', 352),
#   ('host', 274),
#   ('year', 249),
#   ('games', 185),
#   ('players', 146),
#   ('runs', 137),
#   ('team', 127),
#   ('years', 115)],
#  [('%', 527),
#   ('subject', 364),
#   ('lines', 335),
#   ('article', 298),
#   ('team', 281),
#   ('host', 267),
#   ('period', 229),
#   ('game', 223),
#   ('games', 200),
#   ('players', 198)],
#  [('subject', 383),
#   ('lines', 348),
#   ('article', 323),
#   ('key', 311),
#   ('people', 296),
#   ('encryption', 287),
#   ('host', 258),
#   ('keys', 241),
#   ('the government', 231),
#   ('information', 210)],
#  [('lines', 429),
#   ('subject', 378),
#   ('host', 269),
#   ('article', 231),
#   ('posting', 124),
#   ('distribution', 116),
#   ('wire', 88),
#   ('ground', 70),
#   ('use', 67),
#   ('power', 66)],
#  [('lines', 405),
#   ('article', 402),
#   ('subject', 385),
#   ('people', 215),
#   ('host', 200),
#   ('years', 153),
#   ('patients', 127),
#   ('%', 118),
#   ('food', 115),
#   ('science', 114)],
#  [('lines', 408),
#   ('article', 348),
#   ('subject', 320),
#   ('host', 282),
#   ('posting', 181),
#   ('orbit', 157),
#   ('space', 156),
#   ('years', 140),
#   ('people', 128),
#   ('world', 115)],
#  [('people', 469),
#   ('lines', 383),
#   ('subject', 364),
#   ('article', 288),
#   ('faith', 239),
#   ('life', 189),
#   ('things', 181),
#   ('time', 159),
#   ('truth', 135),
#   ('reason', 126)],
#  [('article', 440),
#   ('people', 415),
#   ('subject', 391),
#   ('lines', 338),
#   ('host', 279),
#   ('guns', 270),
#   ('weapons', 205),
#   ('file', 188),
#   ('distribution', 171),
#   ('gun', 157)],
#  [('people', 733),
#   ('article', 492),
#   ('subject', 452),
#   ('lines', 356),
#   ('years', 234),
#   ('government', 216),
#   ('host', 207),
#   ('today', 180),
#   ('soldiers', 176),
#   ('children', 172)],
#  [('article', 510),
#   ('people', 471),
#   ('subject', 326),
#   ('lines', 292),
#   ('government', 222),
#   ('host', 197),
#   ('%', 177),
#   ('stephanopoulos', 143),
#   ('time', 139),
#   ('money', 124)],
#  [('people', 313),
#   ('article', 303),
#   ('subject', 243),
#   ('lines', 235),
#   ('host', 128),
#   ('life', 121),
#   ('morality', 85),
#   ('years', 84),
#   ('#', 78),
#   ('posting', 77)]]

# %%
dataset.to_csv('dataset_lda_20_newsgroup_withNounPhrases.csv',sep='\t',index=False)

# %%
# initializing list of lists 
test_list = top_elements_topics
single_list = []
for x in test_list:
    for u,v in x:
        single_list.append(u)
freq = collections.Counter(single_list)

# %%
freq
# Out:
# Counter({'people': 10,
#          'article': 19,
#          'subject': 20,
#          'lines': 20,
#          'host': 19,
#          'posting': 11,
#          'atheism': 1,
#          'atheists': 1,
#          'things': 2,
#          'system': 2,
#          'version': 2,
#          'files': 2,
#          'graphics': 1,
#          'images': 1,
#          'image': 1,
#          'g)r': 1,
#          '%': 4,
#          'w': 1,
#          'windows': 1,
#          '#': 2,
#          'drive': 2,
#          'drives': 1,
#          'bus': 1,
#          'card': 1,
#          'distribution': 6,
#          'problem': 1,
#          'mb': 1,
#          'thanks': 1,
#          'x': 1,
#          'program': 1,
#          'information': 2,
#          'file': 2,
#          'sale': 1,
#          'shipping': 1,
#          'condition': 1,
#          'offer': 1,
#          'price': 1,
#          'car': 1,
#          'cars': 1,
#          'the car': 1,
#          'bike': 1,
#          'dod': 1,
#          'the bike': 1,
#          'bikes': 1,
#          'year': 1,
#          'games': 2,
#          'players': 2,
#          'runs': 1,
#          'team': 2,
#          'years': 5,
#          'period': 1,
#          'game': 1,
#          'key': 1,
#          'encryption': 1,
#          'keys': 1,
#          'the government': 1,
#          'wire': 1,
#          'ground': 1,
#          'use': 1,
#          'power': 1,
#          'patients': 1,
#          'food': 1,
#          'science': 1,
#          'orbit': 1,
#          'space': 1,
#          'world': 1,
#          'faith': 1,
#          'life': 2,
#          'time': 2,
#          'truth': 1,
#          'reason': 1,
#          'guns': 1,
#          'weapons': 1,
#          'gun': 1,
#          'government': 2,
#          'today': 1,
#          'soldiers': 1,
#          'children': 1,
#          'stephanopoulos': 1,
#          'money': 1,
#          'morality': 1})

# %%
common_element=[]
for u,v in freq.items():
    if v>1:
        common_element.append(u)
common_element
# Out:
# ['people',
#  'article',
#  'subject',
#  'lines',
#  'host',
#  'posting',
#  'things',
#  'system',
#  'version',
#  'files',
#  '%',
#  '#',
#  'drive',
#  'distribution',
#  'information',
#  'file',
#  'games',
#  'players',
#  'team',
#  'years',
#  'life',
#  'time',
#  'government']

# %%
new_top_elements_topics = []
for top10_in_topic in top_elements_topics:
    new_list_topic = []
    for u,v in top10_in_topic:
        if u not in common_element:
            new_list_topic.append((u,v))
    new_top_elements_topics.append(new_list_topic)

# %%
new_top_elements_topics[12]
# Out:
# [('wire', 88), ('ground', 70), ('use', 67), ('power', 66)]

# %%
top_elements_topics[12]
# Out:
# [('lines', 429),
#  ('subject', 378),
#  ('host', 269),
#  ('article', 231),
#  ('posting', 124),
#  ('distribution', 116),
#  ('wire', 88),
#  ('ground', 70),
#  ('use', 67),
#  ('power', 66)]

# %%
topic_id = 12
dataset_sub = dataset[dataset['Topic'] == topic_id]
cnt_vectorizer = TfidfVectorizer(ngram_range=(10,15))
vec = cnt_vectorizer.fit_transform(dataset_sub['Text'])
scores = (vec.toarray()) 
# Getting top ranking features 
sums = vec.sum(axis = 0) 
data1 = [] 
features = cnt_vectorizer.get_feature_names()
for col, term in enumerate(features): 
    data1.append((term, sums[0, col] )) 
ranking = pd.DataFrame(data1, columns = ['term', 'rank'])
ranking['wCount'] = ranking['term'].apply(lambda x: len(x.split()))
ranking = ranking.sort_values(['rank','wCount'],ascending=[False,True])
print(ranking.head(5))
my_top_4=[]
for u,v in new_top_elements_topics[topic_id]:
    my_top_4.append(u)


print(my_top_4)
test_list = my_top_4
df = pd.DataFrame(columns=ranking.columns) #empty dataframe to add filtered rows
for index,row in ranking.iterrows():
    # using list comprehension 
    # checking if string contains list element 
    res = all(ele in row['term'] for ele in test_list) 

    # print result 
    if res == True:
        df.loc[len(df)]=[row['term'],row['rank'],row['wCount']] 
df = df.sort_values(['rank','wCount'],ascending=[False,True])
# Out:
#                                                      term      rank  wCount
# 448593   subject re need to find out number to phone line  0.397750      10
# 400265  re need to find out number to phone line organ...  0.278176      10
# 448606  subject re need to find out number to phone li...  0.278176      11
# 41144       and don want to call up the operator to place  0.275399      10
# 96744   call up the operator to place trace on it ques...  0.275399      10
# ['wire', 'ground', 'use', 'power']

# %%
df
# Out:
# Empty DataFrame
# Columns: [term, rank, wCount]
# Index: []
